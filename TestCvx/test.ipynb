# %%
#!/usr/bin/env python3

import argparse
import sys

import numpy as np
import numpy.random as npr

import itertools
import time

import torch

from qpth.qp import QPFunction
from cvxpylayers.torch.cvxpylayer import CvxpyLayer

from scipy.linalg import sqrtm
from scipy import sparse
import cvxpy as cp
import pandas as pd

from IPython.core import ultratb
sys.excepthook = ultratb.FormattedTB(
    mode='Verbose',
    color_scheme='Linux', call_pdb=1)

# %%
def main():
    parser = argparse.ArgumentParser()
    parser.add_argument('--nTrials', type=int, default=10)
    args = parser.parse_args()
    npr.seed(0)
    prof(args)


def prof(args):
    trials = []
    for nz, nbatch, cuda in itertools.product(
            [6], [50], [True, False]):
        print('--- {} vars/cons, batch size: {}, cuda: {} ---'.format(
            nz, nbatch, cuda))
        for i in range(args.nTrials):
            print('  + Trial {}'.format(i))
            t = prof_dense_qp(i, nz, nbatch, 'dense', cuda)
            trials += t
            print(t)

    for nz, nbatch, cuda in itertools.product(
            [6], [50], [False]):
        print('--- {} vars/cons, batch size: {}, cuda: {} ---'.format(
            nz, nbatch, cuda))
        for i in range(args.nTrials):
            print('  + Trial {}'.format(i))
            t = prof_sparse_qp(i, nz, nbatch, None, cuda)
            trials += t
            print(t)

    df = pd.DataFrame(trials)
    df.to_csv('results.csv', index=False)


def prof_sparse_qp(trial, nz, nbatch, cons, cuda=True):
    trials = []

    npr.seed(trial)

    A = sparse.random(nz, nz, density=.01) + \
        sparse.eye(nz)
    A_rows, A_cols = A.nonzero()

    G = sparse.random(nz, nz, density=.01) + \
        sparse.eye(nz)
    G_rows, G_cols = G.nonzero()
    Q = sparse.eye(nz)

    xs = npr.randn(nbatch, nz)
    p = npr.randn(nbatch, nz)
    b = np.array([A @ xs[i] for i in range(nbatch)])
    h = np.array([G @ xs[i] for i in range(nbatch)])

    def convert(A):
        A = [A.todense() for _ in range(nbatch)]
        return torch.from_numpy(np.array(A)).double().requires_grad_()

    Q_tch, A_tch, G_tch = [convert(mat) for mat in [Q, A, G]]

    p_tch, b_tch, h_tch = [
        torch.from_numpy(x).double().requires_grad_()
        for x in [p, b, h]
    ]

    if cuda:
        p_tch, Q_tch, G_tch, h_tch, A_tch, b_tch = [
            x.cuda() for x in [p_tch, Q_tch, G_tch, h_tch, A_tch, b_tch]]

    torch.cuda.synchronize()
    torch.cuda.synchronize()
    start = time.time()
    x = QPFunction(verbose=False, eps=1e-8, notImprovedLim=5,
                   maxIter=1000)(Q_tch, p_tch, G_tch, h_tch, A_tch, b_tch)
    torch.cuda.synchronize()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'qpth',
        'direction': 'forward',
        'time': t,
        'qp': 'sparse'
    })

    y = x.sum()
    start = time.time()
    y.backward()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'qpth',
        'direction': 'backward',
        'time': t,
        'qp': 'sparse'
    })

    _p = cp.Parameter((nz, 1))
    _b = cp.Parameter((nz, 1))
    _h = cp.Parameter((nz, 1))

    _z = cp.Variable((nz, 1))

    obj = cp.Minimize(0.5 * cp.sum_squares(_z) + _p.T @ _z)
    cons = [G @ _z <= _h,
            A @ _z == _b]
    prob = cp.Problem(obj, cons)

    p_tch, b_tch, h_tch = [torch.from_numpy(x).unsqueeze(-1).requires_grad_()
                           for x in [p, b, h]]

    solver_args = {
        'mode': 'lsqr',
        'verbose': False,
        'max_iters': 1000,
        'eps': 1e-6,
        'use_indirect': False,
        'gpu': False,
        'n_jobs_forward': -1,
        'n_jobs_backward': -1
    }
    solve = CvxpyLayer(prob, [_p, _b, _h], [_z])

    start = time.time()
    z, = solve(p_tch, b_tch, h_tch, solver_args=solver_args)
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'cvxpylayers',
        'direction': 'forward',
        'time': t,
        'qp': 'sparse',
        'canon_time': solve.info.get("canon_time")
    })

    y = z.sum()
    start = time.time()
    y.backward()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'cvxpylayers',
        'direction': 'backward',
        'time': t,
        'qp': 'sparse',
        'dcanon_time': solve.info.get("dcanon_time")
    })
    return trials


def prof_dense_qp(trial, nz, nbatch, cons, cuda=True):
    trials = []

    npr.seed(trial)

    L = npr.rand(nbatch, nz, nz)
    Q = np.matmul(L, L.transpose((0, 2, 1))) + 1e-3 * np.eye(nz, nz)
    p = npr.randn(nbatch, nz)

    if cons == 'dense':
        nineq = nz
        G = npr.randn(nbatch, nineq, nz)
        z0 = npr.randn(nbatch, nz)
        s0 = npr.rand(nbatch, nineq)
        h = np.matmul(G, np.expand_dims(z0, axis=(2))).squeeze(2) + s0
    elif cons == 'box':
        nineq = 2 * nz
        G = np.concatenate((-np.eye(nz), np.eye(nz)))
        G = np.stack([G] * nbatch)
        h = np.ones((nbatch, 2 * nz))
    else:
        raise NotImplementedError

    p_tch, Q_tch, G_tch, h_tch = [
        torch.from_numpy(x).double().requires_grad_()
        for x in [p, Q, G, h]
    ]
    if cuda:
        p_tch, Q_tch, G_tch, h_tch = [x.cuda()
                                      for x in [p_tch, Q_tch, G_tch, h_tch]]

    e = torch.Tensor()

    torch.cuda.synchronize()
    torch.cuda.synchronize()
    start = time.time()
    x = QPFunction(verbose=False, eps=1e-8, notImprovedLim=5,
                   maxIter=1000)(Q_tch, p_tch, G_tch, h_tch, e, e)
    torch.cuda.synchronize()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'qpth',
        'direction': 'forward',
        'time': t,
        'qp': 'dense'
    })

    y = x.sum()
    start = time.time()
    y.backward()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': 'qpth',
        'direction': 'backward',
        'time': t,
        'qp': 'dense'
    })

    _Q_sqrt = cp.Parameter((nz, nz))
    _p = cp.Parameter((nz, 1))
    _G = cp.Parameter((nineq, nz))
    _h = cp.Parameter((nineq, 1))
    _z = cp.Variable((nz, 1))
    obj = cp.Minimize(0.5 * cp.sum_squares(_Q_sqrt @ _z) + _p.T @ _z)
    cons = [_G @ _z <= _h]
    prob = cp.Problem(obj, cons)

    Q_sqrt = np.array([sqrtm(q) for q in Q])
    Q_sqrt_tch, p_tch, G_tch, h_tch = [
        torch.from_numpy(x).double().requires_grad_()
        for x in [Q_sqrt, p, G, h]]

    solver_args = {
        'mode': 'dense',
        'verbose': False,
        'max_iters': 1000,
        'eps': 1e-6,
        'use_indirect': False,
        'gpu': False,
        'n_jobs_forward': 12,
        'n_jobs_backward': 12
    }
    solve = CvxpyLayer(prob, [_Q_sqrt, _p, _G, _h], [_z])

    start = time.time()
    z, = solve(
        Q_sqrt_tch, p_tch.unsqueeze(-1), G_tch, h_tch.unsqueeze(-1),
        solver_args=solver_args
    )
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': f'cvxpylayers',
        'direction': 'forward',
        'time': t,
        'qp': 'dense',
        'canon_time': solve.info.get("canon_time")
    })

    y = z.sum()
    start = time.time()
    y.backward()
    t = time.time() - start
    trials.append({
        'trial': trial,
        'nz': nz,
        'nbatch': nbatch,
        'cuda': cuda,
        'mode': f'cvxpylayers',
        'direction': 'backward',
        'time': t,
        'qp': 'dense',
        'dcanon_time': solve.info.get("dcanon_time")
    })

    return trials

# %%
class MyClass:
    def __init__(self, nTrials=10):
        self.nTrials = nTrials

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument('--nTrials', type=int, default=10)
# args = parser.parse_args()
args = MyClass()
npr.seed(0)
prof(args)
# Out:
# --- 6 vars/cons, batch size: 50, cuda: True ---
#   + Trial 0
# [{'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.10005784034729004, 'qp': 'dense'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.001798391342163086, 'qp': 'dense'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14198565483093262, 'qp': 'dense', 'canon_time': 0.06463098526000977}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07146763801574707, 'qp': 'dense', 'dcanon_time': 0.04568600654602051}]
#   + Trial 1
# [{'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.10954856872558594, 'qp': 'dense'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0017805099487304688, 'qp': 'dense'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14057254791259766, 'qp': 'dense', 'canon_time': 0.06475591659545898}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.06965494155883789, 'qp': 'dense', 'dcanon_time': 0.045899152755737305}]
#   + Trial 2
# [{'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.11097097396850586, 'qp': 'dense'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0017130374908447266, 'qp': 'dense'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1386735439300537, 'qp': 'dense', 'canon_time': 0.06486940383911133}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.0729360580444336, 'qp': 'dense', 'dcanon_time': 0.047457218170166016}]
#   + Trial 3
# [{'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.10189080238342285, 'qp': 'dense'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0017654895782470703, 'qp': 'dense'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1419816017150879, 'qp': 'dense', 'canon_time': 0.0646519660949707}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07264423370361328, 'qp': 'dense', 'dcanon_time': 0.045929670333862305}]
#   + Trial 4
# [{'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.10497546195983887, 'qp': 'dense'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.00189208984375, 'qp': 'dense'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13836121559143066, 'qp': 'dense', 'canon_time': 0.06413817405700684}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07024121284484863, 'qp': 'dense', 'dcanon_time': 0.04677462577819824}]
#   + Trial 5
# [{'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.08847951889038086, 'qp': 'dense'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0018534660339355469, 'qp': 'dense'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1396634578704834, 'qp': 'dense', 'canon_time': 0.06435394287109375}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07141757011413574, 'qp': 'dense', 'dcanon_time': 0.04622697830200195}]
#   + Trial 6
# [{'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.08814668655395508, 'qp': 'dense'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0017023086547851562, 'qp': 'dense'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1435868740081787, 'qp': 'dense', 'canon_time': 0.06432175636291504}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07018351554870605, 'qp': 'dense', 'dcanon_time': 0.0445404052734375}]
#   + Trial 7
# [{'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.10161781311035156, 'qp': 'dense'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0017609596252441406, 'qp': 'dense'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14435744285583496, 'qp': 'dense', 'canon_time': 0.06544685363769531}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07064175605773926, 'qp': 'dense', 'dcanon_time': 0.045712947845458984}]
#   + Trial 8
# [{'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.09335517883300781, 'qp': 'dense'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.001861572265625, 'qp': 'dense'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14131379127502441, 'qp': 'dense', 'canon_time': 0.06467247009277344}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07188010215759277, 'qp': 'dense', 'dcanon_time': 0.046499013900756836}]
#   + Trial 9
# [{'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'forward', 'time': 0.09267115592956543, 'qp': 'dense'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0018017292022705078, 'qp': 'dense'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14248991012573242, 'qp': 'dense', 'canon_time': 0.0644998550415039}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': True, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07264375686645508, 'qp': 'dense', 'dcanon_time': 0.045331478118896484}]
# --- 6 vars/cons, batch size: 50, cuda: False ---
#   + Trial 0
# [{'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.06482982635498047, 'qp': 'dense'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005140066146850586, 'qp': 'dense'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14342117309570312, 'qp': 'dense', 'canon_time': 0.06516003608703613}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07049393653869629, 'qp': 'dense', 'dcanon_time': 0.044805049896240234}]
#   + Trial 1
# [{'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.07923555374145508, 'qp': 'dense'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005106449127197266, 'qp': 'dense'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1425614356994629, 'qp': 'dense', 'canon_time': 0.06466794013977051}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07057499885559082, 'qp': 'dense', 'dcanon_time': 0.04482626914978027}]
#   + Trial 2
# [{'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.09162116050720215, 'qp': 'dense'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005035877227783203, 'qp': 'dense'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1390547752380371, 'qp': 'dense', 'canon_time': 0.06413149833679199}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07047510147094727, 'qp': 'dense', 'dcanon_time': 0.04576444625854492}]
#   + Trial 3
# [{'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.06942009925842285, 'qp': 'dense'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005174398422241211, 'qp': 'dense'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14082837104797363, 'qp': 'dense', 'canon_time': 0.06427788734436035}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07043290138244629, 'qp': 'dense', 'dcanon_time': 0.04606127738952637}]
#   + Trial 4
# [{'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.08525514602661133, 'qp': 'dense'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0051004886627197266, 'qp': 'dense'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1426088809967041, 'qp': 'dense', 'canon_time': 0.06486678123474121}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07043123245239258, 'qp': 'dense', 'dcanon_time': 0.04516291618347168}]
#   + Trial 5
# [{'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.054946184158325195, 'qp': 'dense'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005164384841918945, 'qp': 'dense'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14205265045166016, 'qp': 'dense', 'canon_time': 0.06498146057128906}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07091808319091797, 'qp': 'dense', 'dcanon_time': 0.04626941680908203}]
#   + Trial 6
# [{'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.06167936325073242, 'qp': 'dense'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005140781402587891, 'qp': 'dense'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14077186584472656, 'qp': 'dense', 'canon_time': 0.06406545639038086}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07123684883117676, 'qp': 'dense', 'dcanon_time': 0.046881914138793945}]
#   + Trial 7
# [{'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.06927990913391113, 'qp': 'dense'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005125761032104492, 'qp': 'dense'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1404247283935547, 'qp': 'dense', 'canon_time': 0.06412601470947266}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07064390182495117, 'qp': 'dense', 'dcanon_time': 0.045656681060791016}]
#   + Trial 8
# [{'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.06579351425170898, 'qp': 'dense'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0050852298736572266, 'qp': 'dense'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14102578163146973, 'qp': 'dense', 'canon_time': 0.0651698112487793}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07229423522949219, 'qp': 'dense', 'dcanon_time': 0.04635214805603027}]
#   + Trial 9
# [{'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.05977463722229004, 'qp': 'dense'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.003985166549682617, 'qp': 'dense'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.14206290245056152, 'qp': 'dense', 'canon_time': 0.06506800651550293}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.06968569755554199, 'qp': 'dense', 'dcanon_time': 0.045287370681762695}]
# --- 6 vars/cons, batch size: 50, cuda: False ---
#   + Trial 0
# [{'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.015230417251586914, 'qp': 'sparse'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.004212141036987305, 'qp': 'sparse'}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13332796096801758, 'qp': 'sparse', 'canon_time': 0.0530548095703125}, {'trial': 0, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07011270523071289, 'qp': 'sparse', 'dcanon_time': 0.0455784797668457}]
#   + Trial 1
# [{'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.01222681999206543, 'qp': 'sparse'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.00422978401184082, 'qp': 'sparse'}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13425779342651367, 'qp': 'sparse', 'canon_time': 0.05363869667053223}, {'trial': 1, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.0693962574005127, 'qp': 'sparse', 'dcanon_time': 0.04509758949279785}]
#   + Trial 2
# [{'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.012498855590820312, 'qp': 'sparse'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.004235029220581055, 'qp': 'sparse'}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13403010368347168, 'qp': 'sparse', 'canon_time': 0.05341005325317383}, {'trial': 2, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07237505912780762, 'qp': 'sparse', 'dcanon_time': 0.04518318176269531}]
#   + Trial 3
# [{'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.015306711196899414, 'qp': 'sparse'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005887508392333984, 'qp': 'sparse'}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13544583320617676, 'qp': 'sparse', 'canon_time': 0.053438663482666016}, {'trial': 3, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.06933927536010742, 'qp': 'sparse', 'dcanon_time': 0.04420351982116699}]
#   + Trial 4
# [{'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.012184619903564453, 'qp': 'sparse'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005254030227661133, 'qp': 'sparse'}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1356968879699707, 'qp': 'sparse', 'canon_time': 0.05352044105529785}, {'trial': 4, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.0689084529876709, 'qp': 'sparse', 'dcanon_time': 0.04460859298706055}]
#   + Trial 5
# [{'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.012223482131958008, 'qp': 'sparse'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.004046201705932617, 'qp': 'sparse'}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.1351163387298584, 'qp': 'sparse', 'canon_time': 0.05363774299621582}, {'trial': 5, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07185888290405273, 'qp': 'sparse', 'dcanon_time': 0.04546499252319336}]
#   + Trial 6
# [{'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.01220703125, 'qp': 'sparse'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005209684371948242, 'qp': 'sparse'}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13370490074157715, 'qp': 'sparse', 'canon_time': 0.05281209945678711}, {'trial': 6, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07027435302734375, 'qp': 'sparse', 'dcanon_time': 0.04579806327819824}]
#   + Trial 7
# [{'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.012287616729736328, 'qp': 'sparse'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005225658416748047, 'qp': 'sparse'}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13503623008728027, 'qp': 'sparse', 'canon_time': 0.053177595138549805}, {'trial': 7, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07369565963745117, 'qp': 'sparse', 'dcanon_time': 0.046157121658325195}]
#   + Trial 8
# [{'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.015297412872314453, 'qp': 'sparse'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.0047914981842041016, 'qp': 'sparse'}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13757991790771484, 'qp': 'sparse', 'canon_time': 0.05277228355407715}, {'trial': 8, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.07114553451538086, 'qp': 'sparse', 'dcanon_time': 0.04523134231567383}]
#   + Trial 9
# [{'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'forward', 'time': 0.012238502502441406, 'qp': 'sparse'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'qpth', 'direction': 'backward', 'time': 0.005220651626586914, 'qp': 'sparse'}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'forward', 'time': 0.13404417037963867, 'qp': 'sparse', 'canon_time': 0.054215431213378906}, {'trial': 9, 'nz': 6, 'nbatch': 50, 'cuda': False, 'mode': 'cvxpylayers', 'direction': 'backward', 'time': 0.0697932243347168, 'qp': 'sparse', 'dcanon_time': 0.04502558708190918}]
