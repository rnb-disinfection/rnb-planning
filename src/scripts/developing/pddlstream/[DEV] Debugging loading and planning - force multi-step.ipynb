# %%
from __future__ import print_function
import os
import sys
from test_arg_utils import *

sys.path.append(os.path.join(os.environ["RNB_PLANNING_DIR"], "src"))

from pkg.utils.test_scripts import *
from pkg.planning.pddlstream.plan_rnb import *

rtype = "panda"
dat_root = "stowing-deep"
res_root = "stowing-deep-result"
dat_dir = "20210917-113211"
file_option = "obj_3c_obs7"
data_idx = 1
cname = "ToolReach"

GRASP_SAMPLE = 30
STABLE_SAMPLE = 50

IK_TIMEOUT_SINGLE = 0.01
IK_TRY_NUM = 10
TIMEOUT_MOTION = 3
MAX_TIME = 100

MAX_ITER = 100
MAX_SKELETONS = 30
SEARCH_SAMPLE_RATIO = 100

USE_MOVEIT_IK = True
TIMED_COMPLETE = False

VERBOSE = True
VISUALIZE = True
PLAY_RESULT = True
SHOW_STATE = False
USE_PYBULLET_GUI = False
SAVE_RESULTS = False
STACK_TIMELOG= True


CLEARANCE = 1e-3
TOOL_NAME="grip0"
ROBOT_TYPE = {e.name: e for e in RobotType}[rtype]
# Out:
# [WARN] Motion Planning Logging is ON

# %%
########################################################
################### Create data folders ################
DATASET_PATH = create_data_dirs(dat_root, rtype, dat_dir)
RESULTSET_PATH = create_data_dirs(res_root, rtype, dat_dir)
print("-"*50)
print("DATASET_PATH: {}".format(DATASET_PATH))
print("RESULTSET_PATH: {}".format(RESULTSET_PATH))
print("-"*50)


########################################################
########## Load scene and prepare planner  #############
ROBOT_NAME, TOOL_LINK, TOOL_XYZ, TOOL_RPY, HOME_POSE, GRIP_DEPTH = get_single_robot_params(ROBOT_TYPE)
s_builder, pscene = prepare_single_robot_scene(ROBOT_TYPE, ROBOT_NAME, TOOL_LINK, TOOL_XYZ, TOOL_RPY, VISUALIZE=VISUALIZE)
crob, gscene = pscene.combined_robot, pscene.gscene
crob.home_pose = HOME_POSE
crob.home_dict = list2dict(HOME_POSE, gscene.joint_names)

fname = "data_%s_%02d.pkl" % (file_option, data_idx)
print(fname)
set_meta_data("dat_root", dat_root)
set_meta_data("rtype", rtype)
set_meta_data("dat_dir", dat_dir)
set_meta_data("fname", fname)


file_gtems = os.path.join(DATASET_PATH, fname)
initial_state = load_saved_scene(pscene, file_gtems, VISUALIZE=VISUALIZE)

gscene.NAME_DICT['obj_0'].color = (1,0,0,1)
gscene.update_markers_all()

mplan = MoveitPlanner(pscene)
checkers = get_checkers_by_case_name(cname, pscene)

mplan.motion_filters = checkers
# Out:
# --------------------------------------------------
# DATASET_PATH: /home/rnb/Projects/rnb-planning/data/stowing-deep/panda/20210917-113211
# RESULTSET_PATH: /home/rnb/Projects/rnb-planning/data/stowing-deep-result/panda/20210917-113211
# --------------------------------------------------
# connection command:
# panda0: False
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0, 0]
# Please create a subscriber to the marker
# data_obj_3c_obs7_01.pkl

# %% [markdown]
# ## Edit scene

# %%
for i in range(7):
    gscene.remove(gscene.NAME_DICT["obs{}".format(i)])

# %%
obj0 = pscene.subject_dict['obj_0']
obj1 = pscene.subject_dict['obj_1']
obj2 = pscene.subject_dict['obj_2']

del obj0.action_points_dict["obj_0_side_g"].redundancy['x']
obj0.action_points_dict["obj_0_side_g"].redundancy['u'] = (np.pi*3/4, np.pi*5/4)
del obj1.action_points_dict["obj_1_side_g"].redundancy['x']
obj1.action_points_dict["obj_1_side_g"].redundancy['u'] = (np.pi*3/4, np.pi*5/4)
del obj2.action_points_dict["obj_2_side_g"].redundancy['x']
obj2.action_points_dict["obj_2_side_g"].redundancy['u'] = (np.pi*3/4, np.pi*5/4)

obj0.action_points_dict['bottom_p'].redundancy = {}
obj1.action_points_dict['bottom_p'].redundancy = {}
obj2.action_points_dict['bottom_p'].redundancy = {}

wpa=pscene.actor_dict['wp']
del wpa.redundancy["w"]
gpa=pscene.actor_dict['gp']
del gpa.redundancy["w"]

grip0 = pscene.actor_dict['grip0']
grip0.redundancy = {}
# grip0.redundancy = ['w'] = (-0.01,0.01)

# %%
pscene.set_object_state(initial_state)
gscene.update_markers_all()

wp = gscene.NAME_DICT["wp"]
wp.set_offset_tf(center=np.add(wp.center, (0,0,0.4)))
wpa.update_handle()
wpb = gscene.NAME_DICT["wp_bot"]
wpb.dims = np.subtract(wpb.dims, (0.1, 0.1, 0.0))
wpb.set_offset_tf(center=np.add(wpb.center, (0,0,0.4)))
wp_ceil = gscene.copy_from(wp, new_name="wp_ceil")
wp_ceil.set_offset_tf(center = np.add(wp.center, (0,0,0.3)))

gp = gscene.NAME_DICT["gp"]
gp.set_offset_tf(center=np.add(gp.center, (0,0,0.2)))
gpa.update_handle()
gpb = gscene.NAME_DICT["gp_bot"]
gpb.set_offset_tf(center=np.add(gpb.center, (0,0,0.2)))

gscene.update_markers_all()

# %%
# pscene.remove_subject("obj_1")
# gscene.remove(gscene.NAME_DICT["obj_1"])

pscene.remove_subject("obj_2")
gscene.remove(gscene.NAME_DICT["obj_2"])

# %%
# obj0.set_offset_tf(center=[0.29480234, 0.59536386, 0.1798489])
sprm = obj0.get_state_param()
T = sprm[1]
T[:3,:3] = np.identity(3)
T[:3,3] = [0.20, 0.50, 0.1798489+0.4]
obj0.set_state(obj0.binding, sprm)

sprm = obj1.get_state_param()
T = sprm[1]
T[:3,:3] = np.identity(3)
T[:3,3] = (0.15, 0.45, 0.1798489+0.4)
obj1.set_state(obj1.binding, sprm)

# sprm = obj2.get_state_param()
# T = sprm[1]
# T[:3,:3] = np.identity(3)
# T[:3,3] = (0.40, 0.25, 0.1798489+0.4)
# obj2.set_state(obj2.binding, sprm)

initial_state = pscene.initialize_state(initial_state.Q, force_fit_binding=True)
gscene.update_markers_all()

# %%
GRASP_SAMPLE = 10
STABLE_SAMPLE = 20
SEARCH_SAMPLE_RATIO = 100
MAX_TIME = 300

# %%
VERBOSE = True
VISUALIZE = True
PLAY_RESULT = True
SHOW_STATE = False

# %% [markdown]
# # Solve in PDDLStream

# %%
########################################################
#################### Solve problem  ####################
obj_pscene = pscene.subject_dict[pscene.subject_name_list[0]]
obj_pscene.geometry.color = (0.8, 0.2, 0.2, 1)
gscene.update_markers_all()
goal_pairs=[("obj_0", 'gp')]
# goal_pairs=[("obj_1", 'gp'), ("obj_0", 'gp')]

gtimer = GlobalTimer.instance()
gtimer.reset(stack=STACK_TIMELOG)


res, plan, log_dict = solve_in_pddlstream(pscene, mplan, ROBOT_NAME, TOOL_NAME, HOME_POSE, goal_pairs,
                                          TIMEOUT_MOTION, MAX_TIME, MAX_ITER, MAX_SKELETONS,
                                          GRASP_SAMPLE, STABLE_SAMPLE, SHOW_STATE, SEARCH_SAMPLE_RATIO,
                                          use_pybullet_gui=USE_PYBULLET_GUI, USE_MOVEIT_IK=USE_MOVEIT_IK, 
                                          TIMED_COMPLETE=TIMED_COMPLETE,
                                          IK_TRY_NUM=IK_TRY_NUM, IK_TIMEOUT_SINGLE=IK_TIMEOUT_SINGLE, VERBOSE=VERBOSE)

log_dict.update(mplan.result_log)
log_dict.update(GlobalLogger.instance())
# Out:
# [Pybullet] Load urdf from /home/rnb/Projects/rnb-planning/src/robots/custom_robots_pybullet.urdf
# Objects: {1L: 'obj_0', 2L: 'gp', 3L: 'wp_bot', 4L: 'obj_1', 5L: 'floor', 6L: 'wp_ceil', 7L: 'base', 8L: 'wp', 9L: 'gp_bot'}
# ================ MAKE PROBLEM ======================
# IK checkers: ['GraspChecker', 'ReachChecker']
# MP checkers: []
# timeout motion : 3
# ====================================================
# Robot: 0
# Movable: [4L, 1L]
# Fixed: [2, 3, 5, 6, 7, 8, 9]
# body 4 - surface 2
# body 4 - surface 3
# body 4 - surface 5
# body 4 - surface 6
# body 4 - surface 7
# body 4 - surface 8
# body 4 - surface 9
# body 1 - surface 2
# body 1 - surface 3
# body 1 - surface 5
# body 1 - surface 6
# body 1 - surface 7
# body 1 - surface 8
# body 1 - surface 9
# [INFO] Load stable set data_obj_3c_obs7_01.pkl
# [INFO] Load grasp set data_obj_3c_obs7_01.pkl
# Init: [('CanMove',), ('Conf', q0), ('AtConf', q0), ('HandEmpty',), ('Timer', 0L), ('Graspable', 4L), ('Pose', 4L, p0), ('AtPose', 4L, p0), ('Stackable', 4L, 2), ('Stackable', 4L, 3), ('Supported', 4L, p0, 3), ('Stackable', 4L, 5), ('Stackable', 4L, 6), ('Stackable', 4L, 7), ('Stackable', 4L, 8), ('Supported', 4L, p0, 8), ('Stackable', 4L, 9), ('Timer', 0L), ('Graspable', 1L), ('Pose', 1L, p1), ('AtPose', 1L, p1), ('Stackable', 1L, 2), ('Stackable', 1L, 3), ('Supported', 1L, p1, 3), ('Stackable', 1L, 5), ('Stackable', 1L, 6), ('Stackable', 1L, 7), ('Stackable', 1L, 8), ('Supported', 1L, p1, 8), ('Stackable', 1L, 9)]
# Goal: ('and', ('AtConf', q0), ('On', 1L, 2L))
# Streams: {TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 29 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.006
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 29 | Eager Calls: 0 | Cost: inf | Search Time: 0.006 | Sample Time: 0.000 | Total Time: 0.006
# Attempt: 1 | Results: 19 | Depth: 0 | Success: False | Time: 0.022
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 29 | Eager Calls: 0 | Cost: inf | Search Time: 0.029 | Sample Time: 0.000 | Total Time: 0.029
# Attempt: 1 | Results: 32 | Depth: 1 | Success: False | Time: 0.043
# Attempt: 2 | Results: 69 | Depth: 0 | Success: True | Time: 0.099
# Stream plan (13, 13, 0.001): [sample-grasp:(1)->(#g0), sample-pose:(1, 2)->(#p0), inverse-kinematics:(1, #p0, #g0)->(#q1, #t16), test-cfree-traj-pose:(#t16, 4, p0)->(), inverse-kinematics:(1, p1, #g0)->(#q0, #t15), test-cfree-traj-pose:(#t15, 4, p0)->(), test-cfree-traj-pose:(#t15, 1, p1)->(), test-cfree-pose-pose:(1, #p0, 4, p0)->(), test-cfree-approach-pose:(1, p1, #g0, 4, p0)->(), test-cfree-approach-pose:(1, #p0, #g0, 4, p0)->(), plan-free-motion:(q0, #q0)->(#t57), plan-free-motion:(#q1, q0)->(#t59), plan-holding-motion:(#q0, #q1, 1, #g0)->(#t58)]
# Action plan (5, 0.000): [move_free(q0, #q0, #t57), pick(1, p1, #g0, #q0, #t15), move_holding(#q0, #q1, 1, #g0, #t58), place(1, #p0, #g0, #q1, #t16), move_free(#q1, q0, #t59)]
# iter=0, outs=1) sample-grasp:(1)->[(g0)]
# iter=0, outs=1) sample-pose:(1, 2)->[(p2)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g0)->[(q1, c0)]
# iter=inf, outs=1) test-cfree-traj-pose:(c0, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g0)->[(q2, c1)]
# iter=inf, outs=0) test-cfree-traj-pose:(c1, 4, p0)->[]
# Sampling for up to 13.088 seconds
# iter=1, outs=1) sample-grasp:(1)->[(g1)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g1)->[(q3, c2)]
# iter=inf, outs=1) test-cfree-traj-pose:(c2, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g1)->[(q4, c3)]
# iter=inf, outs=0) test-cfree-traj-pose:(c3, 4, p0)->[]
# iter=2, outs=1) sample-grasp:(1)->[(g2)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g2)->[(q5, c4)]
# iter=inf, outs=1) test-cfree-traj-pose:(c4, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g2)->[(q6, c5)]
# iter=inf, outs=0) test-cfree-traj-pose:(c5, 4, p0)->[]
# iter=3, outs=1) sample-grasp:(1)->[(g3)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g3)->[(q7, c6)]
# iter=inf, outs=1) test-cfree-traj-pose:(c6, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g3)->[(q8, c7)]
# iter=inf, outs=0) test-cfree-traj-pose:(c7, 4, p0)->[]
# iter=4, outs=1) sample-grasp:(1)->[(g4)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g4)->[(q9, c8)]
# iter=inf, outs=1) test-cfree-traj-pose:(c8, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g4)->[(q10, c9)]
# iter=inf, outs=0) test-cfree-traj-pose:(c9, 4, p0)->[]
# iter=5, outs=1) sample-grasp:(1)->[(g5)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g5)->[(q11, c10)]
# iter=inf, outs=1) test-cfree-traj-pose:(c10, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g5)->[(q12, c11)]
# iter=inf, outs=0) test-cfree-traj-pose:(c11, 4, p0)->[]
# iter=6, outs=1) sample-grasp:(1)->[(g6)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g6)->[(q13, c12)]
# iter=inf, outs=1) test-cfree-traj-pose:(c12, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g6)->[(q14, c13)]
# iter=inf, outs=0) test-cfree-traj-pose:(c13, 4, p0)->[]
# iter=7, outs=1) sample-grasp:(1)->[(g7)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g7)->[(q15, c14)]
# iter=inf, outs=1) test-cfree-traj-pose:(c14, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g7)->[(q16, c15)]
# iter=inf, outs=0) test-cfree-traj-pose:(c15, 4, p0)->[]
# iter=8, outs=1) sample-grasp:(1)->[(g8)]
# iter=inf, outs=0) inverse-kinematics:(1, p2, g8)->[]
# iter=1, outs=1) sample-pose:(1, 2)->[(p3)]
# iter=inf, outs=1) inverse-kinematics:(1, p3, g8)->[(q17, c16)]
# iter=inf, outs=1) test-cfree-traj-pose:(c16, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g8)->[(q18, c17)]
# iter=inf, outs=0) test-cfree-traj-pose:(c17, 4, p0)->[]
# iter=2, outs=1) sample-pose:(1, 2)->[(p4)]
# iter=inf, outs=1) inverse-kinematics:(1, p4, g8)->[(q19, c18)]
# iter=inf, outs=1) test-cfree-traj-pose:(c18, 4, p0)->[()]
# iter=3, outs=1) sample-pose:(1, 2)->[(p5)]
# iter=inf, outs=1) inverse-kinematics:(1, p5, g8)->[(q20, c19)]
# iter=inf, outs=1) test-cfree-traj-pose:(c19, 4, p0)->[()]
# iter=4, outs=1) sample-pose:(1, 2)->[(p6)]
# iter=inf, outs=1) inverse-kinematics:(1, p6, g8)->[(q21, c20)]
# iter=inf, outs=1) test-cfree-traj-pose:(c20, 4, p0)->[()]
# iter=5, outs=1) sample-pose:(1, 2)->[(p7)]
# iter=inf, outs=0) inverse-kinematics:(1, p7, g8)->[]
# iter=6, outs=1) sample-pose:(1, 2)->[(p8)]
# iter=inf, outs=0) inverse-kinematics:(1, p8, g8)->[]
# iter=7, outs=1) sample-pose:(1, 2)->[(p9)]
# iter=inf, outs=1) inverse-kinematics:(1, p9, g8)->[(q22, c21)]
# iter=inf, outs=1) test-cfree-traj-pose:(c21, 4, p0)->[()]
# iter=8, outs=1) sample-pose:(1, 2)->[(p10)]
# iter=inf, outs=1) inverse-kinematics:(1, p10, g8)->[(q23, c22)]
# iter=inf, outs=1) test-cfree-traj-pose:(c22, 4, p0)->[()]
# iter=9, outs=1) sample-pose:(1, 2)->[(p11)]
# iter=inf, outs=1) inverse-kinematics:(1, p11, g8)->[(q24, c23)]
# iter=inf, outs=1) test-cfree-traj-pose:(c23, 4, p0)->[()]
# iter=9, outs=1) sample-grasp:(1)->[(g9)]
# iter=inf, outs=1) inverse-kinematics:(1, p2, g9)->[(q25, c24)]
# iter=inf, outs=1) test-cfree-traj-pose:(c24, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p1, g9)->[(q26, c25)]
# iter=inf, outs=0) test-cfree-traj-pose:(c25, 4, p0)->[]
# iter=inf, outs=1) inverse-kinematics:(1, p4, g9)->[(q27, c26)]
# iter=inf, outs=1) test-cfree-traj-pose:(c26, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p5, g9)->[(q28, c27)]
# iter=inf, outs=1) test-cfree-traj-pose:(c27, 4, p0)->[()]
# iter=inf, outs=0) inverse-kinematics:(1, p8, g9)->[]
# iter=inf, outs=1) inverse-kinematics:(1, p3, g9)->[(q29, c28)]
# iter=inf, outs=1) test-cfree-traj-pose:(c28, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p9, g9)->[(q30, c29)]
# iter=inf, outs=1) test-cfree-traj-pose:(c29, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p11, g9)->[(q31, c30)]
# iter=inf, outs=1) test-cfree-traj-pose:(c30, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p10, g9)->[(q32, c31)]
# iter=inf, outs=1) test-cfree-traj-pose:(c31, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p7, g9)->[(q33, c32)]
# iter=inf, outs=1) test-cfree-traj-pose:(c32, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p6, g9)->[(q34, c33)]
# iter=inf, outs=1) test-cfree-traj-pose:(c33, 4, p0)->[()]
# iter=10, outs=1) sample-pose:(1, 2)->[(p12)]
# iter=inf, outs=1) inverse-kinematics:(1, p12, g8)->[(q35, c34)]
# iter=inf, outs=1) test-cfree-traj-pose:(c34, 4, p0)->[()]
# iter=inf, outs=0) inverse-kinematics:(1, p12, g9)->[]
# iter=inf, outs=0) sample-grasp:(1)->[]
# iter=11, outs=1) sample-pose:(1, 2)->[(p13)]
# iter=inf, outs=1) inverse-kinematics:(1, p13, g9)->[(q36, c35)]
# iter=inf, outs=1) test-cfree-traj-pose:(c35, 4, p0)->[()]
# iter=inf, outs=0) inverse-kinematics:(1, p13, g8)->[]
# iter=12, outs=1) sample-pose:(1, 2)->[(p14)]
# iter=inf, outs=1) inverse-kinematics:(1, p14, g9)->[(q37, c36)]
# iter=inf, outs=1) test-cfree-traj-pose:(c36, 4, p0)->[()]
# iter=inf, outs=0) inverse-kinematics:(1, p14, g8)->[]
# iter=13, outs=1) sample-pose:(1, 2)->[(p15)]
# iter=inf, outs=0) inverse-kinematics:(1, p15, g9)->[]
# iter=inf, outs=0) inverse-kinematics:(1, p15, g8)->[]
# iter=14, outs=1) sample-pose:(1, 2)->[(p16)]
# iter=inf, outs=0) inverse-kinematics:(1, p16, g8)->[]
# iter=inf, outs=0) inverse-kinematics:(1, p16, g9)->[]
# iter=15, outs=1) sample-pose:(1, 2)->[(p17)]
# iter=inf, outs=1) inverse-kinematics:(1, p17, g9)->[(q38, c37)]
# iter=inf, outs=1) test-cfree-traj-pose:(c37, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p17, g8)->[(q39, c38)]
# iter=inf, outs=1) test-cfree-traj-pose:(c38, 4, p0)->[()]
# iter=16, outs=1) sample-pose:(1, 2)->[(p18)]
# iter=inf, outs=1) inverse-kinematics:(1, p18, g8)->[(q40, c39)]
# iter=inf, outs=1) test-cfree-traj-pose:(c39, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p18, g9)->[(q41, c40)]
# iter=inf, outs=1) test-cfree-traj-pose:(c40, 4, p0)->[()]
# iter=17, outs=1) sample-pose:(1, 2)->[(p19)]
# iter=inf, outs=1) inverse-kinematics:(1, p19, g8)->[(q42, c41)]
# iter=inf, outs=1) test-cfree-traj-pose:(c41, 4, p0)->[()]
# iter=inf, outs=1) inverse-kinematics:(1, p19, g9)->[(q43, c42)]
# iter=inf, outs=1) test-cfree-traj-pose:(c42, 4, p0)->[()]
# iter=18, outs=1) sample-pose:(1, 2)->[(p20)]
# iter=inf, outs=0) inverse-kinematics:(1, p20, g9)->[]
# iter=inf, outs=0) inverse-kinematics:(1, p20, g8)->[]
# iter=19, outs=1) sample-pose:(1, 2)->[(p21)]
# iter=inf, outs=1) inverse-kinematics:(1, p21, g8)->[(q44, c43)]
# iter=inf, outs=1) test-cfree-traj-pose:(c43, 4, p0)->[()]
# iter=inf, outs=0) inverse-kinematics:(1, p21, g9)->[]
# iter=inf, outs=0) sample-pose:(1, 2)->[]
# Sampling while complexity <= 2
#
# Iteration: 4 | Complexity: 2 | Skeletons: 1 | Skeleton Queue: 8 | Disabled: 0 | Evaluations: 255 | Eager Calls: 0 | Cost: inf | Search Time: 12.922 | Sample Time: 0.313 | Total Time: 13.235
# Attempt: 1 | Results: 81 | Depth: 1 | Success: False | Time: 0.077
# Attempt: 2 | Results: 162 | Depth: 1 | Success: False | Time: 0.186
# Attempt: 3 | Results: 215 | Depth: 1 | Success: False | Time: 0.348
# Attempt: 4 | Results: 276 | Depth: 1 | Success: False | Time: 0.495
# Attempt: 5 | Results: 345 | Depth: 1 | Success: False | Time: 0.667
# Attempt: 6 | Results: 422 | Depth: 1 | Success: False | Time: 0.913
# Attempt: 7 | Results: 507 | Depth: 1 | Success: False | Time: 1.145
# Attempt: 8 | Results: 599 | Depth: 0 | Success: True | Time: 1.442
# Stream plan (25, 21, 0.001): [sample-grasp:(1)->(g0), inverse-kinematics:(1, p1, g0)->(q2, c1), test-cfree-traj-pose:(c1, 1, p1)->(), sample-grasp:(4)->(#g1), inverse-kinematics:(4, p0, #g1)->(#q2, #t121), test-cfree-traj-pose:(#t121, 4, p0)->(), sample-pose:(4, 3)->(#p1), inverse-kinematics:(4, #p1, #g1)->(#q3, #t122), test-cfree-traj-pose:(#t122, 1, p1)->(), test-cfree-traj-pose:(#t121, 1, p1)->(), sample-pose:(1, 2)->(p2), inverse-kinematics:(1, p2, g0)->(q1, c0), test-cfree-traj-pose:(c0, 4, #p1)->(), test-cfree-traj-pose:(c1, 4, #p1)->(), test-cfree-pose-pose:(4, #p1, 1, p1)->(), test-cfree-pose-pose:(1, p2, 4, #p1)->(), test-cfree-approach-pose:(4, p0, #g1, 1, p1)->(), test-cfree-approach-pose:(1, p2, g0, 4, #p1)->(), test-cfree-approach-pose:(1, p1, g0, 4, #p1)->(), test-cfree-approach-pose:(4, #p1, #g1, 1, p1)->(), plan-free-motion:(q1, q0)->(#t691), plan-free-motion:(q0, #q2)->(#t687), plan-free-motion:(#q3, q2)->(#t688), plan-holding-motion:(q2, q1, 1, g0)->(#t690), plan-holding-motion:(#q2, #q3, 4, #g1)->(#t689)]
# Action plan (9, 0.000): [move_free(q0, #q2, #t687), pick(4, p0, #g1, #q2, #t121), move_holding(#q2, #q3, 4, #g1, #t689), place(4, #p1, #g1, #q3, #t122), move_free(#q3, q2, #t688), pick(1, p1, g0, q2, c1), move_holding(q2, q1, 1, g0, #t690), place(1, p2, g0, q1, c0), move_free(q1, q0, #t691)]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 1, p1)->[()]
# iter=0, outs=1) sample-grasp:(4)->[(g10)]
# iter=inf, outs=1) inverse-kinematics:(4, p0, g10)->[(q45, c44)]
# iter=inf, outs=1) test-cfree-traj-pose:(c44, 4, p0)->[()]
# iter=inf, outs=0) sample-pose:(4, 3)->[]
# Sampling for up to 1437.408 seconds
# iter=inf, outs=1) test-cfree-traj-pose:(c9, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c7, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c13, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c11, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c5, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c3, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c25, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c15, 1, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c17, 1, p1)->[()]
#          135831572 function calls (116183658 primitive calls) in 42.200 seconds
#
#    Ordered by: internal time
#    List reduced from 1375 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 8055476/1812611    5.140    0.000   13.420    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:186(check_downstream_helper)
#   9868088    3.400    0.000    4.542    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:145(is_dominated)
# 12485664/3624844    2.360    0.000   10.690    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:198(<genexpr>)
#   1812612    2.225    0.000   18.559    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:308(_process_binding)
#   1812637    2.109    0.000    4.486    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:201(get_priority)
# 8099822/3669412    1.774    0.000   11.705    0.000 {any}
#   1820340    1.705    0.000    2.834    0.000 {_heapq.heappop}
#         2    1.441    0.720   40.665   20.332 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:398(timed_process)
#   9276927    1.422    0.000    1.422    0.000 /home/rnb/Projects/pddlstream/pddlstream/utils.py:356(__lt__)
#   1812612    1.377    0.000   31.542    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py:337(process_root)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-aa18de5b57d4> in <module>()
#      16                                           use_pybullet_gui=USE_PYBULLET_GUI, USE_MOVEIT_IK=USE_MOVEIT_IK,
#      17                                           TIMED_COMPLETE=TIMED_COMPLETE,
# ---> 18                                           IK_TRY_NUM=IK_TRY_NUM, IK_TIMEOUT_SINGLE=IK_TIMEOUT_SINGLE, VERBOSE=VERBOSE)
#      19
#      20 log_dict.update(mplan.result_log)
#
# /home/rnb/Projects/rnb-planning/src/pkg/planning/pddlstream/plan_rnb.pyc in solve_in_pddlstream(pscene, mplan, ROBOT_NAME, TOOL_NAME, HOME_POSE, goal_pairs, TIMEOUT_MOTION, MAX_TIME, MAX_ITER, MAX_SKELETONS, GRASP_SAMPLE, STABLE_SAMPLE, SHOW_STATE, SEARCH_SAMPLE_RATIO, use_pybullet_gui, USE_MOVEIT_IK, TIMED_COMPLETE, VERBOSE, IK_TRY_NUM, IK_TIMEOUT_SINGLE)
#     195             solution = solve(problem, algorithm='adaptive',
#     196                              unit_costs=False, success_cost=INF, max_time=MAX_TIME, max_iterations=MAX_ITER,
# --> 197                              max_skeletons=MAX_SKELETONS, search_sample_ratio=SEARCH_SAMPLE_RATIO, verbose=VERBOSE)
#     198             gtimer.toc("plan") / 1000
#     199             saver.restore()
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/meta.pyc in solve(problem, algorithm, constraints, stream_info, replan_actions, unit_costs, success_cost, max_time, max_iterations, max_memory, initial_complexity, complexity_step, max_complexity, max_skeletons, search_sample_ratio, max_failures, unit_efforts, max_effort, effort_weight, reorder, visualize, verbose, **search_kwargs)
#     145             #bind=bind, max_failures=max_failures,
#     146             unit_efforts=unit_efforts, max_effort=max_effort, effort_weight=effort_weight, reorder=reorder,
# --> 147             visualize=visualize, verbose=verbose, **search_kwargs)
#     148     raise NotImplementedError(algorithm)
#     149
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/focused.pyc in solve_adaptive(problem, max_skeletons, search_sample_ratio, **kwargs)
#     292     #assert search_sample_ratio > 0
#     293     return solve_abstract(problem, max_skeletons=max_skeletons, search_sample_ratio=search_sample_ratio,
# --> 294                           bind=None, max_failures=None, **kwargs)
#     295
#     296 def solve_hierarchical(problem, **kwargs):
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/focused.pyc in solve_abstract(problem, constraints, stream_info, replan_actions, unit_costs, success_cost, max_time, max_iterations, max_memory, initial_complexity, complexity_step, max_complexity, max_skeletons, search_sample_ratio, bind, max_failures, unit_efforts, max_effort, effort_weight, reorder, visualize, verbose, **search_kwargs)
#     229         allocated_sample_time = (search_sample_ratio * store.search_time) - store.sample_time \
#     230             if len(skeleton_queue.skeletons) <= max_skeletons else INF
# --> 231         if skeleton_queue.process(stream_plan, opt_plan, cost, complexity_limit, allocated_sample_time) is INFEASIBLE:
#     232             break
#     233
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py in process(self, stream_plan, action_plan, cost, complexity_limit, max_time, accelerate)
#     438
#     439         # TODO: add and process
# --> 440         self.timed_process(max_time=(max_time - elapsed_time(start_time)))
#     441         self.process_complexity(complexity_limit)
#     442         if accelerate:
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py in timed_process(self, max_time, max_iterations)
#     405         while self.is_active() and (elapsed_time(start_time) < max_time) and (iterations < max_iterations):
#     406             iterations += 1
# --> 407             num_new += self.process_root()
#     408         #print('Iterations: {} | New: {} | Time: {:.3f}'.format(iterations, num_new, elapsed_time(start_time)))
#     409         return num_new + self.greedily_process()
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py in process_root(self)
#     337     def process_root(self):
#     338         _, binding = self.pop_binding()
# --> 339         readd, is_new = self._process_binding(binding)
#     340         if readd is not False:
#     341             self.push_binding(binding)
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py in _process_binding(self, binding)
#     317             return readd, is_new
#     318         binding.visits += 1
# --> 319         instance = binding.result.instance
#     320         if (REQUIRE_DOWNSTREAM and not binding.check_downstream()): # TODO: move check_complexity here
#     321             # TODO: causes redundant plan skeletons to be identified (along with complexity using visits instead of calls)
#
# /home/rnb/Projects/pddlstream/pddlstream/algorithms/skeleton.py in result(self)
#     134     def is_fully_bound(self):
#     135         return self.index == len(self.skeleton.stream_plan)
# --> 136     @property
#     137     def result(self):
#     138         if self._result is False:
#
# KeyboardInterrupt:

# %%
if VISUALIZE and PLAY_RESULT and res:
    play_pddl_plan(pscene, pscene.actor_dict["grip0"], initial_state=initial_state,
                   body_names=log_dict['body_names'], plan=plan, SHOW_PERIOD=0.01)

# %%
print({k:v for k,v in log_dict['body_names'].items() if "obj" in v})
print({k:v for k,v in log_dict['body_names'].items() if v.endswith('p')})

# %%
for k, v in pscene.actor_dict.items():
    print("{}:{}-{}".format(k, v.name, v.geometry.name))

# %% [markdown]
# ## Test saved motion logs
# * save motions by setting LOG_MOTION_PLANNING=True in pkg.planning.motion.interface

# %%
from pkg.planning.motion.interface import MOTION_PATH
mfiles = sorted(os.listdir(MOTION_PATH))

# %%
for mfile in mfiles:
# if True:
#     mfile = mfiles[1]
    mdat = load_pickle(os.path.join(MOTION_PATH, mfile))

    from_state = mdat['from_state']
    to_state = mdat['to_state']
    subject_list = mdat['subject_list']
    success = mdat['success']
    Traj = mdat['Traj']

    pscene.set_object_state(from_state)
    gscene.update_markers_all()
    gscene.show_pose(from_state.Q)
    time.sleep(0.5)
    gscene.show_pose(to_state.Q)


    print("success: {} / {}".format(success, mplan.validate_trajectory(Traj)))
    if success:
        gscene.show_motion(Traj, period=0.01)
# Out:
# success: True / True
# success: True / True
# success: False / True
# success: True / True
# success: True / True
# success: False / True
# success: True / True
# success: True / True
# success: True / True
# success: True / True
# success: True / True

# %% [markdown]
# ## Old version

# %%
from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()

from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
from pkg.planning.task.rrt import TaskRRT
tplan = TaskRRT(pscene)
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)

# %%
ppline.set_motion_planner(mplan)
ppline.set_task_planner(tplan)
# Out:
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %%
from_state = initial_state.copy(pscene)
from_state.Q = HOME_POSE
goal_nodes = [('gp','wp','wp')]
ppline.search(from_state, goal_nodes, verbose=False, display=False, 
              timeout_loop=100, multiprocess=True, timeout=1, add_homing=True)
# Out:
# Use 20/20 agents
# Goal reached
# ++ adding return motion to acquired answer ++
# Goal reached
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 9: first answer acquired ===============================
# ======================= terminated 6: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 4: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 1: first answer acquired from other agent ===============================
# =========================================================================================================
# ======================= terminated 11: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 10: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 13: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 16: first answer acquired from other agent ===============================
# ======================= terminated 8: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 14: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 18: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 3: first answer acquired from other agent ===============================
# ======================= terminated 7: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 5: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 15: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 12: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 17: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 19: first answer acquired from other agent ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 0: first answer acquired from other agent ===============================
# =========================================================================================================

# %%
snode_schedule = ppline.tplan.get_best_schedule()

# %%
ppline.play_schedule(snode_schedule)
# Out:
# ('wp', 'wp', 'wp')->('wp', 'grip0', 'wp')
# ('wp', 'grip0', 'wp')->('wp', 'gp', 'wp')
# ('wp', 'gp', 'wp')->('wp', 'gp', 'grip0')
# ('wp', 'gp', 'grip0')->('wp', 'gp', 'wp')
# ('wp', 'gp', 'wp')->('grip0', 'gp', 'wp')
# ('grip0', 'gp', 'wp')->('wp', 'gp', 'wp')
# ('wp', 'gp', 'wp')->('grip0', 'gp', 'wp')
# ('grip0', 'gp', 'wp')->('gp', 'gp', 'wp')
# ('gp', 'gp', 'wp')->('gp', 'gp', 'grip0')
# ('gp', 'gp', 'grip0')->('gp', 'gp', 'wp')
# ('gp', 'gp', 'wp')->('gp', 'grip0', 'wp')
# ('gp', 'grip0', 'wp')->('gp', 'wp', 'wp')
# ('gp', 'wp', 'wp')->('gp', 'wp', 'wp')
