# %% [markdown]
# # Test runtime
# ### Test with IK checkers
#
# **grasp sample 10**
# solve-mean: 1175.2 ms
# solve-median: 740.8 ms
# success rate: 98.0 %
#
# **grasp sample 20**
# solve-mean: 1190.6 ms
# solve-median: 778.4 ms
# success rate: 96.5 %
#
# **grasp sample 30**
# solve-mean: 1323.0 ms
# solve-median: 837.4 ms
# success rate: 99.0 %
#
# ### Test without IK checkers
#
# **grasp sample 10**
# solve-mean: 1998.9 ms
# solve-median: 1241.1 ms
# success rate: 88.0 %

# %% [markdown]
# ## set running directory to project source

# %%
import os
import numpy as np
import time
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))
import matplotlib.pyplot as plt
from pkg.controller.combined_robot import *

# %% [markdown]
# # params

# %%
ROBOT_TYPE = RobotType.panda

if ROBOT_TYPE in [RobotType.indy7, RobotType.indy7gripper]:
    ROBOT_NAME = "indy0"
    TOOL_LINK = "indy0_tcp"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.14)
    
elif ROBOT_TYPE == RobotType.panda:
    ROBOT_NAME = "panda0"
    TOOL_LINK = "panda0_hand"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.112)
    
else:
    raise(NotImplementedError("Case not defined for {}".format(ROBOT_TYPE)))

# %% [markdown]
# ## 4.1 PlanningScene

# %% [markdown]
# ##### initialize CombinedRobot and GeometryScene

# %%
from pkg.project_config import *
from pkg.geometry.builder.scene_builder import SceneBuilder

s_builder = SceneBuilder(None)   # create scene builder without detector for virtual scene
crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, ((0,0,0), (0,0,0)), None)]
                     , connection_list=[False])
gscene = s_builder.create_gscene(crob)
gtems = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=True, collision=True)
gscene.show_pose(crob.home_pose)
# Out:
# connection command:
# panda0: False
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0, 0]
# Please create a subscriber to the marker

# %% [markdown]
# ##### add geometries

# %%
from pkg.geometry.geometry import *

# add environments (fixed=True for non-movable geometries)
wall = gscene.create_safe(GEOTYPE.BOX, "wall", "base_link", (3,3,0.01), (-0.2,0,0), 
                           rpy=(0,np.pi/2,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
floor = gscene.create_safe(GEOTYPE.BOX, "floor", "base_link", (0.72,1.52,0.01), (0.25,0,0), 
                           rpy=(0,0,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
goal = gscene.create_safe(GEOTYPE.BOX, "goal", "base_link", (0.1,0.1,0.01), (0.3,-0.4,0), 
                          rpy=(0,0,0), color=(0.2,0.2,0.8,1), display=True, fixed=True, collision=True)
 
# add movable (fixed=False for movable geometries)
box1 = gscene.create_safe(GEOTYPE.BOX, "box1", "base_link", (0.1,0.05,0.05), (0.3,0.4,0.031), 
                          rpy=(np.pi/2,0,np.pi/6), color=(0.8,0.2,0.2,1), display=True, fixed=False, collision=True)

box2 = gscene.create_safe(GEOTYPE.BOX, "box2", "base_link", (0.05,0.05,0.05), (0.5,0.4,0.031), 
                          rpy=(np.pi,0,0), color=(0.8,0.8,0.2,1), display=True, fixed=False, collision=True)

box1.permute_axis_match_z_link()
box2.permute_axis_match_z_link()

# %% [markdown]
# ##### create PlanningScene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

# %% [markdown]
# ##### create_binder
# - Binders (or Actors) are binding points where objects can be attached (or binded)
# - Examples are
#   - PlacePlane: plane for object placement
#   - Gripper2Tool: 2-finger gripper tool for grasp objects
#   - SweepTool: action point to pass waypoints for sweep task

# %%
from pkg.planning.constraint.constraint_actor import PlacePlane, Gripper2Tool, SweepFramer

# %%
# create PlacePlane on geometry "floor" and "goal"
# when point is not set, the entire upper surface of the geometry becomes valid binding area.
# when point is set, the specific point becomes the only valid binding point.
pscene.create_binder(bname="floor", gname="floor", _type=PlacePlane)
pscene.create_binder(bname="goal", gname="goal", _type=PlacePlane)

# %%
# add collision boundary for gripper base
# - set link_name="indy0_tcp" to attach the geometry to end-effector link
# - it can be labeled as fixed=True, as it is "fixed" on the indy0_tcp link
gripper =  gscene.create_safe(GEOTYPE.SPHERE, TOOL_NAME, link_name=TOOL_LINK, 
                                dims=(0.01,0.01,0.01), center=TOOL_XYZ, rpy=(-np.pi/2,0,0), 
                                color=(0.8,0.2,0.2,0.5), display=False, fixed=True, collision=False)

# create Gripper2Tool binder
# Gripper2Tool is a 2-finger gripper, which can rotate along z-direction.
# To align the z-direction with the 2 fingers, rotate by 90 degree along roll axis.
# The gripping point is (0,0,0.11) in local coordinate of "gripper" geometry
pscene.create_binder(bname=TOOL_NAME, gname=TOOL_NAME, _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))

# %% [markdown]
# ##### create_subject
# * Subject describes the tasks in the planning scene.
# * There are 2 categories in subject:
#   1. Object: The object has grip points and placement points for pick&place task
#   2. Task: The task is can be any non-physical task. Check SweepLineTask for example
# * The subjects can be composed of multiple action points. Examples are:
#   1. Grasp2Point: grasping point for 2-finger gripper.
#   2. PlacePoint: The point to place object.
#   3. SweepPoint: A waypoint for SweepLineTask.
#   * The above 3 action points inherit DirectePoint, for which the orientation is free along z-axis.
#   * If "point" parameter is not set, the entire upper surface is becomes valid action area.

# %%
from pkg.planning.constraint.constraint_subject import Grasp2Point, PlacePoint, SweepFrame
from pkg.planning.constraint.constraint_subject import CustomObject, SweepLineTask

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
box_obj = pscene.create_subject(oname="box1", gname="box1", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box1, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box1, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box1, [0,0,-0.026], [0,0,0])})

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
obs_obj = pscene.create_subject(oname="box2", gname="box2", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box2, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box2, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box2, [0,0,-0.026], [0,0,0])})

# %% [markdown]
# ## Pipeline

# %%
from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %%
from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)

# %% [markdown]
# ##### initialize_state
# * initialize_state(robot_pose) updates robot pose and gets corresponding binding status of current scene.
# * state.node of ('floor', 0) means the first subject (object) is placed on the floor and the second subject (sweep) has passed 0 waypoints

# %%
initial_state = pscene.initialize_state(crob.home_pose)
print(initial_state.node)
# Out:
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
# ('floor', 'floor')
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ## import planners

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
mplan = MoveitPlanner(pscene)
from pkg.planning.filtering.grasp_filter import GraspChecker
from pkg.planning.filtering.reach_filter import ReachChecker
from pkg.planning.filtering.latticized_filter import LatticedChecker
from pkg.planning.filtering.task_clearance_filter import TaskClearanceChecker

gcheck = GraspChecker(pscene)
rcheck = ReachChecker(pscene)

checkers_all = [rcheck, gcheck]

# tcheck = TaskClearanceChecker(pscene, gcheck)
# checkers_all = [tcheck, rcheck, gcheck]

# lcheck = LatticedChecker(pscene, gcheck)
# checkers_all.append(lcheck)

# %% [markdown]
# ## Test pybullet

# %%
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src/scripts/developing/pddlstream'))

# %%
from convert_pscene import *
from plan_rnb import *

# %% [markdown]
# #### load pybullet, convert scene

# %%
connect_notebook(use_gui=True)
urdf_pybullet_path = copy_meshes(gscene)
robot_body, body_names, movable_bodies = pscene_to_pybullet(
    pscene, urdf_pybullet_path, tool_name=TOOL_NAME, name_exclude_list=[ROBOT_NAME])
print('Objects:', body_names)
saver = WorldSaver()
# Out:
# [Pybullet] Load urdf from /home/rnb/Projects/rnb-planning/src/robots/custom_robots_pybullet.urdf
# ('Objects:', {1L: 'goal', 2L: 'floor', 3L: 'wall', 4L: 'box1', 5L: 'box2'})

# %% [markdown]
# ### Test with IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_wFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=checkers_all,
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_wFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q0), ('AtConf', q0), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p0), ('AtPose', 4L, p0), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p0, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p1), ('AtPose', 5L, p1), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p1, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q0), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.091
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.213
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g0), sample-pose:(4, 1)->(#p0), inverse-kinematics:(4, #p0, #g0)->(#q1, #t15), test-cfree-traj-pose:(#t15, 5, p1)->(), inverse-kinematics:(4, p0, #g0)->(#q0, #t14), test-cfree-traj-pose:(#t14, 5, p1)->(), test-cfree-traj-pose:(#t14, 4, p0)->(), test-cfree-pose-pose:(4, #p0, 5, p1)->(), test-cfree-approach-pose:(4, p0, #g0, 5, p1)->(), test-cfree-approach-pose:(4, #p0, #g0, 5, p1)->(), plan-free-motion:(q0, #q0)->(#t56), plan-free-motion:(#q1, q0)->(#t58), plan-holding-motion:(#q0, #q1, 4, #g0)->(#t57)]
# Action plan (5, 0.000): [move_free(q0, #q0, #t56), pick(4, p0, #g0, #q0, #t14), move_holding(#q0, #q1, 4, #g0, #t57), place(4, #p0, #g0, #q1, #t15), move_free(#q1, q0, #t58)]
# iter=0, outs=1) sample-grasp:(4)->[(g0)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p2)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8450746768275158, 0.3639783948184923, -0.13539074632827944, -2.283717311410417, 0.16135851050405703, 2.627568900231459, 1.8600432880628543)
# go on
# q_grasp: (-0.8660300312265258, 0.48664160044134125, -0.10319927753782625, -2.2621503220200725, 0.19849379555356428, 2.72824767899417, 1.8331025586726346)
# iter=inf, outs=1) inverse-kinematics:(4, p2, g0)->[(q1, c0)]
# iter=inf, outs=1) test-cfree-traj-pose:(c0, 5, p1)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.15245599173190963, 0.42777928887626476, 0.7204444048035783, -2.3428099151108097, -0.5181072325862559, 2.5788338304014533, 1.5463254251485696)
# go on
# q_grasp: (0.2507489381958466, 0.543291140157657, 0.5934265281608123, -2.3150414305692015, -0.6492626173089573, 2.6583219880776743, 1.637474716312226)
# iter=inf, outs=1) inverse-kinematics:(4, p0, g0)->[(q2, c1)]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 4, p0)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p2, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p0, g0, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p2, g0, 5, p1)->[()]
# iter=inf, outs=1) plan-free-motion:(q0, q2)->[(c2)]
# iter=inf, outs=1) plan-free-motion:(q1, q0)->[(c3)]
# iter=inf, outs=1) plan-holding-motion:(q2, q1, 4, g0)->[(c4)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.450, sample_time: 0.205, search_time: 0.244, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6988 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9030 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30447 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5951 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2292 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3198 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6294 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11711 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1591772 function calls (1527757 primitive calls) in 0.730 seconds
#
#    Ordered by: internal time
#    List reduced from 1573 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.132    0.044    0.132    0.044 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100770    0.054    0.000    0.069    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.045    0.022    0.176    0.088 /usr/lib/python2.7/pickle.py:851(load)
#   50463/1    0.037    0.000    0.094    0.094 /usr/lib/python2.7/pickle.py:269(save)
#    201816    0.033    0.000    0.033    0.000 {method 'read' of 'file' objects}
#    100738    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.024    0.012    0.024    0.012 {posix.read}
#         2    0.016    0.008    0.016    0.008 {posix.fork}
#     50398    0.016    0.000    0.027    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100924    0.016    0.000    0.016    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q0 q2 c2
#  2) pick 4 p0 g0 q2 c1
#  3) move_holding q2 q1 4 g0 c4
#  4) place 4 p2 g0 q1 c0
#  5) move_free q1 q0 c3
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q3), ('AtConf', q3), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p3), ('AtPose', 4L, p3), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p3, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p4), ('AtPose', 5L, p4), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p4, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q3), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.100
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.215
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g1), inverse-kinematics:(4, p3, #g1)->(#q2, #t73), test-cfree-traj-pose:(#t73, 4, p3)->(), sample-pose:(4, 1)->(#p1), inverse-kinematics:(4, #p1, #g1)->(#q3, #t74), test-cfree-traj-pose:(#t74, 5, p4)->(), test-cfree-traj-pose:(#t73, 5, p4)->(), test-cfree-pose-pose:(4, #p1, 5, p4)->(), test-cfree-approach-pose:(4, p3, #g1, 5, p4)->(), test-cfree-approach-pose:(4, #p1, #g1, 5, p4)->(), plan-free-motion:(q3, #q2)->(#t116), plan-free-motion:(#q3, q3)->(#t117), plan-holding-motion:(#q2, #q3, 4, #g1)->(#t115)]
# Action plan (5, 0.000): [move_free(q3, #q2, #t116), pick(4, p3, #g1, #q2, #t73), move_holding(#q2, #q3, 4, #g1, #t115), place(4, #p1, #g1, #q3, #t74), move_free(#q3, q3, #t117)]
# iter=0, outs=1) sample-grasp:(4)->[(g1)]
# iter=inf, outs=0) inverse-kinematics:(4, p3, g1)->[]
# Sampling for up to 0.230 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g2)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.7889189224476836, 0.37460939019164025, 0.11156757465454316, -2.2267539227855853, 0.04396912453806109, 2.419285006910191, 1.1226558073043982)
# go on
# q_grasp: (0.7983723063849979, 0.4754437393357041, 0.10718515224712445, -2.2395237294755463, 0.036924391660192596, 2.5328536057618574, 1.1277566413395987)
# iter=inf, outs=1) inverse-kinematics:(4, p3, g2)->[(q4, c5)]
# iter=inf, outs=1) test-cfree-traj-pose:(c5, 4, p3)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p5)]
# q_approach: (-0.7767844814627708, 0.38689944024496453, -0.20233359257966432, -2.252692739512789, 0.5273247725950908, 2.5883020333234077, 1.994786294165567)
# go on
# q_grasp: (-0.8017826893813632, 0.5057325263203927, -0.14301687406774025, -2.2203784066722267, 0.6055813229742928, 2.673544987069579, 1.9398386209012568)
# iter=inf, outs=1) inverse-kinematics:(4, p5, g2)->[(q5, c6)]
# iter=inf, outs=1) test-cfree-traj-pose:(c6, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c5, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p5, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p3, g2, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p5, g2, 5, p4)->[()]
# iter=inf, outs=1) plan-free-motion:(q3, q4)->[(c7)]
# iter=inf, outs=1) plan-free-motion:(q5, q3)->[(c8)]
# iter=inf, outs=1) plan-holding-motion:(q4, q5, 4, g2)->[(c9)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 37, iterations: 3, length: 2, run_time: 0.441, sample_time: 0.195, search_time: 0.246, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6989 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9032 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30450 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5953 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2293 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3199 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6296 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11714 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1592768 function calls (1528661 primitive calls) in 0.729 seconds
#
#    Ordered by: internal time
#    List reduced from 1507 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.138    0.046    0.138    0.046 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100796    0.056    0.000    0.074    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.047    0.023    0.187    0.094 /usr/lib/python2.7/pickle.py:851(load)
#   50477/1    0.036    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    201868    0.034    0.000    0.034    0.000 {method 'read' of 'file' objects}
#    100764    0.028    0.000    0.039    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.027    0.014    0.027    0.014 {posix.read}
#         2    0.016    0.008    0.016    0.008 {posix.fork}
#     50412    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100952    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q3 q4 c7
#  2) pick 4 p3 g2 q4 c5
#  3) move_holding q4 q5 4 g2 c9
#  4) place 4 p5 g2 q5 c6
#  5) move_free q5 q3 c8
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q6), ('AtConf', q6), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p6), ('AtPose', 4L, p6), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p6, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p7), ('AtPose', 5L, p7), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p7, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q6), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.089
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.198
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g2), inverse-kinematics:(4, p6, #g2)->(#q4, #t132), test-cfree-traj-pose:(#t132, 4, p6)->(), test-cfree-traj-pose:(#t132, 5, p7)->(), sample-pose:(4, 1)->(#p2), inverse-kinematics:(4, #p2, #g2)->(#q5, #t133), test-cfree-traj-pose:(#t133, 5, p7)->(), test-cfree-pose-pose:(4, #p2, 5, p7)->(), test-cfree-approach-pose:(4, p6, #g2, 5, p7)->(), test-cfree-approach-pose:(4, #p2, #g2, 5, p7)->(), plan-free-motion:(q6, #q4)->(#t175), plan-free-motion:(#q5, q6)->(#t176), plan-holding-motion:(#q4, #q5, 4, #g2)->(#t174)]
# Action plan (5, 0.000): [move_free(q6, #q4, #t175), pick(4, p6, #g2, #q4, #t132), move_holding(#q4, #q5, 4, #g2, #t174), place(4, #p2, #g2, #q5, #t133), move_free(#q5, q6, #t176)]
# iter=0, outs=1) sample-grasp:(4)->[(g3)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.7350286339226053, -1.1900339266026536, -1.7872282702876245, -2.2152723175424494, -1.2952937102117135, 1.932685953899648, 1.9597325324667079)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.11112838305095853, 0.457488982653831, 0.764468654191538, -2.30684059266634, -0.4942602780200498, 2.506405186205663, 1.5168025545381636)
# go on
# q_grasp: (0.20763783659263904, 0.5716964781010467, 0.6416403160525606, -2.2854296593720433, -0.6186802799645914, 2.590357808800832, 1.6019360446113615)
# iter=inf, outs=1) inverse-kinematics:(4, p6, g3)->[(q8, c10)]
# iter=inf, outs=1) test-cfree-traj-pose:(c10, 4, p6)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c10, 5, p7)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p8)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4661792047026981, 0.2853248069080971, -0.35207937698056313, -2.456528670188126, 0.0373521728615304, 2.7266183146277663, -0.8396358988281233)
# go on
# q_grasp: (-0.5269311358712482, 0.42158700657448916, -0.2836969700173195, -2.433541223773833, 0.10764178432620036, 2.838551517475474, -0.8900239440347084)
# iter=inf, outs=1) inverse-kinematics:(4, p8, g3)->[(q9, c11)]
# iter=inf, outs=1) test-cfree-traj-pose:(c11, 5, p7)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p8, 5, p7)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p6, g3, 5, p7)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p8, g3, 5, p7)->[()]
# iter=inf, outs=1) plan-free-motion:(q6, q8)->[(c12)]
# iter=inf, outs=1) plan-free-motion:(q9, q6)->[(c13)]
# iter=inf, outs=1) plan-holding-motion:(q8, q9, 4, g3)->[(c14)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.427, sample_time: 0.199, search_time: 0.228, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6990 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9033 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30452 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5955 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2294 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3200 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6298 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11717 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1597746 function calls (1533683 primitive calls) in 0.732 seconds
#
#    Ordered by: internal time
#    List reduced from 1507 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.127    0.042    0.128    0.043 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100824    0.061    0.000    0.078    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.201    0.101 /usr/lib/python2.7/pickle.py:851(load)
#    201924    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   50490/1    0.037    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    100792    0.030    0.000    0.042    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.025    0.013    0.025    0.013 {posix.read}
#     50425    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100978    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#         2    0.015    0.007    0.015    0.007 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q6 q8 c12
#  2) pick 4 p6 g3 q8 c10
#  3) move_holding q8 q9 4 g3 c14
#  4) place 4 p8 g3 q9 c11
#  5) move_free q9 q6 c13
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q10), ('AtConf', q10), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p9), ('AtPose', 4L, p9), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p9, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p10), ('AtPose', 5L, p10), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p10, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q10), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.158
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.259
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g3), inverse-kinematics:(4, p9, #g3)->(#q6, #t191), test-cfree-traj-pose:(#t191, 5, p10)->(), sample-pose:(4, 1)->(#p3), inverse-kinematics:(4, #p3, #g3)->(#q7, #t192), test-cfree-traj-pose:(#t192, 5, p10)->(), test-cfree-traj-pose:(#t191, 4, p9)->(), test-cfree-pose-pose:(4, #p3, 5, p10)->(), test-cfree-approach-pose:(4, p9, #g3, 5, p10)->(), test-cfree-approach-pose:(4, #p3, #g3, 5, p10)->(), plan-free-motion:(q10, #q6)->(#t233), plan-free-motion:(#q7, q10)->(#t235), plan-holding-motion:(#q6, #q7, 4, #g3)->(#t234)]
# Action plan (5, 0.000): [move_free(q10, #q6, #t233), pick(4, p9, #g3, #q6, #t191), move_holding(#q6, #q7, 4, #g3, #t234), place(4, #p3, #g3, #q7, #t192), move_free(#q7, q10, #t235)]
# iter=0, outs=1) sample-grasp:(4)->[(g4)]
# iter=inf, outs=0) inverse-kinematics:(4, p9, g4)->[]
# Sampling for up to 0.275 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g5)]
# iter=inf, outs=0) inverse-kinematics:(4, p9, g5)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g6)]
# iter=inf, outs=0) inverse-kinematics:(4, p9, g6)->[]
# iter=3, outs=1) sample-grasp:(4)->[(g7)]
# q_approach: (0.31389345836008803, 0.5240528782951235, 0.5760037455426653, -2.0940354561468455, -0.21150638261134308, 2.221307964791747, 1.2868197415231464)
# go on
# q_grasp: (0.3464076700849669, 0.6017414363014243, 0.5331659607275456, -2.130332349696531, -0.264528224745405, 2.329449540995184, 1.321772012774019)
# iter=inf, outs=1) inverse-kinematics:(4, p9, g7)->[(q11, c15)]
# iter=inf, outs=1) test-cfree-traj-pose:(c15, 5, p10)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p11)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.13648480238836713, 0.5954495130648758, -0.778937398736608, -2.091796033775482, 0.5284684680415759, 2.1205123716286516, 0.5365909647983528)
# go on
# q_grasp: (-0.16571939952975842, 0.665239244001001, -0.7134852851913506, -2.1287183718259683, 0.6058654229982621, 2.2143920084547988, 0.4901929537921457)
# iter=inf, outs=1) inverse-kinematics:(4, p11, g7)->[(q12, c16)]
# iter=inf, outs=1) test-cfree-traj-pose:(c16, 5, p10)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c15, 4, p9)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p11, 5, p10)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p9, g7, 5, p10)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p11, g7, 5, p10)->[()]
# iter=inf, outs=1) plan-free-motion:(q10, q11)->[(c17)]
# iter=inf, outs=1) plan-free-motion:(q12, q10)->[(c18)]
# iter=inf, outs=1) plan-holding-motion:(q11, q12, 4, g7)->[(c19)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 39, iterations: 3, length: 2, run_time: 0.478, sample_time: 0.188, search_time: 0.290, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6991 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9037 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30457 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5957 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2295 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3201 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6300 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11720 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1594577 function calls (1530517 primitive calls) in 0.794 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.128    0.043    0.128    0.043 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#       227    0.086    0.000    0.087    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/downward.py:329(<genexpr>)
#    100850    0.060    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.198    0.099 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.038    0.019    0.038    0.019 {posix.read}
#   50506/1    0.038    0.000    0.095    0.095 /usr/lib/python2.7/pickle.py:269(save)
#    201976    0.038    0.000    0.038    0.000 {method 'read' of 'file' objects}
#    100818    0.030    0.000    0.041    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     50441    0.016    0.000    0.026    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    101010    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q10 q11 c17
#  2) pick 4 p9 g7 q11 c15
#  3) move_holding q11 q12 4 g7 c19
#  4) place 4 p11 g7 q12 c16
#  5) move_free q12 q10 c18
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q13), ('AtConf', q13), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p12), ('AtPose', 4L, p12), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p12, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p13), ('AtPose', 5L, p13), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p13, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q13), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.082
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.185
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g4), inverse-kinematics:(4, p12, #g4)->(#q9, #t251), test-cfree-traj-pose:(#t251, 5, p13)->(), sample-pose:(4, 1)->(#p4), inverse-kinematics:(4, #p4, #g4)->(#q8, #t250), test-cfree-traj-pose:(#t250, 5, p13)->(), test-cfree-traj-pose:(#t251, 4, p12)->(), test-cfree-pose-pose:(4, #p4, 5, p13)->(), test-cfree-approach-pose:(4, p12, #g4, 5, p13)->(), test-cfree-approach-pose:(4, #p4, #g4, 5, p13)->(), plan-free-motion:(q13, #q9)->(#t292), plan-free-motion:(#q8, q13)->(#t293), plan-holding-motion:(#q9, #q8, 4, #g4)->(#t294)]
# Action plan (5, 0.000): [move_free(q13, #q9, #t292), pick(4, p12, #g4, #q9, #t251), move_holding(#q9, #q8, 4, #g4, #t294), place(4, #p4, #g4, #q8, #t250), move_free(#q8, q13, #t293)]
# iter=0, outs=1) sample-grasp:(4)->[(g8)]
# iter=inf, outs=0) inverse-kinematics:(4, p12, g8)->[]
# Sampling for up to 0.201 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g9)]
# iter=inf, outs=0) inverse-kinematics:(4, p12, g9)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g10)]
# iter=inf, outs=0) inverse-kinematics:(4, p12, g10)->[]
# iter=3, outs=1) sample-grasp:(4)->[(g11)]
# q_approach: (-0.19118625714179632, 0.5388391559688276, 1.0098103206508502, -2.4500668993235206, -1.4234603561084889, 2.6436369613325326, 2.2741671808835724)
# go on
# q_grasp: (-0.07532625899171592, 0.6943415741014336, 0.8713162362973347, -2.35191522234808, -1.6013333476106015, 2.6124163161164224, 2.3749262006441363)
# iter=inf, outs=1) inverse-kinematics:(4, p12, g11)->[(q14, c20)]
# iter=inf, outs=1) test-cfree-traj-pose:(c20, 5, p13)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p14)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.9341256303812808, 0.7175387303393481, 0.9442285203637857, -2.092802832232173, -0.55961299487787, 2.203571646465116, -1.4860600557118968)
# go on
# q_grasp: (-1.8780695657043363, 0.7851850491391769, 0.8611202584803638, -2.114028085471153, -0.633904280064839, 2.2923842975635065, -1.4418977622104692)
# iter=inf, outs=1) inverse-kinematics:(4, p14, g11)->[(q15, c21)]
# iter=inf, outs=1) test-cfree-traj-pose:(c21, 5, p13)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c20, 4, p12)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p14, 5, p13)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p12, g11, 5, p13)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p14, g11, 5, p13)->[()]
# iter=inf, outs=1) plan-free-motion:(q13, q14)->[(c22)]
# iter=inf, outs=1) plan-free-motion:(q15, q13)->[(c23)]
# iter=inf, outs=1) plan-holding-motion:(q14, q15, 4, g11)->[(c24)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 39, iterations: 3, length: 2, run_time: 0.454, sample_time: 0.238, search_time: 0.216, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6992 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9041 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30462 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5959 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2296 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3202 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6302 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11723 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1603536 function calls (1539426 primitive calls) in 0.758 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.159    0.053    0.160    0.053 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100882    0.054    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.180    0.090 /usr/lib/python2.7/pickle.py:851(load)
#   50522/1    0.045    0.000    0.112    0.112 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.039    0.020    0.039    0.020 {posix.read}
#    202040    0.036    0.000    0.036    0.000 {method 'read' of 'file' objects}
#    100850    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     50457    0.019    0.000    0.032    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    101042    0.018    0.000    0.018    0.000 {method 'write' of 'file' objects}
#         2    0.017    0.008    0.017    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q13 q14 c22
#  2) pick 4 p12 g11 q14 c20
#  3) move_holding q14 q15 4 g11 c24
#  4) place 4 p14 g11 q15 c21
#  5) move_free q15 q13 c23
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q16), ('AtConf', q16), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p15), ('AtPose', 4L, p15), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p15, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p16), ('AtPose', 5L, p16), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p16, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q16), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.007 | Sample Time: 0.000 | Total Time: 0.007
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.113
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.230
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g5), inverse-kinematics:(4, p15, #g5)->(#q10, #t309), test-cfree-traj-pose:(#t309, 5, p16)->(), sample-pose:(4, 1)->(#p5), inverse-kinematics:(4, #p5, #g5)->(#q11, #t310), test-cfree-traj-pose:(#t310, 5, p16)->(), test-cfree-traj-pose:(#t309, 4, p15)->(), test-cfree-pose-pose:(4, #p5, 5, p16)->(), test-cfree-approach-pose:(4, p15, #g5, 5, p16)->(), test-cfree-approach-pose:(4, #p5, #g5, 5, p16)->(), plan-free-motion:(#q11, q16)->(#t351), plan-free-motion:(q16, #q10)->(#t352), plan-holding-motion:(#q10, #q11, 4, #g5)->(#t353)]
# Action plan (5, 0.000): [move_free(q16, #q10, #t352), pick(4, p15, #g5, #q10, #t309), move_holding(#q10, #q11, 4, #g5, #t353), place(4, #p5, #g5, #q11, #t310), move_free(#q11, q16, #t351)]
# iter=0, outs=1) sample-grasp:(4)->[(g12)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p15, g12)->[]
# Sampling for up to 0.230 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g13)]
# iter=inf, outs=0) inverse-kinematics:(4, p15, g13)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g14)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.1121289553778748, -1.2359508918799278, 1.7975059264354294, -1.9831912850331879, 1.212001828960514, 1.5930033164999653, 0.4083073570417442)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.5775781488683578, 0.4701664297078285, 0.3074477863016661, -2.087625165037115, -0.030345071331656946, 2.222655707215897, 1.1593863275877467)
# go on
# q_grasp: (0.5945339802130163, 0.5459900146901883, 0.2922178565921404, -2.1241663048711805, -0.05292240541780294, 2.3330505407362803, 1.174622410065166)
# iter=inf, outs=1) inverse-kinematics:(4, p15, g14)->[(q17, c25)]
# iter=inf, outs=1) test-cfree-traj-pose:(c25, 5, p16)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p17)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.4314114823083348, -0.5346017396297769, -2.4120617343887534, -2.227428887282498, -0.05053566648846081, 2.5348011556007077, 2.084419134811494)
# go on
# q_grasp: (1.5241827057018724, -0.6402558496257587, -2.4931456538234613, -2.21763024910215, -0.11026045759752705, 2.6377178995121815, 2.1262866457994627)
# iter=inf, outs=1) inverse-kinematics:(4, p17, g14)->[(q18, c26)]
# iter=inf, outs=1) test-cfree-traj-pose:(c26, 5, p16)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c25, 4, p15)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p17, 5, p16)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p15, g14, 5, p16)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p17, g14, 5, p16)->[()]
# iter=inf, outs=1) plan-free-motion:(q18, q16)->[(c27)]
# iter=inf, outs=1) plan-free-motion:(q16, q17)->[(c28)]
# iter=inf, outs=1) plan-holding-motion:(q17, q18, 4, g14)->[(c29)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.519, sample_time: 0.255, search_time: 0.264, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6993 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9044 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30466 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5961 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2297 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3203 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6304 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11726 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1610034 function calls (1545884 primitive calls) in 0.819 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.134    0.045    0.134    0.045 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100914    0.060    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.024    0.200    0.100 /usr/lib/python2.7/pickle.py:851(load)
#    202104    0.042    0.000    0.042    0.000 {method 'read' of 'file' objects}
#   50537/1    0.037    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.032    0.016    0.032    0.016 {posix.read}
#    100882    0.030    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.020    0.010    0.020    0.010 {posix.fork}
#     50472    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    101072    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q16 q17 c28
#  2) pick 4 p15 g14 q17 c25
#  3) move_holding q17 q18 4 g14 c29
#  4) place 4 p17 g14 q18 c26
#  5) move_free q18 q16 c27
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q19), ('AtConf', q19), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p18), ('AtPose', 4L, p18), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p18, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p19), ('AtPose', 5L, p19), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p19, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q19), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.016
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.016
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.033 | Sample Time: 0.000 | Total Time: 0.033
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.105
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.227
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g6), inverse-kinematics:(4, p18, #g6)->(#q12, #t368), test-cfree-traj-pose:(#t368, 5, p19)->(), test-cfree-traj-pose:(#t368, 4, p18)->(), sample-pose:(4, 1)->(#p6), inverse-kinematics:(4, #p6, #g6)->(#q13, #t369), test-cfree-traj-pose:(#t369, 5, p19)->(), test-cfree-pose-pose:(4, #p6, 5, p19)->(), test-cfree-approach-pose:(4, p18, #g6, 5, p19)->(), test-cfree-approach-pose:(4, #p6, #g6, 5, p19)->(), plan-free-motion:(q19, #q12)->(#t410), plan-free-motion:(#q13, q19)->(#t412), plan-holding-motion:(#q12, #q13, 4, #g6)->(#t411)]
# Action plan (5, 0.000): [move_free(q19, #q12, #t410), pick(4, p18, #g6, #q12, #t368), move_holding(#q12, #q13, 4, #g6, #t411), place(4, #p6, #g6, #q13, #t369), move_free(#q13, q19, #t412)]
# iter=0, outs=1) sample-grasp:(4)->[(g15)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.1032478934108088, -0.9775638216036884, 1.919830707716027, -2.0974269101673984, 1.0712469514293295, 1.8994035560818758, 0.4666811349839881)
# go on
# q_grasp: (-1.131180554058199, -1.029960295790517, 2.013113851148346, -2.1121425625693377, 1.1562422549385463, 1.966870599657306, 0.4347028114758673)
# iter=inf, outs=1) inverse-kinematics:(4, p18, g15)->[(q20, c30)]
# iter=inf, outs=1) test-cfree-traj-pose:(c30, 5, p19)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c30, 4, p18)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p20)]
# ...
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p90, g59)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p87, g62)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4589550243637936, 0.4197802952387701, -0.36140550048090603, -2.1805726313623555, 0.14419655705974918, 2.313147010533157, -2.6185723541860533)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p92, g59)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.3738297343444024, -0.4740350328280251, 2.335584697360172, -2.305727579059161, 0.6278470618332914, 2.4838865559439722, 0.7384725096137097)
# go on
# q_grasp: (-1.467465917018911, -0.5869903290185517, 2.462194690445634, -2.2795283534205484, 0.7613547976036985, 2.556696598245157, 0.649710444378579)
# iter=inf, outs=1) inverse-kinematics:(4, p87, g63)->[(q134, c117)]
# iter=inf, outs=1) test-cfree-traj-pose:(c117, 4, p87)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c117, 5, p88)->[()]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g63)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.6664712994287807, 0.4374268831184362, 0.7259491133599331, -2.3979471593556845, -1.18556590143497, 2.781387438277954, 2.091035666366639)
# go on
# q_grasp: (-1.562682070529186, 0.5917273270905348, 0.6002004583031143, -2.291804235441838, -1.3784325784272595, 2.7821471468830827, 2.2292408243225363)
# iter=inf, outs=1) inverse-kinematics:(4, p93, g59)->[(q135, c118)]
# iter=inf, outs=1) test-cfree-traj-pose:(c118, 5, p88)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3371762891242054, 0.4274125821677615, -0.4334112935445221, -2.18915809093985, 0.36457361143642925, 2.340627204483183, 0.8961036182465685)
# go on
# q_grasp: (1.3118890355420063, 0.5204886869378247, -0.3813252198712007, -2.203751416820496, 0.43835417267951327, 2.440194301013725, 0.8479964155990686)
# iter=inf, outs=1) inverse-kinematics:(4, p87, g64)->[(q136, c119)]
# iter=inf, outs=1) test-cfree-traj-pose:(c119, 4, p87)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c119, 5, p88)->[()]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g64)->[]
# q_approach: (-1.7734165535352937, 0.30179590385337696, 0.6596014135074831, -2.610512681955313, 0.02920070224373008, 3.032330083232902, -0.0517683437644912)
# go on
# q_grasp: (-1.5492423164526503, 0.45506093664394787, 0.44085864332873725, -2.5446613470582675, -0.026450945049767548, 3.1396138244246785, -0.009163923223862624)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g59)->[(q137, c120)]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 5, p88)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.746987101716731, 0.6915434581012887, -0.9068620049723332, -2.054636357325205, 0.7281075025746346, 2.0378949138117153, 0.6492161081396229)
# go on
# q_grasp: (1.7219731824765312, 0.7563026742144945, -0.8333676386603002, -2.08588063404441, 0.8098087377532031, 2.119892942818981, 0.6053117646722631)
# iter=inf, outs=1) inverse-kinematics:(4, p87, g65)->[(q138, c121)]
# iter=inf, outs=1) test-cfree-traj-pose:(c121, 4, p87)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c121, 5, p88)->[()]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g65)->[]
# q_approach: (-0.29121667160827874, 0.4027029670009892, -0.47338666437982635, -2.4043562227862956, 0.8109420477412603, 2.9691415385593376, 0.21336380504089245)
# go on
# q_grasp: (-0.4589924537399899, 0.5452193574892168, -0.2880159870861563, -2.2995749559547853, 0.9561329665837766, 3.0339350487544903, 0.07896195267200062)
# iter=inf, outs=1) inverse-kinematics:(4, p95, g59)->[(q139, c122)]
# iter=inf, outs=1) test-cfree-traj-pose:(c122, 5, p88)->[()]
# iter=inf, outs=0) inverse-kinematics:(4, p87, g66)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.4582791711447736, 0.32993449848315004, 0.34070409897245496, -2.3674470530364835, 0.2835486793809517, 2.6038490134010286, -1.2587898608243597)
# go on
# q_grasp: (-1.4236652530168368, 0.4578803551675877, 0.3295979385134444, -2.354012034945113, 0.2702125095155157, 2.721023950976599, -1.2504822388615755)
# iter=inf, outs=1) inverse-kinematics:(4, p96, g59)->[(q140, c123)]
# iter=inf, outs=1) test-cfree-traj-pose:(c123, 5, p88)->[()]
# iter=inf, outs=0) inverse-kinematics:(4, p87, g67)->[]
# q_approach: (0.3366653414029356, 0.6830172220160772, -1.0962221942900026, -2.408993390650599, 1.4671111460801682, 2.565128635828125, -0.48754082207308386)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.3537636397487399, 0.3328782910937882, -0.40706706372703777, -2.471189128044404, 0.9679488828116068, 2.9616246184759243, -0.22750541578697545)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.19317758260849258, 0.546258805147932, -0.9457344544982468, -2.416614051963514, 1.3574236990629043, 2.70535237739266, -0.4558229922978609)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p97, g59)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g67)->[]
# Sampling while complexity <= 3
# iter=1, outs=1) sample-pose:(4, 2)->[(p99)]
# iter=inf, outs=0) inverse-kinematics:(4, p99, g59)->[]
#
# Iteration: 7 | Complexity: 3 | Skeletons: 3 | Skeleton Queue: 61 | Disabled: 0 | Evaluations: 97 | Eager Calls: 0 | Cost: inf | Search Time: 1.638 | Sample Time: 1.340 | Total Time: 2.978
# Attempt: 1 | Results: 88 | Depth: 0 | Success: False | Time: 0.037
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 3 to 4
# Sampling for up to 0.335 seconds
# iter=inf, outs=0) inverse-kinematics:(4, p94, g67)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p96, g67)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p95, g67)->[]
# iter=2, outs=1) sample-pose:(4, 2)->[(p100)]
# q_approach: (-0.743857896951256, 0.5877577744154013, 0.2972112112152416, -1.8904899453599517, -0.036577536426208195, 2.2352360653946084, -1.7794742981060905)
# go on
# q_grasp: (-0.7254688704106664, 0.6640305028356965, 0.28292230217965053, -1.9145487869287436, -0.054902265950633515, 2.334784478063278, -1.7677683658774668)
# iter=inf, outs=1) inverse-kinematics:(4, p100, g59)->[(q141, c124)]
# iter=inf, outs=1) test-cfree-traj-pose:(c124, 5, p88)->[()]
# q_approach: (-0.695322125697329, 0.4231544017552119, 0.2497260968229668, -2.2630657154063627, -0.8771855313542879, 2.812919873327573, -0.9906362225715051)
# go on
# q_grasp: (-0.6367199927065907, 0.5643851606344558, 0.1610884238749813, -2.1722646951366475, -0.9823701141278508, 2.867428385208196, -0.9050686011005736)
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.5842855737792306, 0.4118784490520436, 0.14153731052784235, -2.2738122774889025, -0.7927910364205223, 2.84445981192704, -1.046498523593404)
# go on
# q_grasp: (-0.530770090261886, 0.5554037365628007, 0.05811023870478207, -2.1865699516931487, -0.8790678849357921, 2.9091336705515216, -0.9713127825757488)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.095540153585408, -0.5043589364670209, -2.5362535924839826, -2.23024225569967, -1.123092152763736, 2.6801011432724673, -0.8453635077501522)
# go on
# q_grasp: (2.1630386218752014, -0.6402004527122367, -2.6300664155548312, -2.1384782631755277, -1.254508574266802, 2.7021549330213515, -0.7600818854361298)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.6502504496994775, 0.41734601566030166, 0.20552484077115163, -2.267820418043338, -0.8428461588169545, 2.826135034950637, -1.013311403884783)
# go on
# q_grasp: (-0.5929886437590465, 0.5599810727638114, 0.11817311914020019, -2.1779182845607097, -0.9413461283056931, 2.8850695283563086, -0.9308509719082486)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p100, g61)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.556245525752126, -0.7634862906070455, 2.1589866770361583, -2.116698176299383, 0.9400813078564313, 2.418432945643172, -2.3361663176363)
# go on
# q_grasp: (-2.648890333342138, -0.8561199390594034, 2.272942713835304, -2.066574542771493, 1.0358245069750678, 2.4731501023273137, -2.3905093871626484)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.7066035945674407, 0.9404012349646407, -1.13718097184484, -2.092420226795979, 1.1406446013791653, 2.2672532322828856, -2.4315594872383257)
# go on
# q_grasp: (0.6301201814217822, 1.014175233301469, -1.031902045835717, -2.04917026732812, 1.227813598634376, 2.320005232619346, -2.470948988810369)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p100, g63)->[]
# iter=3, outs=1) sample-pose:(4, 2)->[(p101)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.04179243483964105, 0.5280771097410459, 0.9633142029570366, -2.4074396924238246, -0.36544063299088736, 2.6087029087124955, -0.7953353188584681)
# go on
# q_grasp: (0.12208111874816631, 0.6257953780682624, 0.7916635121570079, -2.384248778526502, -0.4688615092944336, 2.711342647673236, -0.7206216927813027)
# iter=inf, outs=1) inverse-kinematics:(4, p101, g59)->[(q148, c125)]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 5, p88)->[()]
# q_approach: (2.226723859750434, 0.5068326289118643, -0.9494517208898662, -2.4590230045147945, 0.2909707682090532, 2.71706138762665, -0.9269240779744774)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.24079645936887883, 0.4508743602552551, 0.9012056104918998, -2.3837282044783286, -1.0618980179355666, 2.3934341995533956, -0.0017918021995609519)
# go on
# q_grasp: (0.31237973001026376, 0.5821507002938977, 0.7743069024415662, -2.335271992251006, -1.2286771302065664, 2.414155884376811, 0.09145569055045352)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.328299796845305, 0.5919583330940656, -1.0251696566018607, -2.445506738450699, 0.4914155774491159, 2.6800935568891218, -1.0687824785213553)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p101, g61)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.1574488106094551, 0.26204140026615014, -0.05273318643284357, -2.4655641398158994, -0.13721851060557383, 2.7308976273802323, -0.7599543051206242)
# go on
# q_grasp: (1.156291188649565, 0.3994330387856815, -0.06281587640780503, -2.441145753518241, -0.1478032976232016, 2.84414979923141, -0.7527094520517944)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.03683151768977857, 0.5189057755825657, 0.9946669987218314, -2.397087735782041, -0.9193050386388466, 2.501377554369288, -0.22480162786041208)
# go on
# q_grasp: (0.15549440485396238, 0.6309151143869992, 0.8354835161885281, -2.351633791527742, -1.0789834788013914, 2.5461517527830138, -0.1232342223176048)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p101, g63)->[]
# q_approach: (-1.4500020624010193, 0.795909679085052, 1.0534280556231432, -2.1706052915761354, -1.3263503340115765, 2.3615318768727365, -0.8335917827815977)
# go on
# q_grasp: (-1.370170747498414, 0.8955720621341616, 0.9438528348405513, -2.101296916635577, -1.431475299656734, 2.3880139829735563, -0.789815710509405)
# iter=inf, outs=1) inverse-kinematics:(4, p100, g64)->[(q152, c126)]
# iter=inf, outs=1) test-cfree-traj-pose:(c126, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c124, 4, p100)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p91, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p100, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p91, g59, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p87, g64, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p100, g64, 5, p88)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p100, g59, 5, p88)->[()]
# iter=inf, outs=1) plan-free-motion:(q121, q136)->[(c127)]
# iter=inf, outs=1) plan-free-motion:(q133, q121)->[(c128)]
# iter=inf, outs=1) plan-free-motion:(q152, q141)->[(c129)]
# iter=inf, outs=1) plan-holding-motion:(q136, q152, 4, g64)->[(c130)]
# iter=inf, outs=1) plan-holding-motion:(q141, q133, 4, g59)->[(c131)]
# Summary: {complexity: 4, cost: 0.000, evaluations: 125, iterations: 7, length: 2, run_time: 3.473, sample_time: 1.756, search_time: 1.717, skeletons: 3, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7052 | p_success: 0.962 | overhead: 0.001
# External: sample-grasp | n: 9097 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30754 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5996 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2314 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3223 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6341 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11804 | p_success: 0.938 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          4405386 function calls (4283185 primitive calls) in 3.756 seconds
#
#    Ordered by: internal time
#    List reduced from 1511 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3787    0.290    0.000    0.290    0.000 {pybullet.calculateInverseKinematics}
#         5    0.225    0.045    0.228    0.046 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     31983    0.157    0.000    0.157    0.000 {pybullet.resetJointState}
#      2983    0.136    0.000    0.136    0.000 {method 'iteritems' of 'dict' objects}
#      4520    0.130    0.000    0.131    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/../../FastDownward/builds/release64/bin/translate/normalize.py:120(all_conditions)
#         6    0.101    0.017    0.101    0.017 {posix.read}
#      2441    0.084    0.000    0.084    0.000 /usr/local/lib/python2.7/dist-packages/zmq/sugar/socket.py:357(send)
#    101504    0.068    0.000    0.087    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#    203292    0.067    0.000    0.067    0.000 {method 'read' of 'file' objects}
#         2    0.056    0.028    0.221    0.110 /usr/lib/python2.7/pickle.py:851(load)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 9
# Deferred: 0
# Evaluations: 2
#  1) move_free q121 q136 c127
#  2) pick 4 p87 g64 q136 c119
#  3) move_holding q136 q152 4 g64 c130
#  4) place 4 p100 g64 q152 c126
#  5) move_free q152 q141 c129
#  6) pick 4 p100 g59 q141 c124
#  7) move_holding q141 q133 4 g59 c131
#  8) place 4 p91 g59 q133 c116
#  9) move_free q133 q121 c128

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_wFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	25028.0 ms/20 = 1251.4 ms (730.065/3981.083)
# sample_grasps_4: 	85.6 ms/20 = 4.3 ms (2.394/8.134)
# get_stable_4_1: 	36.8 ms/45 = 0.8 ms (0.394/2.13)
# ik_fn: 	4795.4 ms/309 = 15.5 ms (0.602/173.083)
# check_feas: 	964.3 ms/309 = 3.1 ms (0.593/8.769)
# ReachChecker: 	259.0 ms/309 = 0.8 ms (0.211/2.456)
# GraspChecker: 	466.1 ms/298 = 1.6 ms (0.517/5.334)
# free_motion_gen: 	2553.0 ms/47 = 54.3 ms (4.085/112.628)
# holding_motion_gen: 	1320.2 ms/23 = 57.4 ms (33.973/95.417)
# get_stable_4_3: 	0.0 ms/3 = 0.0 ms (0.005/0.007)
# get_stable_4_2: 	17.3 ms/17 = 1.0 ms (0.56/1.955)
#
# solve-mean: 1251.4 ms
# solve-median: 795.7 ms
# success rate: 100.0 %

# %% [markdown]
# ### Test without IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_woFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=[],
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_woFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q87), ('AtConf', q87), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p91), ('AtPose', 4L, p91), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p91, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p92), ('AtPose', 5L, p92), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p92, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q87), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.179
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g20), inverse-kinematics:(4, p91, #g20)->(#q45, #t1783), test-cfree-traj-pose:(#t1783, 4, p91)->(), test-cfree-traj-pose:(#t1783, 5, p92)->(), sample-pose:(4, 1)->(#p22), inverse-kinematics:(4, #p22, #g20)->(#q46, #t1784), test-cfree-traj-pose:(#t1784, 5, p92)->(), test-cfree-pose-pose:(4, #p22, 5, p92)->(), test-cfree-approach-pose:(4, p91, #g20, 5, p92)->(), test-cfree-approach-pose:(4, #p22, #g20, 5, p92)->(), plan-free-motion:(#q46, q87)->(#t1825), plan-free-motion:(q87, #q45)->(#t1826), plan-holding-motion:(#q45, #q46, 4, #g20)->(#t1827)]
# Action plan (5, 0.000): [move_free(q87, #q45, #t1826), pick(4, p91, #g20, #q45, #t1783), move_holding(#q45, #q46, 4, #g20, #t1827), place(4, #p22, #g20, #q46, #t1784), move_free(#q46, q87, #t1825)]
# iter=0, outs=1) sample-grasp:(4)->[(g54)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.2153076140451113, 0.7193415696511525, -0.9317570922425451, -2.3814289460571474, 2.3473192363726336, 3.038316508190859, -0.551065666758976)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g54)->[]
# Sampling for up to 0.174 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g55)]
# q_approach: (-1.4519024783258208, -1.1761139853033047, 2.003800739678055, -1.631944331886783, 0.9823133216275483, 1.3489679522314098, 0.514967537425978)
# go on
# q_grasp: (-1.391637661736404, -1.1990650085098076, 2.038096478826575, -1.737842637684051, 1.0282894835716596, 1.42714513042707, 0.4867566456869842)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g55)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g56)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6336747065619281, 0.34522173469389483, -0.5947815881515433, -2.502758260109791, 0.46875257127886316, 2.9125348747356083, 0.8914942618173828)
# go on
# q_grasp: (1.4447808138643843, 0.4809613248249993, -0.38516408394639184, -2.4325302881399318, 0.6076872919111654, 2.998059992093964, 0.7767776500515463)
# iter=inf, outs=1) inverse-kinematics:(4, p91, g56)->[(q89, c105)]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 4, p91)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 5, p92)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p93)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.17683829558120712, 0.32904683636731263, -0.6592590209016547, -2.521317493595038, 0.8225037472099498, 2.8718055124759942, 0.013270147742465448)
# go on
# q_grasp: (-0.3510109058095045, 0.48142753585519815, -0.4513364721643871, -2.4227048735375294, 1.0589933120437227, 2.9211035860247003, -0.1784026176912355)
# iter=inf, outs=1) inverse-kinematics:(4, p93, g56)->[(q90, c106)]
# iter=inf, outs=1) test-cfree-traj-pose:(c106, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p93, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p91, g56, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p93, g56, 5, p92)->[()]
# iter=inf, outs=1) plan-free-motion:(q90, q87)->[(c107)]
# iter=inf, outs=1) plan-free-motion:(q87, q89)->[(c108)]
# iter=inf, outs=1) plan-holding-motion:(q89, q90, 4, g56)->[(c109)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.567, sample_time: 0.355, search_time: 0.212, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6922 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8978 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30199 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5904 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2265 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3171 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6240 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11575 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1635876 function calls (1572242 primitive calls) in 0.860 seconds
#
#    Ordered by: internal time
#    List reduced from 1479 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.157    0.052    0.158    0.053 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99794    0.057    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.025    0.186    0.093 /usr/lib/python2.7/pickle.py:851(load)
#       635    0.047    0.000    0.047    0.000 {pybullet.calculateInverseKinematics}
#         2    0.040    0.020    0.040    0.020 {posix.read}
#   49977/1    0.036    0.000    0.089    0.089 /usr/lib/python2.7/pickle.py:269(save)
#    199864    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#     99762    0.028    0.000    0.039    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#      5089    0.024    0.000    0.024    0.000 {pybullet.resetJointState}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q87 q89 c108
#  2) pick 4 p91 g56 q89 c105
#  3) move_holding q89 q90 4 g56 c109
#  4) place 4 p93 g56 q90 c106
#  5) move_free q90 q87 c107
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q91), ('AtConf', q91), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p94), ('AtPose', 4L, p94), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p94, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p95), ('AtPose', 5L, p95), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p95, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q91), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.082
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.187
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g21), sample-pose:(4, 1)->(#p23), inverse-kinematics:(4, #p23, #g21)->(#q48, #t1843), test-cfree-traj-pose:(#t1843, 5, p95)->(), inverse-kinematics:(4, p94, #g21)->(#q47, #t1842), test-cfree-traj-pose:(#t1842, 5, p95)->(), test-cfree-traj-pose:(#t1842, 4, p94)->(), test-cfree-pose-pose:(4, #p23, 5, p95)->(), test-cfree-approach-pose:(4, p94, #g21, 5, p95)->(), test-cfree-approach-pose:(4, #p23, #g21, 5, p95)->(), plan-free-motion:(#q48, q91)->(#t1884), plan-free-motion:(q91, #q47)->(#t1885), plan-holding-motion:(#q47, #q48, 4, #g21)->(#t1886)]
# Action plan (5, 0.000): [move_free(q91, #q47, #t1885), pick(4, p94, #g21, #q47, #t1842), move_holding(#q47, #q48, 4, #g21, #t1886), place(4, #p23, #g21, #q48, #t1843), move_free(#q48, q91, #t1884)]
# iter=0, outs=1) sample-grasp:(4)->[(g57)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p96)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p96, g57)->[]
# Sampling for up to 0.190 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p97)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4146220486130724, 0.7232147084839358, -0.45396643209398907, -1.7269376795261238, 0.10632676531683208, 1.9076666130766085, 0.32343035190404157)
# go on
# q_grasp: (-0.4214149553484992, 0.7565514918323127, -0.4430704954980897, -1.8107676641982782, 0.1215901113395851, 2.023001410760455, 0.3131698887394583)
# iter=inf, outs=1) inverse-kinematics:(4, p97, g57)->[(q92, c110)]
# iter=inf, outs=1) test-cfree-traj-pose:(c110, 5, p95)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9423041884060136, 0.5806862769241551, -0.09687202459664623, -1.877247129615524, 0.22729663007276368, 1.950576631629773, 0.9706518620516507)
# go on
# q_grasp: (0.9514770005052784, 0.6169544583381473, -0.08418407628866093, -1.9586787500222456, 0.24768215812150873, 2.0682028270713277, 0.9576246813187703)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g57)->[(q93, c111)]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 4, p94)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p97, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p94, g57, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p97, g57, 5, p95)->[()]
# iter=inf, outs=1) plan-free-motion:(q92, q91)->[(c112)]
# iter=inf, outs=1) plan-free-motion:(q91, q93)->[(c113)]
# iter=inf, outs=1) plan-holding-motion:(q93, q92, 4, g57)->[(c114)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.398, sample_time: 0.179, search_time: 0.219, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6924 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8979 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30202 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5906 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2266 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3172 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6242 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11578 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1586784 function calls (1523183 primitive calls) in 0.701 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.104    0.035    0.105    0.035 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99824    0.060    0.000    0.076    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.193    0.097 /usr/lib/python2.7/pickle.py:851(load)
#   49991/1    0.037    0.000    0.090    0.090 /usr/lib/python2.7/pickle.py:269(save)
#    199924    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#         2    0.032    0.016    0.032    0.016 {posix.read}
#     99792    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#     49926    0.015    0.000    0.024    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#     99980    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q91 q93 c113
#  2) pick 4 p94 g57 q93 c111
#  3) move_holding q93 q92 4 g57 c114
#  4) place 4 p97 g57 q92 c110
#  5) move_free q92 q91 c112
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q94), ('AtConf', q94), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p98), ('AtPose', 4L, p98), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p98, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p99), ('AtPose', 5L, p99), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p99, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q94), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.096
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.235
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g22), inverse-kinematics:(4, p98, #g22)->(#q49, #t1901), test-cfree-traj-pose:(#t1901, 4, p98)->(), sample-pose:(4, 1)->(#p24), inverse-kinematics:(4, #p24, #g22)->(#q50, #t1902), test-cfree-traj-pose:(#t1902, 5, p99)->(), test-cfree-traj-pose:(#t1901, 5, p99)->(), test-cfree-pose-pose:(4, #p24, 5, p99)->(), test-cfree-approach-pose:(4, p98, #g22, 5, p99)->(), test-cfree-approach-pose:(4, #p24, #g22, 5, p99)->(), plan-free-motion:(#q50, q94)->(#t1943), plan-free-motion:(q94, #q49)->(#t1944), plan-holding-motion:(#q49, #q50, 4, #g22)->(#t1945)]
# Action plan (5, 0.000): [move_free(q94, #q49, #t1944), pick(4, p98, #g22, #q49, #t1901), move_holding(#q49, #q50, 4, #g22, #t1945), place(4, #p24, #g22, #q50, #t1902), move_free(#q50, q94, #t1943)]
# iter=0, outs=1) sample-grasp:(4)->[(g58)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g58)->[]
# Sampling for up to 0.223 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g59)]
# q_approach: (-0.6051752266837097, 1.4236449442224763, 1.3736971672423777, -2.579612977589119, -2.1541155507479712, 1.8310653978677442, 2.354237828311577)
# go on
# q_grasp: (-0.5494205972735643, 1.4616676985166466, 1.2653802344850225, -2.480222972498226, -2.2482740336297042, 1.884110373433792, 2.347700199241115)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.460620585522514, -1.5378085472753196, 1.849616336591094, -2.538595747334552, 2.005299704610922, 2.1919010695544006, 0.29981672952626515)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.717207014603605, 0.4990710217541687, -0.5469755923136913, -2.2443800679858805, 2.5397010515645917, 3.2628551283595897, -1.0213232249618125)
# go on
# q_grasp: (1.6594256670391294, 0.6490505682414648, -0.5143637330936656, -2.1618336385411263, 2.5459935250107346, 3.187332308192318, -0.9977688737837398)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g59)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g60)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.129940055450128, 0.6112390620831178, -1.0301197835992433, -2.42985678935642, 1.1009845671497966, 2.686536485053188, 0.462676375821035)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.71389979194755, -0.3047511583700157, -2.7157285208676014, -2.4840238282195815, -0.7004655246149153, 2.867543012046386, 1.7546519414316757)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g60)->[]
# iter=3, outs=1) sample-grasp:(4)->[(g61)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.17874639573274542, 1.1374769517538854, 1.2038521895773393, -1.8781811832346804, -0.8239896425998763, 1.7440369187911269, 1.6726923383992254)
# go on
# q_grasp: (-0.17824263677035704, 1.1769515945486235, 1.1425073567821773, -1.9404756615773726, -0.8847809822390776, 1.8295088103449486, 1.7021559584471642)
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.2344512348608219, 0.5848336302627009, -0.40251068241000093, -1.9249355941897155, 0.3938111913432734, 1.9703917896582388, 0.8572570055579846)
# go on
# q_grasp: (1.2386975322112856, 0.6342825024223652, -0.3743659824030847, -1.986296214063154, 0.43644233521834486, 2.075852723570028, 0.8314789091082417)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g61)->[]
# iter=4, outs=1) sample-grasp:(4)->[(g62)]
# q_approach: (1.2392375115479022, 0.5422879610910561, -0.3894675731172022, -1.9864798774207026, 0.37607602496574, 2.0612278080414583, 0.8724954805635704)
# go on
# q_grasp: (1.239536751201837, 0.5976231432528558, -0.3586717414459903, -2.044490057382021, 0.4229049652936962, 2.169663858062348, 0.8434999766154803)
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.783820951383597, 0.8473786468779795, -1.012486837532283, -1.9497664589368835, 0.8341620250756491, 1.831402685181252, 0.582553395738182)
# go on
# q_grasp: (1.7800865271836308, 0.8962516248642809, -0.9497434969582378, -1.9939576856445524, 0.9027144456640753, 1.909273999013711, 0.5511974629513501)
# iter=inf, outs=1) inverse-kinematics:(4, p98, g62)->[(q101, c115)]
# iter=inf, outs=1) test-cfree-traj-pose:(c115, 4, p98)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p100)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.593206118587994, 0.35416606193583394, -0.3105819867448346, -2.3853157801536806, -0.9345368916514414, 2.8710291314450456, -0.547692875286517)
# go on
# q_grasp: (-0.5888944430418368, 0.5162444662267394, -0.35866755309860265, -2.2995597880548875, -0.9907143472504004, 2.9664894484585296, -0.4812647483047807)
# iter=inf, outs=1) inverse-kinematics:(4, p100, g62)->[(q102, c116)]
# iter=inf, outs=1) test-cfree-traj-pose:(c116, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c115, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p100, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p98, g62, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p100, g62, 5, p99)->[()]
# iter=inf, outs=1) plan-free-motion:(q102, q94)->[(c117)]
# iter=inf, outs=1) plan-free-motion:(q94, q101)->[(c118)]
# iter=inf, outs=1) plan-holding-motion:(q101, q102, 4, g62)->[(c119)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 40, iterations: 3, length: 2, run_time: 0.563, sample_time: 0.294, search_time: 0.269, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6925 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8984 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30208 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5908 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2267 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3173 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6244 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11581 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1624438 function calls (1560803 primitive calls) in 0.844 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.127    0.042    0.127    0.042 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99852    0.054    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.179    0.090 /usr/lib/python2.7/pickle.py:851(load)
#   50008/1    0.037    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    199980    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#       388    0.030    0.000    0.030    0.000 {pybullet.calculateInverseKinematics}
#     99820    0.026    0.000    0.036    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.024    0.012    0.024    0.012 {posix.read}
#      3297    0.017    0.000    0.017    0.000 {pybullet.resetJointState}
#     49943    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q94 q101 c118
#  2) pick 4 p98 g62 q101 c115
#  3) move_holding q101 q102 4 g62 c119
#  4) place 4 p100 g62 q102 c116
#  5) move_free q102 q94 c117
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q103), ('AtConf', q103), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p101), ('AtPose', 4L, p101), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p101, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p102), ('AtPose', 5L, p102), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p102, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q103), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.019
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.027 | Sample Time: 0.000 | Total Time: 0.027
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.112
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.212
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g23), inverse-kinematics:(4, p101, #g23)->(#q51, #t1960), test-cfree-traj-pose:(#t1960, 5, p102)->(), sample-pose:(4, 1)->(#p25), inverse-kinematics:(4, #p25, #g23)->(#q52, #t1961), test-cfree-traj-pose:(#t1961, 5, p102)->(), test-cfree-traj-pose:(#t1960, 4, p101)->(), test-cfree-pose-pose:(4, #p25, 5, p102)->(), test-cfree-approach-pose:(4, p101, #g23, 5, p102)->(), test-cfree-approach-pose:(4, #p25, #g23, 5, p102)->(), plan-free-motion:(q103, #q51)->(#t2002), plan-free-motion:(#q52, q103)->(#t2003), plan-holding-motion:(#q51, #q52, 4, #g23)->(#t2004)]
# Action plan (5, 0.000): [move_free(q103, #q51, #t2002), pick(4, p101, #g23, #q51, #t1960), move_holding(#q51, #q52, 4, #g23, #t2004), place(4, #p25, #g23, #q52, #t1961), move_free(#q52, q103, #t2003)]
# iter=0, outs=1) sample-grasp:(4)->[(g63)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6258714181493832, 0.5921668573496742, -0.7633860313746874, -2.0827445706669643, 0.6059840666343767, 2.12533083457955, 0.726767308313793)
# go on
# q_grasp: (1.5992686215647776, 0.6653403690359281, -0.6959140140639104, -2.1112569265986587, 0.6881009814682999, 2.212560675836015, 0.6789875528302193)
# iter=inf, outs=1) inverse-kinematics:(4, p101, g63)->[(q104, c120)]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 5, p102)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p103)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2215517413249337, 0.3516141331126039, 0.29747090075794413, -2.3682587415318697, 0.531541765536062, 2.7784918344743295, 2.2587067101664733)
# go on
# q_grasp: (-1.2040515189769647, 0.49789320966600153, 0.3132095678680738, -2.3192172262036994, 0.5464177153539975, 2.8830421268426747, 2.2384659367052793)
# iter=inf, outs=1) inverse-kinematics:(4, p103, g63)->[(q105, c121)]
# iter=inf, outs=1) test-cfree-traj-pose:(c121, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 4, p101)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p103, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p101, g63, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p103, g63, 5, p102)->[()]
# iter=inf, outs=1) plan-free-motion:(q103, q104)->[(c122)]
# iter=inf, outs=1) plan-free-motion:(q105, q103)->[(c123)]
# iter=inf, outs=1) plan-holding-motion:(q104, q105, 4, g63)->[(c124)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.508, sample_time: 0.253, search_time: 0.255, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6926 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8985 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30210 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5910 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2268 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3174 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6246 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11584 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1578393 function calls (1514793 primitive calls) in 0.832 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.179    0.060    0.180    0.060 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99886    0.055    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#   50021/1    0.053    0.000    0.133    0.133 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.045    0.023    0.182    0.091 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.039    0.019    0.039    0.019 {posix.read}
#    200048    0.038    0.000    0.038    0.000 {method 'read' of 'file' objects}
#     99854    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49956    0.021    0.000    0.035    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100040    0.021    0.000    0.021    0.000 {method 'write' of 'file' objects}
#         2    0.018    0.009    0.018    0.009 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q103 q104 c122
#  2) pick 4 p101 g63 q104 c120
#  3) move_holding q104 q105 4 g63 c124
#  4) place 4 p103 g63 q105 c121
#  5) move_free q105 q103 c123
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q106), ('AtConf', q106), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p104), ('AtPose', 4L, p104), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p104, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p105), ('AtPose', 5L, p105), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p105, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q106), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g24), inverse-kinematics:(4, p104, #g24)->(#q53, #t2019), test-cfree-traj-pose:(#t2019, 4, p104)->(), sample-pose:(4, 1)->(#p26), inverse-kinematics:(4, #p26, #g24)->(#q54, #t2020), test-cfree-traj-pose:(#t2020, 5, p105)->(), test-cfree-traj-pose:(#t2019, 5, p105)->(), test-cfree-pose-pose:(4, #p26, 5, p105)->(), test-cfree-approach-pose:(4, p104, #g24, 5, p105)->(), test-cfree-approach-pose:(4, #p26, #g24, 5, p105)->(), plan-free-motion:(q106, #q53)->(#t2062), plan-free-motion:(#q54, q106)->(#t2063), plan-holding-motion:(#q53, #q54, 4, #g24)->(#t2061)]
# Action plan (5, 0.000): [move_free(q106, #q53, #t2062), pick(4, p104, #g24, #q53, #t2019), move_holding(#q53, #q54, 4, #g24, #t2061), place(4, #p26, #g24, #q54, #t2020), move_free(#q54, q106, #t2063)]
# iter=0, outs=1) sample-grasp:(4)->[(g64)]
# q_approach: (0.192120065456175, 0.5507885500113415, 0.6996004181985822, -2.120028026909611, -0.31944583175786967, 2.2458424224229803, 1.3644598539399206)
# go on
# q_grasp: (0.2355012004362731, 0.6298479819802765, 0.6389457089918664, -2.150846691214588, -0.387275341967781, 2.3485802281198036, 1.4084214406300628)
# iter=inf, outs=1) inverse-kinematics:(4, p104, g64)->[(q107, c125)]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 4, p104)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p106, g64)->[]
# Sampling for up to 0.182 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.04850148378346279, 0.5935509460890934, -0.9405148754347938, -2.216703621199621, 0.649400094786745, 2.160496025984867, 0.5051470742256251)
# go on
# q_grasp: (-0.0032312995073874714, 0.6707385780877653, -0.8440620615149829, -2.240055313868342, 0.7500890087786326, 2.245373512353603, 0.44619986822891633)
# iter=inf, outs=1) inverse-kinematics:(4, p107, g64)->[(q108, c126)]
# iter=inf, outs=1) test-cfree-traj-pose:(c126, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p107, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p104, g64, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p107, g64, 5, p105)->[()]
# iter=inf, outs=1) plan-free-motion:(q106, q107)->[(c127)]
# iter=inf, outs=1) plan-free-motion:(q108, q106)->[(c128)]
# iter=inf, outs=1) plan-holding-motion:(q107, q108, 4, g64)->[(c129)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.431, sample_time: 0.200, search_time: 0.231, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6928 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8986 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30213 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5912 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2269 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3175 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6248 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11587 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590542 function calls (1526913 primitive calls) in 0.740 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.111    0.037    0.112    0.037 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99912    0.058    0.000    0.074    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.024    0.188    0.094 /usr/lib/python2.7/pickle.py:851(load)
#   50035/1    0.041    0.000    0.102    0.102 /usr/lib/python2.7/pickle.py:269(save)
#    200100    0.034    0.000    0.034    0.000 {method 'read' of 'file' objects}
#         2    0.033    0.016    0.033    0.016 {posix.read}
#     99880    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49970    0.016    0.000    0.027    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100068    0.016    0.000    0.016    0.000 {method 'write' of 'file' objects}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q106 q107 c127
#  2) pick 4 p104 g64 q107 c125
#  3) move_holding q107 q108 4 g64 c129
#  4) place 4 p107 g64 q108 c126
#  5) move_free q108 q106 c128
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q109), ('AtConf', q109), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p108), ('AtPose', 4L, p108), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p108, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p109), ('AtPose', 5L, p109), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p109, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q109), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.178
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g25), sample-pose:(4, 1)->(#p27), inverse-kinematics:(4, #p27, #g25)->(#q56, #t2079), test-cfree-traj-pose:(#t2079, 5, p109)->(), inverse-kinematics:(4, p108, #g25)->(#q55, #t2078), test-cfree-traj-pose:(#t2078, 4, p108)->(), test-cfree-traj-pose:(#t2078, 5, p109)->(), test-cfree-pose-pose:(4, #p27, 5, p109)->(), test-cfree-approach-pose:(4, p108, #g25, 5, p109)->(), test-cfree-approach-pose:(4, #p27, #g25, 5, p109)->(), plan-free-motion:(#q56, q109)->(#t2121), plan-free-motion:(q109, #q55)->(#t2122), plan-holding-motion:(#q55, #q56, 4, #g25)->(#t2120)]
# Action plan (5, 0.000): [move_free(q109, #q55, #t2122), pick(4, p108, #g25, #q55, #t2078), move_holding(#q55, #q56, 4, #g25, #t2120), place(4, #p27, #g25, #q56, #t2079), move_free(#q56, q109, #t2121)]
# iter=0, outs=1) sample-grasp:(4)->[(g65)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p110)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.5217681844440692, 1.2497063160207205, -1.3138238471961572, -2.3180458030950035, 1.2502045493133906, 2.208513407822154, 1.5894036354803658)
# go on
# q_grasp: (0.4342072331098595, 1.293684961859948, -1.2012778571394627, -2.2771728227373607, 1.348189582093488, 2.2746134625997696, 1.543672137109852)
# Approach motion failed
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p110, g65)->[]
# Sampling for up to 0.173 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p111)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.2238007828552059, 0.6195245845566902, -1.0012289839782778, -2.360286950901237, 0.4023643377499472, 2.575011702036958, 2.3387252338147135)
# go on
# q_grasp: (0.07282095162398053, 0.7034744262953286, -0.8474678467296006, -2.3403988048280904, 0.4871741433601139, 2.6766219431673943, 2.278123828966335)
# iter=inf, outs=1) inverse-kinematics:(4, p111, g65)->[(q111, c130)]
# iter=inf, outs=1) test-cfree-traj-pose:(c130, 5, p109)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.2953546580612645, 0.2928546457784743, -0.41955314970829743, -2.57743258613227, -0.6468471516090225, 3.141816595233023, 1.8179728179768198)
# go on
# q_grasp: (1.285359243651392, 0.4804471324872723, -0.4189707342980187, -2.490843305451842, -0.628943206735579, 3.2496955344992204, 1.8345308590952234)
# Approach motion failed
# q_approach: (-1.5939740110777156, -0.3265470775204209, 2.624575519636656, -2.614803286689616, 0.15104275831516012, 3.1745713205234622, 1.1856096404426624)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p108, g65)->[]
# iter=1, outs=1) sample-grasp:(4)->[(g66)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.31674771729693757, 0.8468130236648528, -1.04200439558982, -2.0797521618228, 1.292522586567922, 1.6462263563508819, 1.111236773955241)
# go on
# ...
#  3) move_holding q286 q315 4 g102 c251
#  4) place 4 p184 g102 q315 c239
#  5) move_free q315 q322 c249
#  6) pick 4 p184 g104 q322 c245
#  7) move_holding q322 q319 4 g104 c252
#  8) place 4 p185 g104 q319 c243
#  9) move_free q319 q303 c248
# 10) pick 4 p185 g100 q303 c233
# 11) move_holding q303 q275 4 g100 c250
# 12) place 4 p175 g100 q275 c227
# 13) move_free q275 q273 c246
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q323), ('AtConf', q323), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p187), ('AtPose', 4L, p187), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p187, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p188), ('AtPose', 5L, p188), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p188, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q323), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.092
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g39), inverse-kinematics:(4, p187, #g39)->(#q124, #t6812), test-cfree-traj-pose:(#t6812, 4, p187)->(), test-cfree-traj-pose:(#t6812, 5, p188)->(), sample-pose:(4, 1)->(#p55), inverse-kinematics:(4, #p55, #g39)->(#q125, #t6813), test-cfree-traj-pose:(#t6813, 5, p188)->(), test-cfree-pose-pose:(4, #p55, 5, p188)->(), test-cfree-approach-pose:(4, p187, #g39, 5, p188)->(), test-cfree-approach-pose:(4, #p55, #g39, 5, p188)->(), plan-free-motion:(#q125, q323)->(#t6855), plan-free-motion:(q323, #q124)->(#t6856), plan-holding-motion:(#q124, #q125, 4, #g39)->(#t6854)]
# Action plan (5, 0.000): [move_free(q323, #q124, #t6856), pick(4, p187, #g39, #q124, #t6812), move_holding(#q124, #q125, 4, #g39, #t6854), place(4, #p55, #g39, #q125, #t6813), move_free(#q125, q323, #t6855)]
# iter=0, outs=1) sample-grasp:(4)->[(g105)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3913936235978617, 0.6473202107520545, -0.5811027389467883, -1.900133139286519, 0.5076304860483215, 1.9148299600943661, 0.781916790402671)
# go on
# q_grasp: (1.398103623530459, 0.6903477801426051, -0.5461776682705444, -1.96870440285634, 0.5584177305168011, 2.0175317388372718, 0.7516506681507357)
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9252176461857935, 0.5499701425495943, -0.07162518045062206, -1.924093777707574, 0.20833247549578734, 2.0041072069347488, 0.9843463195388161)
# go on
# q_grasp: (0.9327564158787751, 0.5967763503979702, -0.059341439252450265, -1.9919463400673665, 0.22759101392092934, 2.11858304937491, 0.9724612060070925)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p187, g105)->[]
# Sampling for up to 0.194 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.17631073013576, -0.4933263891832346, 2.228479048758484, -2.4210273363131987, 0.831968921098863, 2.6964918113921437, 0.6274784135221078)
# go on
# q_grasp: (-1.3397081947220357, -0.6124484020390284, 2.41739871424993, -2.3511509330287836, 1.0011247295408192, 2.7521988990371056, 0.5029594365338195)
# iter=inf, outs=1) inverse-kinematics:(4, p187, g106)->[(q326, c253)]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 4, p187)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 5, p188)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p189)]
# q_approach: (-2.3279233827442067, 0.6364385832627303, 1.1796690649194002, -2.5291811192723106, -1.0895847749141718, 2.583995130234229, 0.7000293126645228)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2776426030072112, 0.1968001149737276, 0.3024917278553469, -2.6201597327308193, 0.07150512557995935, 2.8789059050012162, -0.11023388619594422)
# go on
# q_grasp: (-1.2052666740182152, 0.35834396014592257, 0.2228711629221178, -2.5835872254045102, 0.010239247901524917, 3.0039797908166617, -0.06824290318793176)
# iter=inf, outs=1) inverse-kinematics:(4, p189, g106)->[(q327, c254)]
# iter=inf, outs=1) test-cfree-traj-pose:(c254, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p189, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p187, g106, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p189, g106, 5, p188)->[()]
# iter=inf, outs=1) plan-free-motion:(q327, q323)->[(c255)]
# iter=inf, outs=1) plan-free-motion:(q323, q326)->[(c256)]
# iter=inf, outs=1) plan-holding-motion:(q326, q327, 4, g106)->[(c257)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 37, iterations: 3, length: 2, run_time: 0.445, sample_time: 0.214, search_time: 0.230, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6986 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9028 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30443 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5947 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2290 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3196 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6290 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11705 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1605339 function calls (1541366 primitive calls) in 0.754 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.119    0.040    0.119    0.040 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100716    0.061    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.051    0.025    0.197    0.099 /usr/lib/python2.7/pickle.py:851(load)
#   50437/1    0.037    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    201708    0.036    0.000    0.036    0.000 {method 'read' of 'file' objects}
#    100684    0.030    0.000    0.041    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.028    0.014    0.028    0.014 {posix.read}
#         2    0.017    0.008    0.017    0.008 {posix.fork}
#    100872    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#     50372    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q323 q326 c256
#  2) pick 4 p187 g106 q326 c253
#  3) move_holding q326 q327 4 g106 c257
#  4) place 4 p189 g106 q327 c254
#  5) move_free q327 q323 c255
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q328), ('AtConf', q328), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p190), ('AtPose', 4L, p190), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p190, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p191), ('AtPose', 5L, p191), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p191, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q328), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.223
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g40), inverse-kinematics:(4, p190, #g40)->(#q126, #t6871), test-cfree-traj-pose:(#t6871, 5, p191)->(), test-cfree-traj-pose:(#t6871, 4, p190)->(), sample-pose:(4, 1)->(#p56), inverse-kinematics:(4, #p56, #g40)->(#q127, #t6872), test-cfree-traj-pose:(#t6872, 5, p191)->(), test-cfree-pose-pose:(4, #p56, 5, p191)->(), test-cfree-approach-pose:(4, p190, #g40, 5, p191)->(), test-cfree-approach-pose:(4, #p56, #g40, 5, p191)->(), plan-free-motion:(q328, #q126)->(#t6913), plan-free-motion:(#q127, q328)->(#t6915), plan-holding-motion:(#q126, #q127, 4, #g40)->(#t6914)]
# Action plan (5, 0.000): [move_free(q328, #q126, #t6913), pick(4, p190, #g40, #q126, #t6871), move_holding(#q126, #q127, 4, #g40, #t6914), place(4, #p56, #g40, #q127, #t6872), move_free(#q127, q328, #t6915)]
# iter=0, outs=1) sample-grasp:(4)->[(g107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4150246091802521, 1.2298875449035673, 1.3715062786356178, -2.210035248790946, -1.3123426805092073, 1.8936688794986642, 1.961933398401645)
# go on
# q_grasp: (-0.3753213593695801, 1.274773837173716, 1.26617175391218, -2.1974265254599317, -1.4031453163847043, 1.9545435621335112, 1.9861627345873272)
# iter=inf, outs=1) inverse-kinematics:(4, p190, g107)->[(q329, c258)]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 4, p190)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p192)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8899689531601122, 0.19880541274066688, -0.010427111186110756, -2.609277576096338, 0.01160885297981413, 2.8995182994797184, -2.377668987321695)
# go on
# q_grasp: (-0.8953571293780338, 0.36052263655602007, -0.003902137474369012, -2.5668661808489133, 0.016590275136949703, 3.0187008837854807, -2.3817649049534415)
# iter=inf, outs=1) inverse-kinematics:(4, p192, g107)->[(q330, c259)]
# iter=inf, outs=1) test-cfree-traj-pose:(c259, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p192, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p190, g107, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p192, g107, 5, p191)->[()]
# iter=inf, outs=1) plan-free-motion:(q328, q329)->[(c260)]
# iter=inf, outs=1) plan-free-motion:(q330, q328)->[(c261)]
# iter=inf, outs=1) plan-holding-motion:(q329, q330, 4, g107)->[(c262)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.461, sample_time: 0.208, search_time: 0.253, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6987 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9029 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30445 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5949 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2291 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3197 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6292 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11708 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590432 function calls (1526433 primitive calls) in 0.749 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.149    0.050    0.150    0.050 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100744    0.055    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.185    0.092 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.042    0.021    0.042    0.021 {posix.read}
#    201764    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   50450/1    0.038    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    100712    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.017    0.009    0.017    0.009 {posix.fork}
#     50385    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100898    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q328 q329 c260
#  2) pick 4 p190 g107 q329 c258
#  3) move_holding q329 q330 4 g107 c262
#  4) place 4 p192 g107 q330 c259
#  5) move_free q330 q328 c261

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_woFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	34496.5 ms/20 = 1724.8 ms (687.496/7622.712)
# sample_grasps_4: 	85.5 ms/20 = 4.3 ms (2.434/11.882)
# ik_fn: 	9237.5 ms/250 = 36.9 ms (7.103/346.615)
# check_feas: 	196.0 ms/250 = 0.8 ms (0.358/2.581)
# get_stable_4_1: 	38.3 ms/45 = 0.9 ms (0.42/1.737)
# free_motion_gen: 	2745.4 ms/47 = 58.4 ms (30.977/127.642)
# holding_motion_gen: 	1370.9 ms/27 = 50.8 ms (29.073/106.567)
# get_stable_4_2: 	16.7 ms/16 = 1.0 ms (0.558/1.901)
# get_stable_4_3: 	0.0 ms/4 = 0.0 ms (0.002/0.007)
# sample_grasps_5: 	4.8 ms/1 = 4.8 ms (4.782/4.782)
# get_stable_5_2: 	0.9 ms/1 = 0.9 ms (0.89/0.89)
#
# solve-mean: 1724.8 ms
# solve-median: 842.1 ms
# success rate: 100.0 %

# %% [markdown]
# ## play plan

# %%
SIMULATE = False
if (plan is None) or not has_gui():
    disconnect()
else:
    command = postprocess_plan(plan)
    if SIMULATE:
#         wait_for_user('Simulate?')
        command.control()
    else:
#         wait_for_user('Execute?')
        #command.step()
        command.refine(num_steps=10).execute(time_step=0.001)
