# %% [markdown]
# # Test runtime
# ### Test with IK checkers
#
# **grasp sample 10**
# solve-mean: 1175.2 ms
# solve-median: 740.8 ms
# success rate: 98.0 %
#
# **grasp sample 20**
# solve-mean: 1190.6 ms
# solve-median: 778.4 ms
# success rate: 96.5 %
#
# **grasp sample 30**
# solve-mean: 1323.0 ms
# solve-median: 837.4 ms
# success rate: 99.0 %
#
# ### Test without IK checkers
#
# **grasp sample 10**
# solve-mean: 1998.9 ms
# solve-median: 1241.1 ms
# success rate: 88.0 %

# %% [markdown]
# ## set running directory to project source

# %%
import os
import numpy as np
import time
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))
import matplotlib.pyplot as plt
from pkg.controller.combined_robot import *

# %% [markdown]
# # params

# %%
ROBOT_TYPE = RobotType.panda

if ROBOT_TYPE in [RobotType.indy7, RobotType.indy7gripper]:
    ROBOT_NAME = "indy0"
    TOOL_LINK = "indy0_tcp"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.14)
    
elif ROBOT_TYPE == RobotType.panda:
    ROBOT_NAME = "panda0"
    TOOL_LINK = "panda0_hand"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.112)
    
else:
    raise(NotImplementedError("Case not defined for {}".format(ROBOT_TYPE)))

# %% [markdown]
# ## 4.1 PlanningScene

# %% [markdown]
# ##### initialize CombinedRobot and GeometryScene

# %%
from pkg.project_config import *
from pkg.geometry.builder.scene_builder import SceneBuilder

s_builder = SceneBuilder(None)   # create scene builder without detector for virtual scene
crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, ((0,0,0), (0,0,0)), None)]
                     , connection_list=[False])
gscene = s_builder.create_gscene(crob)
gtems = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=True, collision=True)
gscene.show_pose(crob.home_pose)
# Out:
# connection command:
# panda0: False
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0, 0]
# Please create a subscriber to the marker

# %% [markdown]
# ##### add geometries

# %%
from pkg.geometry.geometry import *

# add environments (fixed=True for non-movable geometries)
wall = gscene.create_safe(GEOTYPE.BOX, "wall", "base_link", (3,3,0.01), (-0.2,0,0), 
                           rpy=(0,np.pi/2,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
floor = gscene.create_safe(GEOTYPE.BOX, "floor", "base_link", (0.72,1.52,0.01), (0.25,0,0), 
                           rpy=(0,0,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
goal = gscene.create_safe(GEOTYPE.BOX, "goal", "base_link", (0.1,0.1,0.01), (0.3,-0.4,0), 
                          rpy=(0,0,0), color=(0.2,0.2,0.8,1), display=True, fixed=True, collision=True)
 
# add movable (fixed=False for movable geometries)
box1 = gscene.create_safe(GEOTYPE.BOX, "box1", "base_link", (0.1,0.05,0.05), (0.3,0.4,0.031), 
                          rpy=(np.pi/2,0,np.pi/6), color=(0.8,0.2,0.2,1), display=True, fixed=False, collision=True)

box2 = gscene.create_safe(GEOTYPE.BOX, "box2", "base_link", (0.05,0.05,0.05), (0.5,0.4,0.031), 
                          rpy=(np.pi,0,0), color=(0.8,0.8,0.2,1), display=True, fixed=False, collision=True)

box1.permute_axis_match_z_link()
box2.permute_axis_match_z_link()

# %% [markdown]
# ##### create PlanningScene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

# %% [markdown]
# ##### create_binder
# - Binders (or Actors) are binding points where objects can be attached (or binded)
# - Examples are
#   - PlacePlane: plane for object placement
#   - Gripper2Tool: 2-finger gripper tool for grasp objects
#   - SweepTool: action point to pass waypoints for sweep task

# %%
from pkg.planning.constraint.constraint_actor import PlacePlane, Gripper2Tool, SweepFramer

# %%
# create PlacePlane on geometry "floor" and "goal"
# when point is not set, the entire upper surface of the geometry becomes valid binding area.
# when point is set, the specific point becomes the only valid binding point.
pscene.create_binder(bname="floor", gname="floor", _type=PlacePlane, point=None)
pscene.create_binder(bname="goal", gname="goal", _type=PlacePlane, point=None)

# %%
# add collision boundary for gripper base
# - set link_name="indy0_tcp" to attach the geometry to end-effector link
# - it can be labeled as fixed=True, as it is "fixed" on the indy0_tcp link
gripper =  gscene.create_safe(GEOTYPE.SPHERE, TOOL_NAME, link_name=TOOL_LINK, 
                                dims=(0.01,0.01,0.01), center=TOOL_XYZ, rpy=(-np.pi/2,0,0), 
                                color=(0.8,0.2,0.2,0.5), display=False, fixed=True, collision=False)

# create Gripper2Tool binder
# Gripper2Tool is a 2-finger gripper, which can rotate along z-direction.
# To align the z-direction with the 2 fingers, rotate by 90 degree along roll axis.
# The gripping point is (0,0,0.11) in local coordinate of "gripper" geometry
pscene.create_binder(bname=TOOL_NAME, gname=TOOL_NAME, _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))

# %% [markdown]
# ##### create_subject
# * Subject describes the tasks in the planning scene.
# * There are 2 categories in subject:
#   1. Object: The object has grip points and placement points for pick&place task
#   2. Task: The task is can be any non-physical task. Check SweepLineTask for example
# * The subjects can be composed of multiple action points. Examples are:
#   1. Grasp2Point: grasping point for 2-finger gripper.
#   2. PlacePoint: The point to place object.
#   3. SweepPoint: A waypoint for SweepLineTask.
#   * The above 3 action points inherit DirectePoint, for which the orientation is free along z-axis.
#   * If "point" parameter is not set, the entire upper surface is becomes valid action area.

# %%
from pkg.planning.constraint.constraint_subject import Grasp2Point, PlacePoint, SweepFrame
from pkg.planning.constraint.constraint_subject import CustomObject, SweepLineTask

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
box_obj = pscene.create_subject(oname="box1", gname="box1", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box1, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box1, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box1, [0,0,-0.026], [0,0,0])})

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
obs_obj = pscene.create_subject(oname="box2", gname="box2", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box2, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box2, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box2, [0,0,-0.026], [0,0,0])})

# %% [markdown]
# ## Pipeline

# %%
from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %%
from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ##### initialize_state
# * initialize_state(robot_pose) updates robot pose and gets corresponding binding status of current scene.
# * state.node of ('floor', 0) means the first subject (object) is placed on the floor and the second subject (sweep) has passed 0 waypoints

# %%
initial_state = pscene.initialize_state(crob.home_pose)
print(initial_state.node)
# Out:
# ('floor', 'floor')

# %% [markdown]
# ## import planners

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
mplan = MoveitPlanner(pscene)
from pkg.planning.filtering.grasp_filter import GraspChecker
from pkg.planning.filtering.reach_filter import ReachChecker
from pkg.planning.filtering.latticized_filter import LatticedChecker
from pkg.planning.filtering.task_clearance_filter import TaskClearanceChecker

gcheck = GraspChecker(pscene)
rcheck = ReachChecker(pscene)

checkers_all = [rcheck, gcheck]

# tcheck = TaskClearanceChecker(pscene, gcheck)
# checkers_all = [tcheck, rcheck, gcheck]

# lcheck = LatticedChecker(pscene, gcheck)
# checkers_all.append(lcheck)

# %% [markdown]
# ## Test pybullet

# %%
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src/scripts/developing/pddlstream'))

# %%
from convert_pscene import *
from plan_rnb import *

# %% [markdown]
# #### load pybullet, convert scene

# %%
connect_notebook(use_gui=False)
urdf_pybullet_path = copy_meshes(gscene)
robot_body, body_names, movable_bodies = pscene_to_pybullet(
    pscene, urdf_pybullet_path, tool_name=TOOL_NAME, name_exclude_list=[ROBOT_NAME])
print('Objects:', body_names)
saver = WorldSaver()
# Out:
# [Pybullet] Load urdf from /home/rnb/Projects/rnb-planning/src/robots/custom_robots_pybullet.urdf
# ('Objects:', {1L: 'goal', 2L: 'floor', 3L: 'wall', 4L: 'box1', 5L: 'box2'})

# %% [markdown]
# ### Test with IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_wFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=checkers_all,
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_wFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q0), ('AtConf', q0), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p0), ('AtPose', 4L, p0), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p0, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p1), ('AtPose', 5L, p1), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p1, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q0), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.077
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.211
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g0), sample-pose:(4, 1)->(#p0), inverse-kinematics:(4, #p0, #g0)->(#q1, #t15), test-cfree-traj-pose:(#t15, 5, p1)->(), inverse-kinematics:(4, p0, #g0)->(#q0, #t14), test-cfree-traj-pose:(#t14, 5, p1)->(), test-cfree-traj-pose:(#t14, 4, p0)->(), test-cfree-pose-pose:(4, #p0, 5, p1)->(), test-cfree-approach-pose:(4, p0, #g0, 5, p1)->(), test-cfree-approach-pose:(4, #p0, #g0, 5, p1)->(), plan-free-motion:(#q1, q0)->(#t56), plan-free-motion:(q0, #q0)->(#t57), plan-holding-motion:(#q0, #q1, 4, #g0)->(#t58)]
# Action plan (5, 0.000): [move_free(q0, #q0, #t57), pick(4, p0, #g0, #q0, #t14), move_holding(#q0, #q1, 4, #g0, #t58), place(4, #p0, #g0, #q1, #t15), move_free(#q1, q0, #t56)]
# iter=0, outs=1) sample-grasp:(4)->[(g0)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p2)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.10934100892808687, 0.5892939420103624, -0.792316762742401, -2.16195921514258, 0.6949602344811137, 2.479401972785107, 1.2853643104546078)
# go on
# q_grasp: (-0.19276657683141177, 0.6931403022933915, -0.6844522338772351, -2.1267540504242524, 0.7983490826826644, 2.545733442681981, 1.219179561569472)
# iter=inf, outs=1) inverse-kinematics:(4, p2, g0)->[(q1, c0)]
# iter=inf, outs=1) test-cfree-traj-pose:(c0, 5, p1)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.74307876509086, -0.3446907347795339, -2.653782364084008, -2.3860496800872797, -0.3578403988343666, 2.6695065272288376, 1.4446060303171162)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.7082456254472143, 0.41540250835955445, -0.7210937178628472, -2.3687773593032833, 0.5637329522913839, 2.6216869104686844, 0.7914830402979092)
# go on
# q_grasp: (1.6008026810977196, 0.535350255160236, -0.5833189727948819, -2.3313399501628616, 0.7057624543115247, 2.6959199317544047, 0.6914185041154357)
# iter=inf, outs=1) inverse-kinematics:(4, p0, g0)->[(q3, c1)]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 4, p0)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p2, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p0, g0, 5, p1)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p2, g0, 5, p1)->[()]
# iter=inf, outs=1) plan-free-motion:(q1, q0)->[(c2)]
# iter=inf, outs=1) plan-free-motion:(q0, q3)->[(c3)]
# iter=inf, outs=1) plan-holding-motion:(q3, q1, 4, g0)->[(c4)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.778, sample_time: 0.528, search_time: 0.250, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7819 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9885 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37625 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6132 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2381 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3296 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6481 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12075 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1668202 function calls (1601378 primitive calls) in 1.064 seconds
#
#    Ordered by: internal time
#    List reduced from 1573 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.429    0.143    0.430    0.143 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106322    0.055    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.045    0.022    0.178    0.089 /usr/lib/python2.7/pickle.py:851(load)
#   53239/1    0.037    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    212920    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#         2    0.033    0.017    0.033    0.017 {posix.read}
#    106290    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     53174    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    106476    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#         2    0.013    0.007    0.013    0.007 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q0 q3 c3
#  2) pick 4 p0 g0 q3 c1
#  3) move_holding q3 q1 4 g0 c4
#  4) place 4 p2 g0 q1 c0
#  5) move_free q1 q0 c2
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q4), ('AtConf', q4), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p3), ('AtPose', 4L, p3), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p3, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p4), ('AtPose', 5L, p4), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p4, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q4), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.089
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.184
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g1), sample-pose:(4, 1)->(#p1), inverse-kinematics:(4, #p1, #g1)->(#q3, #t74), test-cfree-traj-pose:(#t74, 5, p4)->(), inverse-kinematics:(4, p3, #g1)->(#q2, #t73), test-cfree-traj-pose:(#t73, 4, p3)->(), test-cfree-traj-pose:(#t73, 5, p4)->(), test-cfree-pose-pose:(4, #p1, 5, p4)->(), test-cfree-approach-pose:(4, p3, #g1, 5, p4)->(), test-cfree-approach-pose:(4, #p1, #g1, 5, p4)->(), plan-free-motion:(q4, #q2)->(#t115), plan-free-motion:(#q3, q4)->(#t117), plan-holding-motion:(#q2, #q3, 4, #g1)->(#t116)]
# Action plan (5, 0.000): [move_free(q4, #q2, #t115), pick(4, p3, #g1, #q2, #t73), move_holding(#q2, #q3, 4, #g1, #t116), place(4, #p1, #g1, #q3, #t74), move_free(#q3, q4, #t117)]
# iter=0, outs=1) sample-grasp:(4)->[(g1)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p5)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p5, g1)->[]
# Sampling for up to 0.184 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p6)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.8782945350660354, 0.4537744297968076, 0.8033758715975337, -2.347384968803189, -0.6244673394322005, 2.5459231533345887, -2.18652927412961)
# go on
# q_grasp: (-1.7761889321858735, 0.5658307700704293, 0.6682426631515505, -2.3181457730895514, -0.7636456701552323, 2.6172718830936708, -2.0921303958787)
# iter=inf, outs=1) inverse-kinematics:(4, p6, g1)->[(q5, c5)]
# iter=inf, outs=1) test-cfree-traj-pose:(c5, 5, p4)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.9290423730866645, -0.8436999102069188, 1.931733152401079, -2.3267289412918313, 1.17851269832373, 2.309254248843928, 0.4275757357492453)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.5074043617893091, -0.3709708637389834, 2.5007426812570515, -2.4056819840251786, 0.48031642973621247, 2.694816075385913, 0.8559599482327461)
# go on
# q_grasp: (-1.6272057535823727, -0.5033663768761202, 2.648543502007755, -2.3593232799976867, 0.6287028553191047, 2.7767755636204137, 0.7464383131184961)
# iter=inf, outs=1) inverse-kinematics:(4, p3, g1)->[(q6, c6)]
# iter=inf, outs=1) test-cfree-traj-pose:(c6, 4, p3)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c6, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p6, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p3, g1, 5, p4)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p6, g1, 5, p4)->[()]
# iter=inf, outs=1) plan-free-motion:(q4, q6)->[(c7)]
# iter=inf, outs=1) plan-free-motion:(q5, q4)->[(c8)]
# iter=inf, outs=1) plan-holding-motion:(q6, q5, 4, g1)->[(c9)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.697, sample_time: 0.484, search_time: 0.213, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7821 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9886 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37628 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6134 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2382 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3297 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6483 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12078 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1678028 function calls (1611171 primitive calls) in 1.030 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.392    0.131    0.395    0.132 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106348    0.069    0.000    0.088    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.056    0.028    0.221    0.110 /usr/lib/python2.7/pickle.py:851(load)
#    212972    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   53253/1    0.038    0.000    0.093    0.093 /usr/lib/python2.7/pickle.py:269(save)
#    106316    0.034    0.000    0.047    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.027    0.014    0.027    0.014 {posix.read}
#     53188    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    106504    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#    106502    0.014    0.000    0.014    0.000 {method 'readline' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q4 q6 c7
#  2) pick 4 p3 g1 q6 c6
#  3) move_holding q6 q5 4 g1 c9
#  4) place 4 p6 g1 q5 c5
#  5) move_free q5 q4 c8
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q7), ('AtConf', q7), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p7), ('AtPose', 4L, p7), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p7, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p8), ('AtPose', 5L, p8), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p8, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q7), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.082
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.186
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g2), sample-pose:(4, 1)->(#p2), inverse-kinematics:(4, #p2, #g2)->(#q5, #t133), test-cfree-traj-pose:(#t133, 5, p8)->(), inverse-kinematics:(4, p7, #g2)->(#q4, #t132), test-cfree-traj-pose:(#t132, 5, p8)->(), test-cfree-traj-pose:(#t132, 4, p7)->(), test-cfree-pose-pose:(4, #p2, 5, p8)->(), test-cfree-approach-pose:(4, p7, #g2, 5, p8)->(), test-cfree-approach-pose:(4, #p2, #g2, 5, p8)->(), plan-free-motion:(q7, #q4)->(#t174), plan-free-motion:(#q5, q7)->(#t175), plan-holding-motion:(#q4, #q5, 4, #g2)->(#t176)]
# Action plan (5, 0.000): [move_free(q7, #q4, #t174), pick(4, p7, #g2, #q4, #t132), move_holding(#q4, #q5, 4, #g2, #t176), place(4, #p2, #g2, #q5, #t133), move_free(#q5, q7, #t175)]
# iter=0, outs=1) sample-grasp:(4)->[(g2)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p9)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.920466196602329, 0.6797039874590277, 0.9962137051668274, -2.2239185557192434, -0.7949252491890424, 2.4127403507975247, -0.7890513914538743)
# go on
# q_grasp: (-1.823897002700759, 0.7640582570928816, 0.871128671371908, -2.199393215954722, -0.8998865460090355, 2.4818458107450643, -0.7243234596331138)
# iter=inf, outs=1) inverse-kinematics:(4, p9, g2)->[(q8, c10)]
# iter=inf, outs=1) test-cfree-traj-pose:(c10, 5, p8)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.7270466418207873, -0.9932991127047501, -1.8491445138773215, -2.336063520638842, -1.375710116147488, 2.1701568544349845, 2.0646359539917776)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.7198701869823054, 0.3912459386653452, -0.7028744278962319, -2.427550234416957, 0.5666497471856369, 2.7432957411557144, 0.8022660297420818)
# go on
# q_grasp: (1.5782173355662246, 0.5189274419719031, -0.5333971751824431, -2.372169872448102, 0.7225969908085779, 2.817635912672256, 0.6852528150458388)
# iter=inf, outs=1) inverse-kinematics:(4, p7, g2)->[(q10, c11)]
# iter=inf, outs=1) test-cfree-traj-pose:(c11, 5, p8)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c11, 4, p7)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p9, 5, p8)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p7, g2, 5, p8)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p9, g2, 5, p8)->[()]
# iter=inf, outs=1) plan-free-motion:(q7, q10)->[(c12)]
# iter=inf, outs=1) plan-free-motion:(q8, q7)->[(c13)]
# iter=inf, outs=1) plan-holding-motion:(q10, q8, 4, g2)->[(c14)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.876, sample_time: 0.660, search_time: 0.217, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7822 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9887 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37630 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6136 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2383 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3298 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6485 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12081 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1672110 function calls (1605311 primitive calls) in 1.186 seconds
#
#    Ordered by: internal time
#    List reduced from 1507 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.584    0.195    0.585    0.195 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106376    0.061    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.200    0.100 /usr/lib/python2.7/pickle.py:851(load)
#    213028    0.041    0.000    0.041    0.000 {method 'read' of 'file' objects}
#   53266/1    0.038    0.000    0.093    0.093 /usr/lib/python2.7/pickle.py:269(save)
#    106344    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.026    0.013    0.026    0.013 {posix.read}
#     53201    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    106530    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#    106530    0.013    0.000    0.013    0.000 {method 'readline' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q7 q10 c12
#  2) pick 4 p7 g2 q10 c11
#  3) move_holding q10 q8 4 g2 c14
#  4) place 4 p9 g2 q8 c10
#  5) move_free q8 q7 c13
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q11), ('AtConf', q11), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p10), ('AtPose', 4L, p10), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p10, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p11), ('AtPose', 5L, p11), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p11, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q11), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.161
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.264
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g3), inverse-kinematics:(4, p10, #g3)->(#q6, #t191), test-cfree-traj-pose:(#t191, 5, p11)->(), sample-pose:(4, 1)->(#p3), inverse-kinematics:(4, #p3, #g3)->(#q7, #t192), test-cfree-traj-pose:(#t192, 5, p11)->(), test-cfree-traj-pose:(#t191, 4, p10)->(), test-cfree-pose-pose:(4, #p3, 5, p11)->(), test-cfree-approach-pose:(4, p10, #g3, 5, p11)->(), test-cfree-approach-pose:(4, #p3, #g3, 5, p11)->(), plan-free-motion:(q11, #q6)->(#t234), plan-free-motion:(#q7, q11)->(#t235), plan-holding-motion:(#q6, #q7, 4, #g3)->(#t233)]
# Action plan (5, 0.000): [move_free(q11, #q6, #t234), pick(4, p10, #g3, #q6, #t191), move_holding(#q6, #q7, 4, #g3, #t233), place(4, #p3, #g3, #q7, #t192), move_free(#q7, q11, #t235)]
# iter=0, outs=1) sample-grasp:(4)->[(g3)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.9790131014127287, -0.6493275766080626, 2.066265620778033, -2.4148441668570126, 1.1161902196266673, 2.6224511581158545, 0.45779884715929836)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.07940491793071679, 0.47732916872134884, 0.9102520659628162, -2.4257580655920488, -1.0525198710194206, 2.6713360697741426, 1.974790461975729)
# go on
# q_grasp: (0.0552867184618701, 0.6156771516189624, 0.7457916554067322, -2.342013356494441, -1.2430002085111866, 2.6911922397830335, 2.10599019807848)
# iter=inf, outs=1) inverse-kinematics:(4, p10, g3)->[(q12, c15)]
# iter=inf, outs=1) test-cfree-traj-pose:(c15, 5, p11)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p12)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.5152565876890202, 1.257793286025664, -1.3516122307988188, -2.1941770545536103, 1.293913043514179, 2.011483858229404, 1.7936526238173873)
# go on
# q_grasp: (0.45761042550807535, 1.305416301321453, -1.2471197820828648, -2.1675262652690233, 1.3830609382750796, 2.0734383767919162, 1.7646064699234543)
# Approach motion failed
# iter=inf, outs=0) inverse-kinematics:(4, p12, g3)->[]
# Sampling for up to 0.236 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p13)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.015331011499736, 0.6168785961733265, 1.1128614770859568, -2.3590325660013454, -0.9303674101187468, 2.2786567789820817, -2.3937707800297763)
# go on
# q_grasp: (-1.9190284943432794, 0.7060000593412551, 0.9647447346540433, -2.341352311095217, -1.0650203250812784, 2.336628769883511, -2.3181967312441616)
# iter=inf, outs=1) inverse-kinematics:(4, p13, g3)->[(q14, c16)]
# iter=inf, outs=1) test-cfree-traj-pose:(c16, 5, p11)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c15, 4, p10)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p13, 5, p11)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p10, g3, 5, p11)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p13, g3, 5, p11)->[()]
# iter=inf, outs=1) plan-free-motion:(q11, q12)->[(c17)]
# iter=inf, outs=1) plan-free-motion:(q14, q11)->[(c18)]
# iter=inf, outs=1) plan-holding-motion:(q12, q14, 4, g3)->[(c19)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.873, sample_time: 0.576, search_time: 0.297, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7824 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9888 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37633 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6138 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2384 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3299 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6487 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12084 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1684846 function calls (1617528 primitive calls) in 1.186 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.456    0.152    0.459    0.153 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#       227    0.089    0.000    0.089    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/downward.py:329(<genexpr>)
#    106402    0.064    0.000    0.084    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.052    0.026    0.209    0.105 /usr/lib/python2.7/pickle.py:851(load)
#   53280/1    0.038    0.000    0.094    0.094 /usr/lib/python2.7/pickle.py:269(save)
#    213080    0.037    0.000    0.037    0.000 {method 'read' of 'file' objects}
#    106370    0.032    0.000    0.044    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.028    0.014    0.028    0.014 {posix.read}
#    106556    0.015    0.000    0.015    0.000 {method 'readline' of 'file' objects}
#     53215    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q11 q12 c17
#  2) pick 4 p10 g3 q12 c15
#  3) move_holding q12 q14 4 g3 c19
#  4) place 4 p13 g3 q14 c16
#  5) move_free q14 q11 c18
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q15), ('AtConf', q15), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p14), ('AtPose', 4L, p14), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p14, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p15), ('AtPose', 5L, p15), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p15, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q15), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.093
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.205
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g4), inverse-kinematics:(4, p14, #g4)->(#q8, #t250), test-cfree-traj-pose:(#t250, 5, p15)->(), test-cfree-traj-pose:(#t250, 4, p14)->(), sample-pose:(4, 1)->(#p4), inverse-kinematics:(4, #p4, #g4)->(#q9, #t251), test-cfree-traj-pose:(#t251, 5, p15)->(), test-cfree-pose-pose:(4, #p4, 5, p15)->(), test-cfree-approach-pose:(4, p14, #g4, 5, p15)->(), test-cfree-approach-pose:(4, #p4, #g4, 5, p15)->(), plan-free-motion:(q15, #q8)->(#t293), plan-free-motion:(#q9, q15)->(#t294), plan-holding-motion:(#q8, #q9, 4, #g4)->(#t292)]
# Action plan (5, 0.000): [move_free(q15, #q8, #t293), pick(4, p14, #g4, #q8, #t250), move_holding(#q8, #q9, 4, #g4, #t292), place(4, #p4, #g4, #q9, #t251), move_free(#q9, q15, #t294)]
# iter=0, outs=1) sample-grasp:(4)->[(g4)]
# iter=inf, outs=0) inverse-kinematics:(4, p14, g4)->[]
# Sampling for up to 0.221 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g5)]
# iter=inf, outs=0) inverse-kinematics:(4, p14, g5)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g6)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.454342464073836, 0.3864997383548468, -0.2608788943778279, -2.637168458948141, 0.7159359771972922, 3.4639269715262775, 0.7621944741041806)
# go on
# q_grasp: (1.2787905853283419, 0.5423687534611177, -0.14123039438754603, -2.539031631774001, 0.5893895300859681, 3.5308523573065274, 0.8373735619412803)
# iter=inf, outs=1) inverse-kinematics:(4, p14, g6)->[(q16, c20)]
# iter=inf, outs=1) test-cfree-traj-pose:(c20, 5, p15)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c20, 4, p14)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p16)]
# q_approach: (1.6155021444814557, -0.38749648893963967, -2.673784913918087, -2.6708849600633466, 0.10978036548709913, 3.4903714350428965, 0.3834054508757646)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.585898413826788, 0.3541908871154088, -0.3002888714824789, -2.373096214180423, 2.0700559089899784, 3.022350344662343, -1.2652210253509264)
# go on
# q_grasp: (-0.564844428489498, 0.5258370170652383, -0.32837028504111976, -2.253506012813525, 2.1731381183382075, 2.9598512335357707, -1.3296717787838426)
# iter=inf, outs=1) inverse-kinematics:(4, p16, g6)->[(q18, c21)]
# iter=inf, outs=1) test-cfree-traj-pose:(c21, 5, p15)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p16, 5, p15)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p14, g6, 5, p15)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p16, g6, 5, p15)->[()]
# iter=inf, outs=1) plan-free-motion:(q15, q16)->[(c22)]
# iter=inf, outs=1) plan-free-motion:(q18, q15)->[(c23)]
# iter=inf, outs=1) plan-holding-motion:(q16, q18, 4, g6)->[(c24)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.871, sample_time: 0.633, search_time: 0.238, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7825 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9891 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37637 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6140 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2385 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3300 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6489 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12087 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1675193 function calls (1608259 primitive calls) in 1.214 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.528    0.176    0.531    0.177 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106430    0.068    0.000    0.087    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.054    0.027    0.219    0.109 /usr/lib/python2.7/pickle.py:851(load)
#   53295/1    0.044    0.000    0.110    0.110 /usr/lib/python2.7/pickle.py:269(save)
#    213136    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#    106398    0.034    0.000    0.046    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.024    0.012    0.024    0.012 {posix.read}
#     53230    0.018    0.000    0.030    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    106588    0.017    0.000    0.017    0.000 {method 'write' of 'file' objects}
#         2    0.016    0.008    0.016    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q15 q16 c22
#  2) pick 4 p14 g6 q16 c20
#  3) move_holding q16 q18 4 g6 c24
#  4) place 4 p16 g6 q18 c21
#  5) move_free q18 q15 c23
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q19), ('AtConf', q19), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p17), ('AtPose', 4L, p17), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p17, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p18), ('AtPose', 5L, p18), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p18, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q19), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.084
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.184
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g5), sample-pose:(4, 1)->(#p5), inverse-kinematics:(4, #p5, #g5)->(#q11, #t310), test-cfree-traj-pose:(#t310, 5, p18)->(), inverse-kinematics:(4, p17, #g5)->(#q10, #t309), test-cfree-traj-pose:(#t309, 4, p17)->(), test-cfree-traj-pose:(#t309, 5, p18)->(), test-cfree-pose-pose:(4, #p5, 5, p18)->(), test-cfree-approach-pose:(4, p17, #g5, 5, p18)->(), test-cfree-approach-pose:(4, #p5, #g5, 5, p18)->(), plan-free-motion:(q19, #q10)->(#t351), plan-free-motion:(#q11, q19)->(#t352), plan-holding-motion:(#q10, #q11, 4, #g5)->(#t353)]
# Action plan (5, 0.000): [move_free(q19, #q10, #t351), pick(4, p17, #g5, #q10, #t309), move_holding(#q10, #q11, 4, #g5, #t353), place(4, #p5, #g5, #q11, #t310), move_free(#q11, q19, #t352)]
# iter=0, outs=1) sample-grasp:(4)->[(g7)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p19)]
# iter=inf, outs=0) inverse-kinematics:(4, p19, g7)->[]
# Sampling for up to 0.199 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p20)]
# iter=inf, outs=0) inverse-kinematics:(4, p20, g7)->[]
# iter=1, outs=1) sample-grasp:(4)->[(g8)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9874899230572539, -0.5876874656271404, -2.0918570552242155, -2.4872517174820326, -1.4768232167072355, 2.715623077634127, -1.2415144442422814)
# go on
# q_grasp: (1.1160781018249446, -0.7367377732812873, -2.231528314980434, -2.3845021624631118, -1.6527801717464983, 2.679817972054036, -1.1354975331419983)
# iter=inf, outs=1) inverse-kinematics:(4, p19, g8)->[(q20, c25)]
# iter=inf, outs=1) test-cfree-traj-pose:(c25, 5, p18)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.5154131531500477, 0.5100367337878966, -0.6313796811692178, -2.1291236951274235, 0.5022033491486942, 2.2209092941061255, 0.797674455428133)
# go on
# q_grasp: (1.4863740495510949, 0.5939193637740527, -0.5680571186212331, -2.1500524273140584, 0.5851403278341444, 2.3124442141601405, 0.7464993690909054)
# iter=inf, outs=1) inverse-kinematics:(4, p17, g8)->[(q21, c26)]
# iter=inf, outs=1) test-cfree-traj-pose:(c26, 4, p17)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c26, 5, p18)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p19, 5, p18)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p17, g8, 5, p18)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p19, g8, 5, p18)->[()]
# iter=inf, outs=1) plan-free-motion:(q19, q21)->[(c27)]
# iter=inf, outs=1) plan-free-motion:(q20, q19)->[(c28)]
# iter=inf, outs=1) plan-holding-motion:(q21, q20, 4, g8)->[(c29)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 39, iterations: 3, length: 2, run_time: 0.704, sample_time: 0.488, search_time: 0.216, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7827 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9893 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37641 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6142 | p_success: 0.894 | overhead: 0.123
# External: plan-holding-motion | n: 2386 | p_success: 0.991 | overhead: 0.058
# External: test-cfree-pose-pose | n: 3301 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6491 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12090 | p_success: 0.939 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1677644 function calls (1610707 primitive calls) in 1.001 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.408    0.136    0.410    0.137 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106460    0.059    0.000    0.075    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.047    0.024    0.193    0.096 /usr/lib/python2.7/pickle.py:851(load)
#    213196    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   53310/1    0.038    0.000    0.094    0.094 /usr/lib/python2.7/pickle.py:269(save)
#    106428    0.028    0.000    0.039    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.027    0.013    0.027    0.013 {posix.read}
#     53245    0.016    0.000    0.026    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    106618    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#         2    0.013    0.006    0.013    0.006 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q19 q21 c27
#  2) pick 4 p17 g8 q21 c26
#  3) move_holding q21 q20 4 g8 c29
#  4) place 4 p19 g8 q20 c25
#  5) move_free q20 q19 c28
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q22), ('AtConf', q22), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p21), ('AtPose', 4L, p21), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p21, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p22), ('AtPose', 5L, p22), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p22, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q22), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.075
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.164
# ...
#    214080    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#    106870    0.030    0.000    0.041    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.027    0.014    0.027    0.014 {posix.read}
#     53466    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    107060    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#         2    0.013    0.006    0.013    0.006 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q143 q144 c102
#  2) pick 4 p71 g33 q144 c100
#  3) move_holding q144 q145 4 g33 c104
#  4) place 4 p73 g33 q145 c101
#  5) move_free q145 q143 c103
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q146), ('AtConf', q146), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p74), ('AtPose', 4L, p74), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p74, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p75), ('AtPose', 5L, p75), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p75, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q146), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.009 | Sample Time: 0.000 | Total Time: 0.009
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.019 | Sample Time: 0.000 | Total Time: 0.019
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.077
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.194
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g18), inverse-kinematics:(4, p74, #g18)->(#q42, #t2514), test-cfree-traj-pose:(#t2514, 4, p74)->(), test-cfree-traj-pose:(#t2514, 5, p75)->(), sample-pose:(4, 1)->(#p20), inverse-kinematics:(4, #p20, #g18)->(#q43, #t2515), test-cfree-traj-pose:(#t2515, 5, p75)->(), test-cfree-pose-pose:(4, #p20, 5, p75)->(), test-cfree-approach-pose:(4, p74, #g18, 5, p75)->(), test-cfree-approach-pose:(4, #p20, #g18, 5, p75)->(), plan-free-motion:(q146, #q42)->(#t2556), plan-free-motion:(#q43, q146)->(#t2557), plan-holding-motion:(#q42, #q43, 4, #g18)->(#t2558)]
# Action plan (5, 0.000): [move_free(q146, #q42, #t2556), pick(4, p74, #g18, #q42, #t2514), move_holding(#q42, #q43, 4, #g18, #t2558), place(4, #p20, #g18, #q43, #t2515), move_free(#q43, q146, #t2557)]
# iter=0, outs=1) sample-grasp:(4)->[(g34)]
# iter=inf, outs=0) inverse-kinematics:(4, p74, g34)->[]
# Sampling for up to 0.211 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g35)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.02284937803460222, 0.5779509211783844, 0.863554380722857, -2.198138191312155, -0.5152151485467599, 2.325887384424954, 1.50919206516413)
# go on
# q_grasp: (0.09582618646275567, 0.6657800332825785, 0.7642392687096646, -2.2047196835555924, -0.6101229859689566, 2.4148985297236973, 1.569631628938754)
# iter=inf, outs=1) inverse-kinematics:(4, p74, g35)->[(q147, c105)]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 4, p74)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 5, p75)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p76)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p76, g35)->[]
# iter=1, outs=1) sample-pose:(4, 1)->[(p77)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.23222104384041667, 0.3537459869157115, -0.6297563952235388, -2.513040089587895, 0.5068874297222296, 2.944442689574613, -2.2528990238917235)
# go on
# q_grasp: (-0.45616434048415355, 0.4917865273149014, -0.38845100780877484, -2.4332842568166493, 0.6495574578234825, 3.033590580251679, -2.3765686137889315)
# iter=inf, outs=1) inverse-kinematics:(4, p77, g35)->[(q148, c106)]
# iter=inf, outs=1) test-cfree-traj-pose:(c106, 5, p75)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p77, 5, p75)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p74, g35, 5, p75)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p77, g35, 5, p75)->[()]
# iter=inf, outs=1) plan-free-motion:(q146, q147)->[(c107)]
# iter=inf, outs=1) plan-free-motion:(q148, q146)->[(c108)]
# iter=inf, outs=1) plan-holding-motion:(q147, q148, 4, g35)->[(c109)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 39, iterations: 3, length: 2, run_time: 0.810, sample_time: 0.581, search_time: 0.229, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7859 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9920 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37775 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6171 | p_success: 0.894 | overhead: 0.124
# External: plan-holding-motion | n: 2400 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3315 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6520 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12145 | p_success: 0.940 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1692091 function calls (1624928 primitive calls) in 1.134 seconds
#
#    Ordered by: internal time
#    List reduced from 1508 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.480    0.160    0.483    0.161 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106932    0.067    0.000    0.087    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.056    0.028    0.219    0.110 /usr/lib/python2.7/pickle.py:851(load)
#    214140    0.040    0.000    0.040    0.000 {method 'read' of 'file' objects}
#   53546/1    0.038    0.000    0.096    0.096 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.035    0.018    0.035    0.018 {posix.read}
#    106900    0.033    0.000    0.046    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#    107090    0.016    0.000    0.016    0.000 {method 'write' of 'file' objects}
#     53481    0.015    0.000    0.026    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    107086    0.014    0.000    0.014    0.000 {method 'readline' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q146 q147 c107
#  2) pick 4 p74 g35 q147 c105
#  3) move_holding q147 q148 4 g35 c109
#  4) place 4 p77 g35 q148 c106
#  5) move_free q148 q146 c108
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q149), ('AtConf', q149), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p78), ('AtPose', 4L, p78), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p78, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p79), ('AtPose', 5L, p79), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p79, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q149), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.017 | Sample Time: 0.000 | Total Time: 0.017
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.079
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.180
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g19), sample-pose:(4, 1)->(#p21), inverse-kinematics:(4, #p21, #g19)->(#q45, #t2574), test-cfree-traj-pose:(#t2574, 5, p79)->(), inverse-kinematics:(4, p78, #g19)->(#q44, #t2573), test-cfree-traj-pose:(#t2573, 4, p78)->(), test-cfree-traj-pose:(#t2573, 5, p79)->(), test-cfree-pose-pose:(4, #p21, 5, p79)->(), test-cfree-approach-pose:(4, p78, #g19, 5, p79)->(), test-cfree-approach-pose:(4, #p21, #g19, 5, p79)->(), plan-free-motion:(#q45, q149)->(#t2616), plan-free-motion:(q149, #q44)->(#t2617), plan-holding-motion:(#q44, #q45, 4, #g19)->(#t2615)]
# Action plan (5, 0.000): [move_free(q149, #q44, #t2617), pick(4, p78, #g19, #q44, #t2573), move_holding(#q44, #q45, 4, #g19, #t2615), place(4, #p21, #g19, #q45, #t2574), move_free(#q45, q149, #t2616)]
# iter=0, outs=1) sample-grasp:(4)->[(g36)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p80)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.183480948809101, 0.9535632429875972, 1.1400985453230073, -2.0630489023670937, -0.7984238599070421, 2.1267734323261065, -1.0714204394949995)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3098463600159687, -0.5944647427488272, -2.3933779746392645, -2.109231395932361, -0.28111761989287626, 2.328950074407459, -1.401923704814848)
# go on
# q_grasp: (1.370415155841778, -0.6779606364107351, -2.462096662178128, -2.126511226419855, -0.34567258673053936, 2.4286718254024873, -1.3594515510016931)
# iter=inf, outs=1) inverse-kinematics:(4, p80, g36)->[(q150, c110)]
# iter=inf, outs=1) test-cfree-traj-pose:(c110, 5, p79)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.7043179278531632, 0.2835393180709108, 0.12394323857705146, -2.511222239823445, -0.9835101826169922, 3.002382433579061, 2.0437020826828016)
# go on
# q_grasp: (0.8227608431230432, 0.44960358063678996, -0.024752661003849742, -2.393119174853745, -1.1691123672541004, 3.070240121031931, 2.2229095311417706)
# iter=inf, outs=1) inverse-kinematics:(4, p78, g36)->[(q151, c111)]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 4, p78)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 5, p79)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p80, 5, p79)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p78, g36, 5, p79)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p80, g36, 5, p79)->[()]
# iter=inf, outs=1) plan-free-motion:(q150, q149)->[(c112)]
# iter=inf, outs=1) plan-free-motion:(q149, q151)->[(c113)]
# iter=inf, outs=1) plan-holding-motion:(q151, q150, 4, g36)->[(c114)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.908, sample_time: 0.696, search_time: 0.212, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7860 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9921 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 37777 | p_success: 0.183 | overhead: 0.045
# External: plan-free-motion | n: 6173 | p_success: 0.894 | overhead: 0.124
# External: plan-holding-motion | n: 2401 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3316 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6522 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12148 | p_success: 0.940 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1677177 function calls (1610073 primitive calls) in 1.209 seconds
#
#    Ordered by: internal time
#    List reduced from 1507 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.620    0.207    0.621    0.207 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    106962    0.058    0.000    0.074    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.024    0.189    0.095 /usr/lib/python2.7/pickle.py:851(load)
#   53559/1    0.037    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    214200    0.036    0.000    0.036    0.000 {method 'read' of 'file' objects}
#    106930    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.029    0.014    0.029    0.014 {posix.read}
#     53494    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    107116    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#         2    0.013    0.006    0.013    0.006 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q149 q151 c113
#  2) pick 4 p78 g36 q151 c111
#  3) move_holding q151 q150 4 g36 c114
#  4) place 4 p80 g36 q150 c110
#  5) move_free q150 q149 c112

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_wFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	29848.4 ms/20 = 1492.4 ms (942.475/6524.864)
# sample_grasps_4: 	87.3 ms/20 = 4.4 ms (2.348/9.821)
# get_stable_4_1: 	25.2 ms/34 = 0.7 ms (0.433/1.575)
# ik_fn: 	3560.2 ms/154 = 23.1 ms (0.899/165.385)
# check_feas: 	506.1 ms/154 = 3.3 ms (0.882/8.068)
# ReachChecker: 	125.0 ms/154 = 0.8 ms (0.339/2.193)
# GraspChecker: 	271.3 ms/148 = 1.8 ms (0.657/6.068)
# free_motion_gen: 	9458.8 ms/43 = 220.0 ms (5.176/693.434)
# holding_motion_gen: 	3135.1 ms/21 = 149.3 ms (75.456/356.452)
# get_stable_4_3: 	0.0 ms/1 = 0.0 ms (0.005/0.005)
# get_stable_4_2: 	5.2 ms/7 = 0.7 ms (0.469/0.941)
#
# solve-mean: 1492.4 ms
# solve-median: 1191.7 ms
# success rate: 100.0 %

# %% [markdown]
# ### Test without IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_woFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=[],
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_woFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q87), ('AtConf', q87), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p91), ('AtPose', 4L, p91), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p91, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p92), ('AtPose', 5L, p92), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p92, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q87), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.179
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g20), inverse-kinematics:(4, p91, #g20)->(#q45, #t1783), test-cfree-traj-pose:(#t1783, 4, p91)->(), test-cfree-traj-pose:(#t1783, 5, p92)->(), sample-pose:(4, 1)->(#p22), inverse-kinematics:(4, #p22, #g20)->(#q46, #t1784), test-cfree-traj-pose:(#t1784, 5, p92)->(), test-cfree-pose-pose:(4, #p22, 5, p92)->(), test-cfree-approach-pose:(4, p91, #g20, 5, p92)->(), test-cfree-approach-pose:(4, #p22, #g20, 5, p92)->(), plan-free-motion:(#q46, q87)->(#t1825), plan-free-motion:(q87, #q45)->(#t1826), plan-holding-motion:(#q45, #q46, 4, #g20)->(#t1827)]
# Action plan (5, 0.000): [move_free(q87, #q45, #t1826), pick(4, p91, #g20, #q45, #t1783), move_holding(#q45, #q46, 4, #g20, #t1827), place(4, #p22, #g20, #q46, #t1784), move_free(#q46, q87, #t1825)]
# iter=0, outs=1) sample-grasp:(4)->[(g54)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.2153076140451113, 0.7193415696511525, -0.9317570922425451, -2.3814289460571474, 2.3473192363726336, 3.038316508190859, -0.551065666758976)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g54)->[]
# Sampling for up to 0.174 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g55)]
# q_approach: (-1.4519024783258208, -1.1761139853033047, 2.003800739678055, -1.631944331886783, 0.9823133216275483, 1.3489679522314098, 0.514967537425978)
# go on
# q_grasp: (-1.391637661736404, -1.1990650085098076, 2.038096478826575, -1.737842637684051, 1.0282894835716596, 1.42714513042707, 0.4867566456869842)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g55)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g56)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6336747065619281, 0.34522173469389483, -0.5947815881515433, -2.502758260109791, 0.46875257127886316, 2.9125348747356083, 0.8914942618173828)
# go on
# q_grasp: (1.4447808138643843, 0.4809613248249993, -0.38516408394639184, -2.4325302881399318, 0.6076872919111654, 2.998059992093964, 0.7767776500515463)
# iter=inf, outs=1) inverse-kinematics:(4, p91, g56)->[(q89, c105)]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 4, p91)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 5, p92)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p93)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.17683829558120712, 0.32904683636731263, -0.6592590209016547, -2.521317493595038, 0.8225037472099498, 2.8718055124759942, 0.013270147742465448)
# go on
# q_grasp: (-0.3510109058095045, 0.48142753585519815, -0.4513364721643871, -2.4227048735375294, 1.0589933120437227, 2.9211035860247003, -0.1784026176912355)
# iter=inf, outs=1) inverse-kinematics:(4, p93, g56)->[(q90, c106)]
# iter=inf, outs=1) test-cfree-traj-pose:(c106, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p93, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p91, g56, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p93, g56, 5, p92)->[()]
# iter=inf, outs=1) plan-free-motion:(q90, q87)->[(c107)]
# iter=inf, outs=1) plan-free-motion:(q87, q89)->[(c108)]
# iter=inf, outs=1) plan-holding-motion:(q89, q90, 4, g56)->[(c109)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.567, sample_time: 0.355, search_time: 0.212, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6922 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8978 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30199 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5904 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2265 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3171 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6240 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11575 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1635876 function calls (1572242 primitive calls) in 0.860 seconds
#
#    Ordered by: internal time
#    List reduced from 1479 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.157    0.052    0.158    0.053 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99794    0.057    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.025    0.186    0.093 /usr/lib/python2.7/pickle.py:851(load)
#       635    0.047    0.000    0.047    0.000 {pybullet.calculateInverseKinematics}
#         2    0.040    0.020    0.040    0.020 {posix.read}
#   49977/1    0.036    0.000    0.089    0.089 /usr/lib/python2.7/pickle.py:269(save)
#    199864    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#     99762    0.028    0.000    0.039    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#      5089    0.024    0.000    0.024    0.000 {pybullet.resetJointState}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q87 q89 c108
#  2) pick 4 p91 g56 q89 c105
#  3) move_holding q89 q90 4 g56 c109
#  4) place 4 p93 g56 q90 c106
#  5) move_free q90 q87 c107
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q91), ('AtConf', q91), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p94), ('AtPose', 4L, p94), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p94, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p95), ('AtPose', 5L, p95), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p95, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q91), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.082
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.187
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g21), sample-pose:(4, 1)->(#p23), inverse-kinematics:(4, #p23, #g21)->(#q48, #t1843), test-cfree-traj-pose:(#t1843, 5, p95)->(), inverse-kinematics:(4, p94, #g21)->(#q47, #t1842), test-cfree-traj-pose:(#t1842, 5, p95)->(), test-cfree-traj-pose:(#t1842, 4, p94)->(), test-cfree-pose-pose:(4, #p23, 5, p95)->(), test-cfree-approach-pose:(4, p94, #g21, 5, p95)->(), test-cfree-approach-pose:(4, #p23, #g21, 5, p95)->(), plan-free-motion:(#q48, q91)->(#t1884), plan-free-motion:(q91, #q47)->(#t1885), plan-holding-motion:(#q47, #q48, 4, #g21)->(#t1886)]
# Action plan (5, 0.000): [move_free(q91, #q47, #t1885), pick(4, p94, #g21, #q47, #t1842), move_holding(#q47, #q48, 4, #g21, #t1886), place(4, #p23, #g21, #q48, #t1843), move_free(#q48, q91, #t1884)]
# iter=0, outs=1) sample-grasp:(4)->[(g57)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p96)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p96, g57)->[]
# Sampling for up to 0.190 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p97)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4146220486130724, 0.7232147084839358, -0.45396643209398907, -1.7269376795261238, 0.10632676531683208, 1.9076666130766085, 0.32343035190404157)
# go on
# q_grasp: (-0.4214149553484992, 0.7565514918323127, -0.4430704954980897, -1.8107676641982782, 0.1215901113395851, 2.023001410760455, 0.3131698887394583)
# iter=inf, outs=1) inverse-kinematics:(4, p97, g57)->[(q92, c110)]
# iter=inf, outs=1) test-cfree-traj-pose:(c110, 5, p95)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9423041884060136, 0.5806862769241551, -0.09687202459664623, -1.877247129615524, 0.22729663007276368, 1.950576631629773, 0.9706518620516507)
# go on
# q_grasp: (0.9514770005052784, 0.6169544583381473, -0.08418407628866093, -1.9586787500222456, 0.24768215812150873, 2.0682028270713277, 0.9576246813187703)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g57)->[(q93, c111)]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 4, p94)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p97, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p94, g57, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p97, g57, 5, p95)->[()]
# iter=inf, outs=1) plan-free-motion:(q92, q91)->[(c112)]
# iter=inf, outs=1) plan-free-motion:(q91, q93)->[(c113)]
# iter=inf, outs=1) plan-holding-motion:(q93, q92, 4, g57)->[(c114)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.398, sample_time: 0.179, search_time: 0.219, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6924 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8979 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30202 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5906 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2266 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3172 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6242 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11578 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1586784 function calls (1523183 primitive calls) in 0.701 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.104    0.035    0.105    0.035 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99824    0.060    0.000    0.076    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.193    0.097 /usr/lib/python2.7/pickle.py:851(load)
#   49991/1    0.037    0.000    0.090    0.090 /usr/lib/python2.7/pickle.py:269(save)
#    199924    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#         2    0.032    0.016    0.032    0.016 {posix.read}
#     99792    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#     49926    0.015    0.000    0.024    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#     99980    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q91 q93 c113
#  2) pick 4 p94 g57 q93 c111
#  3) move_holding q93 q92 4 g57 c114
#  4) place 4 p97 g57 q92 c110
#  5) move_free q92 q91 c112
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q94), ('AtConf', q94), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p98), ('AtPose', 4L, p98), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p98, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p99), ('AtPose', 5L, p99), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p99, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q94), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.096
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.235
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g22), inverse-kinematics:(4, p98, #g22)->(#q49, #t1901), test-cfree-traj-pose:(#t1901, 4, p98)->(), sample-pose:(4, 1)->(#p24), inverse-kinematics:(4, #p24, #g22)->(#q50, #t1902), test-cfree-traj-pose:(#t1902, 5, p99)->(), test-cfree-traj-pose:(#t1901, 5, p99)->(), test-cfree-pose-pose:(4, #p24, 5, p99)->(), test-cfree-approach-pose:(4, p98, #g22, 5, p99)->(), test-cfree-approach-pose:(4, #p24, #g22, 5, p99)->(), plan-free-motion:(#q50, q94)->(#t1943), plan-free-motion:(q94, #q49)->(#t1944), plan-holding-motion:(#q49, #q50, 4, #g22)->(#t1945)]
# Action plan (5, 0.000): [move_free(q94, #q49, #t1944), pick(4, p98, #g22, #q49, #t1901), move_holding(#q49, #q50, 4, #g22, #t1945), place(4, #p24, #g22, #q50, #t1902), move_free(#q50, q94, #t1943)]
# iter=0, outs=1) sample-grasp:(4)->[(g58)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g58)->[]
# Sampling for up to 0.223 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g59)]
# q_approach: (-0.6051752266837097, 1.4236449442224763, 1.3736971672423777, -2.579612977589119, -2.1541155507479712, 1.8310653978677442, 2.354237828311577)
# go on
# q_grasp: (-0.5494205972735643, 1.4616676985166466, 1.2653802344850225, -2.480222972498226, -2.2482740336297042, 1.884110373433792, 2.347700199241115)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.460620585522514, -1.5378085472753196, 1.849616336591094, -2.538595747334552, 2.005299704610922, 2.1919010695544006, 0.29981672952626515)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.717207014603605, 0.4990710217541687, -0.5469755923136913, -2.2443800679858805, 2.5397010515645917, 3.2628551283595897, -1.0213232249618125)
# go on
# q_grasp: (1.6594256670391294, 0.6490505682414648, -0.5143637330936656, -2.1618336385411263, 2.5459935250107346, 3.187332308192318, -0.9977688737837398)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g59)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g60)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.129940055450128, 0.6112390620831178, -1.0301197835992433, -2.42985678935642, 1.1009845671497966, 2.686536485053188, 0.462676375821035)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.71389979194755, -0.3047511583700157, -2.7157285208676014, -2.4840238282195815, -0.7004655246149153, 2.867543012046386, 1.7546519414316757)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g60)->[]
# iter=3, outs=1) sample-grasp:(4)->[(g61)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.17874639573274542, 1.1374769517538854, 1.2038521895773393, -1.8781811832346804, -0.8239896425998763, 1.7440369187911269, 1.6726923383992254)
# go on
# q_grasp: (-0.17824263677035704, 1.1769515945486235, 1.1425073567821773, -1.9404756615773726, -0.8847809822390776, 1.8295088103449486, 1.7021559584471642)
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.2344512348608219, 0.5848336302627009, -0.40251068241000093, -1.9249355941897155, 0.3938111913432734, 1.9703917896582388, 0.8572570055579846)
# go on
# q_grasp: (1.2386975322112856, 0.6342825024223652, -0.3743659824030847, -1.986296214063154, 0.43644233521834486, 2.075852723570028, 0.8314789091082417)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g61)->[]
# iter=4, outs=1) sample-grasp:(4)->[(g62)]
# q_approach: (1.2392375115479022, 0.5422879610910561, -0.3894675731172022, -1.9864798774207026, 0.37607602496574, 2.0612278080414583, 0.8724954805635704)
# go on
# q_grasp: (1.239536751201837, 0.5976231432528558, -0.3586717414459903, -2.044490057382021, 0.4229049652936962, 2.169663858062348, 0.8434999766154803)
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.783820951383597, 0.8473786468779795, -1.012486837532283, -1.9497664589368835, 0.8341620250756491, 1.831402685181252, 0.582553395738182)
# go on
# q_grasp: (1.7800865271836308, 0.8962516248642809, -0.9497434969582378, -1.9939576856445524, 0.9027144456640753, 1.909273999013711, 0.5511974629513501)
# iter=inf, outs=1) inverse-kinematics:(4, p98, g62)->[(q101, c115)]
# iter=inf, outs=1) test-cfree-traj-pose:(c115, 4, p98)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p100)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.593206118587994, 0.35416606193583394, -0.3105819867448346, -2.3853157801536806, -0.9345368916514414, 2.8710291314450456, -0.547692875286517)
# go on
# q_grasp: (-0.5888944430418368, 0.5162444662267394, -0.35866755309860265, -2.2995597880548875, -0.9907143472504004, 2.9664894484585296, -0.4812647483047807)
# iter=inf, outs=1) inverse-kinematics:(4, p100, g62)->[(q102, c116)]
# iter=inf, outs=1) test-cfree-traj-pose:(c116, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c115, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p100, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p98, g62, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p100, g62, 5, p99)->[()]
# iter=inf, outs=1) plan-free-motion:(q102, q94)->[(c117)]
# iter=inf, outs=1) plan-free-motion:(q94, q101)->[(c118)]
# iter=inf, outs=1) plan-holding-motion:(q101, q102, 4, g62)->[(c119)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 40, iterations: 3, length: 2, run_time: 0.563, sample_time: 0.294, search_time: 0.269, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6925 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8984 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30208 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5908 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2267 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3173 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6244 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11581 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1624438 function calls (1560803 primitive calls) in 0.844 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.127    0.042    0.127    0.042 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99852    0.054    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.179    0.090 /usr/lib/python2.7/pickle.py:851(load)
#   50008/1    0.037    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    199980    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#       388    0.030    0.000    0.030    0.000 {pybullet.calculateInverseKinematics}
#     99820    0.026    0.000    0.036    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.024    0.012    0.024    0.012 {posix.read}
#      3297    0.017    0.000    0.017    0.000 {pybullet.resetJointState}
#     49943    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q94 q101 c118
#  2) pick 4 p98 g62 q101 c115
#  3) move_holding q101 q102 4 g62 c119
#  4) place 4 p100 g62 q102 c116
#  5) move_free q102 q94 c117
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q103), ('AtConf', q103), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p101), ('AtPose', 4L, p101), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p101, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p102), ('AtPose', 5L, p102), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p102, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q103), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.019
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.027 | Sample Time: 0.000 | Total Time: 0.027
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.112
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.212
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g23), inverse-kinematics:(4, p101, #g23)->(#q51, #t1960), test-cfree-traj-pose:(#t1960, 5, p102)->(), sample-pose:(4, 1)->(#p25), inverse-kinematics:(4, #p25, #g23)->(#q52, #t1961), test-cfree-traj-pose:(#t1961, 5, p102)->(), test-cfree-traj-pose:(#t1960, 4, p101)->(), test-cfree-pose-pose:(4, #p25, 5, p102)->(), test-cfree-approach-pose:(4, p101, #g23, 5, p102)->(), test-cfree-approach-pose:(4, #p25, #g23, 5, p102)->(), plan-free-motion:(q103, #q51)->(#t2002), plan-free-motion:(#q52, q103)->(#t2003), plan-holding-motion:(#q51, #q52, 4, #g23)->(#t2004)]
# Action plan (5, 0.000): [move_free(q103, #q51, #t2002), pick(4, p101, #g23, #q51, #t1960), move_holding(#q51, #q52, 4, #g23, #t2004), place(4, #p25, #g23, #q52, #t1961), move_free(#q52, q103, #t2003)]
# iter=0, outs=1) sample-grasp:(4)->[(g63)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6258714181493832, 0.5921668573496742, -0.7633860313746874, -2.0827445706669643, 0.6059840666343767, 2.12533083457955, 0.726767308313793)
# go on
# q_grasp: (1.5992686215647776, 0.6653403690359281, -0.6959140140639104, -2.1112569265986587, 0.6881009814682999, 2.212560675836015, 0.6789875528302193)
# iter=inf, outs=1) inverse-kinematics:(4, p101, g63)->[(q104, c120)]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 5, p102)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p103)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2215517413249337, 0.3516141331126039, 0.29747090075794413, -2.3682587415318697, 0.531541765536062, 2.7784918344743295, 2.2587067101664733)
# go on
# q_grasp: (-1.2040515189769647, 0.49789320966600153, 0.3132095678680738, -2.3192172262036994, 0.5464177153539975, 2.8830421268426747, 2.2384659367052793)
# iter=inf, outs=1) inverse-kinematics:(4, p103, g63)->[(q105, c121)]
# iter=inf, outs=1) test-cfree-traj-pose:(c121, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 4, p101)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p103, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p101, g63, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p103, g63, 5, p102)->[()]
# iter=inf, outs=1) plan-free-motion:(q103, q104)->[(c122)]
# iter=inf, outs=1) plan-free-motion:(q105, q103)->[(c123)]
# iter=inf, outs=1) plan-holding-motion:(q104, q105, 4, g63)->[(c124)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.508, sample_time: 0.253, search_time: 0.255, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6926 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8985 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30210 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5910 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2268 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3174 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6246 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11584 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1578393 function calls (1514793 primitive calls) in 0.832 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.179    0.060    0.180    0.060 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99886    0.055    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#   50021/1    0.053    0.000    0.133    0.133 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.045    0.023    0.182    0.091 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.039    0.019    0.039    0.019 {posix.read}
#    200048    0.038    0.000    0.038    0.000 {method 'read' of 'file' objects}
#     99854    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49956    0.021    0.000    0.035    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100040    0.021    0.000    0.021    0.000 {method 'write' of 'file' objects}
#         2    0.018    0.009    0.018    0.009 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q103 q104 c122
#  2) pick 4 p101 g63 q104 c120
#  3) move_holding q104 q105 4 g63 c124
#  4) place 4 p103 g63 q105 c121
#  5) move_free q105 q103 c123
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q106), ('AtConf', q106), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p104), ('AtPose', 4L, p104), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p104, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p105), ('AtPose', 5L, p105), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p105, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q106), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g24), inverse-kinematics:(4, p104, #g24)->(#q53, #t2019), test-cfree-traj-pose:(#t2019, 4, p104)->(), sample-pose:(4, 1)->(#p26), inverse-kinematics:(4, #p26, #g24)->(#q54, #t2020), test-cfree-traj-pose:(#t2020, 5, p105)->(), test-cfree-traj-pose:(#t2019, 5, p105)->(), test-cfree-pose-pose:(4, #p26, 5, p105)->(), test-cfree-approach-pose:(4, p104, #g24, 5, p105)->(), test-cfree-approach-pose:(4, #p26, #g24, 5, p105)->(), plan-free-motion:(q106, #q53)->(#t2062), plan-free-motion:(#q54, q106)->(#t2063), plan-holding-motion:(#q53, #q54, 4, #g24)->(#t2061)]
# Action plan (5, 0.000): [move_free(q106, #q53, #t2062), pick(4, p104, #g24, #q53, #t2019), move_holding(#q53, #q54, 4, #g24, #t2061), place(4, #p26, #g24, #q54, #t2020), move_free(#q54, q106, #t2063)]
# iter=0, outs=1) sample-grasp:(4)->[(g64)]
# q_approach: (0.192120065456175, 0.5507885500113415, 0.6996004181985822, -2.120028026909611, -0.31944583175786967, 2.2458424224229803, 1.3644598539399206)
# go on
# q_grasp: (0.2355012004362731, 0.6298479819802765, 0.6389457089918664, -2.150846691214588, -0.387275341967781, 2.3485802281198036, 1.4084214406300628)
# iter=inf, outs=1) inverse-kinematics:(4, p104, g64)->[(q107, c125)]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 4, p104)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p106, g64)->[]
# Sampling for up to 0.182 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.04850148378346279, 0.5935509460890934, -0.9405148754347938, -2.216703621199621, 0.649400094786745, 2.160496025984867, 0.5051470742256251)
# go on
# q_grasp: (-0.0032312995073874714, 0.6707385780877653, -0.8440620615149829, -2.240055313868342, 0.7500890087786326, 2.245373512353603, 0.44619986822891633)
# iter=inf, outs=1) inverse-kinematics:(4, p107, g64)->[(q108, c126)]
# iter=inf, outs=1) test-cfree-traj-pose:(c126, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p107, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p104, g64, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p107, g64, 5, p105)->[()]
# iter=inf, outs=1) plan-free-motion:(q106, q107)->[(c127)]
# iter=inf, outs=1) plan-free-motion:(q108, q106)->[(c128)]
# iter=inf, outs=1) plan-holding-motion:(q107, q108, 4, g64)->[(c129)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.431, sample_time: 0.200, search_time: 0.231, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6928 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8986 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30213 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5912 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2269 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3175 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6248 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11587 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590542 function calls (1526913 primitive calls) in 0.740 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.111    0.037    0.112    0.037 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99912    0.058    0.000    0.074    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.024    0.188    0.094 /usr/lib/python2.7/pickle.py:851(load)
#   50035/1    0.041    0.000    0.102    0.102 /usr/lib/python2.7/pickle.py:269(save)
#    200100    0.034    0.000    0.034    0.000 {method 'read' of 'file' objects}
#         2    0.033    0.016    0.033    0.016 {posix.read}
#     99880    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49970    0.016    0.000    0.027    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100068    0.016    0.000    0.016    0.000 {method 'write' of 'file' objects}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q106 q107 c127
#  2) pick 4 p104 g64 q107 c125
#  3) move_holding q107 q108 4 g64 c129
#  4) place 4 p107 g64 q108 c126
#  5) move_free q108 q106 c128
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q109), ('AtConf', q109), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p108), ('AtPose', 4L, p108), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p108, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p109), ('AtPose', 5L, p109), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p109, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q109), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.178
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g25), sample-pose:(4, 1)->(#p27), inverse-kinematics:(4, #p27, #g25)->(#q56, #t2079), test-cfree-traj-pose:(#t2079, 5, p109)->(), inverse-kinematics:(4, p108, #g25)->(#q55, #t2078), test-cfree-traj-pose:(#t2078, 4, p108)->(), test-cfree-traj-pose:(#t2078, 5, p109)->(), test-cfree-pose-pose:(4, #p27, 5, p109)->(), test-cfree-approach-pose:(4, p108, #g25, 5, p109)->(), test-cfree-approach-pose:(4, #p27, #g25, 5, p109)->(), plan-free-motion:(#q56, q109)->(#t2121), plan-free-motion:(q109, #q55)->(#t2122), plan-holding-motion:(#q55, #q56, 4, #g25)->(#t2120)]
# Action plan (5, 0.000): [move_free(q109, #q55, #t2122), pick(4, p108, #g25, #q55, #t2078), move_holding(#q55, #q56, 4, #g25, #t2120), place(4, #p27, #g25, #q56, #t2079), move_free(#q56, q109, #t2121)]
# iter=0, outs=1) sample-grasp:(4)->[(g65)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p110)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.5217681844440692, 1.2497063160207205, -1.3138238471961572, -2.3180458030950035, 1.2502045493133906, 2.208513407822154, 1.5894036354803658)
# go on
# q_grasp: (0.4342072331098595, 1.293684961859948, -1.2012778571394627, -2.2771728227373607, 1.348189582093488, 2.2746134625997696, 1.543672137109852)
# Approach motion failed
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p110, g65)->[]
# Sampling for up to 0.173 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p111)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.2238007828552059, 0.6195245845566902, -1.0012289839782778, -2.360286950901237, 0.4023643377499472, 2.575011702036958, 2.3387252338147135)
# go on
# q_grasp: (0.07282095162398053, 0.7034744262953286, -0.8474678467296006, -2.3403988048280904, 0.4871741433601139, 2.6766219431673943, 2.278123828966335)
# iter=inf, outs=1) inverse-kinematics:(4, p111, g65)->[(q111, c130)]
# iter=inf, outs=1) test-cfree-traj-pose:(c130, 5, p109)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.2953546580612645, 0.2928546457784743, -0.41955314970829743, -2.57743258613227, -0.6468471516090225, 3.141816595233023, 1.8179728179768198)
# go on
# q_grasp: (1.285359243651392, 0.4804471324872723, -0.4189707342980187, -2.490843305451842, -0.628943206735579, 3.2496955344992204, 1.8345308590952234)
# Approach motion failed
# q_approach: (-1.5939740110777156, -0.3265470775204209, 2.624575519636656, -2.614803286689616, 0.15104275831516012, 3.1745713205234622, 1.1856096404426624)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p108, g65)->[]
# iter=1, outs=1) sample-grasp:(4)->[(g66)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.31674771729693757, 0.8468130236648528, -1.04200439558982, -2.0797521618228, 1.292522586567922, 1.6462263563508819, 1.111236773955241)
# go on
# ...
#  3) move_holding q286 q315 4 g102 c251
#  4) place 4 p184 g102 q315 c239
#  5) move_free q315 q322 c249
#  6) pick 4 p184 g104 q322 c245
#  7) move_holding q322 q319 4 g104 c252
#  8) place 4 p185 g104 q319 c243
#  9) move_free q319 q303 c248
# 10) pick 4 p185 g100 q303 c233
# 11) move_holding q303 q275 4 g100 c250
# 12) place 4 p175 g100 q275 c227
# 13) move_free q275 q273 c246
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q323), ('AtConf', q323), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p187), ('AtPose', 4L, p187), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p187, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p188), ('AtPose', 5L, p188), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p188, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q323), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.092
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g39), inverse-kinematics:(4, p187, #g39)->(#q124, #t6812), test-cfree-traj-pose:(#t6812, 4, p187)->(), test-cfree-traj-pose:(#t6812, 5, p188)->(), sample-pose:(4, 1)->(#p55), inverse-kinematics:(4, #p55, #g39)->(#q125, #t6813), test-cfree-traj-pose:(#t6813, 5, p188)->(), test-cfree-pose-pose:(4, #p55, 5, p188)->(), test-cfree-approach-pose:(4, p187, #g39, 5, p188)->(), test-cfree-approach-pose:(4, #p55, #g39, 5, p188)->(), plan-free-motion:(#q125, q323)->(#t6855), plan-free-motion:(q323, #q124)->(#t6856), plan-holding-motion:(#q124, #q125, 4, #g39)->(#t6854)]
# Action plan (5, 0.000): [move_free(q323, #q124, #t6856), pick(4, p187, #g39, #q124, #t6812), move_holding(#q124, #q125, 4, #g39, #t6854), place(4, #p55, #g39, #q125, #t6813), move_free(#q125, q323, #t6855)]
# iter=0, outs=1) sample-grasp:(4)->[(g105)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3913936235978617, 0.6473202107520545, -0.5811027389467883, -1.900133139286519, 0.5076304860483215, 1.9148299600943661, 0.781916790402671)
# go on
# q_grasp: (1.398103623530459, 0.6903477801426051, -0.5461776682705444, -1.96870440285634, 0.5584177305168011, 2.0175317388372718, 0.7516506681507357)
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9252176461857935, 0.5499701425495943, -0.07162518045062206, -1.924093777707574, 0.20833247549578734, 2.0041072069347488, 0.9843463195388161)
# go on
# q_grasp: (0.9327564158787751, 0.5967763503979702, -0.059341439252450265, -1.9919463400673665, 0.22759101392092934, 2.11858304937491, 0.9724612060070925)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p187, g105)->[]
# Sampling for up to 0.194 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.17631073013576, -0.4933263891832346, 2.228479048758484, -2.4210273363131987, 0.831968921098863, 2.6964918113921437, 0.6274784135221078)
# go on
# q_grasp: (-1.3397081947220357, -0.6124484020390284, 2.41739871424993, -2.3511509330287836, 1.0011247295408192, 2.7521988990371056, 0.5029594365338195)
# iter=inf, outs=1) inverse-kinematics:(4, p187, g106)->[(q326, c253)]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 4, p187)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 5, p188)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p189)]
# q_approach: (-2.3279233827442067, 0.6364385832627303, 1.1796690649194002, -2.5291811192723106, -1.0895847749141718, 2.583995130234229, 0.7000293126645228)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2776426030072112, 0.1968001149737276, 0.3024917278553469, -2.6201597327308193, 0.07150512557995935, 2.8789059050012162, -0.11023388619594422)
# go on
# q_grasp: (-1.2052666740182152, 0.35834396014592257, 0.2228711629221178, -2.5835872254045102, 0.010239247901524917, 3.0039797908166617, -0.06824290318793176)
# iter=inf, outs=1) inverse-kinematics:(4, p189, g106)->[(q327, c254)]
# iter=inf, outs=1) test-cfree-traj-pose:(c254, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p189, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p187, g106, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p189, g106, 5, p188)->[()]
# iter=inf, outs=1) plan-free-motion:(q327, q323)->[(c255)]
# iter=inf, outs=1) plan-free-motion:(q323, q326)->[(c256)]
# iter=inf, outs=1) plan-holding-motion:(q326, q327, 4, g106)->[(c257)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 37, iterations: 3, length: 2, run_time: 0.445, sample_time: 0.214, search_time: 0.230, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6986 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9028 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30443 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5947 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2290 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3196 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6290 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11705 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1605339 function calls (1541366 primitive calls) in 0.754 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.119    0.040    0.119    0.040 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100716    0.061    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.051    0.025    0.197    0.099 /usr/lib/python2.7/pickle.py:851(load)
#   50437/1    0.037    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    201708    0.036    0.000    0.036    0.000 {method 'read' of 'file' objects}
#    100684    0.030    0.000    0.041    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.028    0.014    0.028    0.014 {posix.read}
#         2    0.017    0.008    0.017    0.008 {posix.fork}
#    100872    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#     50372    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q323 q326 c256
#  2) pick 4 p187 g106 q326 c253
#  3) move_holding q326 q327 4 g106 c257
#  4) place 4 p189 g106 q327 c254
#  5) move_free q327 q323 c255
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q328), ('AtConf', q328), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p190), ('AtPose', 4L, p190), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p190, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p191), ('AtPose', 5L, p191), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p191, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q328), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.223
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g40), inverse-kinematics:(4, p190, #g40)->(#q126, #t6871), test-cfree-traj-pose:(#t6871, 5, p191)->(), test-cfree-traj-pose:(#t6871, 4, p190)->(), sample-pose:(4, 1)->(#p56), inverse-kinematics:(4, #p56, #g40)->(#q127, #t6872), test-cfree-traj-pose:(#t6872, 5, p191)->(), test-cfree-pose-pose:(4, #p56, 5, p191)->(), test-cfree-approach-pose:(4, p190, #g40, 5, p191)->(), test-cfree-approach-pose:(4, #p56, #g40, 5, p191)->(), plan-free-motion:(q328, #q126)->(#t6913), plan-free-motion:(#q127, q328)->(#t6915), plan-holding-motion:(#q126, #q127, 4, #g40)->(#t6914)]
# Action plan (5, 0.000): [move_free(q328, #q126, #t6913), pick(4, p190, #g40, #q126, #t6871), move_holding(#q126, #q127, 4, #g40, #t6914), place(4, #p56, #g40, #q127, #t6872), move_free(#q127, q328, #t6915)]
# iter=0, outs=1) sample-grasp:(4)->[(g107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4150246091802521, 1.2298875449035673, 1.3715062786356178, -2.210035248790946, -1.3123426805092073, 1.8936688794986642, 1.961933398401645)
# go on
# q_grasp: (-0.3753213593695801, 1.274773837173716, 1.26617175391218, -2.1974265254599317, -1.4031453163847043, 1.9545435621335112, 1.9861627345873272)
# iter=inf, outs=1) inverse-kinematics:(4, p190, g107)->[(q329, c258)]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 4, p190)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p192)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8899689531601122, 0.19880541274066688, -0.010427111186110756, -2.609277576096338, 0.01160885297981413, 2.8995182994797184, -2.377668987321695)
# go on
# q_grasp: (-0.8953571293780338, 0.36052263655602007, -0.003902137474369012, -2.5668661808489133, 0.016590275136949703, 3.0187008837854807, -2.3817649049534415)
# iter=inf, outs=1) inverse-kinematics:(4, p192, g107)->[(q330, c259)]
# iter=inf, outs=1) test-cfree-traj-pose:(c259, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p192, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p190, g107, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p192, g107, 5, p191)->[()]
# iter=inf, outs=1) plan-free-motion:(q328, q329)->[(c260)]
# iter=inf, outs=1) plan-free-motion:(q330, q328)->[(c261)]
# iter=inf, outs=1) plan-holding-motion:(q329, q330, 4, g107)->[(c262)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.461, sample_time: 0.208, search_time: 0.253, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6987 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9029 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30445 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5949 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2291 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3197 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6292 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11708 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590432 function calls (1526433 primitive calls) in 0.749 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.149    0.050    0.150    0.050 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100744    0.055    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.185    0.092 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.042    0.021    0.042    0.021 {posix.read}
#    201764    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   50450/1    0.038    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    100712    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.017    0.009    0.017    0.009 {posix.fork}
#     50385    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100898    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q328 q329 c260
#  2) pick 4 p190 g107 q329 c258
#  3) move_holding q329 q330 4 g107 c262
#  4) place 4 p192 g107 q330 c259
#  5) move_free q330 q328 c261

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_woFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	114004.4 ms/20 = 5700.2 ms (944.096/10438.012)
# sample_grasps_4: 	87.0 ms/20 = 4.3 ms (2.755/12.515)
# get_stable_4_1: 	426.4 ms/441 = 1.0 ms (0.395/2.828)
# ik_fn: 	64947.5 ms/4492 = 14.5 ms (1.353/231.827)
# check_feas: 	15598.1 ms/4492 = 3.5 ms (1.345/10.35)
# ReachChecker: 	4004.7 ms/4492 = 0.9 ms (0.35/3.058)
# GraspChecker: 	8115.1 ms/4492 = 1.8 ms (0.59/6.77)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9d45d5cb80db> in <module>()
#       2
#       3 time_array = np.array(gtimer.timelist_dict["solve"])
# ----> 4 success_array = np.array(log_woFeas)<1
#       5 print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
#       6 print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
#
# NameError: name 'log_woFeas' is not defined

# %% [markdown]
# ## play plan

# %%
SIMULATE = False
if (plan is None) or not has_gui():
    disconnect()
else:
    command = postprocess_plan(plan)
    if SIMULATE:
#         wait_for_user('Simulate?')
        command.control()
    else:
#         wait_for_user('Execute?')
        #command.step()
        command.refine(num_steps=10).execute(time_step=0.001)
