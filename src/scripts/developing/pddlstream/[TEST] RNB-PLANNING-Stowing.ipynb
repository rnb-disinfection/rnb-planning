# %% [markdown]
# # Test runtime
# ### Test with IK checkers
#
# **grasp sample 10**
# solve-mean: 1175.2 ms
# solve-median: 740.8 ms
# success rate: 98.0 %
#
# **grasp sample 20**
# solve-mean: 1190.6 ms
# solve-median: 778.4 ms
# success rate: 96.5 %
#
# **grasp sample 30**
# solve-mean: 1323.0 ms
# solve-median: 837.4 ms
# success rate: 99.0 %
#
# ### Test without IK checkers
#
# **grasp sample 10**
# solve-mean: 1998.9 ms
# solve-median: 1241.1 ms
# success rate: 88.0 %

# %% [markdown]
# ## set running directory to project source

# %%
import os
import numpy as np
import time
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))
import matplotlib.pyplot as plt
from pkg.controller.combined_robot import *

# %% [markdown]
# # params

# %%
ROBOT_TYPE = RobotType.indy7

if ROBOT_TYPE in [RobotType.indy7, RobotType.indy7gripper]:
    ROBOT_NAME = "indy0"
    TOOL_LINK = "indy0_tcp"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.14)
    
elif ROBOT_TYPE == RobotType.panda:
    ROBOT_NAME = "panda0"
    TOOL_LINK = "panda0_hand"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.112)
    
else:
    raise(NotImplementedError("Case not defined for {}".format(ROBOT_TYPE)))

# %% [markdown]
# ## 4.1 PlanningScene

# %% [markdown]
# ##### initialize CombinedRobot and GeometryScene

# %%
from pkg.project_config import *
from pkg.geometry.builder.scene_builder import SceneBuilder

s_builder = SceneBuilder(None)   # create scene builder without detector for virtual scene
crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, ((0,0,0), (0,0,0)), None)]
                     , connection_list=[False])
gscene = s_builder.create_gscene(crob)
gtems = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=True, collision=True)
gscene.show_pose(crob.home_pose)
# Out:
# connection command:
# indy0: False
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran0']/actuator[@name='indy0_motor0']
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran1']/actuator[@name='indy0_motor1']
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran2']/actuator[@name='indy0_motor2']
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran3']/actuator[@name='indy0_motor3']
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran4']/actuator[@name='indy0_motor4']
# Unknown tag "hardwareInterface" in /robot[@name='custom_robots']/transmission[@name='indy0_tran5']/actuator[@name='indy0_motor5']
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0]
# Please create a subscriber to the marker

# %% [markdown]
# ##### add geometries

# %%
from pkg.geometry.geometry import *

# add environments (fixed=True for non-movable geometries)
wall = gscene.create_safe(GEOTYPE.BOX, "wall", "base_link", (3,3,0.01), (-0.2,0,0), 
                           rpy=(0,np.pi/2,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
floor = gscene.create_safe(GEOTYPE.BOX, "floor", "base_link", (0.72,1.52,0.01), (0.25,0,0), 
                           rpy=(0,0,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
goal = gscene.create_safe(GEOTYPE.BOX, "goal", "base_link", (0.1,0.1,0.01), (0.3,-0.4,0), 
                          rpy=(0,0,0), color=(0.2,0.2,0.8,1), display=True, fixed=True, collision=True)
 
# add movable (fixed=False for movable geometries)
box1 = gscene.create_safe(GEOTYPE.BOX, "box1", "base_link", (0.1,0.05,0.05), (0.3,0.4,0.031), 
                          rpy=(np.pi/2,0,np.pi/6), color=(0.8,0.2,0.2,1), display=True, fixed=False, collision=True)

box2 = gscene.create_safe(GEOTYPE.BOX, "box2", "base_link", (0.05,0.05,0.05), (0.5,0.4,0.031), 
                          rpy=(np.pi,0,0), color=(0.8,0.8,0.2,1), display=True, fixed=False, collision=True)

box1.permute_axis_match_z_link()
box2.permute_axis_match_z_link()

# %% [markdown]
# ##### create PlanningScene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

# %% [markdown]
# ##### create_binder
# - Binders (or Actors) are binding points where objects can be attached (or binded)
# - Examples are
#   - PlacePlane: plane for object placement
#   - Gripper2Tool: 2-finger gripper tool for grasp objects
#   - SweepTool: action point to pass waypoints for sweep task

# %%
from pkg.planning.constraint.constraint_actor import PlacePlane, Gripper2Tool, SweepFramer

# %%
# create PlacePlane on geometry "floor" and "goal"
# when point is not set, the entire upper surface of the geometry becomes valid binding area.
# when point is set, the specific point becomes the only valid binding point.
pscene.create_binder(bname="floor", gname="floor", _type=PlacePlane, point=None)
pscene.create_binder(bname="goal", gname="goal", _type=PlacePlane, point=None)

# %%
# add collision boundary for gripper base
# - set link_name="indy0_tcp" to attach the geometry to end-effector link
# - it can be labeled as fixed=True, as it is "fixed" on the indy0_tcp link
gripper =  gscene.create_safe(GEOTYPE.SPHERE, TOOL_NAME, link_name=TOOL_LINK, 
                                dims=(0.01,0.01,0.01), center=TOOL_XYZ, rpy=(-np.pi/2,0,0), 
                                color=(0.8,0.2,0.2,0.5), display=False, fixed=True, collision=False)

# create Gripper2Tool binder
# Gripper2Tool is a 2-finger gripper, which can rotate along z-direction.
# To align the z-direction with the 2 fingers, rotate by 90 degree along roll axis.
# The gripping point is (0,0,0.11) in local coordinate of "gripper" geometry
pscene.create_binder(bname=TOOL_NAME, gname=TOOL_NAME, _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))

# %% [markdown]
# ##### create_subject
# * Subject describes the tasks in the planning scene.
# * There are 2 categories in subject:
#   1. Object: The object has grip points and placement points for pick&place task
#   2. Task: The task is can be any non-physical task. Check SweepLineTask for example
# * The subjects can be composed of multiple action points. Examples are:
#   1. Grasp2Point: grasping point for 2-finger gripper.
#   2. PlacePoint: The point to place object.
#   3. SweepPoint: A waypoint for SweepLineTask.
#   * The above 3 action points inherit DirectePoint, for which the orientation is free along z-axis.
#   * If "point" parameter is not set, the entire upper surface is becomes valid action area.

# %%
from pkg.planning.constraint.constraint_subject import Grasp2Point, PlacePoint, SweepFrame
from pkg.planning.constraint.constraint_subject import CustomObject, SweepLineTask

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
box_obj = pscene.create_subject(oname="box1", gname="box1", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box1, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box1, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box1, [0,0,-0.026], [0,0,0])})

# %%
## create box object with grasping points along positive & negative y-direction and placement point in the bottom face
obs_obj = pscene.create_subject(oname="box2", gname="box2", _type=CustomObject, 
                             action_points_dict = {
                                 "handle1": Grasp2Point("handle1", box2, [0,0,0], [-np.pi/2,0,0]),
                                 "handle2": Grasp2Point("handle2", box2, [0,0,0], [np.pi/2,0,0]),
                                 "bottom": PlacePoint("bottom", box2, [0,0,-0.026], [0,0,0])})

# %% [markdown]
# ## Pipeline

# %%
from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %%
from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.

# %% [markdown]
# ##### initialize_state
# * initialize_state(robot_pose) updates robot pose and gets corresponding binding status of current scene.
# * state.node of ('floor', 0) means the first subject (object) is placed on the floor and the second subject (sweep) has passed 0 waypoints

# %%
initial_state = pscene.initialize_state(crob.home_pose)
print(initial_state.node)
# Out:
#    Use a production WSGI server instead.
# ('floor', 'floor')
#  * Debug mode: off

# %% [markdown]
# ## import planners

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
mplan = MoveitPlanner(pscene)
from pkg.planning.filtering.grasp_filter import GraspChecker
from pkg.planning.filtering.reach_filter import ReachChecker
from pkg.planning.filtering.latticized_filter import LatticedChecker
from pkg.planning.filtering.task_clearance_filter import TaskClearanceChecker

gcheck = GraspChecker(pscene)
rcheck = ReachChecker(pscene)

checkers_all = [rcheck, gcheck]

# tcheck = TaskClearanceChecker(pscene, gcheck)
# checkers_all = [tcheck, rcheck, gcheck]

# lcheck = LatticedChecker(pscene, gcheck)
# checkers_all.append(lcheck)

# %% [markdown]
# ## Test pybullet

# %%
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src/scripts/developing/pddlstream'))

# %%
from convert_pscene import *
from plan_rnb import *

# %% [markdown]
# #### load pybullet, convert scene

# %%
connect_notebook(use_gui=False)
urdf_pybullet_path = copy_meshes(gscene)
robot_body, body_names, movable_bodies = pscene_to_pybullet(
    pscene, urdf_pybullet_path, tool_name=TOOL_NAME, name_exclude_list=[ROBOT_NAME])
print('Objects:', body_names)
saver = WorldSaver()
# Out:
# [Pybullet] Load urdf from /home/rnb/Projects/rnb-planning/src/robots/custom_robots_pybullet.urdf
# ('Objects:', {1L: 'goal', 2L: 'floor', 3L: 'wall', 4L: 'box1', 5L: 'box2'})

# %% [markdown]
# ### Test with IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_wFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=checkers_all,
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_wFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q0), ('AtConf', q0), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p0), ('AtPose', 4L, p0), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p0, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p1), ('AtPose', 5L, p1), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p1, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q0), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.024
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.033 | Sample Time: 0.000 | Total Time: 0.033
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.077
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.170
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g0), sample-pose:(4, 1)->(#p0), inverse-kinematics:(4, #p0, #g0)->(#q1, #t15), test-cfree-traj-pose:(#t15, 5, p1)->(), inverse-kinematics:(4, p0, #g0)->(#q0, #t14), test-cfree-traj-pose:(#t14, 5, p1)->(), test-cfree-traj-pose:(#t14, 4, p0)->(), test-cfree-pose-pose:(4, #p0, 5, p1)->(), test-cfree-approach-pose:(4, p0, #g0, 5, p1)->(), test-cfree-approach-pose:(4, #p0, #g0, 5, p1)->(), plan-free-motion:(q0, #q0)->(#t56), plan-free-motion:(#q1, q0)->(#t58), plan-holding-motion:(#q0, #q1, 4, #g0)->(#t57)]
# Action plan (5, 0.000): [move_free(q0, #q0, #t56), pick(4, p0, #g0, #q0, #t14), move_holding(#q0, #q1, 4, #g0, #t57), place(4, #p0, #g0, #q1, #t15), move_free(#q1, q0, #t58)]
# iter=0, outs=1) sample-grasp:(4)->[(g0)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p2)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8471023797673753, -0.9135309979328035, -1.0063776202877113, 2.644306350712315, 1.5937334814086914, 2.2488977832438795)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8470572141563067, -0.9137764655008748, -1.005785499914606, 2.644307609994313, 1.5940942982892308, 2.2487652139126895)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.34131249333253577, -0.9199457272505939, -1.388377915052311, -0.26831170511476415, -1.3996823306763289, -0.34755618630567153)
# go on
# q_grasp: (-0.3643026396744044, -0.9397095752824445, -1.4980114671724416, -0.2894049464892786, -1.2712188565494633, -0.3268790246528652)
# iter=inf, outs=1) inverse-kinematics:(4, p2, g0)->[(q1, c0)]
# iter=inf, outs=1) test-cfree-traj-pose:(c0, 5, p1)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.662583117603752, -2.3021903872631633, 2.0829020790293877, -0.9022293475189923, -2.4122748343314946, 3.442764021406179)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.7560838609354936, 2.3538617196860927, -2.896457476130092, -1.7991717196237698, 2.6764342623152877, -1.0635412711342356)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p0, g0)->[]
# Sampling for up to 0.049 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g1)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8879527041169063, -0.8569167841528409, -1.093048002071995, 2.6911324889802746, 1.5019501012599075, 2.227172646381676)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.49347538384261036, -2.041167399353522, 1.7725573398557448, 1.0476870415210493, 2.7908440867690048, 0.46672903693101403)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p2, g1)->[]
# iter=1, outs=1) sample-pose:(4, 1)->[(p3)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.3214352077532148, 0.844894492068533, 1.2081762853013125, -2.8567199959396747, -1.5492978582198247, 0.5096819641310931)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p3, g1)->[]
# Sampling while complexity <= 2
#
# Iteration: 4 | Complexity: 2 | Skeletons: 1 | Skeleton Queue: 3 | Disabled: 0 | Evaluations: 28 | Eager Calls: 0 | Cost: inf | Search Time: 0.213 | Sample Time: 0.205 | Total Time: 0.417
# Attempt: 1 | Results: 45 | Depth: 0 | Success: False | Time: 0.023
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 2 to 3
# Sampling for up to 0.031 seconds
# iter=2, outs=1) sample-pose:(4, 1)->[(p4)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.500291791778592, -2.175553162947753, 1.4241377194546692, -2.3246654258973973, 2.4414473696976984, -1.346621576617628)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6020359213704727, 0.6171126937292806, 2.128287159019085, 0.7141978596979155, 0.7824330510664748, 3.6587292341721307)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p4, g1)->[]
# Sampling while complexity <= 3
#
# Iteration: 5 | Complexity: 3 | Skeletons: 1 | Skeleton Queue: 3 | Disabled: 0 | Evaluations: 30 | Eager Calls: 0 | Cost: inf | Search Time: 0.237 | Sample Time: 0.248 | Total Time: 0.485
# Attempt: 1 | Results: 48 | Depth: 1 | Success: False | Time: 0.108
# Attempt: 2 | Results: 210 | Depth: 1 | Success: False | Time: 0.318
# Attempt: 3 | Results: 338 | Depth: 0 | Success: True | Time: 0.661
# Stream plan (25, 22, 0.001): [sample-grasp:(4)->(g1), sample-pose:(4, 2)->(#p1), inverse-kinematics:(4, #p1, g1)->(#q5, #t92), test-cfree-traj-pose:(#t92, 5, p1)->(), sample-grasp:(4)->(g0), sample-pose:(4, 1)->(p3), inverse-kinematics:(4, p3, g0)->(#q2, #t89), test-cfree-traj-pose:(#t89, 5, p1)->(), inverse-kinematics:(4, p0, g1)->(#q3, #t90), test-cfree-traj-pose:(#t90, 4, p0)->(), test-cfree-traj-pose:(#t90, 5, p1)->(), inverse-kinematics:(4, #p1, g0)->(#q4, #t91), test-cfree-traj-pose:(#t91, 5, p1)->(), test-cfree-traj-pose:(#t91, 4, #p1)->(), test-cfree-pose-pose:(4, p3, 5, p1)->(), test-cfree-pose-pose:(4, #p1, 5, p1)->(), test-cfree-approach-pose:(4, p3, g0, 5, p1)->(), test-cfree-approach-pose:(4, p0, g1, 5, p1)->(), test-cfree-approach-pose:(4, #p1, g1, 5, p1)->(), test-cfree-approach-pose:(4, #p1, g0, 5, p1)->(), plan-free-motion:(#q2, q0)->(#t388), plan-free-motion:(q0, #q3)->(#t390), plan-free-motion:(#q5, #q4)->(#t391), plan-holding-motion:(#q3, #q5, 4, g1)->(#t387), plan-holding-motion:(#q4, #q2, 4, g0)->(#t389)]
# Action plan (9, 0.000): [move_free(q0, #q3, #t390), pick(4, p0, g1, #q3, #t90), move_holding(#q3, #q5, 4, g1, #t387), place(4, #p1, g1, #q5, #t92), move_free(#q5, #q4, #t391), pick(4, #p1, g0, #q4, #t91), move_holding(#q4, #q2, 4, g0, #t389), place(4, p3, g0, #q2, #t89), move_free(#q2, q0, #t388)]
# iter=0, outs=1) sample-pose:(4, 2)->[(p5)]
# iter=inf, outs=0) inverse-kinematics:(4, p5, g0)->[]
# Sampling for up to 0.659 seconds
# iter=inf, outs=0) inverse-kinematics:(4, p5, g1)->[]
# iter=1, outs=1) sample-pose:(4, 2)->[(p6)]
# iter=inf, outs=0) inverse-kinematics:(4, p6, g0)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p6, g1)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g2)]
# iter=inf, outs=0) inverse-kinematics:(4, p5, g2)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p6, g2)->[]
# q_approach: (-0.3832532911724222, -0.7924183931806246, -1.526550147654488, -0.2277328669475159, -1.2275705736443208, -0.39165327278539736)
# go on
# q_grasp: (-0.40328461428660695, -0.8305527569208264, -1.6173880697123377, -0.24943547278537825, -1.0992183651455547, -0.3731929241850944)
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.1903407216825044, 0.7858795686457716, 1.2127158626864811, -0.399652284938437, 1.3810228245651093, 2.1847162708003145)
# go on
# q_grasp: (2.161418219158787, 0.8252504725236421, 1.279278780318285, -0.417864872722594, 1.2741715966851181, 2.203839749722123)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.5210608791978465, -2.0400444825934057, 1.8379224576211575, 1.032623735707643, 2.830915440621503, 0.40965990075126524)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.7467931708188313, 0.7946678451530051, 1.5249349131159313, 2.9086646299325323, -1.2247956149896013, -0.40013600580835634)
# go on
# q_grasp: (2.72607744730155, 0.8338203317153852, 1.612248130169919, 2.8868630797081676, -1.0990759552598393, -0.3822259444672651)
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.38320611109452835, -0.7922395053192973, -1.5270488768684316, -0.22776984299680503, -1.2272373677841497, -0.3915260126329792)
# go on
# q_grasp: (-0.40328370768898675, -0.8305496255774721, -1.6173976818897355, -0.2494366172146566, -1.0992116363030253, -0.3731900637400634)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p2, g2)->[]
# q_approach: (-0.776079412737177, -0.7606946197555938, -1.3415428494318928, 0.26009922508238337, -1.4155365882545308, 0.5375737445064815)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.7760559729637792, -0.7605301003630935, -1.3420954633807234, 0.26010721986738333, -1.4151127805885224, 0.5374843290229885)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.7600785668027359, 0.7646620825321742, 1.4789048523611252, 0.009839619356149477, 1.3457849871401157, -3.124225189944638)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p3, g2)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6417259650042013, 0.5849263292452731, 2.1051583218367265, 0.6319233631269077, 0.7419488734083031, -2.5061222072761375)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6667263377485004, 2.138670723954293, -1.4611547750299523, 0.7404436259734616, 2.501607672656752, -1.3519181991571105)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p4, g2)->[]
# iter=2, outs=1) sample-pose:(4, 2)->[(p7)]
# iter=inf, outs=0) inverse-kinematics:(4, p7, g0)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p7, g1)->[]
# iter=inf, outs=0) inverse-kinematics:(4, p7, g2)->[]
# iter=3, outs=1) sample-grasp:(4)->[(g3)]
# iter=inf, outs=0) inverse-kinematics:(4, p5, g3)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.9691210952407205, 1.6681325941412921, -0.6450655655411175, -0.039241871221171704, 2.4028883659905955, -3.260458575455061)
# go on
# q_grasp: (-2.9702731392546036, 1.7907678326778602, -0.7905741774127991, -0.04062424698902355, 2.425946042224007, -3.2631893489551813)
# iter=inf, outs=1) inverse-kinematics:(4, p6, g3)->[(q6, c1)]
# iter=inf, outs=1) test-cfree-traj-pose:(c1, 5, p1)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1

# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p8, g0)->[]
# Sampling while complexity <= 3
#
# Iteration: 6 | Complexity: 3 | Skeletons: 2 | Skeleton Queue: 14 | Disabled: 0 | Evaluations: 53 | Eager Calls: 0 | Cost: inf | Search Time: 0.955 | Sample Time: 0.885 | Total Time: 1.840
# Attempt: 1 | Results: 190 | Depth: 0 | Success: True | Time: 0.215
# Stream plan (25, 20, 0.001): [sample-grasp:(4)->(g0), sample-pose:(4, 1)->(p2), inverse-kinematics:(4, p2, g0)->(q1, c0), test-cfree-traj-pose:(c0, 5, p1)->(), sample-grasp:(4)->(g1), sample-pose:(4, 3)->(#p2), inverse-kinematics:(4, #p2, g1)->(#q6, #t257), test-cfree-traj-pose:(#t257, 5, p1)->(), inverse-kinematics:(4, #p2, g0)->(#q7, #t258), test-cfree-traj-pose:(#t258, 5, p1)->(), inverse-kinematics:(4, p0, g1)->(#q3, #t90), test-cfree-traj-pose:(#t90, 5, p1)->(), test-cfree-traj-pose:(#t90, 4, p0)->(), test-cfree-traj-pose:(#t258, 4, #p2)->(), test-cfree-pose-pose:(4, p2, 5, p1)->(), test-cfree-pose-pose:(4, #p2, 5, p1)->(), test-cfree-approach-pose:(4, p2, g0, 5, p1)->(), test-cfree-approach-pose:(4, p0, g1, 5, p1)->(), test-cfree-approach-pose:(4, #p2, g0, 5, p1)->(), test-cfree-approach-pose:(4, #p2, g1, 5, p1)->(), plan-free-motion:(q1, q0)->(#t432), plan-free-motion:(q0, #q3)->(#t431), plan-free-motion:(#q6, #q7)->(#t430), plan-holding-motion:(#q7, q1, 4, g0)->(#t429), plan-holding-motion:(#q3, #q6, 4, g1)->(#t428)]
# Action plan (9, 0.000): [move_free(q0, #q3, #t431), pick(4, p0, g1, #q3, #t90), move_holding(#q3, #q6, 4, g1, #t428), place(4, #p2, g1, #q6, #t257), move_free(#q6, #q7, #t430), pick(4, #p2, g0, #q7, #t258), move_holding(#q7, q1, 4, g0, #t429), place(4, p2, g0, q1, c0), move_free(q1, q0, #t432)]
# iter=inf, outs=0) sample-pose:(4, 3)->[]
# Sampling for up to 0.293 seconds
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.5051650139060833, -2.0986341531105617, 1.3466430806029144, -2.454687337863632, 2.52214593371986, -1.584645256957124)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.5834587077282076, 0.6567948487866162, 1.9058159259453606, 0.46934132837528786, 0.9035547887629523, -2.5324398105708443)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p8, g2)->[]
# q_approach: (-1.0321354244935588, -0.6952542028306887, -1.371002204426056, 0.5800703731678495, -1.1895095762071417, 1.236414463624912)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.5435329611387463, 0.6976710737464028, 1.908167455099625, 0.5245732624013594, 0.9493054954314929, -2.6174854752808314)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.5840979387212013, -0.7013710032988407, -1.9004613967645894, -2.6113728967061745, 0.9493591742235097, -2.6070592962213386)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6994141810168952, 2.1541389826570114, -2.0946436674437474, -1.17162531045947, -2.631570422122199, -3.248728299008298)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.0973958058244415, 0.6979869636026128, 1.3668097760470568, -2.564067465926532, -1.1964224517783468, 1.227708137134712)
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.0974650051256982, 0.6978015749512891, 1.367254387644963, -2.5640097871294514, -1.1961307959005056, 1.227609988154942)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p8, g1)->[]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.288444541095793, -2.092804479843474, 2.1333200861510053, 2.031659261703003, -2.839672637029386, 3.2696698595590377)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.

# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.253215221490175, 0.5360494387414994, 1.6529257867212892, -0.6777827040134445, 0.8438041349790584, 1.5927188884206016)
# go on
# q_grasp: (2.213971305701897, 0.6235404195834842, 1.6418175176054035, -0.7260751464719153, 0.765467675995369, 1.627881973710086)
# obstacles: [4L, 1, 2, 3]
# ...
# Action plan (9, 0.000): [move_free(q135, #q76, #t5306), pick(4, p94, g53, #q76, #t5008), move_holding(#q76, #q75, 4, g53, #t5305), place(4, #p30, g53, #q75, #t5007), move_free(#q75, #q78, #t5307), pick(4, #p30, g52, #q78, #t5010), move_holding(#q78, #q77, 4, g52, #t5308), place(4, p97, g52, #q77, #t5009), move_free(#q77, q135, #t5309)]
# iter=0, outs=1) sample-pose:(4, 2)->[(p98)]
# q_approach: (1.3239092674998256, -0.913075697381109, -1.2866349713191674, -0.25220496759976035, -1.3405197844067844, -0.4727732317203275)
# go on
# q_grasp: (1.303299953377339, -0.9419443644157816, -1.3795191137790244, -0.26972061653592805, -1.2192428241932827, -0.45621696150227)
# iter=inf, outs=1) inverse-kinematics:(4, p98, g52)->[(q137, c130)]
# iter=inf, outs=1) test-cfree-traj-pose:(c130, 5, p95)->[()]
# Sampling for up to 0.466 seconds
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.601668602429667, 0.7582711439361137, 1.4223644311908383, 0.0056007278175835345, 1.2885591778780634, 0.013885715637334749)
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.601597025947881, 0.7584962968926745, 1.4217737804356811, 0.005594181618730603, 1.2889628128617157, 0.0139599306455392)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.1400696172037188, -0.7558478395861431, -1.321566536729782, 0.19230572285024108, -1.338798865104503, -2.595383784910205)
# go on
# q_grasp: (1.1542434798094006, -0.7961470599461853, -1.3991927168498592, 0.20367391446971927, -1.2213850086540505, -2.6074288478177907)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g53)->[(q138, c131)]
# iter=inf, outs=1) test-cfree-traj-pose:(c131, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c131, 4, p94)->[()]
# q_approach: (-2.543961603543597, 2.1258710605688504, -2.207204466205176, -1.59377270193743, -2.825491870887941, 0.25414106421815025)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.8438835931626545, 0.580454546956529, 2.0166073443036465, 0.5703586094941046, 0.6372386640633875, 1.056902399475976)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.8474254826632865, 2.07139596038283, -1.4741336663540074, 0.5523777935582104, 2.481696887492223, 1.9822991235066252)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g53)->[]
# q_approach: (-0.4921163347895427, -2.0701647376340784, 1.8949675623593005, 0.8111599172112912, 2.8208584546282665, 0.2898299187461891)
# go on
# q_grasp: (-0.5249531700465547, -2.1779009244586844, 1.9955223078251656, 0.8699837918686945, 2.821427830296545, 0.3177579225542566)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.142203010965003, 0.7308099618003833, 1.3316708312375194, -0.40538596614294187, 1.3397367148492387, 2.2384664321043446)
# go on
# q_grasp: (2.111503214547048, 0.7728047930701661, 1.3995853076608251, -0.4275179773112448, 1.228907340778163, 2.25979516778572)
# iter=inf, outs=1) inverse-kinematics:(4, p97, g52)->[(q140, c132)]
# iter=inf, outs=1) test-cfree-traj-pose:(c132, 5, p95)->[()]
# iter=1, outs=1) sample-pose:(4, 2)->[(p99)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3484916426741844, -0.5807882109954932, -1.7611837533167374, 2.9432366144152207, 1.2275669424263176, -3.4662606748524136)
# go on
# q_grasp: (1.3297584613497124, -0.6338113174142481, -1.847990564337445, 2.9218562153147603, 1.0882151409387932, -3.4479427726242386)
# iter=inf, outs=1) inverse-kinematics:(4, p99, g52)->[(q141, c133)]
# iter=inf, outs=1) test-cfree-traj-pose:(c133, 5, p95)->[()]
# q_approach: (2.862543538639242, -1.0686339835512435, 3.046752348391509, 0.2970129685071786, 1.3324103730939003, 0.9866044706249797)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p99, g53)->[]
# Sampling while complexity <= 3
# iter=2, outs=1) sample-grasp:(4)->[(g54)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.6028643814108077, 0.850769919605404, 1.281201955071678, 0.006550447484017044, 1.4377789547826387, 0.012880132184920822)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.1020178292487788, -0.8487070381807883, -1.1589883311196238, 0.22964083830259482, -1.5009258274363515, 3.6612177734020808)
# go on
# q_grasp: (1.1191867097679333, -0.8723704781506858, -1.25958755640255, 0.23991102391495076, -1.3768617534438545, 3.6468561739507037)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g54)->[(q142, c134)]
# iter=inf, outs=1) test-cfree-traj-pose:(c134, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c134, 4, p94)->[()]
# q_approach: (0.10529288198799192, -0.850200341167127, -3.0380699224347936, 2.52725918530654, -0.7995573817878887, 1.912810540430499)
# go on
# q_grasp: (0.3734353595978223, -1.020064555703983, -2.9501157717497155, 2.6215437216946107, -0.9705546107202945, 2.063095190952371)
# Approach motion failed
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.988512094783624, -1.905062442154791, 2.2934199580240633, -1.2149384495812534, -3.0500767487813834, -1.0240629470885965)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.12025675652555111, -0.867221629113162, -3.0448570345406316, 2.5431486424448226, -0.8248371202109325, 1.905626634019773)
# go on
# q_grasp: (0.37344635803037235, -1.0201977051802227, -2.9501754473608814, 2.6216124296068934, -0.9707247269573487, 2.0629871958118624)
# Approach motion failed
# q_approach: (0.10606423857947837, -0.8500104837307721, -3.037750013850164, 2.527115774328901, -0.7994626269858688, 1.9138309664465927)
# go on
# q_grasp: (0.3734323268110252, -1.0200278714317468, -2.950099328437147, 2.621524784780644, -0.9705077401778098, 2.0631249490477535)
# Approach motion failed
# iter=inf, outs=0) inverse-kinematics:(4, p99, g54)->[]
# q_approach: (-2.6167812115056246, 2.1660210785454432, -2.2443992316388526, -1.5900457224098121, -2.7213427796897025, 0.18880573864426742)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.2914106609487861, -0.580598952050505, -2.140413932106236, -2.3211170694676877, 0.6037545419396907, 0.8012123103094784)
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.8408176948787158, -0.5925197568431919, -1.5428529462118503, 0.5027578545418325, -0.8534803401449668, -1.3690816476411858)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-2.627862695965636, 2.1649059501070513, -2.2501043657180886, -1.562352515976365, -2.7204592979106557, 0.20690877463982998)
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p98, g54)->[]
#
# Iteration: 6 | Complexity: 3 | Skeletons: 2 | Skeleton Queue: 13 | Disabled: 0 | Evaluations: 55 | Eager Calls: 0 | Cost: inf | Search Time: 1.033 | Sample Time: 1.211 | Total Time: 2.245
# Attempt: 1 | Results: 414 | Depth: 0 | Success: True | Time: 0.468
# Stream plan (25, 17, 0.001): [sample-grasp:(4)->(g53), inverse-kinematics:(4, p94, g53)->(q138, c131), test-cfree-traj-pose:(c131, 5, p95)->(), sample-grasp:(4)->(g52), sample-pose:(4, 1)->(p96), inverse-kinematics:(4, p96, g52)->(q136, c129), test-cfree-traj-pose:(c129, 5, p95)->(), test-cfree-traj-pose:(c131, 4, p94)->(), sample-pose:(4, 3)->(#p31), inverse-kinematics:(4, #p31, g53)->(#q79, #t5175), test-cfree-traj-pose:(#t5175, 5, p95)->(), inverse-kinematics:(4, #p31, g52)->(#q80, #t5176), test-cfree-traj-pose:(#t5176, 5, p95)->(), test-cfree-traj-pose:(#t5176, 4, #p31)->(), test-cfree-pose-pose:(4, p96, 5, p95)->(), test-cfree-pose-pose:(4, #p31, 5, p95)->(), test-cfree-approach-pose:(4, p94, g53, 5, p95)->(), test-cfree-approach-pose:(4, p96, g52, 5, p95)->(), test-cfree-approach-pose:(4, #p31, g53, 5, p95)->(), test-cfree-approach-pose:(4, #p31, g52, 5, p95)->(), plan-free-motion:(q136, q135)->(#t5615), plan-free-motion:(q135, q138)->(#t5619), plan-free-motion:(#q79, #q80)->(#t5617), plan-holding-motion:(q138, #q79, 4, g53)->(#t5616), plan-holding-motion:(#q80, q136, 4, g52)->(#t5618)]
# Action plan (9, 0.000): [move_free(q135, q138, #t5619), pick(4, p94, g53, q138, c131), move_holding(q138, #q79, 4, g53, #t5616), place(4, #p31, g53, #q79, #t5175), move_free(#q79, #q80, #t5617), pick(4, #p31, g52, #q80, #t5176), move_holding(#q80, q136, 4, g52, #t5618), place(4, p96, g52, q136, c129), move_free(q136, q135, #t5615)]
# Sampling for up to 0.306 seconds
# iter=inf, outs=0) sample-pose:(4, 3)->[]
# q_approach: (-1.4083697266368953, -2.1111307770776992, 2.641328959068175, 2.6707850586107913, -3.023820858552185, 2.5549291671360392)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.5123678802550204, -2.182239002016633, 2.7512647322162764, 0.8799876843471878, 2.7589745000287746, 1.5612814839917983)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6657936017203192, 2.0846092930862077, -2.2662850028637456, 0.3349567963933538, 2.8887307840768055, -2.9968354413802283)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p96, g54)->[]
# q_approach: (-0.9495265607401016, -0.4182289115740624, -1.8480572333121181, 0.5620853840111462, -0.7145987084361548, -1.3996576063444677)
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.5384126510301228, 2.2024298220362817, -2.495407038080798, -0.9506989391913426, -2.6079599530658877, 0.6018244082674189)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.584626543509753, 0.3943084591969754, 2.5117686438097087, 1.0697782656754145, 0.49291880143033934, 0.5162212478635819)
# go on
# q_grasp: (1.8508023351732037, 0.48465155872086196, 2.5614575278807834, 1.5881704446840195, 0.41657921065602593, 0.23271481581126588)
# iter=inf, outs=1) inverse-kinematics:(4, p97, g54)->[(q146, c135)]
# iter=inf, outs=1) test-cfree-traj-pose:(c135, 5, p95)->[()]
# iter=2, outs=1) sample-pose:(4, 1)->[(p100)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.7167242541290315, -0.7893595415967556, -1.2393976631285006, 0.3122439227735831, -1.4224728209054078, -2.41670407332863)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.8432877343010248, 0.7922673923371654, 1.454485164633136, 0.10177785609601839, 1.313679434135406, 0.19154303005605558)
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.7163114873860589, -0.7878841178815309, -1.243030060274219, 0.3123593495867372, -1.420055562825418, -2.417012632194128)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p100, g54)->[]
# q_approach: (-1.2695670714982077, -0.714765072928554, -1.5553556917911342, -3.05004535865874, 1.1900038113757008, 0.2193821897125267)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.4664730688669616, 0.7129606707488798, 1.372331210504763, -2.88378561953128, -1.283890062022476, -2.381761914808497)
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2700730443573343, -0.7133821794301006, -1.5592803513790525, -3.0498693956312004, 1.1872450638444052, 0.21859192417833082)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p100, g53)->[]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p97, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p94, g54, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p97, g54, 5, p95)->[()]
# iter=inf, outs=1) plan-free-motion:(q135, q142)->[(c136)]
# iter=inf, outs=1) plan-free-motion:(q146, q135)->[(c137)]
# iter=inf, outs=1) plan-holding-motion:(q142, q146, 4, g54)->[(c138)]
# Summary: {complexity: 3, cost: 0.000, evaluations: 67, iterations: 6, length: 2, run_time: 3.129, sample_time: 1.567, search_time: 1.562, skeletons: 3, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 7926 | p_success: 0.965 | overhead: 0.001
# External: sample-grasp | n: 9976 | p_success: 0.989 | overhead: 0.002
# External: inverse-kinematics | n: 38003 | p_success: 0.184 | overhead: 0.045
# External: plan-free-motion | n: 6218 | p_success: 0.895 | overhead: 0.123
# External: plan-holding-motion | n: 2424 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3339 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6569 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 12246 | p_success: 0.940 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          4119607 function calls (4002421 primitive calls) in 3.428 seconds
#
#    Ordered by: internal time
#    List reduced from 1511 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      7457    0.535    0.000    0.535    0.000 {pybullet.calculateInverseKinematics}
#     46470    0.182    0.000    0.182    0.000 {pybullet.resetJointState}
#      3423    0.181    0.000    0.186    0.000 /home/rnb/Projects/pddlstream/pddlstream/algorithms/../../FastDownward/builds/release64/bin/translate/pddl/conditions.py:290(instantiate)
#         3    0.128    0.043    0.129    0.043 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#         6    0.091    0.015    0.091    0.015 {posix.read}
#    107774    0.067    0.000    0.086    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#    215832    0.064    0.000    0.064    0.000 {method 'read' of 'file' objects}
#      7580    0.058    0.000    0.151    0.000 /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:2508(within_tol)
#         2    0.055    0.027    0.215    0.108 /usr/lib/python2.7/pickle.py:851(load)
#     23622    0.041    0.000    0.041    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q135 q142 c136
#  2) pick 4 p94 g54 q142 c134
#  3) move_holding q142 q146 4 g54 c138
#  4) place 4 p97 g54 q146 c135
#  5) move_free q146 q135 c137

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_wFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	36830.2 ms/20 = 1841.5 ms (703.19/5481.78)
# sample_grasps_4: 	78.7 ms/20 = 3.9 ms (2.878/9.41)
# get_stable_4_1: 	40.1 ms/45 = 0.9 ms (0.499/2.171)
# ik_fn: 	13152.8 ms/226 = 58.2 ms (0.695/270.329)
# check_feas: 	748.9 ms/226 = 3.3 ms (0.685/8.933)
# ReachChecker: 	202.1 ms/226 = 0.9 ms (0.233/2.528)
# GraspChecker: 	388.8 ms/212 = 1.8 ms (0.533/4.853)
# get_stable_4_2: 	14.4 ms/16 = 0.9 ms (0.489/1.335)
# get_stable_4_3: 	0.0 ms/5 = 0.0 ms (0.003/0.006)
# free_motion_gen: 	2187.3 ms/45 = 48.6 ms (4.008/86.75)
# holding_motion_gen: 	1052.8 ms/23 = 45.8 ms (27.388/78.251)
#
# solve-mean: 1841.5 ms
# solve-median: 1100.7 ms
# success rate: 100.0 %

# %% [markdown]
# ### Test without IK checkers

# %%
gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)

# %%
log_woFeas = []
for _ in range(20):
    problem = pddlstream_from_problem_rnb(pscene, robot_body, body_names=body_names, 
                                          movable=movable_bodies, checkers=[],
                                          tool_name=TOOL_NAME, tool_link_name=TOOL_LINK, mplan=mplan)
    _, _, _, stream_map, init, goal = problem
    print('Init:', init)
    print('Goal:', goal)
    print('Streams:', str_from_object(set(stream_map)))
    with Profiler():
        with LockRenderer(lock=not True):
            with gtimer.block("solve"):
                solution = solve(problem, algorithm='adaptive', unit_costs=False, success_cost=INF, max_time=10)
            saver.restore()
    print_solution(solution)
    plan, cost, evaluations = solution
    log_woFeas.append(cost)
# Out:
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q87), ('AtConf', q87), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p91), ('AtPose', 4L, p91), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p91, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p92), ('AtPose', 5L, p92), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p92, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q87), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.179
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g20), inverse-kinematics:(4, p91, #g20)->(#q45, #t1783), test-cfree-traj-pose:(#t1783, 4, p91)->(), test-cfree-traj-pose:(#t1783, 5, p92)->(), sample-pose:(4, 1)->(#p22), inverse-kinematics:(4, #p22, #g20)->(#q46, #t1784), test-cfree-traj-pose:(#t1784, 5, p92)->(), test-cfree-pose-pose:(4, #p22, 5, p92)->(), test-cfree-approach-pose:(4, p91, #g20, 5, p92)->(), test-cfree-approach-pose:(4, #p22, #g20, 5, p92)->(), plan-free-motion:(#q46, q87)->(#t1825), plan-free-motion:(q87, #q45)->(#t1826), plan-holding-motion:(#q45, #q46, 4, #g20)->(#t1827)]
# Action plan (5, 0.000): [move_free(q87, #q45, #t1826), pick(4, p91, #g20, #q45, #t1783), move_holding(#q45, #q46, 4, #g20, #t1827), place(4, #p22, #g20, #q46, #t1784), move_free(#q46, q87, #t1825)]
# iter=0, outs=1) sample-grasp:(4)->[(g54)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (2.2153076140451113, 0.7193415696511525, -0.9317570922425451, -2.3814289460571474, 2.3473192363726336, 3.038316508190859, -0.551065666758976)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g54)->[]
# Sampling for up to 0.174 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g55)]
# q_approach: (-1.4519024783258208, -1.1761139853033047, 2.003800739678055, -1.631944331886783, 0.9823133216275483, 1.3489679522314098, 0.514967537425978)
# go on
# q_grasp: (-1.391637661736404, -1.1990650085098076, 2.038096478826575, -1.737842637684051, 1.0282894835716596, 1.42714513042707, 0.4867566456869842)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p91, g55)->[]
# iter=2, outs=1) sample-grasp:(4)->[(g56)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6336747065619281, 0.34522173469389483, -0.5947815881515433, -2.502758260109791, 0.46875257127886316, 2.9125348747356083, 0.8914942618173828)
# go on
# q_grasp: (1.4447808138643843, 0.4809613248249993, -0.38516408394639184, -2.4325302881399318, 0.6076872919111654, 2.998059992093964, 0.7767776500515463)
# iter=inf, outs=1) inverse-kinematics:(4, p91, g56)->[(q89, c105)]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 4, p91)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c105, 5, p92)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p93)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.17683829558120712, 0.32904683636731263, -0.6592590209016547, -2.521317493595038, 0.8225037472099498, 2.8718055124759942, 0.013270147742465448)
# go on
# q_grasp: (-0.3510109058095045, 0.48142753585519815, -0.4513364721643871, -2.4227048735375294, 1.0589933120437227, 2.9211035860247003, -0.1784026176912355)
# iter=inf, outs=1) inverse-kinematics:(4, p93, g56)->[(q90, c106)]
# iter=inf, outs=1) test-cfree-traj-pose:(c106, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p93, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p91, g56, 5, p92)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p93, g56, 5, p92)->[()]
# iter=inf, outs=1) plan-free-motion:(q90, q87)->[(c107)]
# iter=inf, outs=1) plan-free-motion:(q87, q89)->[(c108)]
# iter=inf, outs=1) plan-holding-motion:(q89, q90, 4, g56)->[(c109)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.567, sample_time: 0.355, search_time: 0.212, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6922 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8978 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30199 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5904 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2265 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3171 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6240 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11575 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1635876 function calls (1572242 primitive calls) in 0.860 seconds
#
#    Ordered by: internal time
#    List reduced from 1479 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.157    0.052    0.158    0.053 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99794    0.057    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.025    0.186    0.093 /usr/lib/python2.7/pickle.py:851(load)
#       635    0.047    0.000    0.047    0.000 {pybullet.calculateInverseKinematics}
#         2    0.040    0.020    0.040    0.020 {posix.read}
#   49977/1    0.036    0.000    0.089    0.089 /usr/lib/python2.7/pickle.py:269(save)
#    199864    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#     99762    0.028    0.000    0.039    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#      5089    0.024    0.000    0.024    0.000 {pybullet.resetJointState}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q87 q89 c108
#  2) pick 4 p91 g56 q89 c105
#  3) move_holding q89 q90 4 g56 c109
#  4) place 4 p93 g56 q90 c106
#  5) move_free q90 q87 c107
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q91), ('AtConf', q91), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p94), ('AtPose', 4L, p94), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p94, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p95), ('AtPose', 5L, p95), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p95, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q91), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.082
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.187
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g21), sample-pose:(4, 1)->(#p23), inverse-kinematics:(4, #p23, #g21)->(#q48, #t1843), test-cfree-traj-pose:(#t1843, 5, p95)->(), inverse-kinematics:(4, p94, #g21)->(#q47, #t1842), test-cfree-traj-pose:(#t1842, 5, p95)->(), test-cfree-traj-pose:(#t1842, 4, p94)->(), test-cfree-pose-pose:(4, #p23, 5, p95)->(), test-cfree-approach-pose:(4, p94, #g21, 5, p95)->(), test-cfree-approach-pose:(4, #p23, #g21, 5, p95)->(), plan-free-motion:(#q48, q91)->(#t1884), plan-free-motion:(q91, #q47)->(#t1885), plan-holding-motion:(#q47, #q48, 4, #g21)->(#t1886)]
# Action plan (5, 0.000): [move_free(q91, #q47, #t1885), pick(4, p94, #g21, #q47, #t1842), move_holding(#q47, #q48, 4, #g21, #t1886), place(4, #p23, #g21, #q48, #t1843), move_free(#q48, q91, #t1884)]
# iter=0, outs=1) sample-grasp:(4)->[(g57)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p96)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p96, g57)->[]
# Sampling for up to 0.190 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p97)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4146220486130724, 0.7232147084839358, -0.45396643209398907, -1.7269376795261238, 0.10632676531683208, 1.9076666130766085, 0.32343035190404157)
# go on
# q_grasp: (-0.4214149553484992, 0.7565514918323127, -0.4430704954980897, -1.8107676641982782, 0.1215901113395851, 2.023001410760455, 0.3131698887394583)
# iter=inf, outs=1) inverse-kinematics:(4, p97, g57)->[(q92, c110)]
# iter=inf, outs=1) test-cfree-traj-pose:(c110, 5, p95)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9423041884060136, 0.5806862769241551, -0.09687202459664623, -1.877247129615524, 0.22729663007276368, 1.950576631629773, 0.9706518620516507)
# go on
# q_grasp: (0.9514770005052784, 0.6169544583381473, -0.08418407628866093, -1.9586787500222456, 0.24768215812150873, 2.0682028270713277, 0.9576246813187703)
# iter=inf, outs=1) inverse-kinematics:(4, p94, g57)->[(q93, c111)]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c111, 4, p94)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p97, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p94, g57, 5, p95)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p97, g57, 5, p95)->[()]
# iter=inf, outs=1) plan-free-motion:(q92, q91)->[(c112)]
# iter=inf, outs=1) plan-free-motion:(q91, q93)->[(c113)]
# iter=inf, outs=1) plan-holding-motion:(q93, q92, 4, g57)->[(c114)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.398, sample_time: 0.179, search_time: 0.219, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6924 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8979 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30202 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5906 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2266 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3172 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6242 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11578 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1586784 function calls (1523183 primitive calls) in 0.701 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.104    0.035    0.105    0.035 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99824    0.060    0.000    0.076    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.050    0.025    0.193    0.097 /usr/lib/python2.7/pickle.py:851(load)
#   49991/1    0.037    0.000    0.090    0.090 /usr/lib/python2.7/pickle.py:269(save)
#    199924    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#         2    0.032    0.016    0.032    0.016 {posix.read}
#     99792    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#     49926    0.015    0.000    0.024    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#     99980    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q91 q93 c113
#  2) pick 4 p94 g57 q93 c111
#  3) move_holding q93 q92 4 g57 c114
#  4) place 4 p97 g57 q92 c110
#  5) move_free q92 q91 c112
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q94), ('AtConf', q94), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p98), ('AtPose', 4L, p98), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p98, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p99), ('AtPose', 5L, p99), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p99, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q94), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.096
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.235
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#
->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p100)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.593206118587994, 0.35416606193583394, -0.3105819867448346, -2.3853157801536806, -0.9345368916514414, 2.8710291314450456, -0.547692875286517)
# go on
# q_grasp: (-0.5888944430418368, 0.5162444662267394, -0.35866755309860265, -2.2995597880548875, -0.9907143472504004, 2.9664894484585296, -0.4812647483047807)
# iter=inf, outs=1) inverse-kinematics:(4, p100, g62)->[(q102, c116)]
# iter=inf, outs=1) test-cfree-traj-pose:(c116, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c115, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p100, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p98, g62, 5, p99)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p100, g62, 5, p99)->[()]
# iter=inf, outs=1) plan-free-motion:(q102, q94)->[(c117)]
# iter=inf, outs=1) plan-free-motion:(q94, q101)->[(c118)]
# iter=inf, outs=1) plan-holding-motion:(q101, q102, 4, g62)->[(c119)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 40, iterations: 3, length: 2, run_time: 0.563, sample_time: 0.294, search_time: 0.269, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6925 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8984 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30208 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5908 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2267 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3173 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6244 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11581 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1624438 function calls (1560803 primitive calls) in 0.844 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.127    0.042    0.127    0.042 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99852    0.054    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.179    0.090 /usr/lib/python2.7/pickle.py:851(load)
#   50008/1    0.037    0.000    0.091    0.091 /usr/lib/python2.7/pickle.py:269(save)
#    199980    0.035    0.000    0.035    0.000 {method 'read' of 'file' objects}
#       388    0.030    0.000    0.030    0.000 {pybullet.calculateInverseKinematics}
#     99820    0.026    0.000    0.036    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.024    0.012    0.024    0.012 {posix.read}
#      3297    0.017    0.000    0.017    0.000 {pybullet.resetJointState}
#     49943    0.016    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q94 q101 c118
#  2) pick 4 p98 g62 q101 c115
#  3) move_holding q101 q102 4 g62 c119
#  4) place 4 p100 g62 q102 c116
#  5) move_free q102 q94 c117
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q103), ('AtConf', q103), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p101), ('AtPose', 4L, p101), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p101, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p102), ('AtPose', 5L, p102), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p102, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q103), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.019
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.027 | Sample Time: 0.000 | Total Time: 0.027
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.112
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.212
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g23), inverse-kinematics:(4, p101, #g23)->(#q51, #t1960), test-cfree-traj-pose:(#t1960, 5, p102)->(), sample-pose:(4, 1)->(#p25), inverse-kinematics:(4, #p25, #g23)->(#q52, #t1961), test-cfree-traj-pose:(#t1961, 5, p102)->(), test-cfree-traj-pose:(#t1960, 4, p101)->(), test-cfree-pose-pose:(4, #p25, 5, p102)->(), test-cfree-approach-pose:(4, p101, #g23, 5, p102)->(), test-cfree-approach-pose:(4, #p25, #g23, 5, p102)->(), plan-free-motion:(q103, #q51)->(#t2002), plan-free-motion:(#q52, q103)->(#t2003), plan-holding-motion:(#q51, #q52, 4, #g23)->(#t2004)]
# Action plan (5, 0.000): [move_free(q103, #q51, #t2002), pick(4, p101, #g23, #q51, #t1960), move_holding(#q51, #q52, 4, #g23, #t2004), place(4, #p25, #g23, #q52, #t1961), move_free(#q52, q103, #t2003)]
# iter=0, outs=1) sample-grasp:(4)->[(g63)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.6258714181493832, 0.5921668573496742, -0.7633860313746874, -2.0827445706669643, 0.6059840666343767, 2.12533083457955, 0.726767308313793)
# go on
# q_grasp: (1.5992686215647776, 0.6653403690359281, -0.6959140140639104, -2.1112569265986587, 0.6881009814682999, 2.212560675836015, 0.6789875528302193)
# iter=inf, outs=1) inverse-kinematics:(4, p101, g63)->[(q104, c120)]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 5, p102)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p103)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2215517413249337, 0.3516141331126039, 0.29747090075794413, -2.3682587415318697, 0.531541765536062, 2.7784918344743295, 2.2587067101664733)
# go on
# q_grasp: (-1.2040515189769647, 0.49789320966600153, 0.3132095678680738, -2.3192172262036994, 0.5464177153539975, 2.8830421268426747, 2.2384659367052793)
# iter=inf, outs=1) inverse-kinematics:(4, p103, g63)->[(q105, c121)]
# iter=inf, outs=1) test-cfree-traj-pose:(c121, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c120, 4, p101)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p103, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p101, g63, 5, p102)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p103, g63, 5, p102)->[()]
# iter=inf, outs=1) plan-free-motion:(q103, q104)->[(c122)]
# iter=inf, outs=1) plan-free-motion:(q105, q103)->[(c123)]
# iter=inf, outs=1) plan-holding-motion:(q104, q105, 4, g63)->[(c124)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.508, sample_time: 0.253, search_time: 0.255, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6926 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8985 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30210 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5910 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2268 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3174 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6246 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11584 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1578393 function calls (1514793 primitive calls) in 0.832 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.179    0.060    0.180    0.060 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99886    0.055    0.000    0.070    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#   50021/1    0.053    0.000    0.133    0.133 /usr/lib/python2.7/pickle.py:269(save)
#         2    0.045    0.023    0.182    0.091 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.039    0.019    0.039    0.019 {posix.read}
#    200048    0.038    0.000    0.038    0.000 {method 'read' of 'file' objects}
#     99854    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49956    0.021    0.000    0.035    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100040    0.021    0.000    0.021    0.000 {method 'write' of 'file' objects}
#         2    0.018    0.009    0.018    0.009 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q103 q104 c122
#  2) pick 4 p101 g63 q104 c120
#  3) move_holding q104 q105 4 g63 c124
#  4) place 4 p103 g63 q105 c121
#  5) move_free q105 q103 c123
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q106), ('AtConf', q106), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p104), ('AtPose', 4L, p104), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p104, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p105), ('AtPose', 5L, p105), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p105, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q106), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.009
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g24), inverse-kinematics:(4, p104, #g24)->(#q53, #t2019), test-cfree-traj-pose:(#t2019, 4, p104)->(), sample-pose:(4, 1)->(#p26), inverse-kinematics:(4, #p26, #g24)->(#q54, #t2020), test-cfree-traj-pose:(#t2020, 5, p105)->(), test-cfree-traj-pose:(#t2019, 5, p105)->(), test-cfree-pose-pose:(4, #p26, 5, p105)->(), test-cfree-approach-pose:(4, p104, #g24, 5, p105)->(), test-cfree-approach-pose:(4, #p26, #g24, 5, p105)->(), plan-free-motion:(q106, #q53)->(#t2062), plan-free-motion:(#q54, q106)->(#t2063), plan-holding-motion:(#q53, #q54, 4, #g24)->(#t2061)]
# Action plan (5, 0.000): [move_free(q106, #q53, #t2062), pick(4, p104, #g24, #q53, #t2019), move_holding(#q53, #q54, 4, #g24, #t2061), place(4, #p26, #g24, #q54, #t2020), move_free(#q54, q106, #t2063)]
# iter=0, outs=1) sample-grasp:(4)->[(g64)]
# q_approach: (0.192120065456175, 0.5507885500113415, 0.6996004181985822, -2.120028026909611, -0.31944583175786967, 2.2458424224229803, 1.3644598539399206)
# go on
# q_grasp: (0.2355012004362731, 0.6298479819802765, 0.6389457089918664, -2.150846691214588, -0.387275341967781, 2.3485802281198036, 1.4084214406300628)
# iter=inf, outs=1) inverse-kinematics:(4, p104, g64)->[(q107, c125)]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 4, p104)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p106, g64)->[]
# Sampling for up to 0.182 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.04850148378346279, 0.5935509460890934, -0.9405148754347938, -2.216703621199621, 0.649400094786745, 2.160496025984867, 0.5051470742256251)
# go on
# q_grasp: (-0.0032312995073874714, 0.6707385780877653, -0.8440620615149829, -2.240055313868342, 0.7500890087786326, 2.245373512353603, 0.44619986822891633)
# iter=inf, outs=1) inverse-kinematics:(4, p107, g64)->[(q108, c126)]
# iter=inf, outs=1) test-cfree-traj-pose:(c126, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c125, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p107, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p104, g64, 5, p105)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p107, g64, 5, p105)->[()]
# iter=inf, outs=1) plan-free-motion:(q106, q107)->[(c127)]
# iter=inf, outs=1) plan-free-motion:(q108, q106)->[(c128)]
# iter=inf, outs=1) plan-holding-motion:(q107, q108, 4, g64)->[(c129)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 38, iterations: 3, length: 2, run_time: 0.431, sample_time: 0.200, search_time: 0.231, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6928 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 8986 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30213 | p_success: 0.217 | overhead: 0.048
# External: plan-free-motion | n: 5912 | p_success: 0.891 | overhead: 0.126
# External: plan-holding-motion | n: 2269 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3175 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6248 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11587 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590542 function calls (1526913 primitive calls) in 0.740 seconds
#
#    Ordered by: internal time
#    List reduced from 1475 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.111    0.037    0.112    0.037 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#     99912    0.058    0.000    0.074    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.049    0.024    0.188    0.094 /usr/lib/python2.7/pickle.py:851(load)
#   50035/1    0.041    0.000    0.102    0.102 /usr/lib/python2.7/pickle.py:269(save)
#    200100    0.034    0.000    0.034    0.000 {method 'read' of 'file' objects}
#         2    0.033    0.016    0.033    0.016 {posix.read}
#     99880    0.029    0.000    0.040    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#     49970    0.016    0.000    0.027    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100068    0.016    0.000    0.016    0.000 {method 'write' of 'file' objects}
#         2    0.015    0.008    0.015    0.008 {posix.fork}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q106 q107 c127
#  2) pick 4 p104 g64 q107 c125
#  3) move_holding q107 q108 4 g64 c129
#  4) place 4 p107 g64 q108 c126
#  5) move_free q108 q106 c128
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q109), ('AtConf', q109), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p108), ('AtPose', 4L, p108), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p108, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p109), ('AtPose', 5L, p109), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p109, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q109), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.078
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.178
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g25), sample-pose:(4, 1)->(#p27), inverse-kinematics:(4, #p27, #g25)->(#q56, #t2079), test-cfree-traj-pose:(#t2079, 5, p109)->(), inverse-kinematics:(4, p108, #g25)->(#q55, #t2078), test-cfree-traj-pose:(#t2078, 4, p108)->(), test-cfree-traj-pose:(#t2078, 5, p109)->(), test-cfree-pose-pose:(4, #p27, 5, p109)->(), test-cfree-approach-pose:(4, p108, #g25, 5, p109)->(), test-cfree-approach-pose:(4, #p27, #g25, 5, p109)->(), plan-free-motion:(#q56, q109)->(#t2121), plan-free-motion:(q109, #q55)->(#t2122), plan-holding-motion:(#q55, #q56, 4, #g25)->(#t2120)]
# Action plan (5, 0.000): [move_free(q109, #q55, #t2122), pick(4, p108, #g25, #q55, #t2078), move_holding(#q55, #q56, 4, #g25, #t2120), place(4, #p27, #g25, #q56, #t2079), move_free(#q56, q109, #t2121)]
# iter=0, outs=1) sample-grasp:(4)->[(g65)]
# iter=0, outs=1) sample-pose:(4, 1)->[(p110)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.5217681844440692, 1.2497063160207205, -1.3138238471961572, -2.3180458030950035, 1.2502045493133906, 2.208513407822154, 1.5894036354803658)
# go on
# q_grasp: (0.4342072331098595, 1.293684961859948, -1.2012778571394627, -2.2771728227373607, 1.348189582093488, 2.2746134625997696, 1.543672137109852)
# Approach motion failed
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p110, g65)->[]
# Sampling for up to 0.173 seconds
# iter=1, outs=1) sample-pose:(4, 1)->[(p111)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.2238007828552059, 0.6195245845566902, -1.0012289839782778, -2.360286950901237, 0.4023643377499472, 2.575011702036958, 2.3387252338147135)
# go on
# q_grasp: (0.07282095162398053, 0.7034744262953286, -0.8474678467296006, -2.3403988048280904, 0.4871741433601139, 2.6766219431673943, 2.278123828966335)
# iter=inf, outs=1) inverse-kinematics:(4, p111, g65)->[(q111, c130)]
# iter=inf, outs=1) test-cfree-traj-pose:(c130, 5, p109)->[()]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.2953546580612645, 0.2928546457784743, -0.41955314970829743, -2.57743258613227, -0.6468471516090225, 3.141816595233023, 1.8179728179768198)
# go on
# q_grasp: (1.285359243651392, 0.4804471324872723, -0.4189707342980187, -2.490843305451842, -0.628943206735579, 3.2496955344992204, 1.8345308590952234)
# Approach motion failed
# q_approach: (-1.5939740110777156, -0.3265470775204209, 2.624575519636656, -2.614803286689616, 0.15104275831516012, 3.1745713205234622, 1.1856096404426624)
# go on
# q_grasp: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p108, g65)->[]
# iter=1, outs=1) sample-grasp:(4)->[(g66)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.31674771729693757, 0.8468130236648528, -1.04200439558982, -2.0797521618228, 1.292522586567922, 1.6462263563508819, 1.111236773955241)
# go on
# ...
#  3) move_holding q286 q315 4 g102 c251
#  4) place 4 p184 g102 q315 c239
#  5) move_free q315 q322 c249
#  6) pick 4 p184 g104 q322 c245
#  7) move_holding q322 q319 4 g104 c252
#  8) place 4 p185 g104 q319 c243
#  9) move_free q319 q303 c248
# 10) pick 4 p185 g100 q303 c233
# 11) move_holding q303 q275 4 g100 c250
# 12) place 4 p175 g100 q275 c227
# 13) move_free q275 q273 c246
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q323), ('AtConf', q323), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p187), ('AtPose', 4L, p187), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p187, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p188), ('AtPose', 5L, p188), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p188, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q323), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-pose-pose]
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.007
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.092
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.200
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g39), inverse-kinematics:(4, p187, #g39)->(#q124, #t6812), test-cfree-traj-pose:(#t6812, 4, p187)->(), test-cfree-traj-pose:(#t6812, 5, p188)->(), sample-pose:(4, 1)->(#p55), inverse-kinematics:(4, #p55, #g39)->(#q125, #t6813), test-cfree-traj-pose:(#t6813, 5, p188)->(), test-cfree-pose-pose:(4, #p55, 5, p188)->(), test-cfree-approach-pose:(4, p187, #g39, 5, p188)->(), test-cfree-approach-pose:(4, #p55, #g39, 5, p188)->(), plan-free-motion:(#q125, q323)->(#t6855), plan-free-motion:(q323, #q124)->(#t6856), plan-holding-motion:(#q124, #q125, 4, #g39)->(#t6854)]
# Action plan (5, 0.000): [move_free(q323, #q124, #t6856), pick(4, p187, #g39, #q124, #t6812), move_holding(#q124, #q125, 4, #g39, #t6854), place(4, #p55, #g39, #q125, #t6813), move_free(#q125, q323, #t6855)]
# iter=0, outs=1) sample-grasp:(4)->[(g105)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (1.3913936235978617, 0.6473202107520545, -0.5811027389467883, -1.900133139286519, 0.5076304860483215, 1.9148299600943661, 0.781916790402671)
# go on
# q_grasp: (1.398103623530459, 0.6903477801426051, -0.5461776682705444, -1.96870440285634, 0.5584177305168011, 2.0175317388372718, 0.7516506681507357)
# obstacles: [4L, 1, 2, 3]
# q_approach: (0.9252176461857935, 0.5499701425495943, -0.07162518045062206, -1.924093777707574, 0.20833247549578734, 2.0041072069347488, 0.9843463195388161)
# go on
# q_grasp: (0.9327564158787751, 0.5967763503979702, -0.059341439252450265, -1.9919463400673665, 0.22759101392092934, 2.11858304937491, 0.9724612060070925)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# iter=inf, outs=0) inverse-kinematics:(4, p187, g105)->[]
# Sampling for up to 0.194 seconds
# iter=1, outs=1) sample-grasp:(4)->[(g106)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.17631073013576, -0.4933263891832346, 2.228479048758484, -2.4210273363131987, 0.831968921098863, 2.6964918113921437, 0.6274784135221078)
# go on
# q_grasp: (-1.3397081947220357, -0.6124484020390284, 2.41739871424993, -2.3511509330287836, 1.0011247295408192, 2.7521988990371056, 0.5029594365338195)
# iter=inf, outs=1) inverse-kinematics:(4, p187, g106)->[(q326, c253)]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 4, p187)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c253, 5, p188)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p189)]
# q_approach: (-2.3279233827442067, 0.6364385832627303, 1.1796690649194002, -2.5291811192723106, -1.0895847749141718, 2.583995130234229, 0.7000293126645228)
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-1.2776426030072112, 0.1968001149737276, 0.3024917278553469, -2.6201597327308193, 0.07150512557995935, 2.8789059050012162, -0.11023388619594422)
# go on
# q_grasp: (-1.2052666740182152, 0.35834396014592257, 0.2228711629221178, -2.5835872254045102, 0.010239247901524917, 3.0039797908166617, -0.06824290318793176)
# iter=inf, outs=1) inverse-kinematics:(4, p189, g106)->[(q327, c254)]
# iter=inf, outs=1) test-cfree-traj-pose:(c254, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p189, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p187, g106, 5, p188)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p189, g106, 5, p188)->[()]
# iter=inf, outs=1) plan-free-motion:(q327, q323)->[(c255)]
# iter=inf, outs=1) plan-free-motion:(q323, q326)->[(c256)]
# iter=inf, outs=1) plan-holding-motion:(q326, q327, 4, g106)->[(c257)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 37, iterations: 3, length: 2, run_time: 0.445, sample_time: 0.214, search_time: 0.230, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6986 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9028 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30443 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5947 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2290 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3196 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6290 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11705 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1605339 function calls (1541366 primitive calls) in 0.754 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.119    0.040    0.119    0.040 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100716    0.061    0.000    0.077    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.051    0.025    0.197    0.099 /usr/lib/python2.7/pickle.py:851(load)
#   50437/1    0.037    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    201708    0.036    0.000    0.036    0.000 {method 'read' of 'file' objects}
#    100684    0.030    0.000    0.041    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.028    0.014    0.028    0.014 {posix.read}
#         2    0.017    0.008    0.017    0.008 {posix.fork}
#    100872    0.015    0.000    0.015    0.000 {method 'write' of 'file' objects}
#     50372    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q323 q326 c256
#  2) pick 4 p187 g106 q326 c253
#  3) move_holding q326 q327 4 g106 c257
#  4) place 4 p189 g106 q327 c254
#  5) move_free q327 q323 c255
# Robot: 0
# Movable: [4L, 5L]
# Fixed: [1, 2, 3]
# body 4 - surface 1
# body 4 - surface 2
# body 4 - surface 3
# body 5 - surface 1
# body 5 - surface 2
# body 5 - surface 3
# ('Init:', [('CanMove',), ('Conf', q328), ('AtConf', q328), ('HandEmpty',), ('Graspable', 4L), ('Pose', 4L, p190), ('AtPose', 4L, p190), ('Stackable', 4L, 1), ('Stackable', 4L, 2), ('Supported', 4L, p190, 2), ('Stackable', 4L, 3), ('Graspable', 5L), ('Pose', 5L, p191), ('AtPose', 5L, p191), ('Stackable', 5L, 1), ('Stackable', 5L, 2), ('Supported', 5L, p191, 2), ('Stackable', 5L, 3)])
# ('Goal:', ('and', ('AtConf', q328), ('On', 4L, 1)))
# ('Streams:', '{TrajCollision, inverse-kinematics, plan-free-motion, plan-holding-motion, sample-grasp, sample-pose, test-cfree-approach-pose, test-cfree-pose-pose, test-cfree-traj-pose}')
# Warning! All actions have no cost. Recommend setting unit_costs=True
# Warning! Undeclared predicates: ['conf', 'graspable']
# Setting negate=True for stream [test-cfree-approach-pose]
# Setting negate=True for stream [test-cfree-traj-pose]
# Setting negate=True for stream [test-cfree-pose-pose]
# Streams: [sample-pose:('?o', '?r')->('?p',), sample-grasp:('?o',)->('?g',), inverse-kinematics:('?o', '?p', '?g')->('?q', '?t'), plan-free-motion:('?q1', '?q2')->('?t',), plan-holding-motion:('?q1', '?q2', '?o', '?g')->('?t',)]
# Functions: []
# Negated: [test-cfree-pose-pose:('?o1', '?p1', '?o2', '?p2')->(), test-cfree-approach-pose:('?o1', '?p1', '?g1', '?o2', '?p2')->(), test-cfree-traj-pose:('?t', '?o2', '?p2')->()]
# Optimizers: []
#
# Iteration: 1 | Complexity: 0 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.000 | Sample Time: 0.000 | Total Time: 0.000
# Attempt: 1 | Results: 1 | Depth: 0 | Success: False | Time: 0.008
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 0 to 1
#
# Iteration: 2 | Complexity: 1 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.008 | Sample Time: 0.000 | Total Time: 0.008
# Attempt: 1 | Results: 11 | Depth: 0 | Success: False | Time: 0.010
# Stream plan (inf, 0, inf): None
# Action plan (inf, inf): None
# No plan: increasing complexity from 1 to 2
#
# Iteration: 3 | Complexity: 2 | Skeletons: 0 | Skeleton Queue: 0 | Disabled: 0 | Evaluations: 18 | Eager Calls: 0 | Cost: inf | Search Time: 0.018 | Sample Time: 0.000 | Total Time: 0.018
# Attempt: 1 | Results: 24 | Depth: 1 | Success: False | Time: 0.085
# Attempt: 2 | Results: 61 | Depth: 0 | Success: True | Time: 0.223
# Stream plan (13, 13, 0.001): [sample-grasp:(4)->(#g40), inverse-kinematics:(4, p190, #g40)->(#q126, #t6871), test-cfree-traj-pose:(#t6871, 5, p191)->(), test-cfree-traj-pose:(#t6871, 4, p190)->(), sample-pose:(4, 1)->(#p56), inverse-kinematics:(4, #p56, #g40)->(#q127, #t6872), test-cfree-traj-pose:(#t6872, 5, p191)->(), test-cfree-pose-pose:(4, #p56, 5, p191)->(), test-cfree-approach-pose:(4, p190, #g40, 5, p191)->(), test-cfree-approach-pose:(4, #p56, #g40, 5, p191)->(), plan-free-motion:(q328, #q126)->(#t6913), plan-free-motion:(#q127, q328)->(#t6915), plan-holding-motion:(#q126, #q127, 4, #g40)->(#t6914)]
# Action plan (5, 0.000): [move_free(q328, #q126, #t6913), pick(4, p190, #g40, #q126, #t6871), move_holding(#q126, #q127, 4, #g40, #t6914), place(4, #p56, #g40, #q127, #t6872), move_free(#q127, q328, #t6915)]
# iter=0, outs=1) sample-grasp:(4)->[(g107)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.4150246091802521, 1.2298875449035673, 1.3715062786356178, -2.210035248790946, -1.3123426805092073, 1.8936688794986642, 1.961933398401645)
# go on
# q_grasp: (-0.3753213593695801, 1.274773837173716, 1.26617175391218, -2.1974265254599317, -1.4031453163847043, 1.9545435621335112, 1.9861627345873272)
# iter=inf, outs=1) inverse-kinematics:(4, p190, g107)->[(q329, c258)]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-traj-pose:(c258, 4, p190)->[()]
# iter=0, outs=1) sample-pose:(4, 1)->[(p192)]
# q_approach: None
# obstacles: [4L, 1, 2, 3]
# q_approach: (-0.8899689531601122, 0.19880541274066688, -0.010427111186110756, -2.609277576096338, 0.01160885297981413, 2.8995182994797184, -2.377668987321695)
# go on
# q_grasp: (-0.8953571293780338, 0.36052263655602007, -0.003902137474369012, -2.5668661808489133, 0.016590275136949703, 3.0187008837854807, -2.3817649049534415)
# iter=inf, outs=1) inverse-kinematics:(4, p192, g107)->[(q330, c259)]
# iter=inf, outs=1) test-cfree-traj-pose:(c259, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-pose-pose:(4, p192, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p190, g107, 5, p191)->[()]
# iter=inf, outs=1) test-cfree-approach-pose:(4, p192, g107, 5, p191)->[()]
# iter=inf, outs=1) plan-free-motion:(q328, q329)->[(c260)]
# iter=inf, outs=1) plan-free-motion:(q330, q328)->[(c261)]
# iter=inf, outs=1) plan-holding-motion:(q329, q330, 4, g107)->[(c262)]
# Summary: {complexity: 2, cost: 0.000, evaluations: 36, iterations: 3, length: 2, run_time: 0.461, sample_time: 0.208, search_time: 0.253, skeletons: 1, solutions: 1, solved: True, timeout: False}
#
# Total External Statistics
# External: sample-pose | n: 6987 | p_success: 0.963 | overhead: 0.001
# External: sample-grasp | n: 9029 | p_success: 0.994 | overhead: 0.002
# External: inverse-kinematics | n: 30445 | p_success: 0.218 | overhead: 0.048
# External: plan-free-motion | n: 5949 | p_success: 0.892 | overhead: 0.125
# External: plan-holding-motion | n: 2291 | p_success: 0.991 | overhead: 0.059
# External: test-cfree-pose-pose | n: 3197 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-approach-pose | n: 6292 | p_success: 1.000 | overhead: 0.001
# External: test-cfree-traj-pose | n: 11708 | p_success: 0.937 | overhead: 0.001
# Wrote: statistics/py2/kuka-tamp.pkl
#          1590432 function calls (1526433 primitive calls) in 0.749 seconds
#
#    Ordered by: internal time
#    List reduced from 1474 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.149    0.050    0.150    0.050 pkg/planning/motion/moveit/moveit_py.py:156(plan_joint_motion_py)
#    100744    0.055    0.000    0.072    0.000 /usr/lib/python2.7/pickle.py:917(load_int)
#         2    0.046    0.023    0.185    0.092 /usr/lib/python2.7/pickle.py:851(load)
#         2    0.042    0.021    0.042    0.021 {posix.read}
#    201764    0.039    0.000    0.039    0.000 {method 'read' of 'file' objects}
#   50450/1    0.038    0.000    0.092    0.092 /usr/lib/python2.7/pickle.py:269(save)
#    100712    0.027    0.000    0.037    0.000 /usr/lib/python2.7/pickle.py:1184(load_append)
#         2    0.017    0.009    0.017    0.009 {posix.fork}
#     50385    0.015    0.000    0.025    0.000 /usr/lib/python2.7/pickle.py:443(save_int)
#    100898    0.014    0.000    0.014    0.000 {method 'write' of 'file' objects}
#
#
#
# Solved: True
# Cost: 0.000
# Length: 5
# Deferred: 0
# Evaluations: 2
#  1) move_free q328 q329 c260
#  2) pick 4 p190 g107 q329 c258
#  3) move_holding q329 q330 4 g107 c262
#  4) place 4 p192 g107 q330 c259
#  5) move_free q330 q328 c261

# %%
print(gtimer)

time_array = np.array(gtimer.timelist_dict["solve"])
success_array = np.array(log_woFeas)<1
print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
print("success rate: {} %".format(np.mean(success_array)*100))
# Out:
# solve: 	114004.4 ms/20 = 5700.2 ms (944.096/10438.012)
# sample_grasps_4: 	87.0 ms/20 = 4.3 ms (2.755/12.515)
# get_stable_4_1: 	426.4 ms/441 = 1.0 ms (0.395/2.828)
# ik_fn: 	64947.5 ms/4492 = 14.5 ms (1.353/231.827)
# check_feas: 	15598.1 ms/4492 = 3.5 ms (1.345/10.35)
# ReachChecker: 	4004.7 ms/4492 = 0.9 ms (0.35/3.058)
# GraspChecker: 	8115.1 ms/4492 = 1.8 ms (0.59/6.77)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9d45d5cb80db> in <module>()
#       2
#       3 time_array = np.array(gtimer.timelist_dict["solve"])
# ----> 4 success_array = np.array(log_woFeas)<1
#       5 print("solve-mean: {} ms".format(np.round(np.mean(time_array[np.where(success_array)[0]]), 1)))
#       6 print("solve-median: {} ms".format(np.round(np.median(time_array[np.where(success_array)[0]]), 1)))
#
# NameError: name 'log_woFeas' is not defined

# %% [markdown]
# ## play plan

# %%
SIMULATE = False
if (plan is None) or not has_gui():
    disconnect()
else:
    command = postprocess_plan(plan)
    if SIMULATE:
#         wait_for_user('Simulate?')
        command.control()
    else:
#         wait_for_user('Execute?')
        #command.step()
        command.refine(num_steps=10).execute(time_step=0.001)
