# %% [markdown]
# ## set running directory

# %%
from __future__ import print_function
import os
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))

# %%
from pkg.controller.combined_robot import *
from pkg.utils.utils import get_now, try_mkdir


DATA_PATH = os.path.join(os.environ['RNB_PLANNING_DIR'], "data")
try_mkdir(DATA_PATH)

TEST_DATA_PATH = os.path.join(DATA_PATH, "stowing-deep")
try_mkdir(TEST_DATA_PATH)

# %%
VISUALIZE = True
PLAY_RESULT = False
CLEARANCE = 1e-3
TOOL_RPY = (-np.pi/2,0,0)
TIMEOUT_MOTION = 5
MAX_TIME = 100


ROBOT_TYPE = RobotType.indy7gripper

if ROBOT_TYPE in [RobotType.indy7, RobotType.indy7gripper]:
    ROBOT_NAME = "indy0"
    TOOL_LINK = "indy0_tcp"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.14)
    HOME_POSE = (0,0,0,0,0,0)
    GRIP_DEPTH = 0.05
    
elif ROBOT_TYPE == RobotType.panda:
    ROBOT_NAME = "panda0"
    TOOL_LINK = "panda0_hand"
    TOOL_NAME = "grip0"
    TOOL_XYZ = (0,0,0.112)
    HOME_POSE = (0,-0.3,0,-0.5,0,2.5,0)
    GRIP_DEPTH = 0.03

# %% [markdown]
# ## init combined robot config

# %%
from pkg.project_config import *

crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, None,
                INDY_IP)]
              , connection_list=[False])

from pkg.geometry.builder.scene_builder import SceneBuilder
s_builder = SceneBuilder(None)
# s_builder.reset_reference_coord(ref_name="floor")
# Out:
# connection command:
# indy0: False

# %% [markdown]
# ## get ghnd with detected robot config

# %%
# xyz_rpy_robots = s_builder.detect_items(level_mask=[DetectionLevel.ROBOT])
xyz_rpy_robots = {ROBOT_NAME: ((0,0,0), (0,0,0))}
crob.update_robot_pos_dict(xyz_rpy_robots=xyz_rpy_robots)
gscene = s_builder.create_gscene(crob, start_rviz=VISUALIZE)
HOME_DICT = list2dict(HOME_POSE, gscene.joint_names)
# Out:
# Unable to register with master node [http://localhost:11311]: master may not be running yet. Will keep trying.
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0]

# %%
from pkg.utils.joint_utils import get_tf
shoulder_link = gscene.urdf_content.joint_map[gscene.joint_names[1]].child
shoulder_height = get_tf(shoulder_link, HOME_DICT, gscene.urdf_content)[2,3]

# %% [markdown]
# ## add environment

# %%
from pkg.geometry.geometry import *
gtems_robot = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=False, collision=True)

# %% [markdown]
# ## init planning scene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %% [markdown]
# ## Register binders

# %%
from pkg.planning.constraint.constraint_actor import Gripper2Tool, PlacePlane, SweepTool

# %%
gscene.create_safe(gtype=GEOTYPE.SPHERE, name="grip0", link_name=TOOL_LINK, 
                 dims=(0.01,)*3, center=TOOL_XYZ, rpy=TOOL_RPY, color=(1,0,0,1), display=True, collision=False, fixed=True)
gripper = pscene.create_binder(bname="grip0", gname="grip0", _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))
# Out:
# Please create a subscriber to the marker

# %% [markdown]
# ## ui

# %%
from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# # Object Classes

# %%
from pkg.planning.constraint.constraint_subject import CustomObject, Grasp2Point, PlacePoint, SweepPoint, SweepTask
from pkg.planning.filtering.lattice_model.scene_building import *

##
# @class WorkPlane
# @brief working plane. target and obstacle objects are generated on this plane
class WorkPlane(ObstacleBase):
    RTH_MIN = (0.3, -np.pi/2, -0.1)
    RTH_MAX = (0.5, +np.pi/2, +0.4)
    RPY_MIN = (0, 0, 0)
    RPY_MAX = (0, 0, 0)
    DIM_MIN = (0.4, 0.6, 0.05)
    DIM_MAX = (0.4, 0.6, 0.05)
    GTYPE = GEOTYPE.BOX
    COLOR=  (0.8,0.8,0.2,1)
    
    def __init__(self, gscene, name, floor_height=None, *args, **kwargs):
        assert floor_height is not None, "floor_height needed"
        if floor_height > self.RTH_MIN[2]:
            self.RTH_MIN = self.RTH_MIN[:2]+(floor_height,)
        self.H = 0.4
        ObstacleBase.__init__(self, gscene, name, *args, **kwargs)
        
    def is_overlapped_with(self, gtem):
        verts, radii = gtem.get_vertice_radius()
        verts_global = np.add(np.matmul(verts, gtem.orientation_mat.transpose()), gtem.center)
        verts_wp = np.multiply(DEFAULT_VERT_DICT[self.GTYPE], tuple(self.DIM[:2])+(self.H,))
        verts_wp_global = np.add(np.matmul(verts_wp, self.geometry.orientation_mat.transpose()), 
                                 np.add(self.geometry.center, (0,0,self.H/2)))
        return get_gjk_distance(get_point_list(verts_global), get_point_list(verts_wp_global))-radii < 1e-4
            
    
##
# @class Box
# @brief box with the top and the front side open
class Box(WorkPlane):
    RPY_MIN = (0, 0, 0)
    RPY_MAX = (0, 0, 0)
    DIM_MIN = (0.3, 0.3, 0.05)
    DIM_MAX = (0.6, 0.6, 0.05)
    COLOR =  (0.8,0.8,0.2,0.5)
    H_RANGE = (0.3, 0.6)
    THICKNESS = 0.05
    def __init__(self, gscene, name, H=None, **kwargs):
        WorkPlane.__init__(self, gscene=gscene, name=name, **kwargs)
        self.H = np.random.uniform(*self.H_RANGE) if H is None else H

        ## back wall
        self.subgeo_list.append(gscene.create_safe(
            gtype=self.GTYPE, name=self.name+"_bw", link_name="base_link", 
            dims=(self.THICKNESS, self.DIM[1], self.H), center=(self.DIM[0]/2+self.THICKNESS/2, 0,self.H/2), rpy=(0,0,0),
            color=self.COLOR, display=True, collision=True, fixed=True,
            parent=self.name))

        ## left wall
        self.subgeo_list.append(gscene.create_safe(
            gtype=self.GTYPE, name=self.name+"_lw", link_name="base_link", 
            dims=(self.DIM[0], self.THICKNESS, self.H), center=(0, -self.DIM[1]/2-self.THICKNESS/2, self.H/2), rpy=(0,0,0),
            color=self.COLOR, display=True, collision=True, fixed=True,
            parent=self.name))

        ## right wall
        self.subgeo_list.append(gscene.create_safe(
            gtype=self.GTYPE, name=self.name+"_rw", link_name="base_link", 
            dims=(self.DIM[0], self.THICKNESS, self.H), center=(0, self.DIM[1]/2+self.THICKNESS/2, self.H/2), rpy=(0,0,0),
            color=self.COLOR, display=True, collision=True, fixed=True,
            parent=self.name))

        
##
# @class SideBox
# @brief box with a side face open
class SideBox(Box):
    RTH_MIN = (0.3, -np.pi/2, -0.1)
    RTH_MAX = (0.5, +np.pi/2, +0.4)
    RPY_MIN = (0, 0, np.pi/6)
    RPY_MAX = (0, 0, np.pi/6)
    DIM_MIN = (0.4, 0.6, 0.05)
    DIM_MAX = (0.4, 0.6, 0.05)
    COLOR =  (0.2,0.2,0.8,1)
    H_RANGE = (0.4, 0.4)
    THICKNESS = 0.05
    def __init__(self, gscene, name, **kwargs):
        Box.__init__(self, gscene=gscene, name=name, **kwargs)

        ## top
        self.subgeo_list.append(gscene.create_safe(
            gtype=self.GTYPE, name=self.name+"_tp", link_name="base_link", 
            dims=(self.DIM[0], self.DIM[1], self.THICKNESS), center=(0, 0, self.H+self.THICKNESS/2), rpy=(0,0,0),
            color=self.COLOR, display=True, collision=True, fixed=True,
            parent=self.name))

##
# @class TopBox
# @brief box with the top face open
class TopBox(Box):
    DIM_MIN = (0.3, 0.3, 0.05)
    DIM_MAX = (0.6, 0.6, 0.05)
    H_RANGE = (0.3, 0.6)
    def __init__(self, gscene, name, **kwargs):
        Box.__init__(self, gscene=gscene, name=name, **kwargs)

        ## front wall
        self.subgeo_list.append(gscene.create_safe(
            gtype=self.GTYPE, name=self.name+"_fw", link_name="base_link", 
            dims=(self.THICKNESS, self.DIM[1], self.H), center=(-self.DIM[0]/2-self.THICKNESS/2, 0,self.H/2), rpy=(0,0,0),
            color=self.COLOR, display=True, collision=True, fixed=True,
            parent=self.name))
        
##
# @class Floor
# @brief Floor - lowerbound of the workspace
class Floor(ObstacleBase):
    RTH_MIN = (0.0, 0, -0.5)
    RTH_MAX = (0.0, 0, -0.5)
    RPY_MIN = (0, 0, 0)
    RPY_MAX = (0, 0, 0)
    DIM_MIN = (3, 3, 0.1)
    DIM_MAX = (3, 3, 0.1)
    GTYPE = GEOTYPE.BOX
    
##
# @class Pole
# @brief occasional poles that obstruct robot motion
class Pole(ObstacleBase):
    RTH_MIN = (0.3, -np.pi, 0)
    RTH_MAX = (0.3, +np.pi, 0)
    RPY_MIN = (0, 0, -np.pi/6)
    RPY_MAX = (0, 0, +np.pi/6)
    DIM_MIN = (0.1, 0.1, 4)
    DIM_MAX = (0.1, 0.1, 4)
    GTYPE = GEOTYPE.BOX
    COLOR = (0.7,0.7,0.7,0.3)
    
##
# @class PlaneObstacle
# @brief Obstacles on the workplane
class PlaneObject(ObstacleBase):
    RTH_MIN = (0.3, -np.pi/2, -0.2)
    RTH_MAX = (0.8, +np.pi/2, +0.5)
    RPY_MIN = (0, 0, -np.pi)
    RPY_MAX = (0, 0, +np.pi)
    DIM_MIN = (0.04, 0.1, 0.2)
    DIM_MAX = (0.04, 0.1, 0.2)
    GTYPE = GEOTYPE.BOX
    COLOR =  (0.2,0.8,0.2,1)
    def __init__(self, gscene, name, workplane, GRIP_DEPTH, CLEARANCE, XYZ_LOC=None, **kwargs):
        self.GRIP_DEPTH = GRIP_DEPTH
        ObstacleBase.__init__(self, gscene=gscene, name=name, **kwargs)
        verts, radii = self.geometry.get_vertice_radius()
        verts_rot = np.matmul(self.geometry.orientation_mat, verts.transpose()) ## verices with global orientaion
        verts_rot_loc = np.matmul(workplane.geometry.Toff[:3,:3].transpose(), verts_rot) ## verices with local orientaion
        max_verts = np.max(verts_rot_loc, axis=-1)
        min_verts = np.min(verts_rot_loc, axis=-1)
        if XYZ_LOC is None:
            self.XYZ_LOC = np.random.uniform(np.negative(workplane.DIM)/2-min_verts+radii,np.array(workplane.DIM)/2-max_verts-radii)
            self.XYZ_LOC[2] = workplane.DIM[2]/2 + self.DIM[2]/2 + CLEARANCE
        else:
            self.XYZ_LOC = self.XYZ_LOC
        self.XYZ = np.matmul(workplane.geometry.Toff[:3,:3], self.XYZ_LOC) + workplane.geometry.Toff[:3,3]
        self.geometry.set_offset_tf(center = self.XYZ)
        self.RTH = cart2cyl(*self.XYZ)
        gscene.update_marker(self.geometry)
           
def disperse_objects(gscene, object_class, key, Nmax, workplane_on, GRIP_DEPTH, CLEARANCE=1e-3):
    clear_class(gscene, key, Nmax)
        
    obs_list = []
    while len(obs_list)<Nmax:
        iw = len(obs_list)
        obs = object_class(gscene, "{}_{}".format(key, iw), workplane_on, GRIP_DEPTH=GRIP_DEPTH, CLEARANCE=CLEARANCE)
        remove_this = False
        for obs_pre in obs_list:
            if obs_pre.is_overlapped_with(obs.geometry):
                remove_this = True
                break
        if remove_this:
            gscene.remove(obs.geometry)
        else:
            obs_list.append(obs)
    return obs_list

# %%
ROBOT_DATA_ROOT = os.path.join(TEST_DATA_PATH, ROBOT_TYPE.name)
try_mkdir(ROBOT_DATA_ROOT)

DATASET_PATH = os.path.join(ROBOT_DATA_ROOT, get_now())
# DATASET_PATH = os.path.join(ROBOT_DATA_ROOT, '20210223-051658')
try_mkdir(DATASET_PATH)
print("")
print("DATASET_PATH: {}".format(DATASET_PATH))
print("")
# Out:
# DATASET_PATH: /home/rnb/Projects/rnb-planning/data/stowing-deep/indy7gripper/20210730-000918

# %% [markdown]
# ## Init pybullet

# %%
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src/scripts/developing/pddlstream'))
from convert_pscene import *
from plan_rnb import *
connect_notebook(use_gui=False)
urdf_pybullet_path = copy_meshes(gscene)
# Out:
# generate table - Geometry
# generate table - Handle
# generate table - Bindergenerate table - Object

# %% [markdown]
# ### sampling 1-obj

# %%
Nmax_obj = 1
f_option = "obj_1"

SAMPLE_NUM = 100

SHOW_PERIOD = 0.01

GRASP_SAMPLE = 50

results_dict_1_shelf = defaultdict(list)
# results_dict_3_plane = {int(k): v for k, v in load_json(os.path.join(DATASET_PATH, "results_dict_3_plane.json")).items()}


gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)
gtimer.tic("full_loop")
for i_s in range(SAMPLE_NUM):
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH, CLEARANCE=CLEARANCE)

    gtem_args = []
    for gtem in gscene:
        if gtem.link_name == "base_link":
            gtem_args.append(deepcopy(gtem.get_args()))
    obj_args = {obj.name: {"GRIP_DEPTH": obj.GRIP_DEPTH, "DIM": obj.DIM, "CLEARANCE": CLEARANCE, "gname": obj.geometry.name} 
                for obj in obj_list}
    
    save_pickle(os.path.join(DATASET_PATH, "data_"+f_option+"_%02d.pkl"%i_s), 
                {"gtem_args":gtem_args, "obj_args": obj_args})
    gscene.update_markers_all()
    print("============ STEP ({} / {}) / Elapsed: {} s / ETA: {} s =============".format(i_s, SAMPLE_NUM,
                                     *np.round(np.divide(gtimer.eta("full_loop", i_s+1, SAMPLE_NUM), 1000), 1)))
# Out:
# ============ STEP (0 / 100) / Elapsed: 0.1 s / ETA: 6.0 s =============
# ============ STEP (1 / 100) / Elapsed: 0.2 s / ETA: 10.8 s =============
# ============ STEP (2 / 100) / Elapsed: 0.3 s / ETA: 10.6 s =============
# ============ STEP (3 / 100) / Elapsed: 0.4 s / ETA: 10.4 s =============
# ============ STEP (4 / 100) / Elapsed: 0.5 s / ETA: 10.4 s =============
# ============ STEP (5 / 100) / Elapsed: 0.7 s / ETA: 11.2 s =============
# ============ STEP (6 / 100) / Elapsed: 0.9 s / ETA: 13.4 s =============
# ============ STEP (7 / 100) / Elapsed: 1.0 s / ETA: 13.0 s =============
# ============ STEP (8 / 100) / Elapsed: 1.1 s / ETA: 12.6 s =============
# ============ STEP (9 / 100) / Elapsed: 1.2 s / ETA: 12.4 s =============
# ============ STEP (10 / 100) / Elapsed: 1.4 s / ETA: 12.7 s =============
# ============ STEP (11 / 100) / Elapsed: 1.9 s / ETA: 15.6 s =============
# ============ STEP (12 / 100) / Elapsed: 2.0 s / ETA: 15.2 s =============
# ============ STEP (13 / 100) / Elapsed: 2.1 s / ETA: 15.2 s =============
# ============ STEP (14 / 100) / Elapsed: 2.3 s / ETA: 15.2 s =============
# ============ STEP (15 / 100) / Elapsed: 2.7 s / ETA: 16.9 s =============
# ============ STEP (16 / 100) / Elapsed: 2.8 s / ETA: 16.5 s =============
# ============ STEP (17 / 100) / Elapsed: 2.9 s / ETA: 16.1 s =============
# ============ STEP (18 / 100) / Elapsed: 3.0 s / ETA: 15.8 s =============
# ============ STEP (19 / 100) / Elapsed: 3.1 s / ETA: 15.5 s =============
# ============ STEP (20 / 100) / Elapsed: 3.3 s / ETA: 15.5 s =============
# ============ STEP (21 / 100) / Elapsed: 3.4 s / ETA: 15.2 s =============
# ============ STEP (22 / 100) / Elapsed: 3.7 s / ETA: 16.2 s =============
# ============ STEP (23 / 100) / Elapsed: 3.9 s / ETA: 16.1 s =============
# ============ STEP (24 / 100) / Elapsed: 4.0 s / ETA: 16.1 s =============
# ============ STEP (25 / 100) / Elapsed: 4.1 s / ETA: 15.9 s =============
# ============ STEP (26 / 100) / Elapsed: 4.2 s / ETA: 15.6 s =============
# ============ STEP (27 / 100) / Elapsed: 4.3 s / ETA: 15.4 s =============
# ============ STEP (28 / 100) / Elapsed: 4.4 s / ETA: 15.2 s =============
# ============ STEP (29 / 100) / Elapsed: 4.5 s / ETA: 15.1 s =============
# ============ STEP (30 / 100) / Elapsed: 4.8 s / ETA: 15.4 s =============
# ============ STEP (31 / 100) / Elapsed: 4.9 s / ETA: 15.3 s =============
# ============ STEP (32 / 100) / Elapsed: 5.1 s / ETA: 15.4 s =============
# ============ STEP (33 / 100) / Elapsed: 5.2 s / ETA: 15.3 s =============
# ============ STEP (34 / 100) / Elapsed: 5.3 s / ETA: 15.3 s =============
# ============ STEP (35 / 100) / Elapsed: 5.5 s / ETA: 15.1 s =============
# ============ STEP (36 / 100) / Elapsed: 5.7 s / ETA: 15.3 s =============
# ============ STEP (37 / 100) / Elapsed: 5.9 s / ETA: 15.4 s =============
# ============ STEP (38 / 100) / Elapsed: 6.0 s / ETA: 15.4 s =============
# ============ STEP (39 / 100) / Elapsed: 6.2 s / ETA: 15.4 s =============
# ============ STEP (40 / 100) / Elapsed: 6.3 s / ETA: 15.3 s =============
# ============ STEP (41 / 100) / Elapsed: 6.4 s / ETA: 15.2 s =============
# ============ STEP (42 / 100) / Elapsed: 6.5 s / ETA: 15.1 s =============
# ============ STEP (43 / 100) / Elapsed: 6.6 s / ETA: 15.0 s =============
# ============ STEP (44 / 100) / Elapsed: 7.0 s / ETA: 15.4 s =============
# ============ STEP (45 / 100) / Elapsed: 7.1 s / ETA: 15.5 s =============
# ============ STEP (46 / 100) / Elapsed: 7.2 s / ETA: 15.3 s =============
# ============ STEP (47 / 100) / Elapsed: 7.5 s / ETA: 15.7 s =============
# ============ STEP (48 / 100) / Elapsed: 7.6 s / ETA: 15.6 s =============
# ============ STEP (49 / 100) / Elapsed: 7.8 s / ETA: 15.6 s =============
# ============ STEP (50 / 100) / Elapsed: 7.9 s / ETA: 15.6 s =============
# ============ STEP (51 / 100) / Elapsed: 8.0 s / ETA: 15.5 s =============
# ============ STEP (52 / 100) / Elapsed: 8.3 s / ETA: 15.6 s =============
# ============ STEP (53 / 100) / Elapsed: 8.5 s / ETA: 15.8 s =============
# ============ STEP (54 / 100) / Elapsed: 8.7 s / ETA: 15.9 s =============
# ============ STEP (55 / 100) / Elapsed: 8.9 s / ETA: 15.9 s =============
# ============ STEP (56 / 100) / Elapsed: 9.0 s / ETA: 15.8 s =============
# ============ STEP (57 / 100) / Elapsed: 9.1 s / ETA: 15.7 s =============
# ============ STEP (58 / 100) / Elapsed: 9.2 s / ETA: 15.6 s =============
# ============ STEP (59 / 100) / Elapsed: 9.5 s / ETA: 15.9 s =============
# ============ STEP (60 / 100) / Elapsed: 9.7 s / ETA: 15.8 s =============
# ============ STEP (61 / 100) / Elapsed: 9.9 s / ETA: 16.0 s =============
# ============ STEP (62 / 100) / Elapsed: 10.1 s / ETA: 16.0 s =============
# ============ STEP (63 / 100) / Elapsed: 10.2 s / ETA: 15.9 s =============
# ============ STEP (64 / 100) / Elapsed: 10.4 s / ETA: 16.0 s =============
# ============ STEP (65 / 100) / Elapsed: 10.5 s / ETA: 15.9 s =============
# ============ STEP (66 / 100) / Elapsed: 10.6 s / ETA: 15.8 s =============
# ============ STEP (67 / 100) / Elapsed: 10.7 s / ETA: 15.8 s =============
# ============ STEP (68 / 100) / Elapsed: 10.8 s / ETA: 15.7 s =============
# ============ STEP (69 / 100) / Elapsed: 10.9 s / ETA: 15.6 s =============
# ============ STEP (70 / 100) / Elapsed: 11.0 s / ETA: 15.5 s =============
# ============ STEP (71 / 100) / Elapsed: 11.1 s / ETA: 15.5 s =============
# ============ STEP (72 / 100) / Elapsed: 11.2 s / ETA: 15.4 s =============
# ============ STEP (73 / 100) / Elapsed: 11.4 s / ETA: 15.4 s =============
# ============ STEP (74 / 100) / Elapsed: 11.6 s / ETA: 15.5 s =============
# ============ STEP (75 / 100) / Elapsed: 11.7 s / ETA: 15.4 s =============
# ============ STEP (76 / 100) / Elapsed: 11.9 s / ETA: 15.5 s =============
# ============ STEP (77 / 100) / Elapsed: 12.0 s / ETA: 15.4 s =============
# ============ STEP (78 / 100) / Elapsed: 12.1 s / ETA: 15.3 s =============
# ============ STEP (79 / 100) / Elapsed: 12.3 s / ETA: 15.4 s =============
# ============ STEP (80 / 100) / Elapsed: 12.4 s / ETA: 15.3 s =============
# ============ STEP (81 / 100) / Elapsed: 12.5 s / ETA: 15.3 s =============
# ============ STEP (82 / 100) / Elapsed: 12.8 s / ETA: 15.4 s =============
# ============ STEP (83 / 100) / Elapsed: 12.9 s / ETA: 15.4 s =============
# ============ STEP (84 / 100) / Elapsed: 13.2 s / ETA: 15.5 s =============
# ============ STEP (85 / 100) / Elapsed: 13.3 s / ETA: 15.5 s =============
# ============ STEP (86 / 100) / Elapsed: 13.5 s / ETA: 15.5 s =============
# ============ STEP (87 / 100) / Elapsed: 13.6 s / ETA: 15.4 s =============
# ============ STEP (88 / 100) / Elapsed: 14.1 s / ETA: 15.8 s =============
# ============ STEP (89 / 100) / Elapsed: 14.2 s / ETA: 15.8 s =============
# ============ STEP (90 / 100) / Elapsed: 14.3 s / ETA: 15.7 s =============
# ============ STEP (91 / 100) / Elapsed: 14.8 s / ETA: 16.1 s =============
# ============ STEP (92 / 100) / Elapsed: 14.9 s / ETA: 16.0 s =============
# ============ STEP (93 / 100) / Elapsed: 15.0 s / ETA: 15.9 s =============
# ============ STEP (94 / 100) / Elapsed: 15.2 s / ETA: 16.0 s =============
# ============ STEP (95 / 100) / Elapsed: 15.4 s / ETA: 16.0 s =============
# ============ STEP (96 / 100) / Elapsed: 15.5 s / ETA: 16.0 s =============
# ============ STEP (97 / 100) / Elapsed: 15.6 s / ETA: 15.9 s =============
# ============ STEP (98 / 100) / Elapsed: 15.7 s / ETA: 15.9 s =============
# ============ STEP (99 / 100) / Elapsed: 15.8 s / ETA: 15.8 s =============

# %% [markdown]
# ### sampling 3-obj

# %%
Nmax_obj = 3
f_option = "obj_3"

SAMPLE_NUM = 100

SHOW_PERIOD = 0.01

GRASP_SAMPLE = 50

results_dict_1_shelf = defaultdict(list)
# results_dict_3_plane = {int(k): v for k, v in load_json(os.path.join(DATASET_PATH, "results_dict_3_plane.json")).items()}


gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)
gtimer.tic("full_loop")
for i_s in range(SAMPLE_NUM):
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH, CLEARANCE=CLEARANCE)

    gtem_args = []
    for gtem in gscene:
        if gtem.link_name == "base_link":
            gtem_args.append(deepcopy(gtem.get_args()))
    obj_args = {obj.name: {"GRIP_DEPTH": obj.GRIP_DEPTH, "DIM": obj.DIM, "CLEARANCE": CLEARANCE, "gname": obj.geometry.name} 
                for obj in obj_list}
    
    save_pickle(os.path.join(DATASET_PATH, "data_"+f_option+"_%02d.pkl"%i_s), 
                {"gtem_args":gtem_args, "obj_args": obj_args})
    gscene.update_markers_all()
    print("============ STEP ({} / {}) / Elapsed: {} s / ETA: {} s =============".format(i_s, SAMPLE_NUM,
                                     *np.round(np.divide(gtimer.eta("full_loop", i_s+1, SAMPLE_NUM), 1000), 1)))
# Out:
# ============ STEP (0 / 100) / Elapsed: 0.2 s / ETA: 15.7 s =============
# ============ STEP (1 / 100) / Elapsed: 0.3 s / ETA: 14.2 s =============
# ============ STEP (2 / 100) / Elapsed: 0.6 s / ETA: 19.1 s =============
# ============ STEP (3 / 100) / Elapsed: 0.8 s / ETA: 20.3 s =============
# ============ STEP (4 / 100) / Elapsed: 1.1 s / ETA: 22.0 s =============
# ============ STEP (5 / 100) / Elapsed: 1.3 s / ETA: 21.5 s =============
# ============ STEP (6 / 100) / Elapsed: 1.5 s / ETA: 21.7 s =============
# ============ STEP (7 / 100) / Elapsed: 1.7 s / ETA: 21.2 s =============
# ============ STEP (8 / 100) / Elapsed: 1.8 s / ETA: 20.2 s =============
# ============ STEP (9 / 100) / Elapsed: 2.0 s / ETA: 20.5 s =============
# ============ STEP (10 / 100) / Elapsed: 2.3 s / ETA: 21.2 s =============
# ============ STEP (11 / 100) / Elapsed: 2.5 s / ETA: 20.9 s =============
# ============ STEP (12 / 100) / Elapsed: 2.6 s / ETA: 20.3 s =============
# ============ STEP (13 / 100) / Elapsed: 2.8 s / ETA: 19.7 s =============
# ============ STEP (14 / 100) / Elapsed: 3.0 s / ETA: 20.1 s =============
# ============ STEP (15 / 100) / Elapsed: 3.1 s / ETA: 19.7 s =============
# ============ STEP (16 / 100) / Elapsed: 3.4 s / ETA: 19.9 s =============
# ============ STEP (17 / 100) / Elapsed: 3.6 s / ETA: 19.7 s =============
# ============ STEP (18 / 100) / Elapsed: 3.7 s / ETA: 19.4 s =============
# ============ STEP (19 / 100) / Elapsed: 3.9 s / ETA: 19.6 s =============
# ============ STEP (20 / 100) / Elapsed: 4.1 s / ETA: 19.3 s =============
# ============ STEP (21 / 100) / Elapsed: 4.2 s / ETA: 19.0 s =============
# ============ STEP (22 / 100) / Elapsed: 4.3 s / ETA: 18.7 s =============
# ============ STEP (23 / 100) / Elapsed: 4.4 s / ETA: 18.5 s =============
# ============ STEP (24 / 100) / Elapsed: 4.6 s / ETA: 18.2 s =============
# ============ STEP (25 / 100) / Elapsed: 4.7 s / ETA: 18.0 s =============
# ============ STEP (26 / 100) / Elapsed: 4.9 s / ETA: 18.0 s =============
# ============ STEP (27 / 100) / Elapsed: 5.0 s / ETA: 18.0 s =============
# ============ STEP (28 / 100) / Elapsed: 5.5 s / ETA: 18.8 s =============
# ============ STEP (29 / 100) / Elapsed: 5.6 s / ETA: 18.6 s =============
# ============ STEP (30 / 100) / Elapsed: 5.8 s / ETA: 18.6 s =============
# ============ STEP (31 / 100) / Elapsed: 5.9 s / ETA: 18.4 s =============
# ============ STEP (32 / 100) / Elapsed: 6.1 s / ETA: 18.4 s =============
# ============ STEP (33 / 100) / Elapsed: 6.2 s / ETA: 18.3 s =============
# ============ STEP (34 / 100) / Elapsed: 6.4 s / ETA: 18.2 s =============
# ============ STEP (35 / 100) / Elapsed: 6.6 s / ETA: 18.5 s =============
# ============ STEP (36 / 100) / Elapsed: 6.8 s / ETA: 18.3 s =============
# ============ STEP (37 / 100) / Elapsed: 6.9 s / ETA: 18.1 s =============
# ============ STEP (38 / 100) / Elapsed: 7.1 s / ETA: 18.1 s =============
# ============ STEP (39 / 100) / Elapsed: 7.2 s / ETA: 18.0 s =============
# ============ STEP (40 / 100) / Elapsed: 7.3 s / ETA: 17.9 s =============
# ============ STEP (41 / 100) / Elapsed: 7.5 s / ETA: 17.8 s =============
# ============ STEP (42 / 100) / Elapsed: 7.7 s / ETA: 17.9 s =============
# ============ STEP (43 / 100) / Elapsed: 7.9 s / ETA: 17.9 s =============
# ============ STEP (44 / 100) / Elapsed: 8.2 s / ETA: 18.3 s =============
# ============ STEP (45 / 100) / Elapsed: 8.3 s / ETA: 18.1 s =============
# ============ STEP (46 / 100) / Elapsed: 8.7 s / ETA: 18.6 s =============
# ============ STEP (47 / 100) / Elapsed: 9.1 s / ETA: 19.0 s =============
# ============ STEP (48 / 100) / Elapsed: 9.4 s / ETA: 19.1 s =============
# ============ STEP (49 / 100) / Elapsed: 9.6 s / ETA: 19.2 s =============
# ============ STEP (50 / 100) / Elapsed: 9.8 s / ETA: 19.2 s =============
# ============ STEP (51 / 100) / Elapsed: 9.9 s / ETA: 19.0 s =============
# ============ STEP (52 / 100) / Elapsed: 10.1 s / ETA: 19.0 s =============
# ============ STEP (53 / 100) / Elapsed: 10.2 s / ETA: 18.9 s =============
# ============ STEP (54 / 100) / Elapsed: 10.4 s / ETA: 18.9 s =============
# ============ STEP (55 / 100) / Elapsed: 10.7 s / ETA: 19.1 s =============
# ============ STEP (56 / 100) / Elapsed: 10.8 s / ETA: 19.0 s =============
# ============ STEP (57 / 100) / Elapsed: 10.9 s / ETA: 18.9 s =============
# ============ STEP (58 / 100) / Elapsed: 11.1 s / ETA: 18.9 s =============
# ============ STEP (59 / 100) / Elapsed: 11.3 s / ETA: 18.9 s =============
# ============ STEP (60 / 100) / Elapsed: 11.5 s / ETA: 18.9 s =============
# ============ STEP (61 / 100) / Elapsed: 11.7 s / ETA: 18.9 s =============
# ============ STEP (62 / 100) / Elapsed: 11.9 s / ETA: 18.9 s =============
# ============ STEP (63 / 100) / Elapsed: 12.1 s / ETA: 19.0 s =============
# ============ STEP (64 / 100) / Elapsed: 12.3 s / ETA: 18.9 s =============
# ============ STEP (65 / 100) / Elapsed: 12.7 s / ETA: 19.3 s =============
# ============ STEP (66 / 100) / Elapsed: 12.8 s / ETA: 19.2 s =============
# ============ STEP (67 / 100) / Elapsed: 13.0 s / ETA: 19.1 s =============
# ============ STEP (68 / 100) / Elapsed: 13.4 s / ETA: 19.4 s =============
# ============ STEP (69 / 100) / Elapsed: 13.7 s / ETA: 19.5 s =============
# ============ STEP (70 / 100) / Elapsed: 13.8 s / ETA: 19.4 s =============
# ============ STEP (71 / 100) / Elapsed: 14.0 s / ETA: 19.4 s =============
# ============ STEP (72 / 100) / Elapsed: 14.1 s / ETA: 19.4 s =============
# ============ STEP (73 / 100) / Elapsed: 14.3 s / ETA: 19.4 s =============
# ============ STEP (74 / 100) / Elapsed: 14.4 s / ETA: 19.3 s =============
# ============ STEP (75 / 100) / Elapsed: 14.6 s / ETA: 19.2 s =============
# ============ STEP (76 / 100) / Elapsed: 14.7 s / ETA: 19.1 s =============
# ============ STEP (77 / 100) / Elapsed: 14.8 s / ETA: 19.0 s =============
# ============ STEP (78 / 100) / Elapsed: 15.1 s / ETA: 19.1 s =============
# ============ STEP (79 / 100) / Elapsed: 15.2 s / ETA: 19.1 s =============
# ============ STEP (80 / 100) / Elapsed: 15.4 s / ETA: 19.0 s =============
# ============ STEP (81 / 100) / Elapsed: 15.6 s / ETA: 19.0 s =============
# ============ STEP (82 / 100) / Elapsed: 15.8 s / ETA: 19.0 s =============
# ============ STEP (83 / 100) / Elapsed: 16.0 s / ETA: 19.0 s =============
# ============ STEP (84 / 100) / Elapsed: 16.1 s / ETA: 19.0 s =============
# ============ STEP (85 / 100) / Elapsed: 16.3 s / ETA: 19.0 s =============
# ============ STEP (86 / 100) / Elapsed: 16.5 s / ETA: 19.0 s =============
# ============ STEP (87 / 100) / Elapsed: 16.6 s / ETA: 18.9 s =============
# ============ STEP (88 / 100) / Elapsed: 16.9 s / ETA: 19.0 s =============
# ============ STEP (89 / 100) / Elapsed: 17.2 s / ETA: 19.1 s =============
# ============ STEP (90 / 100) / Elapsed: 17.3 s / ETA: 19.0 s =============
# ============ STEP (91 / 100) / Elapsed: 17.4 s / ETA: 19.0 s =============
# ============ STEP (92 / 100) / Elapsed: 17.6 s / ETA: 18.9 s =============
# ============ STEP (93 / 100) / Elapsed: 17.8 s / ETA: 18.9 s =============
# ============ STEP (94 / 100) / Elapsed: 17.9 s / ETA: 18.9 s =============
# ============ STEP (95 / 100) / Elapsed: 18.1 s / ETA: 18.8 s =============
# ============ STEP (96 / 100) / Elapsed: 18.2 s / ETA: 18.8 s =============
# ============ STEP (97 / 100) / Elapsed: 18.5 s / ETA: 18.9 s =============
# ============ STEP (98 / 100) / Elapsed: 18.6 s / ETA: 18.8 s =============
# ============ STEP (99 / 100) / Elapsed: 18.8 s / ETA: 18.8 s =============

# %% [markdown]
# ## sample with pole

# %%
Nmax_obj = 3
f_option = "obj_3_pole"

SAMPLE_NUM = 100

SHOW_PERIOD = 0.01

GRASP_SAMPLE = 50

results_dict_1_shelf = defaultdict(list)
# results_dict_3_plane = {int(k): v for k, v in load_json(os.path.join(DATASET_PATH, "results_dict_3_plane.json")).items()}


gtimer = GlobalTimer.instance()
gtimer.reset(stack=True)
gtimer.tic("full_loop")
for i_s in range(SAMPLE_NUM):
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)

#     pole = Pole(gscene, "pole", RTH=[0.3, gp.RTH[1], 0])

    Tgp = gp.geometry.get_tf(crob.home_pose)
    Pp = (np.matmul(Tgp[:3,:3], np.transpose([[-0.3,0,0]])*(1+np.random.rand()))+Tgp[:3,3:]).flatten()

    Ppcyl = cart2cyl(*Pp)
    pole = Pole(gscene, "pole", RTH=[np.maximum(0.3,Ppcyl[0]-0.1), Ppcyl[1], 0])


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH, CLEARANCE=CLEARANCE)

    gtem_args = []
    for gtem in gscene:
        if gtem.link_name == "base_link":
            gtem_args.append(deepcopy(gtem.get_args()))
    obj_args = {obj.name: {"GRIP_DEPTH": obj.GRIP_DEPTH, "DIM": obj.DIM, "CLEARANCE": CLEARANCE, "gname": obj.geometry.name} 
                for obj in obj_list}
    
    save_pickle(os.path.join(DATASET_PATH, "data_"+f_option+"_%02d.pkl"%i_s), 
                {"gtem_args":gtem_args, "obj_args": obj_args})
    gscene.update_markers_all()
    print("============ STEP ({} / {}) / Elapsed: {} s / ETA: {} s =============".format(i_s, SAMPLE_NUM,
                                     *np.round(np.divide(gtimer.eta("full_loop", i_s+1, SAMPLE_NUM), 1000), 1)))
# Out:
# ============ STEP (0 / 100) / Elapsed: 0.1 s / ETA: 14.6 s =============
# ============ STEP (1 / 100) / Elapsed: 0.3 s / ETA: 14.0 s =============
# ============ STEP (2 / 100) / Elapsed: 0.7 s / ETA: 22.8 s =============
# ============ STEP (3 / 100) / Elapsed: 0.9 s / ETA: 23.1 s =============
# ============ STEP (4 / 100) / Elapsed: 1.1 s / ETA: 22.2 s =============
# ============ STEP (5 / 100) / Elapsed: 1.2 s / ETA: 20.7 s =============
# ============ STEP (6 / 100) / Elapsed: 1.4 s / ETA: 19.7 s =============
# ============ STEP (7 / 100) / Elapsed: 1.8 s / ETA: 22.9 s =============
# ============ STEP (8 / 100) / Elapsed: 2.3 s / ETA: 25.5 s =============
# ============ STEP (9 / 100) / Elapsed: 2.5 s / ETA: 25.3 s =============
# ============ STEP (10 / 100) / Elapsed: 2.7 s / ETA: 24.8 s =============
# ============ STEP (11 / 100) / Elapsed: 2.9 s / ETA: 24.3 s =============
# ============ STEP (12 / 100) / Elapsed: 3.0 s / ETA: 23.4 s =============
# ============ STEP (13 / 100) / Elapsed: 3.2 s / ETA: 22.7 s =============
# ============ STEP (14 / 100) / Elapsed: 3.5 s / ETA: 23.5 s =============
# ============ STEP (15 / 100) / Elapsed: 3.7 s / ETA: 22.9 s =============
# ============ STEP (16 / 100) / Elapsed: 3.8 s / ETA: 22.3 s =============
# ============ STEP (17 / 100) / Elapsed: 4.1 s / ETA: 22.8 s =============
# ============ STEP (18 / 100) / Elapsed: 4.5 s / ETA: 23.5 s =============
# ============ STEP (19 / 100) / Elapsed: 4.7 s / ETA: 23.3 s =============
# ============ STEP (20 / 100) / Elapsed: 4.8 s / ETA: 23.1 s =============
# ============ STEP (21 / 100) / Elapsed: 5.1 s / ETA: 23.4 s =============
# ============ STEP (22 / 100) / Elapsed: 5.3 s / ETA: 23.2 s =============
# ============ STEP (23 / 100) / Elapsed: 5.8 s / ETA: 24.3 s =============
# ============ STEP (24 / 100) / Elapsed: 6.0 s / ETA: 23.9 s =============
# ============ STEP (25 / 100) / Elapsed: 6.2 s / ETA: 23.7 s =============
# ============ STEP (26 / 100) / Elapsed: 6.4 s / ETA: 23.5 s =============
# ============ STEP (27 / 100) / Elapsed: 6.6 s / ETA: 23.6 s =============
# ============ STEP (28 / 100) / Elapsed: 6.8 s / ETA: 23.6 s =============
# ============ STEP (29 / 100) / Elapsed: 7.0 s / ETA: 23.3 s =============
# ============ STEP (30 / 100) / Elapsed: 7.1 s / ETA: 23.0 s =============
# ============ STEP (31 / 100) / Elapsed: 7.3 s / ETA: 22.7 s =============
# ============ STEP (32 / 100) / Elapsed: 7.4 s / ETA: 22.4 s =============
# ============ STEP (33 / 100) / Elapsed: 7.6 s / ETA: 22.3 s =============
# ============ STEP (34 / 100) / Elapsed: 8.0 s / ETA: 22.8 s =============
# ============ STEP (35 / 100) / Elapsed: 8.2 s / ETA: 22.7 s =============
# ============ STEP (36 / 100) / Elapsed: 8.3 s / ETA: 22.5 s =============
# ============ STEP (37 / 100) / Elapsed: 8.5 s / ETA: 22.3 s =============
# ============ STEP (38 / 100) / Elapsed: 8.6 s / ETA: 22.0 s =============
# ============ STEP (39 / 100) / Elapsed: 8.7 s / ETA: 21.8 s =============
# ============ STEP (40 / 100) / Elapsed: 9.1 s / ETA: 22.2 s =============
# ============ STEP (41 / 100) / Elapsed: 9.3 s / ETA: 22.2 s =============
# ============ STEP (42 / 100) / Elapsed: 9.5 s / ETA: 22.1 s =============
# ============ STEP (43 / 100) / Elapsed: 9.9 s / ETA: 22.5 s =============
# ============ STEP (44 / 100) / Elapsed: 10.0 s / ETA: 22.3 s =============
# ============ STEP (45 / 100) / Elapsed: 10.2 s / ETA: 22.1 s =============
# ============ STEP (46 / 100) / Elapsed: 10.3 s / ETA: 21.9 s =============
# ============ STEP (47 / 100) / Elapsed: 10.5 s / ETA: 21.8 s =============
# ============ STEP (48 / 100) / Elapsed: 10.8 s / ETA: 22.0 s =============
# ============ STEP (49 / 100) / Elapsed: 10.9 s / ETA: 21.8 s =============
# ============ STEP (50 / 100) / Elapsed: 11.0 s / ETA: 21.6 s =============
# ============ STEP (51 / 100) / Elapsed: 11.2 s / ETA: 21.6 s =============
# ============ STEP (52 / 100) / Elapsed: 11.4 s / ETA: 21.6 s =============
# ============ STEP (53 / 100) / Elapsed: 11.8 s / ETA: 21.9 s =============
# ============ STEP (54 / 100) / Elapsed: 12.0 s / ETA: 21.8 s =============
# ============ STEP (55 / 100) / Elapsed: 12.1 s / ETA: 21.6 s =============
# ============ STEP (56 / 100) / Elapsed: 12.3 s / ETA: 21.5 s =============
# ============ STEP (57 / 100) / Elapsed: 12.4 s / ETA: 21.4 s =============
# ============ STEP (58 / 100) / Elapsed: 12.5 s / ETA: 21.2 s =============
# ============ STEP (59 / 100) / Elapsed: 12.7 s / ETA: 21.2 s =============
# ============ STEP (60 / 100) / Elapsed: 13.0 s / ETA: 21.3 s =============
# ============ STEP (61 / 100) / Elapsed: 13.1 s / ETA: 21.2 s =============
# ============ STEP (62 / 100) / Elapsed: 13.3 s / ETA: 21.1 s =============
# ============ STEP (63 / 100) / Elapsed: 13.5 s / ETA: 21.1 s =============
# ============ STEP (64 / 100) / Elapsed: 13.7 s / ETA: 21.0 s =============
# ============ STEP (65 / 100) / Elapsed: 13.9 s / ETA: 21.0 s =============
# ============ STEP (66 / 100) / Elapsed: 14.2 s / ETA: 21.2 s =============
# ============ STEP (67 / 100) / Elapsed: 14.4 s / ETA: 21.1 s =============
# ============ STEP (68 / 100) / Elapsed: 14.5 s / ETA: 21.0 s =============
# ============ STEP (69 / 100) / Elapsed: 15.0 s / ETA: 21.4 s =============
# ============ STEP (70 / 100) / Elapsed: 15.1 s / ETA: 21.3 s =============
# ============ STEP (71 / 100) / Elapsed: 15.3 s / ETA: 21.2 s =============
# ============ STEP (72 / 100) / Elapsed: 15.4 s / ETA: 21.1 s =============
# ============ STEP (73 / 100) / Elapsed: 15.5 s / ETA: 21.0 s =============
# ============ STEP (74 / 100) / Elapsed: 15.7 s / ETA: 20.9 s =============
# ============ STEP (75 / 100) / Elapsed: 15.9 s / ETA: 20.9 s =============
# ============ STEP (76 / 100) / Elapsed: 16.1 s / ETA: 20.9 s =============
# ============ STEP (77 / 100) / Elapsed: 16.2 s / ETA: 20.8 s =============
# ============ STEP (78 / 100) / Elapsed: 16.7 s / ETA: 21.1 s =============
# ============ STEP (79 / 100) / Elapsed: 16.9 s / ETA: 21.1 s =============
# ============ STEP (80 / 100) / Elapsed: 17.2 s / ETA: 21.2 s =============
# ============ STEP (81 / 100) / Elapsed: 17.4 s / ETA: 21.2 s =============
# ============ STEP (82 / 100) / Elapsed: 17.6 s / ETA: 21.2 s =============
# ============ STEP (83 / 100) / Elapsed: 17.7 s / ETA: 21.1 s =============
# ============ STEP (84 / 100) / Elapsed: 17.9 s / ETA: 21.1 s =============
# ============ STEP (85 / 100) / Elapsed: 18.0 s / ETA: 21.0 s =============
# ============ STEP (86 / 100) / Elapsed: 18.5 s / ETA: 21.3 s =============
# ============ STEP (87 / 100) / Elapsed: 18.6 s / ETA: 21.2 s =============
# ============ STEP (88 / 100) / Elapsed: 18.8 s / ETA: 21.1 s =============
# ============ STEP (89 / 100) / Elapsed: 18.9 s / ETA: 21.0 s =============
# ============ STEP (90 / 100) / Elapsed: 19.1 s / ETA: 21.0 s =============
# ============ STEP (91 / 100) / Elapsed: 19.3 s / ETA: 20.9 s =============
# ============ STEP (92 / 100) / Elapsed: 19.4 s / ETA: 20.9 s =============
# ============ STEP (93 / 100) / Elapsed: 19.5 s / ETA: 20.8 s =============
# ============ STEP (94 / 100) / Elapsed: 19.8 s / ETA: 20.9 s =============
# ============ STEP (95 / 100) / Elapsed: 20.0 s / ETA: 20.8 s =============
# ============ STEP (96 / 100) / Elapsed: 20.4 s / ETA: 21.1 s =============
# ============ STEP (97 / 100) / Elapsed: 20.6 s / ETA: 21.0 s =============
# ============ STEP (98 / 100) / Elapsed: 20.7 s / ETA: 21.0 s =============
# ============ STEP (99 / 100) / Elapsed: 21.0 s / ETA: 21.0 s =============
