# %% [markdown]
# # [TUTORIAL] Constrained Task Planning (Sweep)
#
# * This tutorial is written to instruct basic usage of the task & motion planning pipeline
# * Indy7 robot and several environment geometries will be added and floor-wiping task will be conducted.

# %% [markdown]
# ## add project source directory to path

# %%
import os
import sys
sys.path.append(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))

# %% [markdown]
# ## init combined robot config

# %%
from pkg.controller.combined_robot import *
from pkg.project_config import *

crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, RobotType.indy7gripper, None,
                INDY_IP)]
              , connection_list=[False])
# Out:
# connection command:
# indy0: False

# %% [markdown]
# ## create scene builder

# %%
from pkg.geometry.builder.scene_builder import SceneBuilder
s_builder = SceneBuilder(None)
# # deprecated: s_builder.reset_reference_coord(ref_name="floor")

# %% [markdown]
# ## create GeometryScene

# %%
xyz_rpy_robots = {"indy0": ((0,0,0), (0,0,0))}
crob.update_robot_pos_dict(xyz_rpy_robots=xyz_rpy_robots)
gscene = s_builder.create_gscene(crob)
# Out:
# Unable to register with master node [http://localhost:11311]: master may not be running yet. Will keep trying.
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0]

# %% [markdown]
# ## init planning scene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

# %% [markdown]
# ## add environment

# %%
from pkg.geometry.geometry import *

floor = gscene.create_safe(GEOTYPE.BOX, "floor", "base_link", (3,3,0.01), (0,0,0), 
                           rpy=(0,0,0), color=(0.8,0.8,0.8,0.5), display=True, fixed=True, collision=True)
goal = gscene.create_safe(GEOTYPE.BOX, "goal", "base_link", (0.1,0.1,0.01), (0.4,-0.4,0), 
                          rpy=(0,0,0), color=(0.8,0.8,0.2,1), display=True, fixed=True, collision=False)

track = gscene.create_safe(GEOTYPE.BOX, "track", "base_link", (0.1,0.5,0.01), (0.5,0,0), rpy=(0,0,0), 
                           color=(1,0.7,0.7,0.5), display=True, fixed=True, collision=False, parent="floor")
wp1 = gscene.create_safe(GEOTYPE.BOX, "wp1", "base_link", (0.1,0.1,0.01), (0, 0.2,0.),rpy=(0,0,0), 
                         color=(0.8,0.2,0.2,1), display=True, fixed=True, collision=False, parent="track")
wp2 = gscene.create_safe(GEOTYPE.BOX, "wp2", "base_link", (0.1,0.1,0.01), (0, -0.2,0), rpy=(0,0,0), 
                         color=(0.8,0.2,0.2,1), display=True, fixed=True, collision=False, parent="track")
# Out:
# Please create a subscriber to the marker

# %%
gtems = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=True, collision=True)

# %% [markdown]
# ## add brush
# * brush is a CustomObject with one grasping handle and one placement point on the bottom face

# %%
from pkg.planning.constraint.constraint_subject import CustomObject, Grasp2Point, PlacePoint

brush_body = gscene.create_safe(gtype=GEOTYPE.BOX, name="brush_body", link_name="base_link", dims=(0.2,0.07,0.02), 
                   center=(0,0.5,0.045), rpy=(0,0,np.pi/2), color=(0.7,0.7,0.3,1), display=True, collision=True, fixed=False)
brush_handle = gscene.create_safe(gtype=GEOTYPE.BOX, name="brush_handle", link_name="base_link", dims=(0.2,0.03,0.05), center=(0,0,0.035), rpy=(0,0,0), 
                   color=(0.7,0.7,0.3,1), display=True, collision=True, fixed=False, parent="brush_body")
brush_face = gscene.create_safe(gtype=GEOTYPE.BOX, name="brush_face", link_name="base_link", dims=(0.19,0.06,0.03), center=(0,0,-0.025), rpy=(0,0,0), 
                   color=(0.8,0.8,0.8,1), display=True, collision=False, fixed=False, parent="brush_body")

brush = pscene.create_subject(oname="brush", gname="brush_body", _type=CustomObject, 
                              action_points_dict={"handle": Grasp2Point("handle", brush_handle, [0,0,0], [np.pi/2, 0, 0]),
                                                  "face": PlacePoint("face", brush_face, [0,0,-0.015], [0,0,0])})

# %% [markdown]
# ## Register binders

# %%
from pkg.planning.constraint.constraint_actor import Gripper2Tool, PlacePlane, PlaceFrame

# %%
gscene.create_safe(gtype=GEOTYPE.SPHERE, name="grip0", link_name="indy0_tcp", 
                 dims=(0.01,)*3, center=(0,0,0.14), rpy=(-np.pi/2,0,0), color=(1,0,0,1), display=True, collision=False, fixed=True)

# %%
pscene.create_binder(bname="grip0", gname="grip0", _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))
pscene.create_binder(bname="floor", gname="floor", _type=PlacePlane, point=None)
pscene.create_binder(bname="goal_bd", gname="goal", _type=PlacePlane, point=(0,0,0.005), rpy=(0,0,0))

# %% [markdown]
# ### planning pipeline

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
mplan = MoveitPlanner(pscene)
mplan.update_gscene()
from pkg.planning.task.rrt import TaskRRT
tplan = TaskRRT(pscene)
tplan.prepare()
from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)
ppline.set_motion_planner(mplan)
ppline.set_task_planner(tplan)

# %% [markdown]
# ## ui

# %%
from pkg.ui.ui_broker import *

# start UI
ui_broker = UIBroker.instance()
ui_broker.initialize(ppline, s_builder)
ui_broker.start_server()

ui_broker.set_tables()
# Out:
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "pkg.ui.dash_launcher" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# ```
# open web ui on <your ip>:8050
# click geometry items / Handles / Binders to highlight geometry on RVIZ
# other functions may be buggy.. please report
# ```

# %% [markdown]
# ## SweepTask (Plane constraint)
# * **SweepTask** is a **WaypointTask** with plane constraint, where a **WaypointTask** is a task of sequentially touching defined waypoints
# * With the plane constraint, the brush face maintains contact with the surface
# * In this example the **SweepTask** contains two wayoints
# * **SweepPoint** and **SweepTool** are action point and actor for sweep task, without fixed orientation

# %%
from pkg.planning.constraint.constraint_subject import SweepPoint, SweepTask
from pkg.planning.constraint.constraint_actor import SweepTool
sweep = pscene.create_subject(oname="sweep", gname="floor", _type=SweepTask, 
                             action_points_dict = {"wp1": SweepPoint("wp1", wp1, [0,0,0.005], [0,0,0]),
                                                   "wp2": SweepPoint("wp2", wp2, [0,0,0.005], [0,0,0])})
pscene.create_binder(bname="brush_face", gname="brush_face", _type=SweepTool, point=(0,0,-0.015), rpy=(0,0,0))
ppline.set_task_planner(tplan)

# %% [markdown]
# ### Planning

# %%
from pkg.planning.constraint.constraint_common \
            import sample_redundancy, combine_redundancy

initial_state = pscene.initialize_state(crob.home_pose)

# %%
# goal_nodes = [("goal",)]
goal_nodes = [("goal", 2)]
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, timeout_loop=60, multiprocess=False)
schedules = ppline.tplan.find_schedules()
schedules_sorted = ppline.tplan.sort_schedule(schedules)
snode_schedule = ppline.tplan.idxSchedule2SnodeScedule(schedules_sorted[0])
# Out:
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->1 (0.18/60.0 s, steps/err: 40(72.4930763245 ms)/0.00195549030136)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 0.9
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->2 (1.29/60.0 s, steps/err: 78(75.178861618 ms)/0.00142094406755)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.8
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->3 (1.34/60.0 s, steps/err: 107(48.702955246 ms)/0.00176359467129)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('floor', 0) = success
# branching: 1->4 (2.42/60.0 s, steps/err: 20(39.577960968 ms)/0.00210982879737)
# ======================================================================================================================================================
# try: 4 - ('floor', 0)->('grip0', 0)
# error: 0.42
# try transition motion
# transition motion tried: True
# result: 4 - ('floor', 0)->('grip0', 0) = success
# branching: 4->5 (2.57/60.0 s, steps/err: 9(146.422147751 ms)/0.000699111810649)
# ======================================================================================================================================================
# try: 5 - ('grip0', 0)->('floor', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('floor', 0) = success
# branching: 5->6 (2.63/60.0 s, steps/err: 39(54.6691417694 ms)/0.00148854903477)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('grip0', 0)
# error: 0.99
# try transition motion
# transition motion tried: True
# result: 3 - ('goal', 0)->('grip0', 0) = success
# branching: 3->7 (2.85/60.0 s, steps/err: 196(216.094017029 ms)/0.00102931780253)
# ======================================================================================================================================================
# try: 5 - ('grip0', 0)->('floor', 0)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 5 - ('grip0', 0)->('floor', 0) = fail
# try: 5 - ('grip0', 0)->('goal', 0)
# error: 1.2
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('goal', 0) = success
# branching: 5->8 (3.95/60.0 s, steps/err: 83(67.2731399536 ms)/0.00170408804874)
# ======================================================================================================================================================
# try: 8 - ('goal', 0)->('goal', 1)
# result: 8 - ('goal', 0)->('goal', 1) = fail
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->9 (4.01/60.0 s, steps/err: 86(47.9950904846 ms)/0.00158485969627)
# ======================================================================================================================================================
# try: 9 - ('goal', 1)->('goal', 2)
# result: 9 - ('goal', 1)->('goal', 2) = fail
# try: 5 - ('grip0', 0)->('floor', 0)
# error: 1.5
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('floor', 0) = success
# branching: 5->10 (4.07/60.0 s, steps/err: 31(43.0240631104 ms)/0.00195033683961)
# ======================================================================================================================================================
# try: 9 - ('goal', 1)->('goal', 2)
# result: 9 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->11 (4.14/60.0 s, steps/err: 59(54.2860031128 ms)/0.00178025658712)
# ======================================================================================================================================================
# try: 11 - ('goal', 0)->('goal', 1)
# result: 11 - ('goal', 0)->('goal', 1) = fail
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 4 - ('floor', 0)->('grip0', 0)
# error: 0.69
# try transition motion
# transition motion tried: True
# result: 4 - ('floor', 0)->('grip0', 0) = success
# branching: 4->12 (4.25/60.0 s, steps/err: 52(79.4229507446 ms)/0.00127988312009)
# ======================================================================================================================================================
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->13 (4.29/60.0 s, steps/err: 72(41.2487983704 ms)/0.00158770088378)
# ======================================================================================================================================================
# try: 13 - ('goal', 1)->('goal', 2)
# result: 13 - ('goal', 1)->('goal', 2) = fail
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 2.3
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 2 - ('grip0', 1)->('grip0', 2) = fail
# try: 9 - ('goal', 1)->('goal', 2)
# result: 9 - ('goal', 1)->('goal', 2) = fail
# try: 9 - ('goal', 1)->('grip0', 1)
# error: 0.052
# try transition motion
# transition motion tried: True
# result: 9 - ('goal', 1)->('grip0', 1) = success
# branching: 9->14 (5.42/60.0 s, steps/err: 2(41.1050319672 ms)/0.00151013888667)
# ======================================================================================================================================================
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 0.77
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 2 - ('grip0', 1)->('grip0', 2) = fail
# try: 7 - ('grip0', 0)->('floor', 0)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 7 - ('grip0', 0)->('floor', 0) = fail
# try: 14 - ('grip0', 1)->('grip0', 2)
# error: 2.6
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 14 - ('grip0', 1)->('grip0', 2) = fail
# try: 11 - ('goal', 0)->('grip0', 0)
# error: 0.55
# try transition motion
# transition motion tried: True
# result: 11 - ('goal', 0)->('grip0', 0) = success
# branching: 11->15 (8.61/60.0 s, steps/err: 13(52.8180599213 ms)/0.0018749017905)
# ======================================================================================================================================================
# try: 15 - ('grip0', 0)->('floor', 0)
# error: 1.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 15 - ('grip0', 0)->('floor', 0) = fail
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 1.2
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 2 - ('grip0', 1)->('grip0', 2) = fail
# try: 2 - ('grip0', 1)->('floor', 1)
# error: 3.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 2 - ('grip0', 1)->('floor', 1) = fail
# try: 7 - ('grip0', 0)->('goal', 0)
# error: 1.5
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0', 0)->('goal', 0) = success
# branching: 7->16 (11.78/60.0 s, steps/err: 88(86.6529941559 ms)/0.00139870565464)
# ======================================================================================================================================================
# try: 16 - ('goal', 0)->('goal', 1)
# result: 16 - ('goal', 0)->('goal', 1) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->17 (11.87/60.0 s, steps/err: 54(72.4010467529 ms)/0.000747575873236)
# ======================================================================================================================================================
# try: 17 - ('goal', 0)->('goal', 1)
# result: 17 - ('goal', 0)->('goal', 1) = fail
# try: 7 - ('grip0', 0)->('goal', 0)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 7 - ('grip0', 0)->('goal', 0) = fail
# try: 10 - ('floor', 0)->('grip0', 0)
# error: 0.21
# try transition motion
# transition motion tried: True
# result: 10 - ('floor', 0)->('grip0', 0) = success
# branching: 10->18 (12.97/60.0 s, steps/err: 6(44.9540615082 ms)/0.00143402233859)
# ======================================================================================================================================================
# try: 11 - ('goal', 0)->('grip0', 0)
# error: 0.62
# try transition motion
# transition motion tried: True
# result: 11 - ('goal', 0)->('grip0', 0) = success
# branching: 11->19 (13.01/60.0 s, steps/err: 22(43.4520244598 ms)/0.00102892015799)
# ======================================================================================================================================================
# try: 18 - ('grip0', 0)->('floor', 0)
# error: 3.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 18 - ('grip0', 0)->('floor', 0) = fail
# try: 14 - ('grip0', 1)->('floor', 1)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 14 - ('grip0', 1)->('floor', 1) = fail
# try: 13 - ('goal', 1)->('grip0', 1)
# error: 0.71
# try transition motion
# transition motion tried: True
# result: 13 - ('goal', 1)->('grip0', 1) = success
# branching: 13->20 (15.13/60.0 s, steps/err: 27(54.3138980865 ms)/0.00138326210146)
# ======================================================================================================================================================
# try: 5 - ('grip0', 0)->('goal', 0)
# error: 0.77
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('goal', 0) = success
# branching: 5->21 (15.21/60.0 s, steps/err: 82(69.4689750671 ms)/0.00145822885141)
# ======================================================================================================================================================
# try: 21 - ('goal', 0)->('goal', 1)
# result: 21 - ('goal', 0)->('goal', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 9 - ('goal', 1)->('goal', 2)
# result: 9 - ('goal', 1)->('goal', 2) = fail
# try: 20 - ('grip0', 1)->('goal', 1)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 20 - ('grip0', 1)->('goal', 1) = success
# branching: 20->22 (16.34/60.0 s, steps/err: 29(35.0539684296 ms)/0.00133795283962)
# ======================================================================================================================================================
# try: 22 - ('goal', 1)->('goal', 2)
# result: 22 - ('goal', 1)->('goal', 2) = fail
# try: 7 - ('grip0', 0)->('goal', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0', 0)->('goal', 0) = success
# branching: 7->23 (16.38/60.0 s, steps/err: 9(28.0809402466 ms)/0.00136994291808)
# ======================================================================================================================================================
# try: 23 - ('goal', 0)->('goal', 1)
# result: 23 - ('goal', 0)->('goal', 1) = fail
# try: 2 - ('grip0', 1)->('floor', 1)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('floor', 1) = success
# branching: 2->24 (16.47/60.0 s, steps/err: 30(67.9681301117 ms)/0.00149063470271)
# ======================================================================================================================================================
# try: 20 - ('grip0', 1)->('grip0', 2)
# error: 1.9
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 20 - ('grip0', 1)->('grip0', 2) = fail
# try: 24 - ('floor', 1)->('floor', 2)
# result: 24 - ('floor', 1)->('floor', 2) = fail
# try: 4 - ('floor', 0)->('floor', 1)
# result: 4 - ('floor', 0)->('floor', 1) = fail
# try: 5 - ('grip0', 0)->('floor', 0)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 5 - ('grip0', 0)->('floor', 0) = fail
# try: 22 - ('goal', 1)->('goal', 2)
# result: 22 - ('goal', 1)->('goal', 2) = fail
# try: 20 - ('grip0', 1)->('grip0', 2)
# error: 1.5
# try constrained motion
# constrained motion tried: True
# result: 20 - ('grip0', 1)->('grip0', 2) = success
# branching: 20->25 (18.66/60.0 s, steps/err: 99(61.9068145752 ms)/0.00139560942431)
# ======================================================================================================================================================
# try: 25 - ('grip0', 2)->('goal', 2)
# error: 2.0
# try transition motion
# transition motion tried: True
# Goal reached
# result: 25 - ('grip0', 2)->('goal', 2) = success
# branching: 25->26 (18.7/60.0 s, steps/err: 24(37.8580093384 ms)/0.0019343387238)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 9 - ('goal', 1)->('grip0', 1)
# error: 0.49
# try transition motion
# transition motion tried: True
# result: 9 - ('goal', 1)->('grip0', 1) = success
# branching: 9->28 (19.01/60.0 s, steps/err: 65(70.5499649048 ms)/0.00181224520157)
# ======================================================================================================================================================
# try: 5 - ('grip0', 0)->('floor', 0)
# error: 3.0
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('floor', 0) = success
# branching: 5->29 (19.05/60.0 s, steps/err: 36(37.5969409943 ms)/0.00112194408869)
# ======================================================================================================================================================
# try: 25 - ('grip0', 2)->('floor', 2)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 25 - ('grip0', 2)->('floor', 2) = fail
# try: 18 - ('grip0', 0)->('goal', 0)
# error: 0.84
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 18 - ('grip0', 0)->('goal', 0) = fail
# try: 20 - ('grip0', 1)->('floor', 1)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 20 - ('grip0', 1)->('floor', 1) = fail
# try: 28 - ('grip0', 1)->('goal', 1)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 28 - ('grip0', 1)->('goal', 1) = success
# branching: 28->30 (22.21/60.0 s, steps/err: 79(69.7779655457 ms)/0.000998370052198)
# ======================================================================================================================================================
# try: 30 - ('goal', 1)->('goal', 2)
# result: 30 - ('goal', 1)->('goal', 2) = fail
# try: 16 - ('goal', 0)->('goal', 1)
# result: 16 - ('goal', 0)->('goal', 1) = fail
# try: 14 - ('grip0', 1)->('grip0', 2)
# error: 0.38
# try constrained motion
# constrained motion tried: True
# result: 14 - ('grip0', 1)->('grip0', 2) = success
# branching: 14->31 (22.59/60.0 s, steps/err: 18(353.600025177 ms)/0.00200175202961)
# ======================================================================================================================================================
# try: 31 - ('grip0', 2)->('goal', 2)
# error: 0.3
# try transition motion
# transition motion tried: True
# Goal reached
# result: 31 - ('grip0', 2)->('goal', 2) = success
# branching: 31->32 (22.62/60.0 s, steps/err: 8(24.0759849548 ms)/0.00208256215522)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 24 - ('floor', 1)->('grip0', 1)
# error: 0.12
# try transition motion
# transition motion tried: True
# result: 24 - ('floor', 1)->('grip0', 1) = success
# branching: 24->34 (22.92/60.0 s, steps/err: 4(40.0619506836 ms)/0.00181910227321)
# ======================================================================================================================================================
# try: 6 - ('floor', 0)->('floor', 1)
# result: 6 - ('floor', 0)->('floor', 1) = fail
# try: 7 - ('grip0', 0)->('floor', 0)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0', 0)->('floor', 0) = success
# branching: 7->35 (23.0/60.0 s, steps/err: 29(65.4017925262 ms)/0.00120954449123)
# ======================================================================================================================================================
# try: 24 - ('floor', 1)->('grip0', 1)
# error: 0.21
# try transition motion
# transition motion tried: True
# result: 24 - ('floor', 1)->('grip0', 1) = success
# branching: 24->36 (23.04/60.0 s, steps/err: 4(34.8868370056 ms)/0.000685362694052)
# ======================================================================================================================================================
# try: 25 - ('grip0', 2)->('floor', 2)
# error: 2.1
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 25 - ('grip0', 2)->('floor', 2) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 31 - ('grip0', 2)->('floor', 2)
# error: 1.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 31 - ('grip0', 2)->('floor', 2) = fail
# try: 28 - ('grip0', 1)->('grip0', 2)
# error: 2.8
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 28 - ('grip0', 1)->('grip0', 2) = fail
# try: 20 - ('grip0', 1)->('floor', 1)
# error: 2.9
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 20 - ('grip0', 1)->('floor', 1) = fail
# try: 24 - ('floor', 1)->('grip0', 1)
# error: 1.1
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 24 - ('floor', 1)->('grip0', 1) = fail
# try: 34 - ('grip0', 1)->('goal', 1)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 34 - ('grip0', 1)->('goal', 1) = success
# branching: 34->37 (28.26/60.0 s, steps/err: 46(65.0699138641 ms)/0.00141527308295)
# ======================================================================================================================================================
# try: 37 - ('goal', 1)->('goal', 2)
# result: 37 - ('goal', 1)->('goal', 2) = fail
# try: 12 - ('grip0', 0)->('floor', 0)
# error: 1.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 0)->('floor', 0) = fail
# try: 28 - ('grip0', 1)->('grip0', 2)
# error: 0.26
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 28 - ('grip0', 1)->('grip0', 2) = fail
# try: 17 - ('goal', 0)->('grip0', 0)
# error: 0.01
# try transition motion
# transition motion tried: True
# result: 17 - ('goal', 0)->('grip0', 0) = success
# branching: 17->38 (30.41/60.0 s, steps/err: 2(40.7769680023 ms)/0.00179711292305)
# ======================================================================================================================================================
# try: 29 - ('floor', 0)->('grip0', 0)
# error: 0.22
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 29 - ('floor', 0)->('grip0', 0) = fail
# try: 22 - ('goal', 1)->('goal', 2)
# result: 22 - ('goal', 1)->('goal', 2) = fail
# try: 7 - ('grip0', 0)->('goal', 0)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0', 0)->('goal', 0) = success
# branching: 7->39 (31.53/60.0 s, steps/err: 59(53.4610748291 ms)/0.00160835734354)
# ======================================================================================================================================================
# try: 39 - ('goal', 0)->('goal', 1)
# result: 39 - ('goal', 0)->('goal', 1) = fail
# try: 28 - ('grip0', 1)->('grip0', 2)
# error: 1.9
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 28 - ('grip0', 1)->('grip0', 2) = fail
# try: 34 - ('grip0', 1)->('goal', 1)
# error: 3.0
# try transition motion
# transition motion tried: True
# result: 34 - ('grip0', 1)->('goal', 1) = success
# branching: 34->40 (32.63/60.0 s, steps/err: 44(65.2599334717 ms)/0.00140644926448)
# ======================================================================================================================================================
# try: 40 - ('goal', 1)->('goal', 2)
# result: 40 - ('goal', 1)->('goal', 2) = fail
# try: 24 - ('floor', 1)->('floor', 2)
# result: 24 - ('floor', 1)->('floor', 2) = fail
# try: 40 - ('goal', 1)->('goal', 2)
# result: 40 - ('goal', 1)->('goal', 2) = fail
# try: 13 - ('goal', 1)->('grip0', 1)
# error: 0.18
# try transition motion
# transition motion tried: True
# result: 13 - ('goal', 1)->('grip0', 1) = success
# branching: 13->41 (32.72/60.0 s, steps/err: 5(51.873922348 ms)/0.00189532063089)
# ======================================================================================================================================================
# try: 23 - ('goal', 0)->('grip0', 0)
# error: 0.23
# try transition motion
# transition motion tried: True
# result: 23 - ('goal', 0)->('grip0', 0) = success
# branching: 23->42 (32.77/60.0 s, steps/err: 6(48.819065094 ms)/0.00181034794311)
# ======================================================================================================================================================
# try: 35 - ('floor', 0)->('grip0', 0)
# error: 0.83
# try transition motion
# transition motion tried: True
# result: 35 - ('floor', 0)->('grip0', 0) = success
# branching: 35->43 (32.8/60.0 s, steps/err: 16(28.9959907532 ms)/0.00116240676761)
# ======================================================================================================================================================
# try: 21 - ('goal', 0)->('grip0', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 21 - ('goal', 0)->('grip0', 0) = success
# branching: 21->44 (32.91/60.0 s, steps/err: 84(104.203939438 ms)/0.00205376347247)
# ======================================================================================================================================================
# try: 22 - ('goal', 1)->('goal', 2)
# result: 22 - ('goal', 1)->('goal', 2) = fail
# try: 41 - ('grip0', 1)->('goal', 1)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 41 - ('grip0', 1)->('goal', 1) = success
# branching: 41->45 (32.97/60.0 s, steps/err: 14(46.7619895935 ms)/0.00210377295107)
# ======================================================================================================================================================
# try: 45 - ('goal', 1)->('goal', 2)
# result: 45 - ('goal', 1)->('goal', 2) = fail
# try: 44 - ('grip0', 0)->('floor', 0)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 44 - ('grip0', 0)->('floor', 0) = success
# branching: 44->46 (33.06/60.0 s, steps/err: 81(73.3139514923 ms)/0.0010646131282)
# ======================================================================================================================================================
# try: 36 - ('grip0', 1)->('grip0', 2)
# error: 1.9
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 36 - ('grip0', 1)->('grip0', 2) = fail
# try: 34 - ('grip0', 1)->('floor', 1)
# error: 2.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 34 - ('grip0', 1)->('floor', 1) = fail
# try: 34 - ('grip0', 1)->('floor', 1)
# error: 0.67
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 34 - ('grip0', 1)->('floor', 1) = fail
# try: 12 - ('grip0', 0)->('grip0', 1)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 12 - ('grip0', 0)->('grip0', 1) = success
# branching: 12->47 (36.21/60.0 s, steps/err: 44(51.237821579 ms)/0.00155421982713)
# ======================================================================================================================================================
# try: 34 - ('grip0', 1)->('goal', 1)
# error: 1.3
# try transition motion
# transition motion tried: True
# result: 34 - ('grip0', 1)->('goal', 1) = success
# branching: 34->48 (36.3/60.0 s, steps/err: 82(88.8369083405 ms)/0.00113864005453)
# ======================================================================================================================================================
# try: 48 - ('goal', 1)->('goal', 2)
# result: 48 - ('goal', 1)->('goal', 2) = fail
# try: 23 - ('goal', 0)->('grip0', 0)
# error: 0.14
# try transition motion
# transition motion tried: True
# result: 23 - ('goal', 0)->('grip0', 0) = success
# branching: 23->49 (36.35/60.0 s, steps/err: 4(30.298948288 ms)/0.00132798899042)
# ======================================================================================================================================================
# try: 31 - ('grip0', 2)->('floor', 2)
# error: 2.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 31 - ('grip0', 2)->('floor', 2) = fail
# try: 39 - ('goal', 0)->('goal', 1)
# result: 39 - ('goal', 0)->('goal', 1) = fail
# try: 41 - ('grip0', 1)->('goal', 1)
# error: 0.59
# try transition motion
# transition motion tried: True
# result: 41 - ('grip0', 1)->('goal', 1) = success
# branching: 41->50 (37.44/60.0 s, steps/err: 4(32.998085022 ms)/0.00134966714499)
# ======================================================================================================================================================
# try: 50 - ('goal', 1)->('goal', 2)
# result: 50 - ('goal', 1)->('goal', 2) = fail
# try: 25 - ('grip0', 2)->('floor', 2)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 25 - ('grip0', 2)->('floor', 2) = fail
# try: 20 - ('grip0', 1)->('floor', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 20 - ('grip0', 1)->('floor', 1) = success
# branching: 20->51 (38.54/60.0 s, steps/err: 51(63.8589859009 ms)/0.00150764455409)
# ======================================================================================================================================================
# try: 39 - ('goal', 0)->('goal', 1)
# result: 39 - ('goal', 0)->('goal', 1) = fail
# try: 39 - ('goal', 0)->('grip0', 0)
# error: 0.029
# try transition motion
# transition motion tried: True
# result: 39 - ('goal', 0)->('grip0', 0) = success
# branching: 39->52 (38.6/60.0 s, steps/err: 2(40.3950214386 ms)/0.000971316597232)
# ======================================================================================================================================================
# try: 25 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 25 - ('grip0', 2)->('goal', 2) = success
# branching: 25->53 (38.68/60.0 s, steps/err: 78(74.4998455048 ms)/0.00122719762953)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 34 - ('grip0', 1)->('grip0', 2)
# error: 2.6
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 34 - ('grip0', 1)->('grip0', 2) = fail
# try: 42 - ('grip0', 0)->('goal', 0)
# error: 2.0
# try transition motion
# transition motion tried: True
# result: 42 - ('grip0', 0)->('goal', 0) = success
# branching: 42->55 (40.08/60.0 s, steps/err: 84(95.2210426331 ms)/0.00158415238632)
# ======================================================================================================================================================
# try: 55 - ('goal', 0)->('goal', 1)
# result: 55 - ('goal', 0)->('goal', 1) = fail
# try: 52 - ('grip0', 0)->('goal', 0)
# error: 0.089
# try transition motion
# transition motion tried: True
# result: 52 - ('grip0', 0)->('goal', 0) = success
# branching: 52->56 (40.12/60.0 s, steps/err: 3(32.0310592651 ms)/0.00180179743144)
# ======================================================================================================================================================
# try: 56 - ('goal', 0)->('goal', 1)
# result: 56 - ('goal', 0)->('goal', 1) = fail
# try: 10 - ('floor', 0)->('grip0', 0)
# error: 0.42
# try transition motion
# transition motion tried: True
# result: 10 - ('floor', 0)->('grip0', 0) = success
# branching: 10->57 (40.27/60.0 s, steps/err: 11(113.198041916 ms)/0.000757016951535)
# ======================================================================================================================================================
# try: 49 - ('grip0', 0)->('goal', 0)
# error: 0.1
# try transition motion
# transition motion tried: True
# result: 49 - ('grip0', 0)->('goal', 0) = success
# branching: 49->58 (40.3/60.0 s, steps/err: 3(28.6989212036 ms)/0.00189254790921)
# ======================================================================================================================================================
# try: 58 - ('goal', 0)->('goal', 1)
# result: 58 - ('goal', 0)->('goal', 1) = fail
# try: 24 - ('floor', 1)->('floor', 2)
# result: 24 - ('floor', 1)->('floor', 2) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 51 - ('floor', 1)->('grip0', 1)
# error: 1.5
# try transition motion
# transition motion tried: True
# result: 51 - ('floor', 1)->('grip0', 1) = success
# branching: 51->59 (41.45/60.0 s, steps/err: 101(91.6121006012 ms)/0.00134191131683)
# ======================================================================================================================================================
# try: 59 - ('grip0', 1)->('floor', 1)
# error: 2.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 59 - ('grip0', 1)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->60 (42.55/60.0 s, steps/err: 47(67.7959918976 ms)/0.00122917645959)
# ======================================================================================================================================================
# try: 51 - ('floor', 1)->('grip0', 1)
# error: 0.59
# try transition motion
# transition motion tried: True
# result: 51 - ('floor', 1)->('grip0', 1) = success
# branching: 51->61 (42.64/60.0 s, steps/err: 94(79.1590213776 ms)/0.00115533838711)
# ======================================================================================================================================================
# try: 24 - ('floor', 1)->('grip0', 1)
# error: 0.57
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 24 - ('floor', 1)->('grip0', 1) = fail
# try: 28 - ('grip0', 1)->('goal', 1)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 28 - ('grip0', 1)->('goal', 1) = success
# branching: 28->62 (43.72/60.0 s, steps/err: 46(52.925825119 ms)/0.00160585368405)
# ======================================================================================================================================================
# try: 62 - ('goal', 1)->('goal', 2)
# result: 62 - ('goal', 1)->('goal', 2) = fail
# try: 45 - ('goal', 1)->('grip0', 1)
# error: 0.62
# try transition motion
# transition motion tried: True
# result: 45 - ('goal', 1)->('grip0', 1) = success
# branching: 45->63 (43.77/60.0 s, steps/err: 14(34.7151756287 ms)/0.000554162184506)
# ======================================================================================================================================================
# try: 49 - ('grip0', 0)->('grip0', 1)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 49 - ('grip0', 0)->('grip0', 1) = success
# branching: 49->64 (43.84/60.0 s, steps/err: 93(74.4438171387 ms)/0.00171988135004)
# ======================================================================================================================================================
# try: 37 - ('goal', 1)->('goal', 2)
# result: 37 - ('goal', 1)->('goal', 2) = fail
# try: 52 - ('grip0', 0)->('goal', 0)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 52 - ('grip0', 0)->('goal', 0) = success
# branching: 52->65 (43.93/60.0 s, steps/err: 57(65.3920173645 ms)/0.00142613092967)
# ======================================================================================================================================================
# try: 65 - ('goal', 0)->('goal', 1)
# result: 65 - ('goal', 0)->('goal', 1) = fail
# try: 28 - ('grip0', 1)->('goal', 1)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 28 - ('grip0', 1)->('goal', 1) = success
# branching: 28->66 (43.99/60.0 s, steps/err: 20(48.6400127411 ms)/0.00182454446087)
# ======================================================================================================================================================
# try: 66 - ('goal', 1)->('goal', 2)
# result: 66 - ('goal', 1)->('goal', 2) = fail
# try: 36 - ('grip0', 1)->('grip0', 2)
# error: 2.4
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 36 - ('grip0', 1)->('grip0', 2) = fail
# try: 19 - ('grip0', 0)->('floor', 0)
# error: 3.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 19 - ('grip0', 0)->('floor', 0) = fail
# try: 31 - ('grip0', 2)->('goal', 2)
# error: 1.2
# try transition motion
# transition motion tried: True
# Goal reached
# result: 31 - ('grip0', 2)->('goal', 2) = success
# branching: 31->67 (46.16/60.0 s, steps/err: 74(106.507062912 ms)/0.00139371682407)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 42 - ('grip0', 0)->('goal', 0)
# error: 0.78
# try transition motion
# transition motion tried: True
# result: 42 - ('grip0', 0)->('goal', 0) = success
# branching: 42->69 (46.46/60.0 s, steps/err: 12(53.7540912628 ms)/0.000980189413109)
# ======================================================================================================================================================
# try: 69 - ('goal', 0)->('goal', 1)
# result: 69 - ('goal', 0)->('goal', 1) = fail
# try: 16 - ('goal', 0)->('grip0', 0)
# error: 1.5
# try transition motion
# transition motion tried: True
# result: 16 - ('goal', 0)->('grip0', 0) = success
# branching: 16->70 (46.62/60.0 s, steps/err: 76(139.991044998 ms)/0.00188130678928)
# ======================================================================================================================================================
# try: 63 - ('grip0', 1)->('floor', 1)
# error: 2.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 63 - ('grip0', 1)->('floor', 1) = fail
# try: 43 - ('grip0', 0)->('goal', 0)
# error: 2.0
# try transition motion
# transition motion tried: True
# result: 43 - ('grip0', 0)->('goal', 0) = success
# branching: 43->71 (47.74/60.0 s, steps/err: 51(62.3710155487 ms)/0.00195129444439)
# ======================================================================================================================================================
# try: 71 - ('goal', 0)->('goal', 1)
# result: 71 - ('goal', 0)->('goal', 1) = fail
# try: 57 - ('grip0', 0)->('grip0', 1)
# error: 1.5
# try transition motion
# transition motion tried: True
# result: 57 - ('grip0', 0)->('grip0', 1) = success
# branching: 57->72 (47.8/60.0 s, steps/err: 15(31.2349796295 ms)/0.0017207261621)
# ======================================================================================================================================================
# try: 71 - ('goal', 0)->('goal', 1)
# result: 71 - ('goal', 0)->('goal', 1) = fail
# try: 59 - ('grip0', 1)->('grip0', 2)
# error: 0.52
# try constrained motion
# constrained motion tried: True
# result: 59 - ('grip0', 1)->('grip0', 2) = success
# branching: 59->73 (48.3/60.0 s, steps/err: 187(478.245973587 ms)/0.00155769414732)
# ======================================================================================================================================================
# try: 73 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 73 - ('grip0', 2)->('goal', 2) = success
# branching: 73->74 (48.35/60.0 s, steps/err: 60(49.4549274445 ms)/0.00166115416137)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 30 - ('goal', 1)->('goal', 2)
# result: 30 - ('goal', 1)->('goal', 2) = fail
# try: 21 - ('goal', 0)->('grip0', 0)
# error: 0.5
# try transition motion
# transition motion tried: True
# result: 21 - ('goal', 0)->('grip0', 0) = success
# branching: 21->76 (48.69/60.0 s, steps/err: 98(76.7390727997 ms)/0.00110895268732)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 1.9
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 37 - ('goal', 1)->('grip0', 1)
# error: 0.51
# try transition motion
# transition motion tried: True
# result: 37 - ('goal', 1)->('grip0', 1) = success
# branching: 37->77 (49.96/60.0 s, steps/err: 62(242.907047272 ms)/0.000978312995763)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 0.59
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->78 (50.04/60.0 s, steps/err: 89(74.7630596161 ms)/0.00125608778789)
# ======================================================================================================================================================
# try: 72 - ('grip0', 1)->('grip0', 2)
# error: 2.7
# try constrained motion
# constrained motion tried: True
# result: 72 - ('grip0', 1)->('grip0', 2) = success
# branching: 72->79 (50.31/60.0 s, steps/err: 71(267.653942108 ms)/0.00143615974224)
# ======================================================================================================================================================
# try: 79 - ('grip0', 2)->('goal', 2)
# error: 2.6
# try transition motion
# transition motion tried: True
# Goal reached
# result: 79 - ('grip0', 2)->('goal', 2) = success
# branching: 79->80 (50.34/60.0 s, steps/err: 17(27.9588699341 ms)/0.0010666110062)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# =========================================================================================================
# ======================= terminated 0: required answers acquired  (50.6/60.0) ===============================
# =========================================================================================================
# ========================== FINISHED (50.6 / 60.0 s) ==============================]

# %% [markdown]
# ### play searched plan

# %%
ppline.play_schedule(snode_schedule, period=0.01)
# Out:
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('floor', 0)
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('floor', 0)
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('grip0', 1)
# ('grip0', 1)->('grip0', 2)
# ('grip0', 2)->('goal', 2)
# ('goal', 2)->('goal', 2)

# %% [markdown]
# ### return to initial state to run next example

# %%
pscene.set_object_state(initial_state)
gscene.show_pose(initial_state.Q)

# %% [markdown]
# ## SweepLineTask (Line constraint)
# * **SweepLineTask** is a **SweepTask** with a line constraint
# * A straight line constraint is generated between two given waypoints
# * By default, **SweepLineTask** fixes orientation while sweeping.
# * **SweepFrame** and **SweepFramer** are action point and actor for sweep task that with fixed orientations.
# * To observe orientation constraint, **SweepFrame** and **SweepFramer** should be used.

# %%
from pkg.planning.constraint.constraint_subject import SweepLineTask, SweepFrame
from pkg.planning.constraint.constraint_actor import SweepFramer

sweep = pscene.create_subject(oname="sweep", gname="floor", _type=SweepLineTask, 
                             action_points_dict = {"wp1": SweepFrame("wp1", wp1, [0,0,0.005], [0,0,0]),
                                                   "wp2": SweepFrame("wp2", wp2, [0,0,0.005], [0,0,0])})
pscene.create_binder(bname="brush_face", gname="brush_face", _type=SweepFramer, point=(0,0,-0.015), rpy=(0,0,0))
ppline.set_task_planner(tplan)

# %% [markdown]
# ### Planning

# %%
from pkg.planning.constraint.constraint_common \
            import sample_redundancy, combine_redundancy

initial_state = pscene.initialize_state(crob.home_pose)

# %%
# goal_nodes = [("goal",)]
goal_nodes = [("goal", 2)]
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, timeout_loop=60, multiprocess=False)
schedules = ppline.tplan.find_schedules()
schedules_sorted = ppline.tplan.sort_schedule(schedules)
snode_schedule = ppline.tplan.idxSchedule2SnodeScedule(schedules_sorted[0])
# Out:
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.3
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->1 (2.15/60.0 s, steps/err: 52(61.6888999939 ms)/0.00174616978829)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->2 (2.19/60.0 s, steps/err: 14(41.0640239716 ms)/0.00189810555179)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->3 (2.24/60.0 s, steps/err: 14(48.7599372864 ms)/0.000781882729952)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->4 (4.37/60.0 s, steps/err: 67(60.9421730042 ms)/0.00149426746775)
# ======================================================================================================================================================
# try: 4 - ('goal', 1)->('goal', 2)
# result: 4 - ('goal', 1)->('goal', 2) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# try constrained motion
# constrained motion tried: True
# result: 2 - ('grip0', 1)->('grip0', 2) = success
# branching: 2->5 (4.81/60.0 s, steps/err: 46(414.671897888 ms)/0.00134441990573)
# ======================================================================================================================================================
# try: 5 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 5 - ('grip0', 2)->('goal', 2) = success
# branching: 5->6 (4.86/60.0 s, steps/err: 71(53.4210205078 ms)/0.00153264996216)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# try constrained motion
# constrained motion tried: True
# result: 2 - ('grip0', 1)->('grip0', 2) = success
# branching: 2->8 (5.66/60.0 s, steps/err: 46(560.36901474 ms)/0.00141290882298)
# ======================================================================================================================================================
# try: 8 - ('grip0', 2)->('goal', 2)
# error: 0.26
# try transition motion
# transition motion tried: True
# Goal reached
# result: 8 - ('grip0', 2)->('goal', 2) = success
# branching: 8->9 (5.69/60.0 s, steps/err: 10(28.4419059753 ms)/0.00185233976176)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 4 - ('goal', 1)->('grip0', 1)
# error: 1.9
# try transition motion
# transition motion tried: True
# result: 4 - ('goal', 1)->('grip0', 1) = success
# branching: 4->11 (7.05/60.0 s, steps/err: 58(90.7509326935 ms)/0.00152477460221)
# ======================================================================================================================================================
# try: 3 - ('grip0', 1)->('goal', 1)
# error: 2.9
# try transition motion
# transition motion tried: True
# result: 3 - ('grip0', 1)->('goal', 1) = success
# branching: 3->12 (7.13/60.0 s, steps/err: 84(84.9330425262 ms)/0.00178367979684)
# ======================================================================================================================================================
# try: 12 - ('goal', 1)->('goal', 2)
# result: 12 - ('goal', 1)->('goal', 2) = fail
# try: 2 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# try constrained motion
# constrained motion tried: True
# result: 2 - ('grip0', 1)->('grip0', 2) = success
# branching: 2->13 (7.94/60.0 s, steps/err: 45(786.25202179 ms)/0.00178845166111)
# ======================================================================================================================================================
# try: 13 - ('grip0', 2)->('goal', 2)
# error: 2.1
# try transition motion
# transition motion tried: True
# Goal reached
# result: 13 - ('grip0', 2)->('goal', 2) = success
# branching: 13->14 (7.98/60.0 s, steps/err: 38(40.8070087433 ms)/0.00159731536723)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 12 - ('goal', 1)->('grip0', 1)
# error: 0.74
# try transition motion
# transition motion tried: True
# result: 12 - ('goal', 1)->('grip0', 1) = success
# branching: 12->16 (8.33/60.0 s, steps/err: 69(110.743999481 ms)/0.000620564912856)
# ======================================================================================================================================================
# try: 13 - ('grip0', 2)->('floor', 2)
# error: 1.6
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 13 - ('grip0', 2)->('floor', 2) = fail
# try: 4 - ('goal', 1)->('goal', 2)
# result: 4 - ('goal', 1)->('goal', 2) = fail
# try: 11 - ('grip0', 1)->('goal', 1)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 11 - ('grip0', 1)->('goal', 1) = success
# branching: 11->17 (9.42/60.0 s, steps/err: 37(38.5649204254 ms)/0.0018567767244)
# ======================================================================================================================================================
# try: 17 - ('goal', 1)->('goal', 2)
# result: 17 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.9
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('floor', 0) = success
# branching: 1->18 (9.52/60.0 s, steps/err: 70(86.1520767212 ms)/0.0021040004003)
# ======================================================================================================================================================
# try: 16 - ('grip0', 1)->('goal', 1)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 16 - ('grip0', 1)->('goal', 1) = success
# branching: 16->19 (9.56/60.0 s, steps/err: 23(36.4949703217 ms)/0.00115855392435)
# ======================================================================================================================================================
# try: 19 - ('goal', 1)->('goal', 2)
# result: 19 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.6
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 11 - ('grip0', 1)->('goal', 1)
# error: 1.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 11 - ('grip0', 1)->('goal', 1) = fail
# try: 18 - ('floor', 0)->('floor', 1)
# result: 18 - ('floor', 0)->('floor', 1) = fail
# try: 12 - ('goal', 1)->('goal', 2)
# result: 12 - ('goal', 1)->('goal', 2) = fail
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->20 (11.74/60.0 s, steps/err: 44(36.4971160889 ms)/0.00148466766355)
# ======================================================================================================================================================
# try: 20 - ('goal', 1)->('goal', 2)
# result: 20 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 19 - ('goal', 1)->('grip0', 1)
# error: 0.95
# try transition motion
# transition motion tried: True
# result: 19 - ('goal', 1)->('grip0', 1) = success
# branching: 19->21 (12.83/60.0 s, steps/err: 40(52.4990558624 ms)/0.000447965098531)
# ======================================================================================================================================================
# try: 18 - ('floor', 0)->('floor', 1)
# result: 18 - ('floor', 0)->('floor', 1) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->22 (14.96/60.0 s, steps/err: 14(47.2400188446 ms)/0.000813910824871)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->23 (15.0/60.0 s, steps/err: 14(42.5040721893 ms)/0.00106485550245)
# ======================================================================================================================================================
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 2.9
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->24 (15.07/60.0 s, steps/err: 68(64.982175827 ms)/0.00144813462419)
# ======================================================================================================================================================
# try: 24 - ('goal', 1)->('goal', 2)
# result: 24 - ('goal', 1)->('goal', 2) = fail
# try: 22 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# try constrained motion
# constrained motion tried: True
# result: 22 - ('grip0', 1)->('grip0', 2) = success
# branching: 22->25 (15.17/60.0 s, steps/err: 46(92.5550460815 ms)/0.00216417227106)
# ======================================================================================================================================================
# try: 25 - ('grip0', 2)->('goal', 2)
# error: 2.4
# try transition motion
# transition motion tried: True
# Goal reached
# result: 25 - ('grip0', 2)->('goal', 2) = success
# branching: 25->26 (15.22/60.0 s, steps/err: 68(47.40691185 ms)/0.00141528914053)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 1.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 8 - ('grip0', 2)->('floor', 2)
# error: 2.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 8 - ('grip0', 2)->('floor', 2) = fail
# try: 11 - ('grip0', 1)->('grip0', 2)
# error: 2.0
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 11 - ('grip0', 1)->('grip0', 2) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->28 (18.62/60.0 s, steps/err: 84(58.4490299225 ms)/0.00147120353443)
# ======================================================================================================================================================
# try: 28 - ('goal', 0)->('goal', 1)
# result: 28 - ('goal', 0)->('goal', 1) = fail
# try: 20 - ('goal', 1)->('goal', 2)
# result: 20 - ('goal', 1)->('goal', 2) = fail
# try: 17 - ('goal', 1)->('grip0', 1)
# error: 0.45
# try transition motion
# transition motion tried: True
# result: 17 - ('goal', 1)->('grip0', 1) = success
# branching: 17->29 (18.69/60.0 s, steps/err: 8(37.407875061 ms)/0.00186097502396)
# ======================================================================================================================================================
# try: 17 - ('goal', 1)->('goal', 2)
# result: 17 - ('goal', 1)->('goal', 2) = fail
# try: 2 - ('grip0', 1)->('floor', 1)
# error: 3.6
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 2 - ('grip0', 1)->('floor', 1) = fail
# try: 2 - ('grip0', 1)->('goal', 1)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 1)->('goal', 1) = success
# branching: 2->30 (19.81/60.0 s, steps/err: 66(78.2070159912 ms)/0.00212751861341)
# ======================================================================================================================================================
# try: 30 - ('goal', 1)->('goal', 2)
# result: 30 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 3.0
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->31 (19.91/60.0 s, steps/err: 59(65.0320053101 ms)/0.00130350195401)
# ======================================================================================================================================================
# try: 31 - ('goal', 0)->('goal', 1)
# result: 31 - ('goal', 0)->('goal', 1) = fail
# try: 18 - ('floor', 0)->('grip0', 0)
# error: 1.3
# try transition motion
# transition motion tried: True
# result: 18 - ('floor', 0)->('grip0', 0) = success
# branching: 18->32 (20.04/60.0 s, steps/err: 85(119.010925293 ms)/0.00164300613649)
# ======================================================================================================================================================
# try: 32 - ('grip0', 0)->('grip0', 1)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 32 - ('grip0', 0)->('grip0', 1) = success
# branching: 32->33 (20.07/60.0 s, steps/err: 15(28.7261009216 ms)/0.000917781388531)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.2
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->34 (20.15/60.0 s, steps/err: 85(65.6659603119 ms)/0.00153315994956)
# ======================================================================================================================================================
# try: 34 - ('goal', 0)->('goal', 1)
# result: 34 - ('goal', 0)->('goal', 1) = fail
# try: 17 - ('goal', 1)->('goal', 2)
# result: 17 - ('goal', 1)->('goal', 2) = fail
# try: 8 - ('grip0', 2)->('floor', 2)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 8 - ('grip0', 2)->('floor', 2) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 11 - ('grip0', 1)->('grip0', 2)
# error: 2.0
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 11 - ('grip0', 1)->('grip0', 2) = fail
# try: 25 - ('grip0', 2)->('floor', 2)
# error: 0.7
# try transition motion
# transition motion tried: True
# result: 25 - ('grip0', 2)->('floor', 2) = success
# branching: 25->35 (23.32/60.0 s, steps/err: 82(56.736946106 ms)/0.0014863936089)
# ======================================================================================================================================================
# try: 35 - ('floor', 2)->('grip0', 2)
# error: 1.8
# try transition motion
# transition motion tried: True
# result: 35 - ('floor', 2)->('grip0', 2) = success
# branching: 35->36 (23.45/60.0 s, steps/err: 95(121.253013611 ms)/0.00162910482167)
# ======================================================================================================================================================
# try: 36 - ('grip0', 2)->('goal', 2)
# error: 1.9
# try transition motion
# transition motion tried: True
# Goal reached
# result: 36 - ('grip0', 2)->('goal', 2) = success
# branching: 36->37 (23.53/60.0 s, steps/err: 51(79.6511173248 ms)/0.0012069362336)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->39 (23.84/60.0 s, steps/err: 88(72.9911327362 ms)/0.00120769046585)
# ======================================================================================================================================================
# try: 39 - ('goal', 0)->('goal', 1)
# result: 39 - ('goal', 0)->('goal', 1) = fail
# try: 35 - ('floor', 2)->('grip0', 2)
# error: 0.28
# try transition motion
# transition motion tried: True
# result: 35 - ('floor', 2)->('grip0', 2) = success
# branching: 35->40 (24.02/60.0 s, steps/err: 9(163.854837418 ms)/0.00104733923958)
# ======================================================================================================================================================
# try: 40 - ('grip0', 2)->('goal', 2)
# error: 0.75
# try transition motion
# transition motion tried: True
# Goal reached
# result: 40 - ('grip0', 2)->('goal', 2) = success
# branching: 40->41 (24.12/60.0 s, steps/err: 94(99.8811721802 ms)/0.0012778019351)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# =========================================================================================================
# ======================= terminated 0: required answers acquired  (24.4/60.0) ===============================
# =========================================================================================================
# ========================== FINISHED (24.4 / 60.0 s) ==============================]

# %% [markdown]
# ### play searched plan

# %%
ppline.play_schedule(snode_schedule, period=0.01)
# Out:
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('grip0', 1)
# ('grip0', 1)->('grip0', 2)
# ('grip0', 2)->('goal', 2)
# ('goal', 2)->('goal', 2)

# %% [markdown]
# ### return to initial state to run next example

# %%
pscene.set_object_state(initial_state)
gscene.show_pose(initial_state.Q)

# %% [markdown]
# ## SweepLineTask without orientation constraint
# * By setting ***SweepLineTask.fix_direction=False***, you can disable orientation consraint
# * As the orientation constraint is disabled, you can use **SweepPoint** and **SweepTool** with **SweepLineTask**

# %%
from pkg.planning.constraint.constraint_subject import SweepLineTask, SweepFrame
from pkg.planning.constraint.constraint_actor import SweepFramer

sweep = pscene.create_subject(oname="sweep", gname="floor", _type=SweepLineTask, 
                             action_points_dict = {"wp1": SweepPoint("wp1", wp1, [0,0,0.005], [0,0,0]),
                                                   "wp2": SweepPoint("wp2", wp2, [0,0,0.005], [0,0,0])})
sweep.fix_direction = False # disable direction constraint
pscene.create_binder(bname="brush_face", gname="brush_face", _type=SweepTool, point=(0,0,-0.015), rpy=(0,0,0))
ppline.set_task_planner(tplan)

# %% [markdown]
# ### Planning

# %%
from pkg.planning.constraint.constraint_common \
            import sample_redundancy, combine_redundancy

initial_state = pscene.initialize_state(crob.home_pose)

# %%
# goal_nodes = [("goal",)]
goal_nodes = [("goal", 2)]
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, timeout_loop=60, multiprocess=False)
schedules = ppline.tplan.find_schedules()
schedules_sorted = ppline.tplan.sort_schedule(schedules)
snode_schedule = ppline.tplan.idxSchedule2SnodeScedule(schedules_sorted[0])
# Out:
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->1 (2.22/60.0 s, steps/err: 47(66.5121078491 ms)/0.00147599788236)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->2 (3.31/60.0 s, steps/err: 90(65.2709007263 ms)/0.00160049544761)
# ======================================================================================================================================================
# try: 2 - ('goal', 0)->('goal', 1)
# result: 2 - ('goal', 0)->('goal', 1) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.8
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->3 (3.4/60.0 s, steps/err: 59(74.7599601746 ms)/0.00129622274348)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 2 - ('goal', 0)->('grip0', 0)
# error: 0.31
# try transition motion
# transition motion tried: True
# result: 2 - ('goal', 0)->('grip0', 0) = success
# branching: 2->4 (3.53/60.0 s, steps/err: 65(105.52406311 ms)/0.00201142139381)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.3
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->5 (3.58/60.0 s, steps/err: 87(57.156085968 ms)/0.000977846318355)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->6 (3.66/60.0 s, steps/err: 61(70.8661079407 ms)/0.00183307888215)
# ======================================================================================================================================================
# try: 6 - ('goal', 0)->('goal', 1)
# result: 6 - ('goal', 0)->('goal', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.0
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->7 (3.81/60.0 s, steps/err: 70(104.178190231 ms)/0.00136537569782)
# ======================================================================================================================================================
# try: 7 - ('grip0', 1)->('grip0', 2)
# error: 2.8
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 7 - ('grip0', 1)->('grip0', 2) = fail
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 7 - ('grip0', 1)->('goal', 1)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0', 1)->('goal', 1) = success
# branching: 7->8 (4.93/60.0 s, steps/err: 95(63.8790130615 ms)/0.00148170682478)
# ======================================================================================================================================================
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 5 - ('grip0', 0)->('goal', 0)
# error: 1.8
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('goal', 0) = success
# branching: 5->9 (5.0/60.0 s, steps/err: 77(62.2470378876 ms)/0.00167291119457)
# ======================================================================================================================================================
# try: 9 - ('goal', 0)->('goal', 1)
# result: 9 - ('goal', 0)->('goal', 1) = fail
# try: 9 - ('goal', 0)->('grip0', 0)
# error: 0.063
# try transition motion
# transition motion tried: True
# result: 9 - ('goal', 0)->('grip0', 0) = success
# branching: 9->10 (5.07/60.0 s, steps/err: 2(50.6851673126 ms)/0.00150184423576)
# ======================================================================================================================================================
# try: 10 - ('grip0', 0)->('floor', 0)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 10 - ('grip0', 0)->('floor', 0) = fail
# try: 10 - ('grip0', 0)->('grip0', 1)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 10 - ('grip0', 0)->('grip0', 1) = success
# branching: 10->11 (6.17/60.0 s, steps/err: 69(75.0131607056 ms)/0.00168699370686)
# ======================================================================================================================================================
# try: 8 - ('goal', 1)->('grip0', 1)
# error: 0.39
# try transition motion
# transition motion tried: True
# result: 8 - ('goal', 1)->('grip0', 1) = success
# branching: 8->12 (6.29/60.0 s, steps/err: 91(114.753007889 ms)/0.00146876815997)
# ======================================================================================================================================================
# try: 5 - ('grip0', 0)->('goal', 0)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 5 - ('grip0', 0)->('goal', 0) = fail
# try: 11 - ('grip0', 1)->('grip0', 2)
# error: 1.9
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 11 - ('grip0', 1)->('grip0', 2) = fail
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 10 - ('grip0', 0)->('goal', 0)
# error: 0.52
# try transition motion
# transition motion tried: True
# result: 10 - ('grip0', 0)->('goal', 0) = success
# branching: 10->13 (8.43/60.0 s, steps/err: 11(31.6140651703 ms)/0.00137989927156)
# ======================================================================================================================================================
# try: 13 - ('goal', 0)->('goal', 1)
# result: 13 - ('goal', 0)->('goal', 1) = fail
# try: 10 - ('grip0', 0)->('goal', 0)
# error: 0.82
# try transition motion
# transition motion tried: True
# result: 10 - ('grip0', 0)->('goal', 0) = success
# branching: 10->14 (8.48/60.0 s, steps/err: 16(33.3919525146 ms)/0.0018289820018)
# ======================================================================================================================================================
# try: 14 - ('goal', 0)->('goal', 1)
# result: 14 - ('goal', 0)->('goal', 1) = fail
# try: 4 - ('grip0', 0)->('floor', 0)
# error: 3.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 4 - ('grip0', 0)->('floor', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->15 (9.6/60.0 s, steps/err: 58(76.0660171509 ms)/0.00146248769471)
# ======================================================================================================================================================
# try: 12 - ('grip0', 1)->('grip0', 2)
# error: 2.8
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 1)->('grip0', 2) = fail
# try: 10 - ('grip0', 0)->('floor', 0)
# error: 2.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 10 - ('grip0', 0)->('floor', 0) = fail
# try: 12 - ('grip0', 1)->('goal', 1)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 1)->('goal', 1) = fail
# try: 10 - ('grip0', 0)->('goal', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 10 - ('grip0', 0)->('goal', 0) = success
# branching: 10->16 (12.72/60.0 s, steps/err: 16(52.0069599152 ms)/0.00173229149357)
# ======================================================================================================================================================
# try: 16 - ('goal', 0)->('goal', 1)
# result: 16 - ('goal', 0)->('goal', 1) = fail
# try: 14 - ('goal', 0)->('grip0', 0)
# error: 1.9
# try transition motion
# transition motion tried: True
# result: 14 - ('goal', 0)->('grip0', 0) = success
# branching: 14->17 (12.81/60.0 s, steps/err: 78(74.0578174591 ms)/0.00143429992122)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.3
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->18 (12.9/60.0 s, steps/err: 55(86.4489078522 ms)/0.00145319037982)
# ======================================================================================================================================================
# try: 16 - ('goal', 0)->('grip0', 0)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 16 - ('goal', 0)->('grip0', 0) = success
# branching: 16->19 (12.94/60.0 s, steps/err: 21(36.53383255 ms)/0.00107537662737)
# ======================================================================================================================================================
# try: 17 - ('grip0', 0)->('floor', 0)
# error: 1.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 17 - ('grip0', 0)->('floor', 0) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 15 - ('grip0', 0)->('floor', 0)
# error: 3.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 15 - ('grip0', 0)->('floor', 0) = fail
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 15 - ('grip0', 0)->('floor', 0)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 15 - ('grip0', 0)->('floor', 0) = fail
# try: 15 - ('grip0', 0)->('goal', 0)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 15 - ('grip0', 0)->('goal', 0) = success
# branching: 15->20 (16.17/60.0 s, steps/err: 97(75.3879547119 ms)/0.00166442376218)
# ======================================================================================================================================================
# try: 20 - ('goal', 0)->('goal', 1)
# result: 20 - ('goal', 0)->('goal', 1) = fail
# try: 12 - ('grip0', 1)->('grip0', 2)
# error: 1.5
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 1)->('grip0', 2) = fail
# try: 4 - ('grip0', 0)->('goal', 0)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 4 - ('grip0', 0)->('goal', 0) = success
# branching: 4->21 (17.23/60.0 s, steps/err: 20(41.9929027557 ms)/0.00173296408166)
# ======================================================================================================================================================
# try: 21 - ('goal', 0)->('goal', 1)
# result: 21 - ('goal', 0)->('goal', 1) = fail
# try: 17 - ('grip0', 0)->('floor', 0)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 17 - ('grip0', 0)->('floor', 0) = fail
# try: 5 - ('grip0', 0)->('grip0', 1)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0', 0)->('grip0', 1) = success
# branching: 5->22 (18.32/60.0 s, steps/err: 56(44.9900627136 ms)/0.0019183539868)
# ======================================================================================================================================================
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 21 - ('goal', 0)->('grip0', 0)
# error: 0.31
# try transition motion
# transition motion tried: True
# result: 21 - ('goal', 0)->('grip0', 0) = success
# branching: 21->23 (19.41/60.0 s, steps/err: 9(49.7350692749 ms)/0.00139930745177)
# ======================================================================================================================================================
# try: 16 - ('goal', 0)->('goal', 1)
# result: 16 - ('goal', 0)->('goal', 1) = fail
# try: 23 - ('grip0', 0)->('grip0', 1)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 23 - ('grip0', 0)->('grip0', 1) = success
# branching: 23->24 (19.47/60.0 s, steps/err: 13(37.5769138336 ms)/0.00124571005701)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 0.83
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->25 (19.5/60.0 s, steps/err: 12(32.9608917236 ms)/0.00191750575739)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 8 - ('goal', 1)->('grip0', 1)
# error: 0.46
# try transition motion
# transition motion tried: True
# result: 8 - ('goal', 1)->('grip0', 1) = success
# branching: 8->26 (19.59/60.0 s, steps/err: 76(76.2128829956 ms)/0.0014086085204)
# ======================================================================================================================================================
# try: 23 - ('grip0', 0)->('floor', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 23 - ('grip0', 0)->('floor', 0) = success
# branching: 23->27 (19.65/60.0 s, steps/err: 70(51.6619682312 ms)/0.000807302410912)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 6 - ('goal', 0)->('goal', 1)
# result: 6 - ('goal', 0)->('goal', 1) = fail
# try: 18 - ('grip0', 1)->('grip0', 2)
# error: 0.78
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 18 - ('grip0', 1)->('grip0', 2) = fail
# try: 15 - ('grip0', 0)->('floor', 0)
# error: 3.6
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 15 - ('grip0', 0)->('floor', 0) = fail
# try: 27 - ('floor', 0)->('grip0', 0)
# error: 0.049
# try transition motion
# transition motion tried: True
# result: 27 - ('floor', 0)->('grip0', 0) = success
# branching: 27->28 (21.82/60.0 s, steps/err: 24(105.530023575 ms)/0.00137197218548)
# ======================================================================================================================================================
# try: 24 - ('grip0', 1)->('goal', 1)
# error: 1.3
# try transition motion
# transition motion tried: True
# result: 24 - ('grip0', 1)->('goal', 1) = success
# branching: 24->29 (21.87/60.0 s, steps/err: 35(46.1149215698 ms)/0.00157757620626)
# ======================================================================================================================================================
# try: 29 - ('goal', 1)->('goal', 2)
# result: 29 - ('goal', 1)->('goal', 2) = fail
# try: 29 - ('goal', 1)->('goal', 2)
# result: 29 - ('goal', 1)->('goal', 2) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 1.8
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->30 (21.95/60.0 s, steps/err: 70(62.5958442688 ms)/0.00127049211316)
# ======================================================================================================================================================
# try: 21 - ('goal', 0)->('goal', 1)
# result: 21 - ('goal', 0)->('goal', 1) = fail
# try: 20 - ('goal', 0)->('grip0', 0)
# error: 0.02
# try transition motion
# transition motion tried: True
# result: 20 - ('goal', 0)->('grip0', 0) = success
# branching: 20->31 (21.99/60.0 s, steps/err: 2(26.6480445862 ms)/0.00146888453991)
# ======================================================================================================================================================
# try: 2 - ('goal', 0)->('grip0', 0)
# error: 1.0
# try transition motion
# transition motion tried: True
# result: 2 - ('goal', 0)->('grip0', 0) = success
# branching: 2->32 (22.11/60.0 s, steps/err: 90(118.062019348 ms)/0.00192253376782)
# ======================================================================================================================================================
# try: 12 - ('grip0', 1)->('grip0', 2)
# error: 2.2
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 1)->('grip0', 2) = fail
# try: 24 - ('grip0', 1)->('grip0', 2)
# error: 1.8
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 24 - ('grip0', 1)->('grip0', 2) = fail
# try: 27 - ('floor', 0)->('floor', 1)
# result: 27 - ('floor', 0)->('floor', 1) = fail
# try: 21 - ('goal', 0)->('grip0', 0)
# error: 0.98
# try transition motion
# transition motion tried: True
# result: 21 - ('goal', 0)->('grip0', 0) = success
# branching: 21->33 (24.26/60.0 s, steps/err: 42(40.5838489532 ms)/0.00190258178016)
# ======================================================================================================================================================
# try: 22 - ('grip0', 1)->('floor', 1)
# error: 1.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 22 - ('grip0', 1)->('floor', 1) = fail
# try: 27 - ('floor', 0)->('grip0', 0)
# error: 0.14
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 27 - ('floor', 0)->('grip0', 0) = fail
# try: 22 - ('grip0', 1)->('floor', 1)
# error: 3.1
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 22 - ('grip0', 1)->('floor', 1) = fail
# try: 9 - ('goal', 0)->('grip0', 0)
# error: 0.78
# try transition motion
# transition motion tried: True
# result: 9 - ('goal', 0)->('grip0', 0) = success
# branching: 9->34 (27.42/60.0 s, steps/err: 62(53.0359745026 ms)/0.0015708442775)
# ======================================================================================================================================================
# try: 31 - ('grip0', 0)->('goal', 0)
# error: 1.6
# try transition motion
# transition motion tried: True
# result: 31 - ('grip0', 0)->('goal', 0) = success
# branching: 31->35 (27.48/60.0 s, steps/err: 84(56.932926178 ms)/0.00136335592682)
# ======================================================================================================================================================
# try: 35 - ('goal', 0)->('goal', 1)
# result: 35 - ('goal', 0)->('goal', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 24 - ('grip0', 1)->('grip0', 2)
# error: 2.5
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 24 - ('grip0', 1)->('grip0', 2) = fail
# try: 30 - ('grip0', 1)->('goal', 1)
# error: 0.85
# try transition motion
# transition motion tried: True
# result: 30 - ('grip0', 1)->('goal', 1) = success
# branching: 30->36 (29.61/60.0 s, steps/err: 87(59.8781108856 ms)/0.00203353767258)
# ======================================================================================================================================================
# try: 36 - ('goal', 1)->('goal', 2)
# result: 36 - ('goal', 1)->('goal', 2) = fail
# try: 25 - ('grip0', 1)->('goal', 1)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 25 - ('grip0', 1)->('goal', 1) = success
# branching: 25->37 (29.7/60.0 s, steps/err: 59(63.4999275208 ms)/0.00121991014797)
# ======================================================================================================================================================
# try: 37 - ('goal', 1)->('goal', 2)
# result: 37 - ('goal', 1)->('goal', 2) = fail
# try: 13 - ('goal', 0)->('goal', 1)
# result: 13 - ('goal', 0)->('goal', 1) = fail
# try: 33 - ('grip0', 0)->('floor', 0)
# error: 3.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 33 - ('grip0', 0)->('floor', 0) = fail
# try: 23 - ('grip0', 0)->('goal', 0)
# error: 1.6
# try transition motion
# transition motion tried: True
# result: 23 - ('grip0', 0)->('goal', 0) = success
# branching: 23->38 (30.8/60.0 s, steps/err: 10(39.2889976501 ms)/0.0018861085613)
# ======================================================================================================================================================
# try: 38 - ('goal', 0)->('goal', 1)
# result: 38 - ('goal', 0)->('goal', 1) = fail
# try: 24 - ('grip0', 1)->('floor', 1)
# error: 3.0
# try transition motion
# transition motion tried: True
# result: 24 - ('grip0', 1)->('floor', 1) = success
# branching: 24->39 (30.87/60.0 s, steps/err: 51(51.1519908905 ms)/0.00178027708503)
# ======================================================================================================================================================
# try: 19 - ('grip0', 0)->('floor', 0)
# error: 0.99
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 19 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.9
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->40 (31.98/60.0 s, steps/err: 40(78.9031982422 ms)/0.00164122778561)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->41 (32.04/60.0 s, steps/err: 60(51.6149997711 ms)/0.00174088864471)
# ======================================================================================================================================================
# try: 39 - ('floor', 1)->('grip0', 1)
# error: 0.46
# try transition motion
# transition motion tried: True
# result: 39 - ('floor', 1)->('grip0', 1) = success
# branching: 39->42 (32.1/60.0 s, steps/err: 84(59.8618984222 ms)/0.00122601171422)
# ======================================================================================================================================================
# try: 38 - ('goal', 0)->('goal', 1)
# result: 38 - ('goal', 0)->('goal', 1) = fail
# try: 12 - ('grip0', 1)->('grip0', 2)
# error: 1.0
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 12 - ('grip0', 1)->('grip0', 2) = fail
# try: 36 - ('goal', 1)->('goal', 2)
# result: 36 - ('goal', 1)->('goal', 2) = fail
# try: 36 - ('goal', 1)->('goal', 2)
# result: 36 - ('goal', 1)->('goal', 2) = fail
# try: 10 - ('grip0', 0)->('goal', 0)
# error: 1.6
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 10 - ('grip0', 0)->('goal', 0) = fail
# try: 36 - ('goal', 1)->('goal', 2)
# result: 36 - ('goal', 1)->('goal', 2) = fail
# try: 2 - ('goal', 0)->('grip0', 0)
# error: 0.26
# try transition motion
# transition motion tried: True
# result: 2 - ('goal', 0)->('grip0', 0) = success
# branching: 2->43 (34.32/60.0 s, steps/err: 88(93.4150218964 ms)/0.0016968210173)
# ======================================================================================================================================================
# try: 39 - ('floor', 1)->('floor', 2)
# result: 39 - ('floor', 1)->('floor', 2) = fail
# try: 40 - ('grip0', 1)->('grip0', 2)
# error: 0.65
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 40 - ('grip0', 1)->('grip0', 2) = fail
# try: 14 - ('goal', 0)->('goal', 1)
# result: 14 - ('goal', 0)->('goal', 1) = fail
# try: 36 - ('goal', 1)->('grip0', 1)
# error: 0.3
# try transition motion
# transition motion tried: True
# result: 36 - ('goal', 1)->('grip0', 1) = success
# branching: 36->44 (35.54/60.0 s, steps/err: 9(24.8639583588 ms)/0.00173578059816)
# ======================================================================================================================================================
# try: 37 - ('goal', 1)->('grip0', 1)
# error: 0.4
# try transition motion
# transition motion tried: True
# result: 37 - ('goal', 1)->('grip0', 1) = success
# branching: 37->45 (35.57/60.0 s, steps/err: 10(29.6199321747 ms)/0.000747617929557)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.9
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->46 (35.64/60.0 s, steps/err: 98(65.3989315033 ms)/0.00198372931763)
# ======================================================================================================================================================
# try: 46 - ('goal', 0)->('goal', 1)
# result: 46 - ('goal', 0)->('goal', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 37 - ('goal', 1)->('goal', 2)
# result: 37 - ('goal', 1)->('goal', 2) = fail
# try: 27 - ('floor', 0)->('grip0', 0)
# error: 0.41
# try transition motion
# transition motion tried: True
# result: 27 - ('floor', 0)->('grip0', 0) = success
# branching: 27->47 (35.81/60.0 s, steps/err: 104(128.012895584 ms)/0.00132587960179)
# ======================================================================================================================================================
# try: 37 - ('goal', 1)->('goal', 2)
# result: 37 - ('goal', 1)->('goal', 2) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 36 - ('goal', 1)->('grip0', 1)
# error: 0.59
# try transition motion
# transition motion tried: True
# result: 36 - ('goal', 1)->('grip0', 1) = success
# branching: 36->48 (35.88/60.0 s, steps/err: 15(49.6909618378 ms)/0.0012443621061)
# ======================================================================================================================================================
# try: 27 - ('floor', 0)->('floor', 1)
# result: 27 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->49 (35.96/60.0 s, steps/err: 58(70.4009532928 ms)/0.0010942131105)
# ======================================================================================================================================================
# try: 39 - ('floor', 1)->('floor', 2)
# result: 39 - ('floor', 1)->('floor', 2) = fail
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 37 - ('goal', 1)->('grip0', 1)
# error: 0.55
# try transition motion
# transition motion tried: True
# result: 37 - ('goal', 1)->('grip0', 1) = success
# branching: 37->50 (36.03/60.0 s, steps/err: 11(31.6119194031 ms)/0.00154551760761)
# ======================================================================================================================================================
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 33 - ('grip0', 0)->('floor', 0)
# error: 2.9
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 33 - ('grip0', 0)->('floor', 0) = fail
# try: 39 - ('floor', 1)->('floor', 2)
# result: 39 - ('floor', 1)->('floor', 2) = fail
# try: 36 - ('goal', 1)->('grip0', 1)
# error: 0.41
# try transition motion
# transition motion tried: True
# result: 36 - ('goal', 1)->('grip0', 1) = success
# branching: 36->51 (37.14/60.0 s, steps/err: 15(34.8200798035 ms)/0.0011372981594)
# ======================================================================================================================================================
# try: 39 - ('floor', 1)->('floor', 2)
# result: 39 - ('floor', 1)->('floor', 2) = fail
# try: 18 - ('grip0', 1)->('floor', 1)
# error: 0.89
# try transition motion
# transition motion tried: True
# result: 18 - ('grip0', 1)->('floor', 1) = success
# branching: 18->52 (37.22/60.0 s, steps/err: 77(70.7881450653 ms)/0.00157350161113)
# ======================================================================================================================================================
# try: 51 - ('grip0', 1)->('goal', 1)
# error: 0.47
# try transition motion
# transition motion tried: True
# result: 51 - ('grip0', 1)->('goal', 1) = success
# branching: 51->53 (37.26/60.0 s, steps/err: 10(34.5160961151 ms)/0.00134595109447)
# ======================================================================================================================================================
# try: 53 - ('goal', 1)->('goal', 2)
# result: 53 - ('goal', 1)->('goal', 2) = fail
# try: 18 - ('grip0', 1)->('grip0', 2)
# error: 2.8
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 18 - ('grip0', 1)->('grip0', 2) = fail
# try: 52 - ('floor', 1)->('floor', 2)
# result: 52 - ('floor', 1)->('floor', 2) = fail
# try: 24 - ('grip0', 1)->('grip0', 2)
# error: 2.8
# try constrained motion
# constrained motion tried: True
# result: 24 - ('grip0', 1)->('grip0', 2) = success
# branching: 24->54 (38.48/60.0 s, steps/err: 90(105.357170105 ms)/0.00196870365457)
# ======================================================================================================================================================
# try: 54 - ('grip0', 2)->('goal', 2)
# error: 1.7
# try transition motion
# transition motion tried: True
# Goal reached
# result: 54 - ('grip0', 2)->('goal', 2) = success
# branching: 54->55 (38.51/60.0 s, steps/err: 10(31.0690402985 ms)/0.00124927383499)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 29 - ('goal', 1)->('goal', 2)
# result: 29 - ('goal', 1)->('goal', 2) = fail
# try: 52 - ('floor', 1)->('grip0', 1)
# error: 0.065
# try transition motion
# transition motion tried: True
# result: 52 - ('floor', 1)->('grip0', 1) = success
# branching: 52->57 (38.84/60.0 s, steps/err: 5(35.1619720459 ms)/0.00143501967122)
# ======================================================================================================================================================
# try: 49 - ('grip0', 0)->('floor', 0)
# error: 2.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 49 - ('grip0', 0)->('floor', 0) = fail
# try: 57 - ('grip0', 1)->('grip0', 2)
# error: 1.5
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 57 - ('grip0', 1)->('grip0', 2) = fail
# try: 54 - ('grip0', 2)->('goal', 2)
# error: 0.59
# try transition motion
# transition motion tried: True
# Goal reached
# result: 54 - ('grip0', 2)->('goal', 2) = success
# branching: 54->58 (40.93/60.0 s, steps/err: 5(44.3649291992 ms)/0.00194203380516)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 54 - ('grip0', 2)->('floor', 2)
# error: 1.7
# try transition motion
# transition motion tried: True
# result: 54 - ('grip0', 2)->('floor', 2) = success
# branching: 54->60 (41.24/60.0 s, steps/err: 62(65.6278133392 ms)/0.0015962506481)
# ======================================================================================================================================================
# try: 60 - ('floor', 2)->('grip0', 2)
# error: 1.2
# try transition motion
# transition motion tried: True
# result: 60 - ('floor', 2)->('grip0', 2) = success
# branching: 60->61 (41.44/60.0 s, steps/err: 72(199.18513298 ms)/0.00135140965057)
# ======================================================================================================================================================
# try: 61 - ('grip0', 2)->('goal', 2)
# error: 2.3
# try transition motion
# transition motion tried: True
# Goal reached
# result: 61 - ('grip0', 2)->('goal', 2) = success
# branching: 61->62 (41.5/60.0 s, steps/err: 30(58.2368373871 ms)/0.00167250376475)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 8 - ('goal', 1)->('goal', 2)
# result: 8 - ('goal', 1)->('goal', 2) = fail
# try: 52 - ('floor', 1)->('floor', 2)
# result: 52 - ('floor', 1)->('floor', 2) = fail
# try: 27 - ('floor', 0)->('grip0', 0)
# error: 0.24
# try transition motion
# transition motion tried: True
# result: 27 - ('floor', 0)->('grip0', 0) = success
# branching: 27->64 (41.9/60.0 s, steps/err: 107(102.056026459 ms)/0.00105428384148)
# ======================================================================================================================================================
# try: 61 - ('grip0', 2)->('goal', 2)
# error: 2.7
# try transition motion
# transition motion tried: True
# Goal reached
# result: 61 - ('grip0', 2)->('goal', 2) = success
# branching: 61->65 (41.93/60.0 s, steps/err: 37(34.276008606 ms)/0.00159396119499)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 40 - ('grip0', 1)->('goal', 1)
# error: 2.9
# try transition motion
# transition motion tried: True
# result: 40 - ('grip0', 1)->('goal', 1) = success
# branching: 40->67 (42.27/60.0 s, steps/err: 64(82.631111145 ms)/0.00158436622347)
# ======================================================================================================================================================
# try: 67 - ('goal', 1)->('goal', 2)
# result: 67 - ('goal', 1)->('goal', 2) = fail
# try: 52 - ('floor', 1)->('grip0', 1)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 52 - ('floor', 1)->('grip0', 1) = success
# branching: 52->68 (42.4/60.0 s, steps/err: 80(93.593120575 ms)/0.00198311307554)
# ======================================================================================================================================================
# try: 53 - ('goal', 1)->('grip0', 1)
# error: 1.4
# try transition motion
# transition motion tried: True
# result: 53 - ('goal', 1)->('grip0', 1) = success
# branching: 53->69 (42.47/60.0 s, steps/err: 70(71.2580680847 ms)/0.0015502779116)
# ======================================================================================================================================================
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->70 (42.56/60.0 s, steps/err: 49(88.2239341736 ms)/0.00127514711277)
# ======================================================================================================================================================
# try: 35 - ('goal', 0)->('goal', 1)
# result: 35 - ('goal', 0)->('goal', 1) = fail
# try: 23 - ('grip0', 0)->('floor', 0)
# error: 2.7
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 23 - ('grip0', 0)->('floor', 0) = fail
# try: 28 - ('grip0', 0)->('floor', 0)
# error: 2.5
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 28 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.3
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->71 (44.74/60.0 s, steps/err: 86(100.697040558 ms)/0.00170720276123)
# ======================================================================================================================================================
# try: 71 - ('goal', 0)->('goal', 1)
# result: 71 - ('goal', 0)->('goal', 1) = fail
# try: 22 - ('grip0', 1)->('floor', 1)
# error: 2.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 22 - ('grip0', 1)->('floor', 1) = fail
# try: 30 - ('grip0', 1)->('grip0', 2)
# error: 1.4
# try constrained motion
# constrained motion tried: False
# Motion Plan Failure
# result: 30 - ('grip0', 1)->('grip0', 2) = fail
# try: 39 - ('floor', 1)->('grip0', 1)
# error: 0.56
# try transition motion
# transition motion tried: True
# result: 39 - ('floor', 1)->('grip0', 1) = success
# branching: 39->72 (46.91/60.0 s, steps/err: 79(91.4180278778 ms)/0.00118374673859)
# ======================================================================================================================================================
# try: 26 - ('grip0', 1)->('goal', 1)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 26 - ('grip0', 1)->('goal', 1) = success
# branching: 26->73 (46.97/60.0 s, steps/err: 55(62.2010231018 ms)/0.00105235788168)
# ======================================================================================================================================================
# try: 73 - ('goal', 1)->('goal', 2)
# result: 73 - ('goal', 1)->('goal', 2) = fail
# try: 60 - ('floor', 2)->('grip0', 2)
# error: 0.46
# try transition motion
# transition motion tried: True
# result: 60 - ('floor', 2)->('grip0', 2) = success
# branching: 60->74 (47.06/60.0 s, steps/err: 61(67.9290294647 ms)/0.00168853119494)
# ======================================================================================================================================================
# try: 74 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 74 - ('grip0', 2)->('goal', 2) = success
# branching: 74->75 (47.14/60.0 s, steps/err: 45(77.5239467621 ms)/0.00159841016079)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 54 - ('grip0', 2)->('goal', 2)
# error: 1.4
# try transition motion
# transition motion tried: True
# Goal reached
# result: 54 - ('grip0', 2)->('goal', 2) = success
# branching: 54->77 (47.45/60.0 s, steps/err: 8(47.5480556488 ms)/0.00149942324475)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# =========================================================================================================
# ======================= terminated 0: required answers acquired  (47.7/60.0) ===============================
# =========================================================================================================
# ========================== FINISHED (47.7 / 60.0 s) ==============================]

# %% [markdown]
# ### play searched plan

# %%
ppline.play_schedule(snode_schedule, period=0.01)
# Out:
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('goal', 0)
# ('goal', 0)->('grip0', 0)
# ('grip0', 0)->('goal', 0)
# ('goal', 0)->('grip0', 0)
# ('grip0', 0)->('grip0', 1)
# ('grip0', 1)->('grip0', 2)
# ('grip0', 2)->('goal', 2)
# ('goal', 2)->('goal', 2)

# %% [markdown]
# ### return to initial state to run next example

# %%
pscene.set_object_state(initial_state)
gscene.show_pose(initial_state.Q)

# %% [markdown]
# ## SweepLineTask (mimic constrained planning by task-space line interpolation)
# * Unfortunately, constrained motion planning shows very poor performance in many cases.
# * In many cases, we can just mimic constrained planning by line interpolation in task-space
# * ***MoveitPlanner.incremental_constraint_motion=True*** is the option that replaces constrained planning with task-space interpolation

# %%
from pkg.planning.constraint.constraint_subject import SweepLineTask, SweepFrame
from pkg.planning.constraint.constraint_actor import SweepFramer

sweep = pscene.create_subject(oname="sweep", gname="floor", _type=SweepLineTask, 
                             action_points_dict = {"wp1": SweepFrame("wp1", wp1, [0,0,0.005], [0,0,0]),
                                                   "wp2": SweepFrame("wp2", wp2, [0,0,0.005], [0,0,0])})
pscene.create_binder(bname="brush_face", gname="brush_face", _type=SweepFramer, point=(0,0,-0.015), rpy=(0,0,0))
ppline.set_task_planner(tplan)
mplan.incremental_constraint_motion = True # this option enables line

# %% [markdown]
# ### Planning

# %%
from pkg.planning.constraint.constraint_common \
            import sample_redundancy, combine_redundancy

initial_state = pscene.initialize_state(crob.home_pose)

# %%
# goal_nodes = [("goal",)]
goal_nodes = [("goal", 2)]
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, timeout_loop=60, multiprocess=False)
schedules = ppline.tplan.find_schedules()
schedules_sorted = ppline.tplan.sort_schedule(schedules)
snode_schedule = ppline.tplan.idxSchedule2SnodeScedule(schedules_sorted[0])
# Out:
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 0 - ('floor', 0)->('grip0', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->1 (2.22/60.0 s, steps/err: 38(90.2218818665 ms)/0.00134524563082)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.3
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 0 - ('floor', 0)->('grip0', 0)
# error: 2.2
# try transition motion
# transition motion tried: True
# result: 0 - ('floor', 0)->('grip0', 0) = success
# branching: 0->2 (3.34/60.0 s, steps/err: 47(82.4790000916 ms)/0.00101391217289)
# ======================================================================================================================================================
# try: 2 - ('grip0', 0)->('goal', 0)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 0)->('goal', 0) = success
# branching: 2->3 (3.39/60.0 s, steps/err: 56(47.5358963013 ms)/0.00151463633313)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 2 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 0)->('grip0', 1) = success
# branching: 2->4 (3.49/60.0 s, steps/err: 60(67.3630237579 ms)/0.00182341433483)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.7
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->5 (3.57/60.0 s, steps/err: 31(56.7729473114 ms)/0.000942273407029)
# ======================================================================================================================================================
# try: 5 - ('goal', 0)->('goal', 1)
# result: 5 - ('goal', 0)->('goal', 1) = fail
# try: 2 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 0)->('grip0', 1) = success
# branching: 2->6 (3.65/60.0 s, steps/err: 60(61.1140727997 ms)/0.00151487084737)
# ======================================================================================================================================================
# try: 3 - ('goal', 0)->('goal', 1)
# result: 3 - ('goal', 0)->('goal', 1) = fail
# try: 1 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('grip0', 1) = success
# branching: 1->7 (3.69/60.0 s, steps/err: 11(27.6739597321 ms)/0.00100327151932)
# ======================================================================================================================================================
# try: 4 - ('grip0', 1)->('floor', 1)
# error: 2.2
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 4 - ('grip0', 1)->('floor', 1) = fail
# try: 2 - ('grip0', 0)->('grip0', 1)
# error: 2.1
# try transition motion
# transition motion tried: True
# result: 2 - ('grip0', 0)->('grip0', 1) = success
# branching: 2->8 (4.79/60.0 s, steps/err: 60(64.7721290588 ms)/0.000961966221303)
# ======================================================================================================================================================
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 1.1
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->9 (4.84/60.0 s, steps/err: 34(47.0349788666 ms)/0.00125193137494)
# ======================================================================================================================================================
# try: 9 - ('goal', 0)->('goal', 1)
# result: 9 - ('goal', 0)->('goal', 1) = fail
# try: 6 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# end
# constrained motion tried: True
# result: 6 - ('grip0', 1)->('grip0', 2) = success
# branching: 6->10 (4.97/60.0 s, steps/err: 41(107.997894287 ms)/0.000116460469274)
# ======================================================================================================================================================
# try: 10 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 10 - ('grip0', 2)->('goal', 2) = success
# branching: 10->11 (5.09/60.0 s, steps/err: 74(118.455886841 ms)/0.00144514909383)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 10 - ('grip0', 2)->('goal', 2)
# error: 2.7
# try transition motion
# transition motion tried: True
# Goal reached
# result: 10 - ('grip0', 2)->('goal', 2) = success
# branching: 10->13 (5.45/60.0 s, steps/err: 22(77.0900249481 ms)/0.00173285702015)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 10 - ('grip0', 2)->('floor', 2)
# error: 3.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 10 - ('grip0', 2)->('floor', 2) = fail
# try: 8 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# end
# constrained motion tried: True
# result: 8 - ('grip0', 1)->('grip0', 2) = success
# branching: 8->15 (6.86/60.0 s, steps/err: 41(142.634868622 ms)/0.000116594592284)
# ======================================================================================================================================================
# try: 15 - ('grip0', 2)->('goal', 2)
# error: 1.2
# try transition motion
# transition motion tried: True
# Goal reached
# result: 15 - ('grip0', 2)->('goal', 2) = success
# branching: 15->16 (6.89/60.0 s, steps/err: 7(25.7601737976 ms)/0.000391481768127)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 2.5
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('floor', 0) = success
# branching: 1->18 (7.21/60.0 s, steps/err: 22(48.0539798737 ms)/0.00154986491096)
# ======================================================================================================================================================
# try: 10 - ('grip0', 2)->('floor', 2)
# error: 1.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 10 - ('grip0', 2)->('floor', 2) = fail
# try: 7 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# end
# constrained motion tried: True
# result: 7 - ('grip0', 1)->('grip0', 2) = success
# branching: 7->19 (8.38/60.0 s, steps/err: 41(128.666162491 ms)/0.00011738969055)
# ======================================================================================================================================================
# try: 19 - ('grip0', 2)->('goal', 2)
# error: 1.5
# try transition motion
# transition motion tried: True
# Goal reached
# result: 19 - ('grip0', 2)->('goal', 2) = success
# branching: 19->20 (8.41/60.0 s, steps/err: 8(37.5030040741 ms)/0.00120508940328)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 3.0
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 0 - ('floor', 0)->('floor', 1)
# result: 0 - ('floor', 0)->('floor', 1) = fail
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 1.8
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 1 - ('grip0', 0)->('goal', 0)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0', 0)->('goal', 0) = success
# branching: 1->22 (10.84/60.0 s, steps/err: 54(70.9149837494 ms)/0.00178991837502)
# ======================================================================================================================================================
# try: 22 - ('goal', 0)->('goal', 1)
# result: 22 - ('goal', 0)->('goal', 1) = fail
# try: 8 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# end
# constrained motion tried: True
# result: 8 - ('grip0', 1)->('grip0', 2) = success
# branching: 8->23 (11.0/60.0 s, steps/err: 41(133.592128754 ms)/0.000116594592284)
# ======================================================================================================================================================
# try: 23 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 23 - ('grip0', 2)->('goal', 2) = success
# branching: 23->24 (11.03/60.0 s, steps/err: 18(33.383846283 ms)/0.000872257117451)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# try: 1 - ('grip0', 0)->('floor', 0)
# error: 1.4
# try transition motion
# transition motion tried: False
# Motion Plan Failure
# result: 1 - ('grip0', 0)->('floor', 0) = fail
# try: 6 - ('grip0', 1)->('grip0', 2)
# error: 0.4
# end
# constrained motion tried: True
# result: 6 - ('grip0', 1)->('grip0', 2) = success
# branching: 6->26 (12.41/60.0 s, steps/err: 41(106.523990631 ms)/0.000116460469274)
# ======================================================================================================================================================
# try: 26 - ('grip0', 2)->('goal', 2)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 26 - ('grip0', 2)->('goal', 2) = success
# branching: 26->27 (12.46/60.0 s, steps/err: 20(54.9218654633 ms)/0.00202191988754)
# ======================================================================================================================================================
# ++ adding return motion to acquired answer ++
# Goal reached
# =========================================================================================================
# ======================= terminated 0: required answers acquired  (12.7/60.0) ===============================
# =========================================================================================================
# ========================== FINISHED (12.7 / 60.0 s) ==============================]

# %% [markdown]
# ### play searched plan

# %%
ppline.play_schedule(snode_schedule, period=0.01)
# Out:
# ('floor', 0)->('grip0', 0)
# ('grip0', 0)->('grip0', 1)
# ('grip0', 1)->('grip0', 2)
# ('grip0', 2)->('goal', 2)
# ('goal', 2)->('goal', 2)

# %% [markdown]
# ### return to initial state

# %%
pscene.set_object_state(initial_state)
gscene.show_pose(initial_state.Q)
