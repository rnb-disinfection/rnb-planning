# %% [markdown]
# ## Check List 4 - MotionFilter
# * Motion filters are quick decision makers that prevents trying to plan a infeasible motion.
# * Here, ReachChecker is tested, compared with actual planning results in random trials
# *\* ~~Strikethrough~~ means no-error but none-functional cases.*
# * **4-A.3 LatticedChecker**
#   - pick, place
#     - single process
#     - *multi process is not supported with LatticedChecker, which uses GPU*
#
# * You need trained model to use ReachChecker
# * To use **LatticedChecker**, get model files from https://github.com/rnb-disinfection/arxiv-highcap/tree/rnb-planning/model/latticized and put them in *$RNB_PLANNING_DIR/model/latticized* folder.
# * For robots that are indy7 variants (indy7gripper...), copy indy7 model file and assign the robot name as the file name.

# %% [markdown]
# **[Trouble Shooting]**
# ```
# LatticedChecker uses tensorflow model on separate python3 program, through a shared memory.
# If some error raises with shared memory, try uncomment and run below cell, to reset shared memory.
# ```

# %%
# import SharedArray as sa
# robot_type_name = "indy7"
# sa.delete("shm://{}.grasp_img".format(robot_type_name))
# sa.delete("shm://{}.arm_img".format(robot_type_name))
# sa.delete("shm://{}.rh_mask".format(robot_type_name))
# sa.delete("shm://{}.result".format(robot_type_name))
# sa.delete("shm://{}.query_in".format(robot_type_name))
# sa.delete("shm://{}.response_out".format(robot_type_name))
# sa.delete("shm://{}.query_quit".format(robot_type_name))

# %% [markdown]
# ## set running directory

# %%
from __future__ import print_function
import os
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))

# %%
from pkg.controller.combined_robot import *
from pkg.utils.utils import get_now, try_mkdir

# %%
VISUALIZE = True
CLEARANCE = 1e-3

# ROBOT_TYPE = RobotType.indy7gripper
# ROBOT_NAME = "indy0"
# TOOL_XYZ = (0,0,0.14)
# TOOL_RPY = (-np.pi/2,0,0)
# GRIP_DEPTH = 0.05
# HOME_POSE = (0,0,0,0,0,0)

ROBOT_TYPE = RobotType.panda
ROBOT_NAME = "panda0"
TOOL_XYZ = (0,0,0.112)
TOOL_RPY = (-np.pi/2,0,0)
GRIP_DEPTH = 0.03
HOME_POSE = (0,-0.3,0,-0.5,0,2.5,0)

# %% [markdown]
# ## init combined robot config

# %%
from pkg.project_config import *

crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, None,
                None)]
              , connection_list=[False])
TOOL_LINK = crob.get_robot_tip_dict().values()[0]
from pkg.geometry.builder.scene_builder import SceneBuilder
s_builder = SceneBuilder(None)
# # deprecated: s_builder.reset_reference_coord(ref_name="floor")
# Out:
# connection command:
# panda0: False

# %% [markdown]
# ## get ghnd with detected robot config

# %%
# xyz_rpy_robots = s_builder.detect_items(level_mask=[DetectionLevel.ROBOT])
xyz_rpy_robots = {ROBOT_NAME: ((0,0,0), (0,0,0))}
crob.update_robot_pos_dict(xyz_rpy_robots=xyz_rpy_robots)
gscene = s_builder.create_gscene(crob, start_rviz=VISUALIZE)
HOME_DICT = list2dict(HOME_POSE, gscene.joint_names)
# Out:
# Unable to register with master node [http://localhost:11311]: master may not be running yet. Will keep trying.
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0, 0]

# %%
from pkg.utils.joint_utils import get_tf
shoulder_link = gscene.urdf_content.joint_map[gscene.joint_names[1]].child
shoulder_height = get_tf(shoulder_link, HOME_DICT, gscene.urdf_content)[2,3]

# %% [markdown]
# ## add environment

# %%
from pkg.geometry.geometry import *
gtems_robot = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=False, collision=True)

# %% [markdown]
# ## init planning scene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %% [markdown]
# ## Register binders

# %%
from pkg.planning.constraint.constraint_actor import Gripper2Tool, PlacePlane, SweepTool

# %%
gscene.create_safe(gtype=GEOTYPE.SPHERE, name="grip0", link_name=TOOL_LINK, 
                   dims=(0.01,)*3, center=TOOL_XYZ, rpy=TOOL_RPY, color=(1,0,0,1), display=True, collision=False, fixed=True)
gripper = pscene.create_binder(bname="grip0", gname="grip0", _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))
# Out:
# Please create a subscriber to the marker

# %% [markdown]
# ## planner
# * Initiailizaing *LatticedChecker* can take ~ 1 min.

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
from pkg.planning.filtering.grasp_filter import GraspChecker
from pkg.planning.filtering.reach_filter import ReachChecker
from pkg.planning.filtering.latticized_filter import LatticedChecker
mplan = MoveitPlanner(pscene)
gcheck = GraspChecker(pscene)
rcheck = ReachChecker(pscene)
lcheck = LatticedChecker(pscene, gcheck)
checkers_all = [gcheck, rcheck, lcheck]

# %%
from pkg.planning.task.rrt import TaskRRT
tplan = TaskRRT(pscene)
tplan.prepare()

# %% [markdown]
# # Object Classes

# %%
from pkg.utils.gjk import get_point_list, get_gjk_distance
from pkg.planning.constraint.constraint_subject import CustomObject, Grasp2Point, PlacePoint, SweepPoint, SweepTask
from pkg.planning.filtering.lattice_model.scene_building import *

# %% [markdown]
# ### Test: pick&place motions

# %% [markdown]
# ##### test few times with visualization

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
import random

Nmax_obj = 3
VISUALIZE = True
result_dict = defaultdict(list)
N_TRIAL = 5
i_count = 0
MP_TIMEOUT = 1

while i_count < N_TRIAL:
    pscene.clear_subjects()
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

    obj_set_list = []
    for i_obj, obj in enumerate(obj_list):
        obj_pscene, handles = add_object(pscene, obj)
        obj_set_list.append((obj, obj_pscene, handles))
    obj, obj_pscene, handles = obj_set_list[0]

    obj_pscene.geometry.color = (0.8,0.2,0.2,1)
    if VISUALIZE:
        gscene.set_rviz()

    initial_state = pscene.initialize_state(HOME_POSE)
    pscene.set_object_state(initial_state)
    tplan.prepare()
    
    scenario = "pick"
    from_state=initial_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("grip0",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
    obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)

    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    i_count += 1
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        pscene.set_object_state(from_state)
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.01)
        pick_state = pscene.rebind_all(
            [to_state.binding_state[sname].get_chain() for sname in pscene.subject_name_list], LastQ)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
    
    if not success:
        pscene.set_object_state(initial_state)
        continue

    scenario = "place"
    from_state=pick_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("gp",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)
    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.01)
    pscene.set_object_state(initial_state)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
# Out:
# 1/5: Result match for pick: True / True
# 2/5: Result mismatch for pick: True / False
# 3/5: Result match for pick: True / True
# 3/5: Result match for place: False / False
# 4/5: Result match for pick: True / True
# 5/5: Result match for pick: True / True
# 5/5: Result match for place: True / True

# %% [markdown]
# ##### test many times without visualization

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
import random

Nmax_obj = 3
VISUALIZE = False
result_dict = defaultdict(list)
N_TRIAL = 50
i_count = 0
MP_TIMEOUT = 1

while i_count < N_TRIAL:
    pscene.clear_subjects()
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

    obj_set_list = []
    for i_obj, obj in enumerate(obj_list):
        obj_pscene, handles = add_object(pscene, obj)
        obj_set_list.append((obj, obj_pscene, handles))
    obj, obj_pscene, handles = obj_set_list[0]

    obj_pscene.geometry.color = (0.8,0.2,0.2,1)
    if VISUALIZE:
        gscene.set_rviz()

    initial_state = pscene.initialize_state(HOME_POSE)
    pscene.set_object_state(initial_state)
    tplan.prepare()
    
    scenario = "pick"
    from_state=initial_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("grip0",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
    obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)

    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    i_count += 1
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        pscene.set_object_state(from_state)
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.05)
        pick_state = pscene.rebind_all(
            [to_state.binding_state[sname].get_chain() for sname in pscene.subject_name_list], LastQ)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
    
    if not success:
        pscene.set_object_state(initial_state)
        continue

    scenario = "place"
    from_state=pick_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("gp",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)
    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.05)
    pscene.set_object_state(initial_state)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
# Out:
# 1/50: Result match for pick: True / True
# 2/50: Result match for pick: True / True
# 3/50: Result match for pick: True / True
# 4/50: Result match for pick: True / True
# 5/50: Result match for pick: True / True
# 6/50: Result match for pick: True / True
# 7/50: Result match for pick: True / True
# 7/50: Result match for place: True / True
# 8/50: Result match for pick: True / True
# 9/50: Result match for pick: True / True
# 10/50: Result match for pick: True / True
# 10/50: Result match for place: False / False
# 11/50: Result match for pick: True / True
# 11/50: Result match for place: True / True
# 12/50: Result match for pick: True / True
# 13/50: Result match for pick: True / True
# 14/50: Result match for pick: True / True
# 14/50: Result match for place: False / False
# 15/50: Result mismatch for pick: True / False
# 16/50: Result match for pick: True / True
# 17/50: Result match for pick: True / True
# 18/50: Result match for pick: True / True
# 18/50: Result match for place: False / False
# 19/50: Result match for pick: True / True
# 20/50: Result mismatch for pick: True / False
# 21/50: Result match for pick: True / True
# 22/50: Result match for pick: True / True
# 23/50: Result match for pick: True / True
# 23/50: Result match for place: True / True
# 24/50: Result match for pick: True / True
# 25/50: Result match for pick: True / True
# 25/50: Result match for place: True / True
# 26/50: Result match for pick: True / True
# 27/50: Result match for pick: True / True
# 28/50: Result match for pick: True / True
# 29/50: Result match for pick: True / True
# 29/50: Result match for place: True / True
# 30/50: Result match for pick: True / True
# 31/50: Result match for pick: True / True
# 32/50: Result match for pick: True / True
# 33/50: Result match for pick: False / False
# 34/50: Result match for pick: True / True
# 35/50: Result match for pick: True / True
# 36/50: Result mismatch for pick: True / False
# 37/50: Result match for pick: True / True
# 38/50: Result mismatch for pick: True / False
# 39/50: Result match for pick: True / True
# 39/50: Result match for place: False / False
# 40/50: Result match for pick: True / True
# 40/50: Result match for place: True / True
# 41/50: Result match for pick: True / True
# 42/50: Result mismatch for pick: True / False
# 43/50: Result match for pick: True / True
# 44/50: Result match for pick: True / True
# 45/50: Result match for pick: True / True
# 45/50: Result match for place: True / True
# 46/50: Result match for pick: True / True
# 47/50: Result match for pick: True / True
# 48/50: Result match for pick: True / True
# 49/50: Result match for pick: True / True
# 50/50: Result match for pick: True / True

# %%
ACCURACY_CUT = 80
print("Accuracy cutline: {} %".format(ACCURACY_CUT))
for k, v in sorted(result_dict.items()):
    v_arr = np.array(v)
    suc_idx = np.where(v_arr[:, 1])[0]
    fail_idx = np.where(np.logical_not(v_arr[:, 1]))[0]
    acc_val = np.round(np.mean(v_arr[:,0]==v_arr[:,1])*100, 1)
    acc_suc = np.round(np.mean(v_arr[suc_idx,0]==v_arr[suc_idx,1])*100, 1)
    acc_fail = np.round(np.mean(v_arr[fail_idx,0]==v_arr[fail_idx,1])*100, 1)
    print("="*60)
    print("{} accuracy: {} % / success accuracy: {} % / fail accuracy: {} % / success count:{}/{}".format(k, acc_val, acc_suc, acc_fail, len(suc_idx), len(v_arr)))
    assert acc_val>ACCURACY_CUT and acc_suc>ACCURACY_CUT, \
            "Accuracy {}/{} is lower than {}. Consider debugging the algorithm.".format(acc_val, acc_suc, ACCURACY_CUT)
    print("""OK with "{}" scenario""".format(k))
# Out:
# Accuracy cutline: 80 %
# ============================================================
# pick accuracy: 90.0 % / success accuracy: 100.0 % / fail accuracy: 16.7 % / success count:44/50
# OK with "pick" scenario
# ============================================================
# place accuracy: 100.0 % / success accuracy: 100.0 % / fail accuracy: 100.0 % / success count:7/11
# OK with "place" scenario

# %% [markdown]
# ### planning: pick&place

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
from copy import deepcopy

pscene.clear_subjects()
    
Nmax_obj = 1
gtimer = GlobalTimer.instance()
gtimer.reset()
## add floor, ceiling
floor = Floor(gscene, "floor")
gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                   dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                   color=floor.geometry.color, display=True, collision=True, fixed=True)
# ceiling = Ceiling(gscene, "ceiling")

## set workplane
wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

gp_colliding = True
while gp_colliding:
    ## set goalplane
    gp = WorkPlane(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
    gp_colliding = wp.is_overlapped_with(gp.geometry)
pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


## add object
obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

obj_set_list = []
for i_obj, obj in enumerate(obj_list):
    obj_pscene, handles = add_object(pscene, obj)
    obj_set_list.append((obj, obj_pscene, handles))
obj, obj_pscene, handles = obj_set_list[0]

obj_pscene.geometry.color = (0.8,0.2,0.2,1)
if VISUALIZE:
    gscene.set_rviz()

mplan.update_gscene()
initial_state = pscene.initialize_state(HOME_POSE)
pscene.set_object_state(initial_state)
from_state = initial_state.copy(pscene)

ppline.set_motion_planner(mplan)
ppline.set_task_planner(tplan)

gtimer = GlobalTimer.instance()
gtimer.reset()

mplan.motion_filters = checkers_all
goal_nodes = [("gp",)+deepcopy(from_state.node)[1:]]
mplan.reset_log(True)
gtimer.tic("plan")
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, 
              timeout_loop=10, multiprocess=True, timeout=1, add_homing=False)
elapsed = gtimer.toc("plan")/1000
schedule = tplan.get_best_schedule(at_home=False)
res = len(schedule)>0
if res:
    ppline.play_schedule(schedule)
else:
    raise(RuntimeError("Failed to make plan - may be impossible problem was generated. try again up to 10 times or debug"))
# Out:
# Use 18/36 agents
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# error: 2.9
# try transition motion
# error: 2.3
# try transition motion
# transition motion tried: True
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->1 (0.29/10.0 s, steps/err: 35(128.192186356 ms)/0.00100235332318)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('gp',)
# error: 2.9
# error: 0.35
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try transition motion
# try transition motion
# error: 1.4
# try transition motion
# transition motion tried: True
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->2 (0.43/10.0 s, steps/err: 57(214.053153992 ms)/0.000746181628421)
# ======================================================================================================================================================
# result: 0 - ('wp',)->('grip0',) = fail
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# try: 0 - ('wp',)->('grip0',)
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 2 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: GraspChecker
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('gp',)
# branching: 1->3 (0.48/10.0 s, steps/err: 39(151.6020298 ms)/0.00150268875258)
# result: 1 - ('grip0',)->('wp',) = success
# result: 1 - ('grip0',)->('wp',) = fail
# try: 3 - ('wp',)->('grip0',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# error: 1.9
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# branching: 1->4 (0.52/10.0 s, steps/err: 30(149.15895462 ms)/0.00142304280366)
# try: 1 - ('grip0',)->('wp',)
# result: 2 - ('grip0',)->('wp',) = fail
# try: 4 - ('wp',)->('grip0',)
# result: 0 - ('wp',)->('grip0',) = success
# ======================================================================================================================================================
# try transition motion
# result: 2 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# try: 5 - ('grip0',)->('gp',)
# try: 5 - ('grip0',)->('wp',)
# try: 5 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('wp',)
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# branching: 0->5 (0.58/10.0 s, steps/err: 45(227.673053741 ms)/0.00186942846201)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try: 5 - ('grip0',)->('wp',)
# result: 5 - ('grip0',)->('gp',) = fail
# error: 1.8
# try: 3 - ('wp',)->('grip0',)
# result: 0 - ('wp',)->('grip0',) = fail
# result: 0 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('wp',) = fail
# try: 3 - ('wp',)->('grip0',)
# try: 4 - ('wp',)->('grip0',)
# try transition motion
# try: 5 - ('grip0',)->('gp',)
# result: 5 - ('grip0',)->('gp',) = fail
# result: 2 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# error: 0.69
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# try: 3 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# try transition motion
# error: 0.37
# result: 5 - ('grip0',)->('gp',) = fail
# result: 0 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 4 - ('wp',)->('grip0',) = fail
# error: 0.64
# result: 3 - ('wp',)->('grip0',) = fail
# try: 2 - ('grip0',)->('wp',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# result: 3 - ('wp',)->('grip0',) = fail
# try: 3 - ('wp',)->('grip0',)
# try: 2 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# try transition motion
# try: 1 - ('grip0',)->('gp',)
# try: 4 - ('wp',)->('grip0',)
# try transition motion
# result: 3 - ('wp',)->('grip0',) = fail
# try: 3 - ('wp',)->('grip0',)
# result: 4 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# try: 5 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# try: 5 - ('grip0',)->('wp',)
# result: 3 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# result: 3 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 5 - ('grip0',)->('wp',)
# try: 5 - ('grip0',)->('wp',)
# error: 1.2
# result: 2 - ('grip0',)->('wp',) = success
# result: 5 - ('grip0',)->('gp',) = fail
# branching: 2->6 (0.76/10.0 s, steps/err: 84(291.641950607 ms)/0.00215594682548)
# Motion Filer Failure: ReachChecker
# try transition motion
# result: 2 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# result: 5 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# try: 3 - ('wp',)->('grip0',)
# try: 5 - ('grip0',)->('wp',)
# try: 3 - ('wp',)->('grip0',)
# error: 2.8
# result: 5 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# transition motion tried: True
# try: 5 - ('grip0',)->('gp',)
# try transition motion
# Motion Filer Failure: ReachChecker
# error: 0.88
# transition motion tried: True
# try: 1 - ('grip0',)->('wp',)
# result: 5 - ('grip0',)->('wp',) = success
# result: 5 - ('grip0',)->('wp',) = fail
# try: 2 - ('grip0',)->('wp',)
# result: 3 - ('wp',)->('grip0',) = fail
# Goal reached
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# branching: 5->7 (0.8/10.0 s, steps/err: 46(210.773944855 ms)/0.00188539401576)
# result: 1 - ('grip0',)->('wp',) = success
# result: 2 - ('grip0',)->('gp',) = success
# result: 5 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('wp',)
# result: 3 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# branching: 1->8 (0.82/10.0 s, steps/err: 18(229.156017303 ms)/0.00100754316372)
# error: 0.56
# result: 2 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# ======================================================================================================================================================
# try transition motion
# branching: 2->9 (0.82/10.0 s, steps/err: 72(343.009233475 ms)/0.00150204036137)
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# try: 4 - ('wp',)->('grip0',)
# try: 7 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# error: 0.31
# result: 1 - ('grip0',)->('wp',) = fail
# result: 4 - ('wp',)->('grip0',) = success
# Motion Filer Failure: ReachChecker
# try: 5 - ('grip0',)->('wp',)
# try transition motion
# try: 2 - ('grip0',)->('gp',)
# result: 7 - ('wp',)->('grip0',) = fail
# try: 10 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('wp',) = fail
# error: 2.8
# branching: 4->10 (0.85/10.0 s, steps/err: 21(288.26713562 ms)/0.00142175272925)
# try transition motion
# try: 0 - ('wp',)->('grip0',)
# ======================================================================================================================================================
# result: 1 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('wp',)
# try: 5 - ('grip0',)->('gp',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 5 - ('grip0',)->('wp',) = success
# error: 0.35
# result: 2 - ('grip0',)->('gp',) = fail
# branching: 5->11 (0.88/10.0 s, steps/err: 28(227.761030197 ms)/0.00141553519948)
# result: 10 - ('grip0',)->('gp',) = fail
# result: 4 - ('wp',)->('grip0',) = success
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# branching: 4->12 (0.89/10.0 s, steps/err: 75(218.729019165 ms)/0.00141895167798)
# try transition motion
# try: 2 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('gp',) = fail
# result: 5 - ('grip0',)->('gp',) = fail
# error: 1.2
# transition motion tried: True
# try: 12 - ('grip0',)->('gp',)
# try transition motion
# try: 5 - ('grip0',)->('gp',)
# try: 12 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# try: 12 - ('grip0',)->('gp',)
# error: 1.5
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 12 - ('grip0',)->('wp',)
# result: 12 - ('grip0',)->('gp',) = fail
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0',)->('gp',) = fail
# result: 2 - ('grip0',)->('wp',) = success
# try: 5 - ('grip0',)->('wp',)
# result: 12 - ('grip0',)->('gp',) = fail
# result: 4 - ('wp',)->('grip0',) = success
# branching: 2->13 (0.93/10.0 s, steps/err: 78(192.816019058 ms)/0.00215342979296)
# try: 2 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('gp',)
# branching: 1->15 (0.94/10.0 s, steps/err: 15(201.276063919 ms)/0.00100764428161)
# ======================================================================================================================================================
# branching: 4->14 (0.94/10.0 s, steps/err: 74(195.340871811 ms)/0.00155190022547)
# transition motion tried: True
# result: 2 - ('grip0',)->('wp',) = fail
# error: 2.8
# try transition motion
# ======================================================================================================================================================
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 2 - ('grip0',)->('wp',) = success
# try: 14 - ('grip0',)->('gp',)
# try: 5 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('wp',)
# try: 0 - ('wp',)->('grip0',)
# branching: 2->16 (0.97/10.0 s, steps/err: 24(226.932048798 ms)/0.0018664689526)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 5 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# result: 0 - ('wp',)->('grip0',) = fail
# branching: 5->17 (0.98/10.0 s, steps/err: 27(190.87600708 ms)/0.0021864353442)
# ======================================================================================================================================================
# result: 14 - ('grip0',)->('gp',) = fail
# try: 17 - ('wp',)->('grip0',)
# error: 0.11
# try transition motion
# try: 1 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# result: 5 - ('grip0',)->('gp',) = fail
# try: 5 - ('grip0',)->('gp',)
# try: 5 - ('grip0',)->('gp',)
# try: 14 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 13 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 17 - ('wp',)->('grip0',) = fail
# error: 2.0
# result: 14 - ('grip0',)->('gp',) = fail
# try: 8 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try transition motion
# result: 1 - ('grip0',)->('gp',) = fail
# result: 5 - ('grip0',)->('gp',) = fail
# try: 15 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# try: 3 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('wp',)->('grip0',) = fail
# result: 13 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try: 10 - ('grip0',)->('wp',)
# error: 2.3
# try: 10 - ('grip0',)->('wp',)
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# try: 8 - ('wp',)->('grip0',)
# result: 4 - ('wp',)->('grip0',) = success
# branching: 1->18 (1.03/10.0 s, steps/err: 74(209.1319561 ms)/0.00138004073062)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# error: 2.5
# result: 10 - ('grip0',)->('wp',) = fail
# branching: 4->19 (1.04/10.0 s, steps/err: 62(196.019887924 ms)/0.00215462432592)
# ======================================================================================================================================================
# ======================================================================================================================================================
# result: 5 - ('grip0',)->('wp',) = success
# result: 8 - ('wp',)->('grip0',) = fail
# try transition motion
# try: 19 - ('grip0',)->('wp',)
# try: 19 - ('grip0',)->('gp',)
# try: 19 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try: 10 - ('grip0',)->('gp',)
# branching: 5->20 (1.06/10.0 s, steps/err: 11(194.159984589 ms)/0.00190394586133)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# transition motion tried: True
# try: 1 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# result: 19 - ('grip0',)->('gp',) = fail
# result: 10 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# try: 15 - ('wp',)->('grip0',)
# branching: 1->21 (1.09/10.0 s, steps/err: 85(226.681947708 ms)/0.00218178764592)
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 15 - ('wp',)->('grip0',) = fail
# try: 3 - ('wp',)->('grip0',)
# error: 1.9
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# result: 12 - ('grip0',)->('gp',) = fail
# try transition motion
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 12 - ('grip0',)->('gp',)
# try: 5 - ('grip0',)->('wp',)
# try: 5 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('gp',) = fail
# try: 10 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 12 - ('grip0',)->('gp',)
# result: 10 - ('grip0',)->('wp',) = fail
# error: 2.7
# try transition motion
# try: 16 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 16 - ('wp',)->('grip0',) = fail
# try: 5 - ('grip0',)->('wp',)
# error: 2.8
# try transition motion
# error: 0.74
# try transition motion
# transition motion tried: True
# result: 3 - ('wp',)->('grip0',) = success
# branching: 3->22 (1.17/10.0 s, steps/err: 65(629.068851471 ms)/0.00105125462091)
# ======================================================================================================================================================
# error: 0.82
# try transition motion
# try: 22 - ('grip0',)->('gp',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 22 - ('grip0',)->('gp',) = fail
# result: 2 - ('grip0',)->('wp',) = success
# branching: 2->23 (1.18/10.0 s, steps/err: 111(312.252998352 ms)/0.0012801471998)
# ======================================================================================================================================================
# try: 22 - ('grip0',)->('gp',)
# transition motion tried: True
# try: 16 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 22 - ('grip0',)->('gp',) = fail
# error: 0.88
# try transition motion
# Motion Filer Failure: GraspChecker
# result: 5 - ('grip0',)->('wp',) = success
# try: 5 - ('grip0',)->('gp',)
# result: 16 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# branching: 5->24 (1.2/10.0 s, steps/err: 21(265.70391655 ms)/0.00100509472236)
# ======================================================================================================================================================
# result: 5 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 16 - ('wp',)->('grip0',)
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: GraspChecker
# result: 1 - ('grip0',)->('gp',) = fail
# result: 16 - ('wp',)->('grip0',) = fail
# error: 0.45
# result: 4 - ('wp',)->('grip0',) = fail
# try transition motion
# try: 5 - ('grip0',)->('gp',)
# try: 10 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# try: 14 - ('grip0',)->('wp',)
# result: 10 - ('grip0',)->('gp',) = fail
# result: 5 - ('grip0',)->('gp',) = fail
# try: 14 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 14 - ('grip0',)->('wp',) = fail
# try: 15 - ('wp',)->('grip0',)
# result: 12 - ('grip0',)->('wp',) = success
# branching: 12->25 (1.22/10.0 s, steps/err: 72(298.968076706 ms)/0.00149892709966)
# ======================================================================================================================================================
# result: 14 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# error: 2.8
# try: 11 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('wp',)->('grip0',) = fail
# try transition motion
# try: 14 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# result: 14 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# try: 10 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# result: 10 - ('grip0',)->('gp',) = fail
# error: 0.22
# transition motion tried: True
# try transition motion
# try: 25 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 3 - ('wp',)->('grip0',) = success
# branching: 3->26 (1.25/10.0 s, steps/err: 12(229.629993439 ms)/0.00198146897729)
# ======================================================================================================================================================
# result: 25 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# try: 16 - ('wp',)->('grip0',)
# try: 26 - ('grip0',)->('gp',)
# try: 19 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('wp',) = fail
# result: 26 - ('grip0',)->('gp',) = fail
# try: 19 - ('grip0',)->('wp',)
# try: 22 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('wp',) = fail
# error: 2.0
# try: 8 - ('wp',)->('grip0',)
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 8 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# transition motion tried: True
# try: 10 - ('grip0',)->('wp',)
# result: 10 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# error: 1.2
# Goal reached
# branching: 10->27 (1.28/10.0 s, steps/err: 8(244.83704567 ms)/0.00181292049573)
# result: 10 - ('grip0',)->('wp',) = fail
# try transition motion
# result: 5 - ('grip0',)->('gp',) = success
# branching: 5->28 (1.29/10.0 s, steps/err: 58(276.045084 ms)/0.0015190077069)
# ======================================================================================================================================================
# transition motion tried: True
# try: 5 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# try: 10 - ('grip0',)->('wp',)
# result: 15 - ('wp',)->('grip0',) = success
# Motion Filer Failure: ReachChecker
# try: 22 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# error: 1.7
# branching: 15->29 (1.3/10.0 s, steps/err: 68(278.584957123 ms)/0.000866676526052)
# ======================================================================================================================================================
# try transition motion
# result: 10 - ('grip0',)->('wp',) = fail
# result: 5 - ('grip0',)->('wp',) = fail
# transition motion tried: True
# try: 29 - ('grip0',)->('gp',)
# try: 22 - ('grip0',)->('gp',)
# error: 0.31
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try transition motion
# result: 19 - ('grip0',)->('wp',) = success
# branching: 19->30 (1.33/10.0 s, steps/err: 38(271.441936493 ms)/0.00179017913885)
# ======================================================================================================================================================
# try: 26 - ('grip0',)->('gp',)
# result: 29 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 22 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try: 19 - ('grip0',)->('wp',)
# result: 3 - ('wp',)->('grip0',) = success
# error: 2.9
# try: 13 - ('wp',)->('grip0',)
# result: 26 - ('grip0',)->('gp',) = fail
# branching: 3->31 (1.35/10.0 s, steps/err: 54(228.980779648 ms)/0.00177780007348)
# Motion Filer Failure: GraspChecker
# ======================================================================================================================================================
# try: 31 - ('grip0',)->('gp',)
# try transition motion
# result: 13 - ('wp',)->('grip0',) = fail
# try: 13 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 8 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 13 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# error: 2.1
# result: 31 - ('grip0',)->('gp',) = fail
# try: 29 - ('grip0',)->('wp',)
# result: 5 - ('grip0',)->('wp',) = success
# try transition motion
# branching: 5->32 (1.37/10.0 s, steps/err: 16(250.487089157 ms)/0.00100225176786)
# Motion Filer Failure: ReachChecker
# try: 14 - ('grip0',)->('wp',)
# result: 29 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try: 13 - ('wp',)->('grip0',)
# result: 14 - ('grip0',)->('wp',) = fail
# error: 2.1
# try: 26 - ('grip0',)->('gp',)
# try: 13 - ('wp',)->('grip0',)
# try transition motion
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 13 - ('wp',)->('grip0',) = fail
# result: 26 - ('grip0',)->('gp',) = fail
# result: 13 - ('wp',)->('grip0',) = fail
# try: 22 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('wp',)
# error: 2.8
# try: 32 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: GraspChecker
# result: 22 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# result: 32 - ('wp',)->('grip0',) = fail
# try: 22 - ('grip0',)->('gp',)
# result: 5 - ('grip0',)->('wp',) = success
# branching: 5->33 (1.41/10.0 s, steps/err: 94(292.603969574 ms)/0.00200368267445)
# Motion Filer Failure: ReachChecker
# result: 22 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# try: 4 - ('wp',)->('grip0',)
# try: 2 - ('grip0',)->('gp',)
# try: 4 - ('wp',)->('grip0',)
# error: 2.8
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 4 - ('wp',)->('grip0',) = fail
# try transition motion
# try: 14 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# result: 14 - ('grip0',)->('wp',) = fail
# try: 17 - ('wp',)->('grip0',)
# try: 23 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 17 - ('wp',)->('grip0',) = fail
# result: 23 - ('wp',)->('grip0',) = fail
# try: 12 - ('grip0',)->('wp',)
# error: 2.5
# transition motion tried: True
# try: 25 - ('wp',)->('grip0',)
# try transition motion
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = success
# result: 12 - ('grip0',)->('wp',) = fail
# Goal reached
# try: 31 - ('grip0',)->('gp',)
# Motion Filer Failure: GraspChecker
# result: 12 - ('grip0',)->('gp',) = success
# branching: 12->35 (1.45/10.0 s, steps/err: 99(320.9400177 ms)/0.00198786478007)
# ======================================================================================================================================================
# branching: 1->34 (1.44/10.0 s, steps/err: 56(214.300870895 ms)/0.00153027914739)
# ======================================================================================================================================================
# try: 3 - ('wp',)->('grip0',)
# try: 12 - ('grip0',)->('wp',)
# result: 25 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# result: 31 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try: 11 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 25 - ('wp',)->('grip0',)
# error: 0.69
# result: 11 - ('wp',)->('grip0',) = success
# result: 12 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: GraspChecker
# transition motion tried: True
# branching: 11->36 (1.46/10.0 s, steps/err: 44(230.413913727 ms)/0.00216283701031)
# try: 36 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# result: 16 - ('wp',)->('grip0',) = success
# Motion Filer Failure: ReachChecker
# try: 12 - ('grip0',)->('wp',)
# transition motion tried: True
# error: 2.8
# result: 3 - ('wp',)->('grip0',) = fail
# try transition motion
# branching: 16->37 (1.48/10.0 s, steps/err: 35(218.206167221 ms)/0.00148673128646)
# result: 5 - ('grip0',)->('wp',) = success
# try: 37 - ('grip0',)->('gp',)
# result: 36 - ('grip0',)->('gp',) = fail
# error: 2.7
# try: 6 - ('wp',)->('grip0',)
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: GraspChecker
# try: 12 - ('grip0',)->('gp',)
# branching: 5->38 (1.5/10.0 s, steps/err: 87(348.628044128 ms)/0.000881920429308)
# result: 37 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# try: 12 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('wp',)->('grip0',) = fail
# try transition motion
# result: 12 - ('grip0',)->('gp',) = fail
# try: 20 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('wp',)
# try: 0 - ('wp',)->('grip0',)
# error: 1.2
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 18 - ('wp',)->('grip0',)
# error: 1.3
# try transition motion
# transition motion tried: True
# result: 22 - ('grip0',)->('wp',) = success
# branching: 22->39 (1.55/10.0 s, steps/err: 105(283.576965332 ms)/0.00081537603315)
# ======================================================================================================================================================
# transition motion tried: True
# try: 36 - ('grip0',)->('wp',)
# result: 22 - ('grip0',)->('wp',) = success
# error: 2.8
# try transition motion
# branching: 22->40 (1.56/10.0 s, steps/err: 64(245.818138123 ms)/0.00179712769268)
# transition motion tried: True
# ======================================================================================================================================================
# result: 4 - ('wp',)->('grip0',) = success
# try: 41 - ('grip0',)->('gp',)
# branching: 4->41 (1.57/10.0 s, steps/err: 51(244.246006012 ms)/0.00140385860968)
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# result: 41 - ('grip0',)->('gp',) = fail
# try: 41 - ('grip0',)->('gp',)
# error: 0.25
# try transition motion
# try: 26 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 41 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = success
# try: 31 - ('grip0',)->('gp',)
# result: 8 - ('wp',)->('grip0',) = success
# error: 0.61
# transition motion tried: True
# try transition motion
# branching: 8->43 (1.6/10.0 s, steps/err: 51(243.468999863 ms)/0.00178426111814)
# ======================================================================================================================================================
# result: 26 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# branching: 1->42 (1.6/10.0 s, steps/err: 35(205.698013306 ms)/0.00079600919384)
# try: 29 - ('grip0',)->('gp',)
# result: 31 - ('grip0',)->('gp',) = fail
# result: 19 - ('grip0',)->('wp',) = success
# ======================================================================================================================================================
# try: 43 - ('grip0',)->('gp',)
# error: 1.7
# branching: 19->44 (1.62/10.0 s, steps/err: 86(266.45898819 ms)/0.00189266834503)
# result: 4 - ('wp',)->('grip0',) = success
# try: 45 - ('grip0',)->('gp',)
# try: 17 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# result: 43 - ('grip0',)->('gp',) = fail
# branching: 4->45 (1.63/10.0 s, steps/err: 53(202.077865601 ms)/0.00148722407291)
# result: 45 - ('grip0',)->('gp',) = fail
# result: 29 - ('grip0',)->('gp',) = fail
# try transition motion
# try: 10 - ('grip0',)->('gp',)
# try: 45 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# try: 19 - ('grip0',)->('wp',)
# error: 1.0
# try: 26 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try: 7 - ('wp',)->('grip0',)
# result: 10 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 37 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 19 - ('grip0',)->('wp',) = fail
# result: 45 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 42 - ('wp',)->('grip0',)
# result: 26 - ('grip0',)->('gp',) = fail
# error: 2.7
# Motion Filer Failure: ReachChecker
# result: 11 - ('wp',)->('grip0',) = success
# try: 34 - ('wp',)->('grip0',)
# branching: 11->46 (1.67/10.0 s, steps/err: 9(197.538852692 ms)/0.00116030853395)
# try transition motion
# Motion Filer Failure: GraspChecker
# result: 37 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# try: 47 - ('grip0',)->('gp',)
# result: 25 - ('wp',)->('grip0',) = success
# branching: 25->47 (1.68/10.0 s, steps/err: 8(207.859992981 ms)/0.00103425072186)
# result: 42 - ('wp',)->('grip0',) = fail
# ======================================================================================================================================================
# try: 46 - ('grip0',)->('gp',)
# error: 2.8
# try: 27 - ('wp',)->('grip0',)
# try: 17 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try transition motion
# try: 46 - ('grip0',)->('wp',)
# result: 47 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 29 - ('grip0',)->('gp',)
# transition motion tried: True
# error: 1.7
# result: 46 - ('grip0',)->('gp',) = fail
# try transition motion
# try: 32 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('wp',) = success
# error: 1.6
# result: 29 - ('grip0',)->('gp',) = fail
# branching: 12->48 (1.73/10.0 s, steps/err: 54(205.857038498 ms)/0.00179904555535)
# try transition motion
# result: 32 - ('wp',)->('grip0',) = fail
# try: 48 - ('wp',)->('grip0',)
# try: 41 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# error: 1.3
# transition motion tried: True
# Motion Filer Failure: GraspChecker
# transition motion tried: True
# try transition motion
# try: 29 - ('grip0',)->('wp',)
# result: 20 - ('wp',)->('grip0',) = success
# result: 1 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# result: 48 - ('wp',)->('grip0',) = fail
# branching: 20->49 (1.76/10.0 s, steps/err: 63(232.223033905 ms)/0.00179180978543)
# transition motion tried: True
# Motion Filer Failure: LatticedChecker
# try: 49 - ('grip0',)->('gp',)
# transition motion tried: True
# branching: 1->50 (1.76/10.0 s, steps/err: 71(234.411001205 ms)/0.0010760499871)
# ======================================================================================================================================================
# result: 18 - ('wp',)->('grip0',) = success
# result: 7 - ('wp',)->('grip0',) = fail
# ======================================================================================================================================================
# result: 29 - ('grip0',)->('wp',) = fail
# try: 51 - ('grip0',)->('gp',)
# branching: 18->51 (1.78/10.0 s, steps/err: 34(226.026058197 ms)/0.00151246934264)
# try: 10 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# try: 46 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('wp',) = success
# branching: 12->52 (1.78/10.0 s, steps/err: 45(295.98402977 ms)/0.000528409075092)
# transition motion tried: True
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try: 23 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# error: 1.3
# Motion Filer Failure: ReachChecker
# result: 49 - ('grip0',)->('gp',) = fail
# result: 46 - ('grip0',)->('wp',) = fail
# result: 51 - ('grip0',)->('gp',) = fail
# result: 36 - ('grip0',)->('wp',) = success
# try: 38 - ('wp',)->('grip0',)
# try: 8 - ('wp',)->('grip0',)
# transition motion tried: True
# try: 19 - ('grip0',)->('gp',)
# try transition motion
# branching: 36->53 (1.81/10.0 s, steps/err: 26(244.308948517 ms)/0.00178226879397)
# try: 10 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 46 - ('grip0',)->('wp',)
# result: 17 - ('wp',)->('grip0',) = success
# try: 50 - ('wp',)->('grip0',)
# error: 2.2
# branching: 17->54 (1.84/10.0 s, steps/err: 45(200.16002655 ms)/0.00135935504791)
# error: 0.5
# try transition motion
# result: 19 - ('grip0',)->('gp',) = fail
# result: 10 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: GraspChecker
# ======================================================================================================================================================
# try transition motion
# result: 50 - ('wp',)->('grip0',) = fail
# try: 54 - ('grip0',)->('gp',)
# error: 1.1
# try transition motion
# try: 51 - ('grip0',)->('wp',)
# try: 22 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try: 24 - ('wp',)->('grip0',)
# result: 54 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# error: 2.6
# result: 24 - ('wp',)->('grip0',) = fail
# try: 41 - ('grip0',)->('gp',)
# transition motion tried: True
# try transition motion
# try: 49 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 46 - ('grip0',)->('wp',) = success
# branching: 46->55 (1.89/10.0 s, steps/err: 9(193.606853485 ms)/0.00128887741814)
# error: 1.8
# result: 49 - ('grip0',)->('gp',) = fail
# try transition motion
# try: 0 - ('wp',)->('grip0',)
# ======================================================================================================================================================
# try: 6 - ('wp',)->('grip0',)
# transition motion tried: True
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: GraspChecker
# error: 2.9
# result: 0 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try transition motion
# try: 56 - ('grip0',)->('gp',)
# transition motion tried: True
# result: 34 - ('wp',)->('grip0',) = success
# result: 6 - ('wp',)->('grip0',) = fail
# result: 17 - ('wp',)->('grip0',) = success
# result: 27 - ('wp',)->('grip0',) = success
# branching: 34->56 (1.92/10.0 s, steps/err: 43(243.24798584 ms)/0.000755041456318)
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# result: 56 - ('grip0',)->('gp',) = fail
# branching: 27->57 (1.93/10.0 s, steps/err: 46(232.189178467 ms)/0.00104516449096)
# error: 0.71
# try: 13 - ('wp',)->('grip0',)
# branching: 17->58 (1.93/10.0 s, steps/err: 42(224.483966827 ms)/0.00162124144769)
# try: 57 - ('grip0',)->('gp',)
# try: 58 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# error: 0.21
# try transition motion
# ======================================================================================================================================================
# try transition motion
# try: 58 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 5 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 58 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 57 - ('grip0',)->('gp',) = fail
# Goal reached
# transition motion tried: True
# result: 58 - ('grip0',)->('wp',) = fail
# error: 0.86
# try transition motion
# result: 41 - ('grip0',)->('wp',) = success
# try: 0 - ('wp',)->('grip0',)
# transition motion tried: True
# try: 30 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# branching: 41->60 (1.97/10.0 s, steps/err: 61(219.690084457 ms)/0.00148047864097)
# result: 8 - ('wp',)->('grip0',) = success
# try: 52 - ('wp',)->('grip0',)
# result: 10 - ('grip0',)->('gp',) = success
# error: 1.6
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: GraspChecker
# result: 30 - ('wp',)->('grip0',) = fail
# ======================================================================================================================================================
# result: 52 - ('wp',)->('grip0',) = fail
# branching: 10->59 (1.98/10.0 s, steps/err: 78(171.638965607 ms)/0.00178666463133)
# result: 0 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try: 61 - ('grip0',)->('gp',)
# try: 54 - ('grip0',)->('gp',)
# try: 58 - ('grip0',)->('gp',)
# branching: 8->61 (1.99/10.0 s, steps/err: 6(156.121015549 ms)/0.00177160095906)
# ======================================================================================================================================================
# try: 19 - ('grip0',)->('wp',)
# error: 1.4
# Motion Filer Failure: ReachChecker
# try: 62 - ('grip0',)->('gp',)
# result: 61 - ('grip0',)->('gp',) = fail
# try transition motion
# ======================================================================================================================================================
# result: 38 - ('wp',)->('grip0',) = success
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 54 - ('grip0',)->('gp',) = fail
# try: 49 - ('grip0',)->('gp',)
# try: 47 - ('grip0',)->('wp',)
# result: 58 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# try transition motion
# branching: 38->62 (2.02/10.0 s, steps/err: 47(188.899040222 ms)/0.000872640469575)
# error: 0.99
# ======================================================================================================================================================
# result: 62 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 56 - ('grip0',)->('wp',)
# try: 49 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 27 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 46 - ('grip0',)->('wp',) = success
# branching: 46->63 (2.04/10.0 s, steps/err: 14(204.636096954 ms)/0.000885952198646)
# result: 56 - ('grip0',)->('wp',) = fail
# result: 49 - ('grip0',)->('gp',) = fail
# try transition motion
# try: 43 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# try: 44 - ('wp',)->('grip0',)
# result: 47 - ('grip0',)->('wp',) = fail
# try: 34 - ('wp',)->('grip0',)
# result: 23 - ('wp',)->('grip0',) = success
# branching: 23->64 (2.06/10.0 s, steps/err: 91(243.379116058 ms)/0.00128197196873)
# Motion Filer Failure: GraspChecker
# try: 64 - ('grip0',)->('gp',)
# try: 19 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# result: 34 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# transition motion tried: False
# Motion Plan Failure
# try: 47 - ('grip0',)->('gp',)
# try: 19 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = fail
# result: 64 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try: 56 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 36 - ('grip0',)->('gp',)
# error: 2.8
# try transition motion
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 19 - ('grip0',)->('wp',) = fail
# Goal reached
# Motion Filer Failure: ReachChecker
# result: 22 - ('grip0',)->('gp',) = success
# error: 1.1
# try: 23 - ('wp',)->('grip0',)
# result: 47 - ('grip0',)->('gp',) = fail
# result: 36 - ('grip0',)->('gp',) = fail
# branching: 22->65 (2.11/10.0 s, steps/err: 59(225.275039673 ms)/0.00181395502127)
# try: 58 - ('grip0',)->('wp',)
# try transition motion
# Motion Filer Failure: GraspChecker
# Goal reached
# ======================================================================================================================================================
# result: 41 - ('grip0',)->('gp',) = success
# result: 23 - ('wp',)->('grip0',) = fail
# try: 17 - ('wp',)->('grip0',)
# transition motion tried: False
# branching: 41->66 (2.13/10.0 s, steps/err: 48(227.834939957 ms)/0.000926188146059)
# ======================================================================================================================================================
# try: 64 - ('grip0',)->('wp',)
# error: 2.5
# transition motion tried: True
# Motion Plan Failure
# try transition motion
# result: 51 - ('grip0',)->('wp',) = success
# branching: 51->67 (2.14/10.0 s, steps/err: 51(277.544975281 ms)/0.00118829359777)
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# transition motion tried: False
# try: 27 - ('wp',)->('grip0',)
# Motion Plan Failure
# result: 58 - ('grip0',)->('wp',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# try: 10 - ('grip0',)->('wp',)
# error: 0.63
# try transition motion
# try: 45 - ('grip0',)->('wp',)
# result: 12 - ('grip0',)->('wp',) = fail
# try: 18 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 6 - ('wp',)->('grip0',)
# result: 10 - ('grip0',)->('wp',) = fail
# error: 2.8
# transition motion tried: True
# try: 26 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# try: 41 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try transition motion
# result: 6 - ('wp',)->('grip0',) = fail
# result: 18 - ('wp',)->('grip0',) = fail
# Goal reached
# Motion Filer Failure: ReachChecker
# result: 41 - ('grip0',)->('wp',) = fail
# result: 5 - ('grip0',)->('gp',) = success
# result: 26 - ('grip0',)->('wp',) = fail
# try: 67 - ('wp',)->('grip0',)
# try: 39 - ('wp',)->('grip0',)
# branching: 5->68 (2.2/10.0 s, steps/err: 42(233.457803726 ms)/0.00191717263669)
# try: 17 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# transition motion tried: False
# try: 5 - ('grip0',)->('gp',)
# result: 67 - ('wp',)->('grip0',) = fail
# ======================================================================================================================================================
# Motion Plan Failure
# error: 2.7
# try: 42 - ('wp',)->('grip0',)
# try: 13 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: GraspChecker
# result: 17 - ('wp',)->('grip0',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# result: 39 - ('wp',)->('grip0',) = fail
# try: 50 - ('wp',)->('grip0',)
# try: 23 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 42 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: GraspChecker
# try: 17 - ('wp',)->('grip0',)
# try: 51 - ('grip0',)->('gp',)
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: GraspChecker
# result: 17 - ('wp',)->('grip0',) = fail
# result: 51 - ('grip0',)->('gp',) = fail
# result: 23 - ('wp',)->('grip0',) = fail
# result: 49 - ('grip0',)->('wp',) = success
# branching: 49->69 (2.24/10.0 s, steps/err: 47(198.992013931 ms)/0.00175074820835)
# try: 41 - ('grip0',)->('gp',)
# try: 22 - ('grip0',)->('wp',)
# transition motion tried: True
# ======================================================================================================================================================
# result: 19 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 41 - ('grip0',)->('gp',) = fail
# try: 58 - ('grip0',)->('gp',)
# try: 36 - ('grip0',)->('gp',)
# result: 22 - ('grip0',)->('wp',) = fail
# error: 0.95
# Motion Filer Failure: ReachChecker
# try: 64 - ('grip0',)->('wp',)
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 64 - ('grip0',)->('wp',) = fail
# try: 61 - ('grip0',)->('gp',)
# transition motion tried: True
# try: 51 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 36 - ('grip0',)->('gp',) = fail
# error: 0.82
# Motion Filer Failure: ReachChecker
# branching: 19->70 (2.27/10.0 s, steps/err: 94(247.099161148 ms)/0.00109563140002)
# try transition motion
# result: 61 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# ...
# transition motion tried: True
# transition motion tried: True
# try transition motion
# result: 19 - ('grip0',)->('wp',) = success
# try: 49 - ('grip0',)->('wp',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# try: 56 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# Motion Filer Failure: GraspChecker
# result: 51 - ('grip0',)->('wp',) = fail
# error: 0.76
# try: 62 - ('grip0',)->('wp',)
# result: 17 - ('wp',)->('grip0',) = success
# result: 73 - ('grip0',)->('gp',) = fail
# branching: 19->75 (2.36/10.0 s, steps/err: 62(281.795978546 ms)/0.00166349218218)
# try transition motion
# try: 76 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# branching: 17->77 (2.37/10.0 s, steps/err: 9(226.856946945 ms)/0.00202141452234)
# try: 77 - ('grip0',)->('gp',)
# result: 56 - ('grip0',)->('gp',) = fail
# result: 13 - ('wp',)->('grip0',) = success
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# branching: 13->76 (2.38/10.0 s, steps/err: 70(419.847011566 ms)/0.00078679447467)
# try: 41 - ('grip0',)->('wp',)
# error: 0.78
# try: 5 - ('grip0',)->('wp',)
# result: 76 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# try transition motion
# try: 43 - ('grip0',)->('wp',)
# try: 54 - ('grip0',)->('wp',)
# transition motion tried: True
# try: 41 - ('grip0',)->('gp',)
# result: 77 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# error: 1.0
# Motion Filer Failure: ReachChecker
# result: 27 - ('wp',)->('grip0',) = success
# try: 2 - ('grip0',)->('wp',)
# result: 54 - ('grip0',)->('wp',) = fail
# try transition motion
# result: 41 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try: 78 - ('grip0',)->('gp',)
# branching: 27->78 (2.41/10.0 s, steps/err: 46(259.235143661 ms)/0.00156713383763)
# try: 41 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# result: 45 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# error: 1.2
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 78 - ('grip0',)->('gp',) = fail
# branching: 45->79 (2.43/10.0 s, steps/err: 18(262.834072113 ms)/0.00178265921094)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# try transition motion
# result: 1 - ('grip0',)->('gp',) = fail
# try: 2 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# Goal reached
# error: 0.87
# try: 57 - ('grip0',)->('gp',)
# try: 51 - ('grip0',)->('gp',)
# try transition motion
# result: 41 - ('grip0',)->('gp',) = fail
# result: 5 - ('grip0',)->('gp',) = success
# Motion Filer Failure: ReachChecker
# error: 1.6
# try: 2 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# branching: 5->80 (2.46/10.0 s, steps/err: 37(234.266996384 ms)/0.0016379633024)
# result: 2 - ('grip0',)->('gp',) = fail
# result: 57 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# try transition motion
# try: 36 - ('grip0',)->('gp',)
# try: 22 - ('grip0',)->('gp',)
# try: 54 - ('grip0',)->('gp',)
# error: 1.0
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# try transition motion
# result: 36 - ('grip0',)->('gp',) = fail
# try: 10 - ('grip0',)->('gp',)
# try: 57 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 54 - ('grip0',)->('gp',) = fail
# result: 22 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# try: 56 - ('grip0',)->('gp',)
# try: 36 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 57 - ('grip0',)->('gp',) = fail
# try: 81 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 50 - ('wp',)->('grip0',) = success
# error: 1.5
# branching: 50->81 (2.5/10.0 s, steps/err: 45(267.882108688 ms)/0.000865876433778)
# ======================================================================================================================================================
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 56 - ('grip0',)->('gp',) = fail
# try transition motion
# transition motion tried: True
# transition motion tried: True
# result: 36 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 26 - ('grip0',)->('gp',)
# try: 37 - ('grip0',)->('gp',)
# result: 64 - ('grip0',)->('wp',) = success
# Goal reached
# branching: 64->82 (2.52/10.0 s, steps/err: 40(211.248874664 ms)/0.00178508658821)
# result: 12 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 14 - ('grip0',)->('gp',)
# result: 58 - ('grip0',)->('gp',) = success
# error: 1.7
# branching: 58->83 (2.53/10.0 s, steps/err: 44(257.014989853 ms)/0.00179050367128)
# Motion Filer Failure: ReachChecker
# try transition motion
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# result: 37 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# result: 81 - ('grip0',)->('gp',) = fail
# try: 22 - ('grip0',)->('gp',)
# try: 22 - ('grip0',)->('gp',)
# try: 43 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# result: 14 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 26 - ('grip0',)->('gp',) = fail
# result: 41 - ('grip0',)->('wp',) = success
# branching: 41->84 (2.54/10.0 s, steps/err: 17(216.245889664 ms)/0.00120690140433)
# Motion Filer Failure: ReachChecker
# try: 29 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# error: 1.4
# result: 22 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# result: 22 - ('grip0',)->('gp',) = fail
# try transition motion
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# result: 43 - ('grip0',)->('gp',) = fail
# result: 29 - ('grip0',)->('gp',) = fail
# result: 13 - ('wp',)->('grip0',) = success
# branching: 13->85 (2.57/10.0 s, steps/err: 27(336.448907852 ms)/0.0016875678375)
# ======================================================================================================================================================
# error: 2.0
# try: 85 - ('grip0',)->('gp',)
# transition motion tried: True
# try transition motion
# Motion Filer Failure: ReachChecker
# error: 1.0
# result: 85 - ('grip0',)->('gp',) = fail
# result: 22 - ('grip0',)->('wp',) = success
# try transition motion
# transition motion tried: True
# branching: 22->86 (2.59/10.0 s, steps/err: 68(235.828876495 ms)/0.00122386810911)
# ======================================================================================================================================================
# result: 49 - ('grip0',)->('wp',) = success
# branching: 49->87 (2.6/10.0 s, steps/err: 67(237.954139709 ms)/0.00103554838284)
# error: 2.7
# ======================================================================================================================================================
# try transition motion
# error: 0.91
# try transition motion
# transition motion tried: True
# result: 62 - ('grip0',)->('wp',) = success
# branching: 62->88 (2.64/10.0 s, steps/err: 69(273.79488945 ms)/0.00109216951113)
# error: 1.8
# ======================================================================================================================================================
# try transition motion
# transition motion tried: True
# result: 5 - ('grip0',)->('wp',) = success
# branching: 5->89 (2.65/10.0 s, steps/err: 73(257.951021194 ms)/0.00138130434153)
# ======================================================================================================================================================
# transition motion tried: True
# error: 1.3
# result: 41 - ('grip0',)->('wp',) = success
# branching: 41->90 (2.66/10.0 s, steps/err: 42(265.682935715 ms)/0.001397302558)
# try transition motion
# ======================================================================================================================================================
# transition motion tried: True
# result: 43 - ('grip0',)->('wp',) = success
# branching: 43->91 (2.67/10.0 s, steps/err: 57(263.017892838 ms)/0.00126334190264)
# ======================================================================================================================================================
# transition motion tried: True
# Goal reached
# result: 51 - ('grip0',)->('gp',) = success
# branching: 51->92 (2.69/10.0 s, steps/err: 44(225.775003433 ms)/0.00143899365297)
# ======================================================================================================================================================
# transition motion tried: True
# result: 2 - ('grip0',)->('wp',) = success
# branching: 2->93 (2.71/10.0 s, steps/err: 85(290.465831757 ms)/0.00204570664726)
# ======================================================================================================================================================
# transition motion tried: True
# Goal reached
# result: 10 - ('grip0',)->('gp',) = success
# branching: 10->94 (2.74/10.0 s, steps/err: 99(245.661020279 ms)/0.000987684181325)
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 10: node queue empty 1th  (3.1/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 9: node queue empty 2th  (3.1/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 8: node queue empty 4th  (3.2/10.0) ===============================
# ======================= terminated 15: node queue empty 4th  (3.2/10.0) ===============================
# ======================= terminated 12: node queue empty 4th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 13: node queue empty 5th  (3.2/10.0) ===============================
# ======================= terminated 3: node queue empty 5th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 1: node queue empty 6th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 16: node queue empty 7th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 17: node queue empty 8th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 7: node queue empty 9th  (3.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 2: node queue empty 10th  (3.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 5: node queue empty 11th  (3.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 14: node queue empty 12th  (3.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 4: node queue empty 13th  (3.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 0: node queue empty 14th  (3.3/10.0) ===============================
# =========================================================================================================
# transition motion tried: False
# Motion Plan Failure
# result: 64 - ('grip0',)->('wp',) = fail
# =========================================================================================================
# ======================= terminated 11: node queue empty 15th  (3.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 6: node queue empty 16th  (3.9/10.0) ===============================
# =========================================================================================================
# ========================== FINISHED (10.2 / 10.0 s) ==============================]
# ('wp',)->('grip0',)
# ('grip0',)->('gp',)

# %%
ppline.play_schedule(schedule)
# Out:
# ('wp',)->('grip0',)
# ('grip0',)->('gp',)
