# %% [markdown]
# ## Check List 4 - MotionFilter
# * Motion filters are quick decision makers that prevents trying to plan a infeasible motion.
# * Here, ReachChecker is tested, compared with actual planning results in random trials
# *\* ~~Strikethrough~~ means no-error but none-functional cases.*
# * **4-A.3 LatticedChecker**
#   - pick, place
#     - single process
#     - *multi process needs multiprocess lock setting with LatticedChecker, which uses shared memory to communicate with python3*
#
# * You need trained model to use ReachChecker
# * To use **LatticedChecker**, get model files from https://github.com/rnb-disinfection/arxiv-highcap/tree/rnb-planning/model/latticized and put them in *$RNB_PLANNING_DIR/model/latticized* folder.
# * For robots that are indy7 variants (indy7gripper...), copy indy7 model file and assign the robot name as the file name.

# %% [markdown]
# **[Trouble Shooting]**
# ```
# LatticedChecker uses tensorflow model on separate python3 program, through a shared memory.
# If some error raises with shared memory, try uncomment and run below cell, to reset shared memory.
# ```

# %%
# import SharedArray as sa
# robot_type_name = "indy7"
# sa.delete("shm://{}.grasp_img".format(robot_type_name))
# sa.delete("shm://{}.arm_img".format(robot_type_name))
# sa.delete("shm://{}.rh_mask".format(robot_type_name))
# sa.delete("shm://{}.result".format(robot_type_name))
# sa.delete("shm://{}.query_in".format(robot_type_name))
# sa.delete("shm://{}.response_out".format(robot_type_name))
# sa.delete("shm://{}.query_quit".format(robot_type_name))

# %% [markdown]
# ## set running directory

# %%
from __future__ import print_function
import os
os.chdir(os.path.join(os.environ["RNB_PLANNING_DIR"], 'src'))

# %%
from pkg.controller.combined_robot import *
from pkg.utils.utils import get_now, try_mkdir

# %%
VISUALIZE = True
CLEARANCE = 1e-3

# ROBOT_TYPE = RobotType.indy7gripper
# ROBOT_NAME = "indy0"
# TOOL_XYZ = (0,0,0.14)
# TOOL_RPY = (-np.pi/2,0,0)
# GRIP_DEPTH = 0.05
# HOME_POSE = (0,0,0,0,0,0)

ROBOT_TYPE = RobotType.panda
ROBOT_NAME = "panda0"
TOOL_XYZ = (0,0,0.112)
TOOL_RPY = (-np.pi/2,0,0)
GRIP_DEPTH = 0.03
HOME_POSE = (0,-0.3,0,-0.5,0,2.5,0)

# %% [markdown]
# ## init combined robot config

# %%
from pkg.project_config import *

crob = CombinedRobot(robots_on_scene=[
    RobotConfig(0, ROBOT_TYPE, None,
                None)]
              , connection_list=[False])
TOOL_LINK = crob.get_robot_tip_dict().values()[0]
from pkg.geometry.builder.scene_builder import SceneBuilder
s_builder = SceneBuilder(None)
# # deprecated: s_builder.reset_reference_coord(ref_name="floor")
# Out:
# connection command:
# panda0: False

# %% [markdown]
# ## get ghnd with detected robot config

# %%
# xyz_rpy_robots = s_builder.detect_items(level_mask=[DetectionLevel.ROBOT])
xyz_rpy_robots = {ROBOT_NAME: ((0,0,0), (0,0,0))}
crob.update_robot_pos_dict(xyz_rpy_robots=xyz_rpy_robots)
gscene = s_builder.create_gscene(crob, start_rviz=VISUALIZE)
HOME_DICT = list2dict(HOME_POSE, gscene.joint_names)
# Out:
# Unable to register with master node [http://localhost:11311]: master may not be running yet. Will keep trying.
# Please create a subscriber to the marker
# publication OK
# published: [0, 0, 0, 0, 0, 0, 0]

# %%
from pkg.utils.joint_utils import get_tf
shoulder_link = gscene.urdf_content.joint_map[gscene.joint_names[1]].child
shoulder_height = get_tf(shoulder_link, HOME_DICT, gscene.urdf_content)[2,3]

# %% [markdown]
# ## add environment

# %%
from pkg.geometry.geometry import *
gtems_robot = s_builder.add_robot_geometries(color=(0,1,0,0.5), display=False, collision=True)

# %% [markdown]
# ## init planning scene

# %%
from pkg.planning.scene import PlanningScene
pscene = PlanningScene(gscene, combined_robot=crob)

from pkg.planning.pipeline import PlanningPipeline
ppline = PlanningPipeline(pscene)

# %% [markdown]
# ## Register binders

# %%
from pkg.planning.constraint.constraint_actor import Gripper2Tool, PlacePlane, SweepTool

# %%
gscene.create_safe(gtype=GEOTYPE.SPHERE, name="grip0", link_name=TOOL_LINK, 
                   dims=(0.01,)*3, center=TOOL_XYZ, rpy=TOOL_RPY, color=(1,0,0,1), display=True, collision=False, fixed=True)
gripper = pscene.create_binder(bname="grip0", gname="grip0", _type=Gripper2Tool, point=(0,0,0), rpy=(0,0,0))
# Out:
# Please create a subscriber to the marker

# %% [markdown]
# ## planner
# * Initiailizaing *LatticedChecker* can take ~ 1 min.

# %%
from pkg.planning.motion.moveit.moveit_planner import MoveitPlanner
from pkg.planning.filtering.grasp_filter import GraspChecker
from pkg.planning.filtering.reach_filter import ReachChecker
from pkg.planning.filtering.latticized_filter import LatticedChecker
mplan = MoveitPlanner(pscene)
gcheck = GraspChecker(pscene)
rcheck = ReachChecker(pscene)
lcheck = LatticedChecker(pscene, gcheck)
checkers_all = [gcheck, rcheck, lcheck]

# %%
from pkg.planning.task.rrt import TaskRRT
tplan = TaskRRT(pscene)
tplan.prepare()

# %% [markdown]
# # Object Classes

# %%
from pkg.utils.gjk import get_point_list, get_gjk_distance
from pkg.planning.constraint.constraint_subject import CustomObject, Grasp2Point, PlacePoint, SweepPoint, SweepTask
from pkg.planning.filtering.lattice_model.scene_building import *

# %% [markdown]
# ### Test: pick&place motions

# %% [markdown]
# ##### test few times with visualization

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
import random

Nmax_obj = 3
VISUALIZE = True
result_dict = defaultdict(list)
N_TRIAL = 5
i_count = 0
MP_TIMEOUT = 1

while i_count < N_TRIAL:
    pscene.clear_subjects()
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

    obj_set_list = []
    for i_obj, obj in enumerate(obj_list):
        obj_pscene, handles = add_object(pscene, obj)
        obj_set_list.append((obj, obj_pscene, handles))
    obj, obj_pscene, handles = obj_set_list[0]

    obj_pscene.geometry.color = (0.8,0.2,0.2,1)
    if VISUALIZE:
        gscene.set_rviz()

    initial_state = pscene.initialize_state(HOME_POSE)
    pscene.set_object_state(initial_state)
    tplan.prepare()
    
    scenario = "pick"
    from_state=initial_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("grip0",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
    obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)

    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    i_count += 1
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        pscene.set_object_state(from_state)
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.01)
        pick_state = pscene.rebind_all(
            [to_state.binding_state[sname].get_chain() for sname in pscene.subject_name_list], LastQ)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
    
    if not success:
        pscene.set_object_state(initial_state)
        continue

    scenario = "place"
    from_state=pick_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("gp",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)
    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.01)
    pscene.set_object_state(initial_state)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
# Out:
# 1/5: Result match for pick: True / True
# 2/5: Result match for pick: True / True
# 3/5: Result mismatch for pick: True / False
# 4/5: Result match for pick: True / True
# 5/5: Result mismatch for pick: False / True

# %% [markdown]
# ##### test many times without visualization

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
import random

Nmax_obj = 3
VISUALIZE = False
result_dict = defaultdict(list)
N_TRIAL = 500
i_count = 0
MP_TIMEOUT = 1

while i_count < N_TRIAL:
    pscene.clear_subjects()
    ## add floor, ceiling
    floor = Floor(gscene, "floor")
    gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                       dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                       color=floor.geometry.color, display=True, collision=True, fixed=True)
    # ceiling = Ceiling(gscene, "ceiling")

    ## set workplane
    wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
    pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

    gp_colliding = True
    while gp_colliding:
        ## set goalplane
        gp = SideBox(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
        gp_colliding = wp.is_overlapped_with(gp.geometry)
    pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


    ## add object
    obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

    obj_set_list = []
    for i_obj, obj in enumerate(obj_list):
        obj_pscene, handles = add_object(pscene, obj)
        obj_set_list.append((obj, obj_pscene, handles))
    obj, obj_pscene, handles = obj_set_list[0]

    obj_pscene.geometry.color = (0.8,0.2,0.2,1)
    if VISUALIZE:
        gscene.set_rviz()

    initial_state = pscene.initialize_state(HOME_POSE)
    pscene.set_object_state(initial_state)
    tplan.prepare()
    
    scenario = "pick"
    from_state=initial_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("grip0",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
    obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)

    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    i_count += 1
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        pscene.set_object_state(from_state)
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.05)
        pick_state = pscene.rebind_all(
            [to_state.binding_state[sname].get_chain() for sname in pscene.subject_name_list], LastQ)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
    
    if not success:
        pscene.set_object_state(initial_state)
        continue

    scenario = "place"
    from_state=pick_state
    pscene.set_object_state(from_state)
    gscene.show_pose(from_state.Q)
    
    to_node = ("gp",)+("wp",)*len(pscene.subject_name_list[1:])
    available_binding_dict = pscene.get_available_binding_dict(from_state, to_node)
    Q_dict = list2dict(from_state.Q, gscene.joint_names)
    
    for _ in range(10): # try multiple times to get available put position
        to_state = pscene.sample_leaf_state(from_state, available_binding_dict, to_node)
        obj, handle, actor = to_state.binding_state["obj_0"].get_instance_chain(pscene)

        pscene.set_object_state(from_state)
        gscene.show_pose(from_state.Q)
        for mfilter in [gcheck, rcheck]: # test gcheck anc rcheck
            success_mfilter = mfilter.check(to_state.binding_state["obj_0"], Q_dict)
            if not success_mfilter:
                break
        if success_mfilter:
            break
    if not success_mfilter:
        continue
        
    # test lcheck
    success_mfilter = lcheck.check(to_state.binding_state["obj_0"], Q_dict)

    Traj, LastQ, error, success = mplan.plan_algorithm(
        from_state, to_state, subject_list=pscene.get_changing_subjects(from_state, to_state)[0], timeout=MP_TIMEOUT)

    result_dict[scenario].append((success_mfilter, success))
    if success:
        if VISUALIZE:
            gscene.show_motion(Traj, period=0.05)
    pscene.set_object_state(initial_state)
    print("{}/{}: Result {} for {}: {} / {}".format(i_count, N_TRIAL, "match" if success_mfilter==success else "mismatch", scenario, success_mfilter, success))
    # assert success_mfilter == success, "Failure: filter result not same with motion planning result"
# Out:
# 1/500: Result match for pick: True / True
# 1/500: Result mismatch for place: False / True
# 2/500: Result match for pick: False / False
# 3/500: Result match for pick: True / True
# 3/500: Result match for place: False / False
# 4/500: Result match for pick: True / True
# 5/500: Result match for pick: True / True
# 6/500: Result match for pick: True / True
# 7/500: Result match for pick: True / True
# 8/500: Result match for pick: True / True
# 9/500: Result match for pick: True / True
# 10/500: Result match for pick: True / True
# 11/500: Result match for pick: True / True
# 12/500: Result match for pick: True / True
# 12/500: Result match for place: False / False
# 13/500: Result mismatch for pick: True / False
# 14/500: Result match for pick: True / True
# 15/500: Result match for pick: True / True
# 16/500: Result mismatch for pick: True / False
# 17/500: Result match for pick: True / True
# 17/500: Result mismatch for place: False / True
# 18/500: Result match for pick: False / False
# 19/500: Result match for pick: True / True
# 20/500: Result match for pick: True / True
# 20/500: Result match for place: False / False
# 21/500: Result match for pick: False / False
# 22/500: Result match for pick: True / True
# 23/500: Result match for pick: True / True
# 24/500: Result match for pick: True / True
# 24/500: Result match for place: False / False
# 25/500: Result match for pick: True / True
# 25/500: Result match for place: True / True
# 26/500: Result match for pick: True / True
# 27/500: Result mismatch for pick: True / False
# 28/500: Result mismatch for pick: True / False
# 29/500: Result match for pick: True / True
# 29/500: Result match for place: True / True
# 30/500: Result match for pick: True / True
# 31/500: Result match for pick: True / True
# 32/500: Result match for pick: True / True
# 33/500: Result mismatch for pick: True / False
# 34/500: Result match for pick: True / True
# 34/500: Result match for place: True / True
# 35/500: Result match for pick: True / True
# 36/500: Result match for pick: True / True
# 37/500: Result match for pick: True / True
# 38/500: Result match for pick: True / True
# 38/500: Result mismatch for place: True / False
# 39/500: Result match for pick: True / True
# 39/500: Result mismatch for place: True / False
# 40/500: Result match for pick: True / True
# 41/500: Result match for pick: True / True
# 41/500: Result match for place: False / False
# 42/500: Result match for pick: True / True
# 42/500: Result mismatch for place: True / False
# 43/500: Result mismatch for pick: True / False
# 44/500: Result match for pick: True / True
# 45/500: Result match for pick: True / True
# 45/500: Result match for place: False / False
# 46/500: Result match for pick: True / True
# 47/500: Result match for pick: True / True
# 48/500: Result match for pick: True / True
# 49/500: Result match for pick: True / True
# 50/500: Result match for pick: True / True
# 50/500: Result match for place: True / True
# 51/500: Result match for pick: True / True
# 51/500: Result match for place: True / True
# 52/500: Result match for pick: True / True
# 53/500: Result match for pick: False / False
# 54/500: Result match for pick: True / True
# 54/500: Result match for place: True / True
# 55/500: Result match for pick: True / True
# 56/500: Result match for pick: True / True
# 56/500: Result match for place: True / True
# 57/500: Result match for pick: True / True
# 58/500: Result match for pick: True / True
# 59/500: Result match for pick: True / True
# 59/500: Result match for place: True / True
# 60/500: Result mismatch for pick: True / False
# 61/500: Result match for pick: True / True
# 62/500: Result match for pick: True / True
# 62/500: Result match for place: True / True
# 63/500: Result mismatch for pick: True / False
# 64/500: Result match for pick: True / True
# 64/500: Result match for place: False / False
# 65/500: Result match for pick: True / True
# 65/500: Result match for place: True / True
# 66/500: Result match for pick: True / True
# 66/500: Result match for place: True / True
# 67/500: Result match for pick: True / True
# 67/500: Result match for place: False / False
# 68/500: Result match for pick: True / True
# 68/500: Result match for place: False / False
# 69/500: Result match for pick: True / True
# 69/500: Result mismatch for place: True / False
# 70/500: Result mismatch for pick: True / False
# 71/500: Result match for pick: True / True
# 71/500: Result mismatch for place: False / True
# 72/500: Result match for pick: True / True
# 73/500: Result mismatch for pick: True / False
# 74/500: Result match for pick: True / True
# 75/500: Result mismatch for pick: False / True
# 75/500: Result mismatch for place: True / False
# 76/500: Result match for pick: True / True
# 76/500: Result match for place: True / True
# 77/500: Result mismatch for pick: True / False
# 78/500: Result match for pick: True / True
# 79/500: Result match for pick: True / True
# 80/500: Result match for pick: True / True
# 81/500: Result match for pick: True / True
# 82/500: Result match for pick: False / False
# 83/500: Result match for pick: True / True
# 84/500: Result mismatch for pick: True / False
# 85/500: Result match for pick: True / True
# 86/500: Result match for pick: True / True
# 86/500: Result match for place: True / True
# 87/500: Result match for pick: False / False
# 88/500: Result match for pick: True / True
# 89/500: Result match for pick: True / True
# 90/500: Result match for pick: True / True
# 91/500: Result match for pick: True / True
# 92/500: Result match for pick: True / True
# 93/500: Result mismatch for pick: True / False
# 94/500: Result mismatch for pick: True / False
# 95/500: Result match for pick: True / True
# 96/500: Result match for pick: True / True
# 97/500: Result match for pick: True / True
# 98/500: Result match for pick: True / True
# 99/500: Result match for pick: True / True
# 100/500: Result match for pick: True / True
# 101/500: Result match for pick: True / True
# 102/500: Result match for pick: False / False
# 103/500: Result match for pick: True / True
# 103/500: Result match for place: True / True
# 104/500: Result match for pick: True / True
# 105/500: Result match for pick: False / False
# 106/500: Result match for pick: True / True
# 106/500: Result match for place: True / True
# 107/500: Result match for pick: True / True
# 108/500: Result match for pick: True / True
# 109/500: Result match for pick: True / True
# 110/500: Result match for pick: True / True
# 111/500: Result match for pick: True / True
# 111/500: Result mismatch for place: True / False
# 112/500: Result match for pick: True / True
# 112/500: Result match for place: False / False
# 113/500: Result match for pick: True / True
# 114/500: Result match for pick: True / True
# 115/500: Result mismatch for pick: True / False
# 116/500: Result match for pick: True / True
# 117/500: Result match for pick: True / True
# 118/500: Result match for pick: True / True
# 119/500: Result match for pick: True / True
# 119/500: Result match for place: True / True
# 120/500: Result match for pick: True / True
# 121/500: Result match for pick: True / True
# 122/500: Result match for pick: True / True
# 123/500: Result match for pick: True / True
# 124/500: Result match for pick: True / True
# 125/500: Result mismatch for pick: True / False
# 126/500: Result match for pick: True / True
# 127/500: Result mismatch for pick: True / False
# 128/500: Result match for pick: True / True
# 128/500: Result match for place: False / False
# 129/500: Result mismatch for pick: True / False
# 130/500: Result match for pick: True / True
# 130/500: Result match for place: True / True
# 131/500: Result match for pick: True / True
# 132/500: Result match for pick: True / True
# 133/500: Result match for pick: True / True
# 133/500: Result match for place: False / False
# 134/500: Result match for pick: True / True
# 135/500: Result match for pick: True / True
# 136/500: Result mismatch for pick: True / False
# 137/500: Result match for pick: True / True
# 138/500: Result match for pick: True / True
# 138/500: Result match for place: False / False
# 139/500: Result match for pick: True / True
# 139/500: Result match for place: True / True
# 140/500: Result match for pick: True / True
# 141/500: Result match for pick: True / True
# 142/500: Result match for pick: True / True
# 143/500: Result match for pick: True / True
# 144/500: Result match for pick: True / True
# 145/500: Result match for pick: True / True
# 146/500: Result match for pick: True / True
# 146/500: Result match for place: True / True
# 147/500: Result match for pick: True / True
# 147/500: Result mismatch for place: True / False
# 148/500: Result match for pick: True / True
# 149/500: Result match for pick: True / True
# 150/500: Result match for pick: True / True
# 150/500: Result mismatch for place: True / False
# 151/500: Result match for pick: True / True
# 151/500: Result match for place: False / False
# 152/500: Result match for pick: True / True
# 152/500: Result mismatch for place: False / True
# 153/500: Result match for pick: True / True
# 154/500: Result match for pick: True / True
# 154/500: Result match for place: True / True
# 155/500: Result match for pick: True / True
# 155/500: Result match for place: True / True
# 156/500: Result match for pick: True / True
# 157/500: Result match for pick: True / True
# 158/500: Result match for pick: True / True
# 159/500: Result match for pick: True / True
# 160/500: Result match for pick: True / True
# 160/500: Result match for place: True / True
# 161/500: Result match for pick: True / True
# 162/500: Result mismatch for pick: True / False
# 163/500: Result match for pick: True / True
# 164/500: Result match for pick: True / True
# 164/500: Result match for place: True / True
# 165/500: Result match for pick: True / True
# 166/500: Result match for pick: True / True
# 167/500: Result match for pick: True / True
# 168/500: Result match for pick: True / True
# 169/500: Result match for pick: True / True
# 170/500: Result match for pick: True / True
# 170/500: Result match for place: False / False
# 171/500: Result match for pick: True / True
# 172/500: Result match for pick: True / True
# 172/500: Result match for place: True / True
# 173/500: Result match for pick: True / True
# 173/500: Result match for place: True / True
# 174/500: Result match for pick: True / True
# 175/500: Result match for pick: True / True
# 175/500: Result match for place: True / True
# 176/500: Result match for pick: True / True
# 177/500: Result match for pick: True / True
# 178/500: Result match for pick: True / True
# 179/500: Result match for pick: True / True
# 180/500: Result match for pick: True / True
# 180/500: Result mismatch for place: False / True
# 181/500: Result match for pick: False / False
# 182/500: Result mismatch for pick: True / False
# 183/500: Result match for pick: True / True
# 184/500: Result match for pick: True / True
# 184/500: Result match for place: False / False
# 185/500: Result match for pick: True / True
# 186/500: Result match for pick: True / True
# 187/500: Result mismatch for pick: True / False
# 188/500: Result mismatch for pick: True / False
# 189/500: Result match for pick: True / True
# 190/500: Result match for pick: True / True
# 190/500: Result match for place: True / True
# 191/500: Result match for pick: True / True
# 192/500: Result match for pick: True / True
# 193/500: Result match for pick: True / True
# 193/500: Result match for place: True / True
# 194/500: Result match for pick: True / True
# 195/500: Result match for pick: True / True
# 196/500: Result match for pick: True / True
# 197/500: Result match for pick: True / True
# 198/500: Result match for pick: True / True
# 199/500: Result match for pick: True / True
# 200/500: Result match for pick: True / True
# 200/500: Result match for place: False / False
# 201/500: Result match for pick: True / True
# 201/500: Result match for place: False / False
# 202/500: Result match for pick: True / True
# 203/500: Result match for pick: True / True
# 203/500: Result match for place: True / True
# 204/500: Result match for pick: True / True
# 205/500: Result mismatch for pick: True / False
# 206/500: Result match for pick: True / True
# 207/500: Result match for pick: True / True
# 208/500: Result mismatch for pick: True / False
# 209/500: Result match for pick: True / True
# 210/500: Result match for pick: True / True
# 211/500: Result match for pick: True / True
# 212/500: Result mismatch for pick: False / True
# 213/500: Result match for pick: True / True
# 214/500: Result match for pick: True / True
# 215/500: Result match for pick: True / True
# 216/500: Result match for pick: True / True
# 216/500: Result match for place: True / True
# 217/500: Result match for pick: True / True
# 218/500: Result mismatch for pick: True / False
# 219/500: Result match for pick: True / True
# 220/500: Result mismatch for pick: True / False
# 221/500: Result mismatch for pick: True / False
# 222/500: Result match for pick: True / True
# 223/500: Result mismatch for pick: True / False
# 224/500: Result mismatch for pick: True / False
# 225/500: Result match for pick: True / True
# 225/500: Result match for place: False / False
# 226/500: Result mismatch for pick: True / False
# 227/500: Result match for pick: True / True
# 228/500: Result mismatch for pick: True / False
# 229/500: Result mismatch for pick: True / False
# 230/500: Result match for pick: True / True
# 230/500: Result match for place: False / False
# 231/500: Result match for pick: True / True
# 231/500: Result match for place: True / True
# 232/500: Result mismatch for pick: True / False
# 233/500: Result match for pick: True / True
# 234/500: Result match for pick: True / True
# 235/500: Result match for pick: True / True
# 236/500: Result match for pick: True / True
# 237/500: Result match for pick: True / True
# 238/500: Result match for pick: True / True
# 239/500: Result match for pick: True / True
# 240/500: Result match for pick: True / True
# 240/500: Result match for place: False / False
# 241/500: Result match for pick: True / True
# 241/500: Result match for place: True / True
# 242/500: Result match for pick: True / True
# 243/500: Result match for pick: True / True
# 243/500: Result match for place: False / False
# 244/500: Result match for pick: False / False
# 245/500: Result match for pick: True / True
# 245/500: Result match for place: True / True
# 246/500: Result match for pick: True / True
# 246/500: Result match for place: False / False
# 247/500: Result match for pick: True / True
# 248/500: Result match for pick: True / True
# 248/500: Result match for place: True / True
# 249/500: Result mismatch for pick: False / True
# 250/500: Result mismatch for pick: True / False
# 251/500: Result match for pick: True / True
# 252/500: Result match for pick: True / True
# 252/500: Result match for place: True / True
# 253/500: Result match for pick: True / True
# 254/500: Result match for pick: True / True
# 255/500: Result match for pick: True / True
# 255/500: Result match for place: True / True
# 256/500: Result match for pick: True / True
# 257/500: Result match for pick: True / True
# 258/500: Result mismatch for pick: True / False
# 259/500: Result match for pick: False / False
# 260/500: Result match for pick: True / True
# 261/500: Result match for pick: True / True
# 262/500: Result match for pick: True / True
# 262/500: Result match for place: True / True
# 263/500: Result match for pick: True / True
# 264/500: Result match for pick: True / True
# 265/500: Result match for pick: True / True
# 265/500: Result mismatch for place: True / False
# 266/500: Result match for pick: True / True
# 267/500: Result match for pick: True / True
# 268/500: Result match for pick: True / True
# 269/500: Result match for pick: True / True
# 270/500: Result mismatch for pick: True / False
# 271/500: Result match for pick: True / True
# 272/500: Result match for pick: True / True
# 273/500: Result match for pick: True / True
# 274/500: Result match for pick: True / True
# 274/500: Result match for place: True / True
# 275/500: Result mismatch for pick: False / True
# 276/500: Result match for pick: True / True
# 277/500: Result match for pick: True / True
# 278/500: Result match for pick: True / True
# 279/500: Result mismatch for pick: True / False
# 280/500: Result match for pick: True / True
# 281/500: Result match for pick: True / True
# 281/500: Result match for place: True / True
# 282/500: Result mismatch for pick: True / False
# 283/500: Result match for pick: True / True
# 284/500: Result match for pick: True / True
# 285/500: Result match for pick: True / True
# 285/500: Result match for place: True / True
# 286/500: Result mismatch for pick: True / False
# 287/500: Result match for pick: True / True
# 288/500: Result mismatch for pick: True / False
# 289/500: Result match for pick: True / True
# 290/500: Result match for pick: True / True
# 291/500: Result match for pick: True / True
# 292/500: Result match for pick: True / True
# 293/500: Result match for pick: True / True
# 294/500: Result match for pick: True / True
# 295/500: Result match for pick: True / True
# 296/500: Result mismatch for pick: True / False
# 297/500: Result match for pick: True / True
# 298/500: Result match for pick: True / True
# 298/500: Result match for place: False / False
# 299/500: Result match for pick: True / True
# 299/500: Result match for place: True / True
# 300/500: Result match for pick: True / True
# 301/500: Result match for pick: True / True
# 302/500: Result match for pick: True / True
# 302/500: Result match for place: True / True
# 303/500: Result match for pick: True / True
# 303/500: Result match for place: True / True
# 304/500: Result match for pick: True / True
# 305/500: Result match for pick: True / True
# 305/500: Result match for place: True / True
# 306/500: Result mismatch for pick: True / False
# 307/500: Result match for pick: True / True
# 307/500: Result mismatch for place: True / False
# 308/500: Result match for pick: True / True
# 309/500: Result match for pick: True / True
# 310/500: Result match for pick: True / True
# 310/500: Result mismatch for place: False / True
# 311/500: Result match for pick: True / True
# 311/500: Result match for place: False / False
# 312/500: Result match for pick: True / True
# 313/500: Result match for pick: True / True
# 313/500: Result match for place: True / True
# 314/500: Result match for pick: True / True
# 314/500: Result mismatch for place: False / True
# 315/500: Result mismatch for pick: True / False
# 316/500: Result match for pick: True / True
# 316/500: Result match for place: True / True
# 317/500: Result match for pick: True / True
# 318/500: Result match for pick: False / False
# 319/500: Result match for pick: True / True
# 319/500: Result mismatch for place: True / False
# 320/500: Result match for pick: True / True
# 321/500: Result match for pick: True / True
# 322/500: Result match for pick: True / True
# 323/500: Result match for pick: True / True
# 324/500: Result mismatch for pick: True / False
# 325/500: Result mismatch for pick: False / True
# 326/500: Result match for pick: True / True
# 327/500: Result match for pick: True / True
# 327/500: Result match for place: True / True
# 328/500: Result mismatch for pick: True / False
# 329/500: Result match for pick: True / True
# 329/500: Result match for place: False / False
# 330/500: Result mismatch for pick: False / True
# 330/500: Result match for place: True / True
# 331/500: Result match for pick: True / True
# 331/500: Result match for place: True / True
# 332/500: Result match for pick: True / True
# 333/500: Result match for pick: True / True
# 334/500: Result mismatch for pick: True / False
# 335/500: Result match for pick: True / True
# 336/500: Result match for pick: True / True
# 337/500: Result match for pick: True / True
# 338/500: Result match for pick: False / False
# 339/500: Result match for pick: True / True
# 340/500: Result match for pick: True / True
# 341/500: Result match for pick: True / True
# 342/500: Result match for pick: True / True
# 343/500: Result mismatch for pick: True / False
# 344/500: Result match for pick: True / True
# 345/500: Result match for pick: True / True
# 346/500: Result match for pick: True / True
# 347/500: Result mismatch for pick: True / False
# 348/500: Result match for pick: True / True
# 349/500: Result match for pick: True / True
# 349/500: Result mismatch for place: True / False
# 350/500: Result mismatch for pick: True / False
# 351/500: Result match for pick: True / True
# 352/500: Result match for pick: True / True
# 353/500: Result match for pick: True / True
# 354/500: Result match for pick: True / True
# 355/500: Result match for pick: True / True
# 355/500: Result match for place: True / True
# 356/500: Result match for pick: True / True
# 356/500: Result match for place: False / False
# 357/500: Result match for pick: True / True
# 357/500: Result match for place: True / True
# 358/500: Result match for pick: True / True
# 359/500: Result match for pick: True / True
# 359/500: Result match for place: False / False
# 360/500: Result mismatch for pick: True / False
# 361/500: Result mismatch for pick: True / False
# 362/500: Result match for pick: True / True
# 363/500: Result match for pick: True / True
# 363/500: Result match for place: True / True
# 364/500: Result mismatch for pick: True / False
# 365/500: Result match for pick: True / True
# 365/500: Result match for place: True / True
# 366/500: Result mismatch for pick: True / False
# 367/500: Result match for pick: True / True
# 368/500: Result match for pick: True / True
# 369/500: Result match for pick: True / True
# 370/500: Result match for pick: True / True
# 370/500: Result match for place: False / False
# 371/500: Result mismatch for pick: True / False
# 372/500: Result match for pick: True / True
# 373/500: Result match for pick: True / True
# 374/500: Result match for pick: True / True
# 375/500: Result match for pick: True / True
# 376/500: Result match for pick: True / True
# 376/500: Result match for place: True / True
# 377/500: Result mismatch for pick: True / False
# 378/500: Result mismatch for pick: True / False
# 379/500: Result match for pick: True / True
# 380/500: Result match for pick: False / False
# 381/500: Result match for pick: True / True
# 381/500: Result mismatch for place: True / False
# 382/500: Result match for pick: True / True
# 382/500: Result match for place: True / True
# 383/500: Result match for pick: True / True
# 384/500: Result match for pick: True / True
# 385/500: Result match for pick: True / True
# 386/500: Result match for pick: True / True
# 387/500: Result match for pick: True / True
# 388/500: Result match for pick: True / True
# 388/500: Result match for place: True / True
# 389/500: Result match for pick: True / True
# 390/500: Result mismatch for pick: True / False
# 391/500: Result match for pick: True / True
# 392/500: Result mismatch for pick: True / False
# 393/500: Result match for pick: True / True
# 394/500: Result match for pick: True / True
# 395/500: Result match for pick: True / True
# 396/500: Result match for pick: True / True
# 397/500: Result match for pick: True / True
# 397/500: Result match for place: True / True
# 398/500: Result match for pick: True / True
# 398/500: Result match for place: True / True
# 399/500: Result match for pick: True / True
# 400/500: Result mismatch for pick: True / False
# 401/500: Result match for pick: True / True
# 401/500: Result mismatch for place: False / True
# 402/500: Result mismatch for pick: True / False
# 403/500: Result match for pick: True / True
# 403/500: Result match for place: True / True
# 404/500: Result match for pick: True / True
# 405/500: Result match for pick: True / True
# 406/500: Result match for pick: True / True
# 407/500: Result match for pick: True / True
# 408/500: Result match for pick: True / True
# 408/500: Result match for place: False / False
# 409/500: Result mismatch for pick: True / False
# 410/500: Result match for pick: True / True
# 411/500: Result match for pick: True / True
# 412/500: Result match for pick: True / True
# 412/500: Result match for place: True / True
# 413/500: Result match for pick: True / True
# 414/500: Result match for pick: True / True
# 414/500: Result match for place: False / False
# 415/500: Result mismatch for pick: True / False
# 416/500: Result mismatch for pick: True / False
# 417/500: Result match for pick: True / True
# 418/500: Result match for pick: True / True
# 418/500: Result match for place: True / True
# 419/500: Result match for pick: True / True
# 420/500: Result match for pick: True / True
# 421/500: Result match for pick: True / True
# 422/500: Result match for pick: True / True
# 422/500: Result match for place: True / True
# 423/500: Result mismatch for pick: True / False
# 424/500: Result match for pick: True / True
# 424/500: Result match for place: True / True
# 425/500: Result match for pick: True / True
# 426/500: Result match for pick: True / True
# 426/500: Result match for place: False / False
# 427/500: Result match for pick: True / True
# 428/500: Result mismatch for pick: False / True
# 429/500: Result match for pick: True / True
# 429/500: Result match for place: True / True
# 430/500: Result match for pick: True / True
# 431/500: Result match for pick: True / True
# 431/500: Result match for place: False / False
# 432/500: Result match for pick: True / True
# 433/500: Result mismatch for pick: True / False
# 434/500: Result match for pick: True / True
# 434/500: Result match for place: True / True
# 435/500: Result match for pick: True / True
# 436/500: Result match for pick: True / True
# 437/500: Result match for pick: True / True
# 437/500: Result match for place: False / False
# 438/500: Result match for pick: True / True
# 438/500: Result match for place: False / False
# 439/500: Result match for pick: True / True
# 440/500: Result match for pick: True / True
# 441/500: Result match for pick: True / True
# 442/500: Result match for pick: True / True
# 443/500: Result match for pick: True / True
# 443/500: Result match for place: False / False
# 444/500: Result match for pick: True / True
# 445/500: Result match for pick: True / True
# 445/500: Result match for place: True / True
# 446/500: Result match for pick: True / True
# 447/500: Result match for pick: True / True
# 447/500: Result match for place: True / True
# 448/500: Result match for pick: True / True
# 449/500: Result match for pick: True / True
# 449/500: Result mismatch for place: True / False
# 450/500: Result match for pick: True / True
# 451/500: Result match for pick: True / True
# 452/500: Result mismatch for pick: False / True
# 452/500: Result match for place: False / False
# 453/500: Result match for pick: True / True
# 453/500: Result match for place: True / True
# 454/500: Result mismatch for pick: True / False
# 455/500: Result match for pick: True / True
# 455/500: Result match for place: True / True
# 456/500: Result match for pick: True / True
# 456/500: Result match for place: False / False
# 457/500: Result match for pick: True / True
# 457/500: Result match for place: True / True
# 458/500: Result match for pick: True / True
# 459/500: Result match for pick: True / True
# 460/500: Result match for pick: True / True
# 460/500: Result match for place: True / True
# 461/500: Result match for pick: True / True
# 462/500: Result match for pick: True / True
# 463/500: Result match for pick: True / True
# 463/500: Result match for place: True / True
# 464/500: Result match for pick: True / True
# 465/500: Result match for pick: True / True
# 466/500: Result match for pick: True / True
# 467/500: Result match for pick: True / True
# 468/500: Result mismatch for pick: True / False
# 469/500: Result mismatch for pick: True / False
# 470/500: Result match for pick: True / True
# 471/500: Result match for pick: True / True
# 472/500: Result match for pick: True / True
# 473/500: Result match for pick: True / True
# 474/500: Result mismatch for pick: True / False
# 475/500: Result match for pick: True / True
# 476/500: Result match for pick: True / True
# 476/500: Result match for place: True / True
# 477/500: Result match for pick: True / True
# 478/500: Result match for pick: True / True
# 479/500: Result match for pick: True / True
# 480/500: Result mismatch for pick: True / False
# 481/500: Result match for pick: True / True
# 482/500: Result match for pick: True / True
# 483/500: Result match for pick: True / True
# 483/500: Result match for place: True / True
# 484/500: Result match for pick: True / True
# 484/500: Result match for place: True / True
# 485/500: Result match for pick: True / True
# 486/500: Result mismatch for pick: True / False
# 487/500: Result mismatch for pick: True / False
# 488/500: Result match for pick: True / True
# 488/500: Result match for place: True / True
# 489/500: Result match for pick: True / True
# 490/500: Result match for pick: True / True
# 491/500: Result match for pick: True / True
# 491/500: Result mismatch for place: True / False
# 492/500: Result match for pick: True / True
# 493/500: Result match for pick: True / True
# 494/500: Result match for pick: True / True
# 495/500: Result match for pick: True / True
# 496/500: Result match for pick: True / True
# 497/500: Result match for pick: True / True
# 498/500: Result match for pick: True / True
# 499/500: Result match for pick: True / True
# 499/500: Result match for place: True / True
# 500/500: Result match for pick: True / True
# 500/500: Result match for place: False / False

# %%
ACCURACY_CUT = 80
print("Accuracy cutline: {} %".format(ACCURACY_CUT))
for k, v in sorted(result_dict.items()):
    v_arr = np.array(v)
    suc_idx = np.where(v_arr[:, 1])[0]
    fail_idx = np.where(np.logical_not(v_arr[:, 1]))[0]
    acc_val = np.round(np.mean(v_arr[:,0]==v_arr[:,1])*100, 1)
    acc_suc = np.round(np.mean(v_arr[suc_idx,0]==v_arr[suc_idx,1])*100, 1)
    acc_fail = np.round(np.mean(v_arr[fail_idx,0]==v_arr[fail_idx,1])*100, 1)
    print("="*60)
    print("{} accuracy: {} % / success accuracy: {} % / fail accuracy: {} % / success count:{}/{}".format(k, acc_val, acc_suc, acc_fail, len(suc_idx), len(v_arr)))
    assert acc_val>ACCURACY_CUT and acc_suc>ACCURACY_CUT, \
            "Accuracy {}/{} is lower than {}. Consider debugging the algorithm.".format(acc_val, acc_suc, ACCURACY_CUT)
    print("""OK with "{}" scenario""".format(k))
# Out:
# Accuracy cutline: 80 %
# ============================================================
# pick accuracy: 83.8 % / success accuracy: 98.1 % / fail accuracy: 16.1 % / success count:413/500
# OK with "pick" scenario
# ============================================================
# place accuracy: 83.5 % / success accuracy: 90.6 % / fail accuracy: 72.2 % / success count:85/139
# OK with "place" scenario

# %% [markdown]
# ### planning: pick&place

# %% [markdown]
#   - singleprocess

# %%
from pkg.planning.constraint.constraint_common import calc_redundancy
from copy import deepcopy

pscene.clear_subjects()
    
Nmax_obj = 1
gtimer = GlobalTimer.instance()
gtimer.reset()
## add floor, ceiling
floor = Floor(gscene, "floor")
gscene.create_safe(gtype=GEOTYPE.BOX, name="base", link_name="base_link", 
                   dims=(0.2, 0.2, -floor.RTH[2]), center=(0,0,floor.RTH[2]/2), rpy=(0,0,0), 
                   color=floor.geometry.color, display=True, collision=True, fixed=True)
# ceiling = Ceiling(gscene, "ceiling")

## set workplane
wp = WorkPlane(gscene, "wp", floor_height=floor.RTH[2]+floor.DIM[2]/2)
pscene.create_binder(bname="wp", gname="wp", _type=PlacePlane, point=None)

gp_colliding = True
while gp_colliding:
    ## set goalplane
    gp = WorkPlane(gscene, "gp", floor_height=wp.RTH[2]+wp.RTH[2]/2)
    gp_colliding = wp.is_overlapped_with(gp.geometry)
pscene.create_binder(bname="gp", gname="gp", _type=PlacePlane, point=None)


## add object
obj_list = disperse_objects(gscene, PlaneObject, "obj", Nmax_obj, workplane_on=wp, GRIP_DEPTH=GRIP_DEPTH)

obj_set_list = []
for i_obj, obj in enumerate(obj_list):
    obj_pscene, handles = add_object(pscene, obj)
    obj_set_list.append((obj, obj_pscene, handles))
obj, obj_pscene, handles = obj_set_list[0]

obj_pscene.geometry.color = (0.8,0.2,0.2,1)
if VISUALIZE:
    gscene.set_rviz()

mplan.update_gscene()
initial_state = pscene.initialize_state(HOME_POSE)
pscene.set_object_state(initial_state)
from_state = initial_state.copy(pscene)

ppline.set_motion_planner(mplan)
ppline.set_task_planner(tplan)

gtimer = GlobalTimer.instance()
gtimer.reset()

mplan.motion_filters = checkers_all
goal_nodes = [("gp",)+deepcopy(from_state.node)[1:]]
mplan.reset_log(True)
gtimer.tic("plan")
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, 
              timeout_loop=10, multiprocess=False, timeout=1, add_homing=False)
elapsed = gtimer.toc("plan")/1000
schedule = tplan.get_best_schedule(at_home=False)
res = len(schedule)>0
if res:
    ppline.play_schedule(schedule)
else:
    raise(RuntimeError("Failed to make plan - may be impossible problem was generated. try again up to 10 times or debug"))
# Out:
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->1 (0.16/10.0 s, steps/err: 48(112.323999405 ms)/0.00126111726896)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# error: 2.6
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = success
# branching: 1->2 (0.29/10.0 s, steps/err: 86(121.584177017 ms)/0.00157738955879)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# error: 3.1
# try transition motion
# transition motion tried: True
# Goal reached
# result: 1 - ('grip0',)->('gp',) = success
# branching: 1->3 (0.39/10.0 s, steps/err: 42(105.686903 ms)/0.00147393642866)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 2 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 2 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# error: 0.16
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = success
# branching: 1->4 (0.5/10.0 s, steps/err: 6(84.370136261 ms)/0.00159979571204)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# error: 3.1
# try transition motion
# transition motion tried: True
# Goal reached
# result: 1 - ('grip0',)->('gp',) = success
# branching: 1->5 (0.64/10.0 s, steps/err: 35(113.22593689 ms)/0.00192368899256)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 2 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 2 - ('wp',)->('grip0',) = success
# branching: 2->6 (0.76/10.0 s, steps/err: 60(118.122816086 ms)/0.00120683197075)
# ======================================================================================================================================================
# try: 6 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 6 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 2 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 2 - ('wp',)->('grip0',) = fail
# try: 2 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 2 - ('wp',)->('grip0',) = fail
# try: 6 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 6 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 2 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 2 - ('wp',)->('grip0',) = fail
# try: 6 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->7 (1.05/10.0 s, steps/err: 55(156.657934189 ms)/0.00109266161065)
# ======================================================================================================================================================
# try: 7 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 7 - ('grip0',)->('gp',) = fail
# try: 7 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 7 - ('grip0',)->('wp',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.7
# try transition motion
# transition motion tried: True
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->8 (1.18/10.0 s, steps/err: 49(107.007026672 ms)/0.00123599787826)
# ======================================================================================================================================================
# try: 8 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 4 - ('wp',)->('grip0',) = fail
# try: 6 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('gp',) = fail
# try: 2 - ('wp',)->('grip0',)
# error: 0.049
# try transition motion
# transition motion tried: True
# result: 2 - ('wp',)->('grip0',) = success
# branching: 2->9 (1.32/10.0 s, steps/err: 8(120.532035828 ms)/0.00173151103695)
# ======================================================================================================================================================
# try: 9 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 9 - ('grip0',)->('gp',) = fail
# try: 6 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 0 - ('wp',)->('grip0',) = success
# branching: 0->10 (1.5/10.0 s, steps/err: 74(169.437170029 ms)/0.00156960820875)
# ======================================================================================================================================================
# try: 10 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('wp',)
# error: 0.5
# try transition motion
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = success
# branching: 1->11 (1.6/10.0 s, steps/err: 13(90.8658504486 ms)/0.00135391722745)
# ======================================================================================================================================================
# try: 10 - ('grip0',)->('gp',)
# error: 2.8
# try transition motion
# transition motion tried: True
# Goal reached
# result: 10 - ('grip0',)->('gp',) = success
# branching: 10->12 (1.74/10.0 s, steps/err: 62(133.194208145 ms)/0.00137285805327)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# try: 11 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 11 - ('wp',)->('grip0',) = success
# branching: 11->13 (1.89/10.0 s, steps/err: 65(142.00091362 ms)/0.00135902467062)
# ======================================================================================================================================================
# try: 13 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 13 - ('grip0',)->('gp',) = fail
# try: 7 - ('grip0',)->('wp',)
# error: 2.4
# try transition motion
# transition motion tried: True
# result: 7 - ('grip0',)->('wp',) = success
# branching: 7->14 (2.01/10.0 s, steps/err: 78(117.479801178 ms)/0.00168182300347)
# ======================================================================================================================================================
# try: 11 - ('wp',)->('grip0',)
# error: 0.27
# try transition motion
# transition motion tried: True
# result: 11 - ('wp',)->('grip0',) = success
# branching: 11->15 (2.13/10.0 s, steps/err: 5(118.844032288 ms)/0.000326335510843)
# ======================================================================================================================================================
# try: 15 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('grip0',)->('gp',) = fail
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 4 - ('wp',)->('grip0',) = fail
# try: 10 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 13 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 13 - ('grip0',)->('wp',) = fail
# try: 8 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('gp',) = fail
# try: 15 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('grip0',)->('gp',) = fail
# try: 7 - ('grip0',)->('gp',)
# error: 2.9
# try transition motion
# transition motion tried: True
# Goal reached
# result: 7 - ('grip0',)->('gp',) = success
# branching: 7->16 (2.29/10.0 s, steps/err: 79(128.664016724 ms)/0.000787566570112)
# ======================================================================================================================================================
# try: 15 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('grip0',)->('gp',) = fail
# try: 7 - ('grip0',)->('gp',)
# error: 2.9
# try transition motion
# transition motion tried: True
# Goal reached
# result: 7 - ('grip0',)->('gp',) = success
# branching: 7->17 (2.43/10.0 s, steps/err: 82(127.752065659 ms)/0.00102357373486)
# ======================================================================================================================================================
# try: 9 - ('grip0',)->('wp',)
# error: 0.096
# try transition motion
# transition motion tried: True
# result: 9 - ('grip0',)->('wp',) = success
# branching: 9->18 (2.53/10.0 s, steps/err: 22(105.239868164 ms)/0.00185408849141)
# ======================================================================================================================================================
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 4 - ('wp',)->('grip0',)
# error: 0.86
# try transition motion
# transition motion tried: True
# result: 4 - ('wp',)->('grip0',) = success
# branching: 4->19 (2.65/10.0 s, steps/err: 31(104.635953903 ms)/0.00137767829217)
# ======================================================================================================================================================
# try: 19 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('gp',) = fail
# try: 14 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 14 - ('wp',)->('grip0',) = fail
# try: 13 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 13 - ('grip0',)->('gp',) = fail
# try: 9 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 9 - ('grip0',)->('gp',) = fail
# try: 11 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 11 - ('wp',)->('grip0',) = fail
# try: 7 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 7 - ('grip0',)->('gp',) = fail
# try: 9 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 9 - ('grip0',)->('wp',) = fail
# try: 8 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('gp',) = fail
# try: 8 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('wp',) = fail
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 2 - ('wp',)->('grip0',)
# error: 2.8
# try transition motion
# transition motion tried: True
# result: 2 - ('wp',)->('grip0',) = success
# branching: 2->20 (2.82/10.0 s, steps/err: 62(120.51987648 ms)/0.00213558537177)
# ======================================================================================================================================================
# try: 20 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 20 - ('grip0',)->('gp',) = fail
# try: 14 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 14 - ('wp',)->('grip0',) = fail
# try: 19 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('gp',) = fail
# try: 11 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 11 - ('wp',)->('grip0',) = fail
# try: 9 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 9 - ('grip0',)->('gp',) = fail
# try: 8 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('gp',) = fail
# try: 15 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('grip0',)->('gp',) = fail
# try: 19 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 19 - ('grip0',)->('gp',) = fail
# try: 20 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 20 - ('grip0',)->('gp',) = fail
# try: 18 - ('wp',)->('grip0',)
# error: 0.99
# try transition motion
# transition motion tried: True
# result: 18 - ('wp',)->('grip0',) = success
# branching: 18->21 (3.02/10.0 s, steps/err: 20(133.185148239 ms)/0.00175109221823)
# ======================================================================================================================================================
# try: 21 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 21 - ('grip0',)->('gp',) = fail
# try: 15 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 15 - ('grip0',)->('wp',) = fail
# try: 9 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 9 - ('grip0',)->('wp',) = fail
# try: 7 - ('grip0',)->('gp',)
# error: 2.9
# try transition motion
# transition motion tried: True
# Goal reached
# result: 7 - ('grip0',)->('gp',) = success
# branching: 7->22 (3.23/10.0 s, steps/err: 78(195.08099556 ms)/0.00230059670904)
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 0: required answers acquired  (3.2/10.0) ===============================
# =========================================================================================================
# ========================== FINISHED (3.2 / 10.0 s) ==============================]
# ('wp',)->('grip0',)
# ('grip0',)->('gp',)

# %% [markdown]
#   - multiprocess
#     - multiprocess lock setting is needed to securely communicate with python3 through shared memory

# %%
lcheck.prepare_multiprocess_lock(ppline.manager)

# %%
mplan.motion_filters = checkers_all
goal_nodes = [("gp",)+deepcopy(from_state.node)[1:]]
mplan.reset_log(True)
gtimer.tic("plan")
ppline.search(initial_state, goal_nodes, verbose=True, display=False, dt_vis=0.01, 
              timeout_loop=10, multiprocess=True, timeout=1, add_homing=False)
elapsed = gtimer.toc("plan")/1000
schedule = tplan.get_best_schedule(at_home=False)
res = len(schedule)>0
if res:
    ppline.play_schedule(schedule)
else:
    raise(RuntimeError("Failed to make plan - may be impossible problem was generated. try again up to 10 times or debug"))
# Out:
# Use 18/36 agents
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.9
# try transition motion
# error: 2.7
# try transition motion
# try: 0 - ('wp',)->('grip0',)
# transition motion tried: True
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = success
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# branching: 0->1 (0.25/10.0 s, steps/err: 37(111.502885818 ms)/0.0016122503223)
# ======================================================================================================================================================
# try: 0 - ('wp',)->('grip0',)
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try: 1 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('gp',) = fail
# result: 0 - ('wp',)->('grip0',) = success
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# branching: 0->2 (0.3/10.0 s, steps/err: 61(204.122066498 ms)/0.00203716974372)
# try: 2 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# Motion Filer Failure: GraspChecker
# error: 2.7
# try: 1 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = fail
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# error: 1.0
# try: 1 - ('grip0',)->('gp',)
# try transition motion
# try: 2 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# error: 2.0
# try transition motion
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('wp',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = fail
# error: 2.4
# try: 0 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('wp',) = fail
# result: 0 - ('wp',)->('grip0',) = fail
# try: 2 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('wp',)
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('wp',)
# try: 0 - ('wp',)->('grip0',)
# result: 2 - ('grip0',)->('wp',) = fail
# error: 1.7
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('wp',) = fail
# try transition motion
# result: 0 - ('wp',)->('grip0',) = fail
# result: 2 - ('grip0',)->('gp',) = fail
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('wp',)
# Motion Filer Failure: GraspChecker
# try: 0 - ('wp',)->('grip0',)
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# result: 0 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('wp',) = fail
# try: 0 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('wp',) = fail
# error: 2.7
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('wp',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('gp',)
# try transition motion
# result: 0 - ('wp',)->('grip0',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# try: 1 - ('grip0',)->('gp',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 0 - ('wp',)->('grip0',) = fail
# result: 2 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# Motion Filer Failure: GraspChecker
# error: 1.6
# result: 1 - ('grip0',)->('gp',) = fail
# try: 2 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('gp',)
# result: 0 - ('wp',)->('grip0',) = fail
# try transition motion
# try: 1 - ('grip0',)->('wp',)
# result: 2 - ('grip0',)->('wp',) = success
# result: 1 - ('grip0',)->('wp',) = success
# try: 2 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# transition motion tried: True
# branching: 2->4 (0.71/10.0 s, steps/err: 82(364.52794075 ms)/0.00145062635658)
# Motion Filer Failure: GraspChecker
# branching: 1->3 (0.71/10.0 s, steps/err: 47(383.982896805 ms)/0.00193040188798)
# result: 2 - ('grip0',)->('gp',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: GraspChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# try: 1 - ('grip0',)->('wp',)
# Goal reached
# ======================================================================================================================================================
# result: 0 - ('wp',)->('grip0',) = fail
# result: 2 - ('grip0',)->('wp',) = fail
# result: 1 - ('grip0',)->('wp',) = success
# try: 4 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = success
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('gp',)
# branching: 1->5 (0.74/10.0 s, steps/err: 76(428.269147873 ms)/0.00179124649204)
# result: 0 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('gp',)
# error: 2.8
# result: 2 - ('grip0',)->('wp',) = success
# branching: 1->6 (0.74/10.0 s, steps/err: 41(307.070970535 ms)/0.00187066808276)
# try: 2 - ('grip0',)->('wp',)
# branching: 2->7 (0.74/10.0 s, steps/err: 56(250.463008881 ms)/0.00182308659614)
# try: 1 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# result: 2 - ('grip0',)->('wp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# try: 1 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# try: 0 - ('wp',)->('grip0',)
# try: 7 - ('wp',)->('grip0',)
# try: 2 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# try: 6 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# try: 6 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: GraspChecker
# result: 1 - ('grip0',)->('gp',) = fail
# try: 3 - ('wp',)->('grip0',)
# result: 6 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: GraspChecker
# result: 0 - ('wp',)->('grip0',) = success
# result: 0 - ('wp',)->('grip0',) = fail
# error: 2.8
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: GraspChecker
# try: 8 - ('grip0',)->('gp',)
# result: 0 - ('wp',)->('grip0',) = fail
# branching: 0->8 (0.78/10.0 s, steps/err: 41(196.135044098 ms)/0.0014498108135)
# try transition motion
# result: 2 - ('grip0',)->('gp',) = fail
# try: 8 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 6 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 3 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# result: 2 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# result: 8 - ('grip0',)->('gp',) = fail
# result: 7 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try: 0 - ('wp',)->('grip0',)
# result: 8 - ('grip0',)->('gp',) = fail
# try: 4 - ('wp',)->('grip0',)
# branching: 2->9 (0.81/10.0 s, steps/err: 49(178.736925125 ms)/0.00192542484817)
# try: 6 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: GraspChecker
# try: 1 - ('grip0',)->('gp',)
# try: 4 - ('wp',)->('grip0',)
# error: 2.9
# try: 8 - ('grip0',)->('gp',)
# try: 6 - ('wp',)->('grip0',)
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# try transition motion
# try: 1 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 4 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# try: 4 - ('wp',)->('grip0',)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('gp',)
# result: 6 - ('wp',)->('grip0',) = fail
# try: 2 - ('grip0',)->('gp',)
# result: 6 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# result: 8 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# error: 0.89
# Motion Filer Failure: ReachChecker
# try: 3 - ('wp',)->('grip0',)
# try: 3 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 3 - ('wp',)->('grip0',)
# try: 1 - ('grip0',)->('gp',)
# result: 4 - ('wp',)->('grip0',) = fail
# try: 3 - ('wp',)->('grip0',)
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# try transition motion
# try: 1 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 8 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('gp',)
# result: 3 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# result: 3 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# try: 9 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# try: 1 - ('grip0',)->('gp',)
# try: 8 - ('grip0',)->('gp',)
# result: 3 - ('wp',)->('grip0',) = fail
# result: 3 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('wp',) = fail
# try: 8 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# try: 8 - ('grip0',)->('gp',)
# try: 9 - ('wp',)->('grip0',)
# try: 7 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: GraspChecker
# result: 9 - ('wp',)->('grip0',) = fail
# try: 8 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('gp',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# transition motion tried: True
# result: 2 - ('grip0',)->('gp',) = fail
# result: 9 - ('wp',)->('grip0',) = fail
# result: 8 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 7 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try: 8 - ('grip0',)->('gp',)
# try: 8 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = success
# result: 1 - ('grip0',)->('wp',) = success
# result: 8 - ('grip0',)->('gp',) = fail
# branching: 0->10 (0.92/10.0 s, steps/err: 54(243.870973587 ms)/0.000623756528324)
# error: 2.8
# transition motion tried: True
# try transition motion
# try: 8 - ('grip0',)->('wp',)
# branching: 1->11 (0.92/10.0 s, steps/err: 31(204.733848572 ms)/0.00152972108071)
# try: 10 - ('grip0',)->('gp',)
# ======================================================================================================================================================
# try: 1 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = success
# try: 6 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# error: 2.9
# try: 0 - ('wp',)->('grip0',)
# branching: 0->12 (0.93/10.0 s, steps/err: 42(291.057825089 ms)/0.00125691747148)
# Motion Filer Failure: GraspChecker
# result: 1 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('gp',) = fail
# try: 11 - ('wp',)->('grip0',)
# try: 12 - ('grip0',)->('gp',)
# result: 6 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# Motion Filer Failure: GraspChecker
# try: 3 - ('wp',)->('grip0',)
# try transition motion
# try: 8 - ('grip0',)->('wp',)
# result: 0 - ('wp',)->('grip0',) = fail
# try: 7 - ('wp',)->('grip0',)
# result: 11 - ('wp',)->('grip0',) = fail
# try: 1 - ('grip0',)->('gp',)
# try: 8 - ('grip0',)->('gp',)
# error: 2.5
# Motion Filer Failure: ReachChecker
# try: 4 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 3 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: GraspChecker
# result: 7 - ('wp',)->('grip0',) = fail
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# error: 2.8
# result: 4 - ('wp',)->('grip0',) = fail
# result: 8 - ('grip0',)->('gp',) = fail
# result: 8 - ('grip0',)->('wp',) = fail
# try transition motion
# try: 8 - ('grip0',)->('gp',)
# try: 8 - ('grip0',)->('wp',)
# result: 12 - ('grip0',)->('gp',) = fail
# try: 12 - ('grip0',)->('gp',)
# try: 1 - ('grip0',)->('gp',)
# try: 2 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# try: 2 - ('grip0',)->('gp',)
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('gp',) = fail
# try: 12 - ('grip0',)->('wp',)
# result: 8 - ('grip0',)->('gp',) = fail
# try: 8 - ('grip0',)->('gp',)
# result: 2 - ('grip0',)->('wp',) = fail
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# error: 3.1
# result: 12 - ('grip0',)->('gp',) = fail
# try: 10 - ('grip0',)->('wp',)
# try transition motion
# Motion Filer Failure: ReachChecker
# error: 3.0
# result: 1 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('wp',) = fail
# try: 11 - ('wp',)->('grip0',)
# try: 12 - ('grip0',)->('wp',)
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: GraspChecker
# result: 11 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('gp',) = fail
# try: 10 - ('grip0',)->('wp',)
# try: 2 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# try transition motion
# Motion Filer Failure: ReachChecker
# error: 2.4
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('wp',) = fail
# try: 6 - ('wp',)->('grip0',)
# result: 12 - ('grip0',)->('wp',) = fail
# try: 12 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('gp',) = fail
# result: 6 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# error: 3.1
# try transition motion
# try: 10 - ('grip0',)->('wp',)
# result: 12 - ('grip0',)->('gp',) = fail
# Motion Filer Failure: ReachChecker
# result: 12 - ('grip0',)->('gp',) = fail
# try: 3 - ('wp',)->('grip0',)
# try: 4 - ('wp',)->('grip0',)
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# try: 10 - ('grip0',)->('gp',)
# result: 3 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# result: 10 - ('grip0',)->('wp',) = fail
# error: 0.81
# Motion Filer Failure: ReachChecker
# Motion Filer Failure: ReachChecker
# Goal reached
# try: 0 - ('wp',)->('grip0',)
# try transition motion
# try: 6 - ('wp',)->('grip0',)
# result: 4 - ('wp',)->('grip0',) = success
# result: 10 - ('grip0',)->('gp',) = fail
# result: 4 - ('wp',)->('grip0',) = fail
# transition motion tried: True
# try: 14 - ('grip0',)->('gp',)
# result: 8 - ('grip0',)->('gp',) = success
# Motion Filer Failure: ReachChecker
# branching: 4->14 (1.09/10.0 s, steps/err: 96(344.721078873 ms)/0.0016427943572)
# error: 2.8
# try transition motion
# Motion Filer Failure: ReachChecker
# result: 6 - ('wp',)->('grip0',) = fail
# ======================================================================================================================================================
# try: 4 - ('wp',)->('grip0',)
# try: 14 - ('grip0',)->('gp',)
# Motion Filer Failure: GraspChecker
# Goal reached
# branching: 8->13 (1.09/10.0 s, steps/err: 53(211.157083511 ms)/0.00173813860796)
# transition motion tried: True
# result: 14 - ('grip0',)->('gp',) = fail
# result: 8 - ('grip0',)->('gp',) = success
# result: 1 - ('grip0',)->('wp',) = success
# transition motion tried: True
# try: 2 - ('grip0',)->('wp',)
# result: 4 - ('wp',)->('grip0',) = fail
# branching: 8->15 (1.11/10.0 s, steps/err: 29(216.778993607 ms)/0.00182206526092)
# branching: 1->16 (1.11/10.0 s, steps/err: 55(335.545063019 ms)/0.00176061267535)
# try: 0 - ('wp',)->('grip0',)
# transition motion tried: True
# result: 2 - ('grip0',)->('wp',) = success
# Motion Filer Failure: ReachChecker
# error: 2.8
# branching: 2->17 (1.12/10.0 s, steps/err: 93(460.451126099 ms)/0.00175551414655)
# ======================================================================================================================================================
# try: 3 - ('wp',)->('grip0',)
# ======================================================================================================================================================
# Goal reached
# try: 8 - ('grip0',)->('wp',)
# ======================================================================================================================================================
# try transition motion
# result: 0 - ('wp',)->('grip0',) = fail
# Motion Filer Failure: ReachChecker
# error: 0.67
# try: 2 - ('grip0',)->('wp',)
# result: 2 - ('grip0',)->('gp',) = success
# ======================================================================================================================================================
# branching: 2->18 (1.14/10.0 s, steps/err: 93(356.48393631 ms)/0.000608440207223)
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('wp',) = fail
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 8 - ('grip0',)->('gp',)
# transition motion tried: True
# try: 10 - ('grip0',)->('wp',)
# try: 3 - ('wp',)->('grip0',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('wp',) = fail
# try: 1 - ('grip0',)->('wp',)
# Goal reached
# result: 2 - ('grip0',)->('wp',) = fail
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# try: 8 - ('grip0',)->('gp',)
# result: 8 - ('grip0',)->('gp',) = success
# try: 10 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('gp',) = fail
# error: 2.5
# Motion Filer Failure: ReachChecker
# ======================================================================================================================================================
# try transition motion
# result: 8 - ('grip0',)->('gp',) = fail
# branching: 8->19 (1.17/10.0 s, steps/err: 94(242.41399765 ms)/0.00192493271928)
# result: 3 - ('wp',)->('grip0',) = fail
# result: 10 - ('grip0',)->('wp',) = fail
# try: 2 - ('grip0',)->('wp',)
# Motion Filer Failure: ReachChecker
# result: 10 - ('grip0',)->('gp',) = fail
# ======================================================================================================================================================
# try: 2 - ('grip0',)->('wp',)
# try: 1 - ('grip0',)->('wp',)
# transition motion tried: True
# try: 9 - ('wp',)->('grip0',)
# error: 3.0
# result: 4 - ('wp',)->('grip0',) = success
# try transition motion
# Motion Filer Failure: ReachChecker
# try: 14 - ('grip0',)->('wp',)
# branching: 4->20 (1.19/10.0 s, steps/err: 74(373.272895813 ms)/0.000908966363803)
# Goal reached
# Motion Filer Failure: ReachChecker
# transition motion tried: True
# Motion Filer Failure: ReachChecker
# result: 2 - ('grip0',)->('wp',) = fail
# result: 8 - ('grip0',)->('gp',) = success
# Motion Filer Failure: ReachChecker
# try: 8 - ('grip0',)->('gp',)
# result: 1 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# try: 14 - ('grip0',)->('gp',)
# transition motion tried: True
# branching: 8->21 (1.21/10.0 s, steps/err: 101(303.421974182 ms)/0.00131235870774)
# result: 2 - ('grip0',)->('wp',) = fail
# ======================================================================================================================================================
# result: 14 - ('grip0',)->('wp',) = fail
# try: 14 - ('grip0',)->('gp',)
# Motion Filer Failure: ReachChecker
# =========================================================================================================
# =========================================================================================================
# try: 20 - ('grip0',)->('gp',)
# try: 4 - ('wp',)->('grip0',)
# ======================= terminated 4: required answers acquired  (1.2/10.0) ===============================
# transition motion tried: True
# result: 1 - ('grip0',)->('wp',) = fail
# error: 2.1
# Motion Filer Failure: ReachChecker
# try: 12 - ('grip0',)->('wp',)
# ======================= terminated 17: Stop called from other agent  (1.2/10.0) ===============================
# =========================================================================================================
# try transition motion
# Motion Filer Failure: GraspChecker
# result: 8 - ('grip0',)->('wp',) = success
# =========================================================================================================
# Motion Filer Failure: ReachChecker
# result: 8 - ('grip0',)->('wp',) = success
# =========================================================================================================
# branching: 8->22 (1.23/10.0 s, steps/err: 31(309.318065643 ms)/0.00204602873828)
# result: 4 - ('wp',)->('grip0',) = fail
# result: 14 - ('grip0',)->('gp',) = fail
# result: 20 - ('grip0',)->('gp',) = fail
# ======================= terminated 0: Stop called from other agent  (1.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# error: 1.7
# ======================================================================================================================================================
# result: 14 - ('grip0',)->('gp',) = fail
# =========================================================================================================
# ======================= terminated 12: Stop called from other agent  (1.2/10.0) ===============================
# ======================= terminated 11: Stop called from other agent  (1.2/10.0) ===============================
# ======================= terminated 5: Stop called from other agent  (1.2/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# try transition motion
# result: 12 - ('grip0',)->('wp',) = success
# branching: 8->24 (1.25/10.0 s, steps/err: 57(307.217121124 ms)/0.00206285062808)
# =========================================================================================================
# =========================================================================================================
# branching: 12->23 (1.26/10.0 s, steps/err: 14(222.084999084 ms)/0.00162313068704)
# =========================================================================================================
# ======================================================================================================================================================
# =========================================================================================================
# ======================================================================================================================================================
# transition motion tried: True
# =========================================================================================================
# ======================= terminated 16: Stop called from other agent  (1.3/10.0) ===============================
# ======================= terminated 10: Stop called from other agent  (1.3/10.0) ===============================
# ======================= terminated 7: Stop called from other agent  (1.3/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# error: 2.8
# Goal reached
# =========================================================================================================
# =========================================================================================================
# ======================= terminated 6: Stop called from other agent  (1.3/10.0) ===============================
# result: 2 - ('grip0',)->('gp',) = success
# =========================================================================================================
# branching: 2->25 (1.29/10.0 s, steps/err: 75(279.765844345 ms)/0.0018288962418)
# try transition motion
# ======================================================================================================================================================
# error: 3.0
# transition motion tried: True
# =========================================================================================================
# try transition motion
# ======================= terminated 9: required answers acquired  (1.3/10.0) ===============================
# =========================================================================================================
# Goal reached
# result: 8 - ('grip0',)->('gp',) = success
# branching: 8->26 (1.32/10.0 s, steps/err: 76(303.758144379 ms)/0.00175002751973)
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 14: required answers acquired  (1.3/10.0) ===============================
# =========================================================================================================
# error: 2.3
# try transition motion
# transition motion tried: True
# transition motion tried: True
# Goal reached
# result: 14 - ('grip0',)->('gp',) = success
# branching: 14->27 (1.36/10.0 s, steps/err: 35(257.802009583 ms)/0.00140398015304)
# transition motion tried: True
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 2: required answers acquired  (1.4/10.0) ===============================
# =========================================================================================================
# Goal reached
# result: 8 - ('grip0',)->('gp',) = success
# result: 0 - ('wp',)->('grip0',) = success
# branching: 8->28 (1.37/10.0 s, steps/err: 51(162.097930908 ms)/0.00181881855918)
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 3: required answers acquired  (1.4/10.0) ===============================
# =========================================================================================================
# branching: 0->29 (1.37/10.0 s, steps/err: 87(283.806800842 ms)/0.00179220820368)
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 13: Stop called from other agent  (1.4/10.0) ===============================
# =========================================================================================================
# transition motion tried: True
# transition motion tried: True
# result: 12 - ('grip0',)->('wp',) = success
# result: 9 - ('wp',)->('grip0',) = success
# branching: 12->30 (1.39/10.0 s, steps/err: 35(161.351203918 ms)/0.000913665050295)
# branching: 9->31 (1.39/10.0 s, steps/err: 41(204.293966293 ms)/0.00139950505016)
# ======================================================================================================================================================
# =========================================================================================================
# ======================================================================================================================================================
# =========================================================================================================
# ======================= terminated 15: Stop called from other agent  (1.4/10.0) ===============================
# ======================= terminated 1: Stop called from other agent  (1.4/10.0) ===============================
# =========================================================================================================
# =========================================================================================================
# [ERROR] Non-joined subprocesses: [8]
# ========================== FINISHED (2.4 / 10.0 s) ==============================]
# ('wp',)->('grip0',)
# ('grip0',)->('gp',)
